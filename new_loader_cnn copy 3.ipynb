# %%
from glob import glob
import pandas as pd
import os
import numpy as np
import tensorflow as tf
import keras

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from glob import glob
import os

class TCRDataLoader:
    def __init__(self, data_dir):
        self.data_dir = data_dir
        self.aa_dict = None
        self.v_dict = None
        self.j_dict = None
        self.label_map = None
        self.max_length = None
        
    def combine_columns(self, df, column_variants, new_column_name):
        """Combine multiple columns that represent the same data type"""
        combined_series = pd.Series([None] * len(df), index=df.index)
        
        for variant in column_variants:
            if variant in df.columns:
                # Fill in non-null values from this column
                mask = df[variant].notna() & combined_series.isna()
                combined_series[mask] = df[variant][mask]
                print(f"  Added {mask.sum()} values from '{variant}' column")
        
        return combined_series
    
    def load_files(self):
        df_list = []
        files = glob(self.data_dir + "/*/*.tsv")
        
        for file_path in files:
            df = pd.read_csv(file_path, sep='\t')
            
            # Extract folder name from file path
            folder_name = os.path.basename(os.path.dirname(file_path))
            
            # Split folder name to get Antigen
            parts = folder_name.split('-')
            antigen = parts[-1]  # Get last part (the antigen)
            
            # Add antigen column to dataframe
            df['Antigen'] = antigen
            
            df_list.append(df)
        
        combined_df = pd.concat(df_list, ignore_index=True)
        
        # Define column candidates for each data type
        column_variants = {
            'sequence': ['aminoAcid', 'beta', 'Amino', 'sequence', 'cdr3', 'CDR3'],
            'v_gene': ['v_beta', 'vGeneName', 'v_gene', 'V_gene', 'TRBV'],
            'j_gene': ['j_beta', 'jGeneName', 'j_gene', 'J_gene', 'TRBJ'],
            'counts': ['counts', 'count', 'count (templates/reads)', 'templates', 'reads', 'frequency']
        }
        
        print("Combining columns:")
        # Combine columns for each data type
        for standard_name, variants in column_variants.items():
            print(f"\nCombining {standard_name} columns:")
            combined_series = self.combine_columns(combined_df, variants, standard_name)
            combined_df[f'combined_{standard_name}'] = combined_series
            
            # Show statistics
            total_values = combined_series.notna().sum()
            print(f"  Total combined values: {total_values}")
        
        return combined_df
    
    def build_vocabulary(self, df):
        # Use combined columns
        # Amino acids
        all_sequences = df['combined_sequence'].dropna()
        if len(all_sequences) == 0:
            raise ValueError("No sequence data found in combined columns!")
            
        giant_string = ''.join(all_sequences)
        unique_letters = sorted(set(giant_string))
        self.aa_dict = {}
        for i, letter in enumerate(unique_letters):
            self.aa_dict[letter] = i+1
        
        # V genes
        v_genes = df['combined_v_gene'].dropna().unique()
        v_genes = sorted(v_genes)
        self.v_dict = {}
        for i, gene in enumerate(v_genes):
            self.v_dict[gene] = i + 1

        # J genes
        j_genes = df['combined_j_gene'].dropna().unique()
        j_genes = sorted(j_genes)
        self.j_dict = {}
        for i, gene in enumerate(j_genes):
            self.j_dict[gene] = i + 1

        # Labels
        antigens = df['Antigen'].unique()
        self.label_map = {}
        for i, antigen in enumerate(sorted(antigens)):
            self.label_map[antigen] = i

        # Max length
        sequence_lengths = [len(seq) for seq in df['combined_sequence'].dropna()]
        self.max_length = max(sequence_lengths) if sequence_lengths else 0
        
        print(f"\nVocabulary built:")
        print(f"  Amino acids: {len(self.aa_dict)} unique")
        print(f"  V genes: {len(self.v_dict)} unique")
        print(f"  J genes: {len(self.j_dict)} unique")
        print(f"  Max sequence length: {self.max_length}")
    
    def encode_sequences(self, sequences):
        encoded_aa = []
        for sequence in sequences:
            sequence_numbers = []
            for letter in sequence:
                number = self.aa_dict.get(letter, 0)
                sequence_numbers.append(number)
            # Add padding zeros if sequence is shorter than max_length
            while len(sequence_numbers) < self.max_length:
                sequence_numbers.append(0)
            encoded_aa.append(sequence_numbers)
        return encoded_aa
    
    def encode_v_genes(self, v_genes):
        encoded_v = []
        for v_gene in v_genes:
            encoded_v.append(self.v_dict.get(v_gene, 0))
        return encoded_v
    
    def encode_j_genes(self, j_genes):
        encoded_j = []
        for j_gene in j_genes:
            encoded_j.append(self.j_dict.get(j_gene, 0))
        return encoded_j
    
    def load_and_encode_data(self, batch_size=100, shuffle=True):
        # 1. Load files and combine columns
        df = self.load_files()
        
        # 2. Build vocabularies
        self.build_vocabulary(df)
        
        # 3. Filter out rows with missing amino acid sequences
        valid_rows = df['combined_sequence'].notna()
        df_valid = df[valid_rows].copy()
        
        print(f"Valid data: {len(df_valid)} out of {len(df)} total rows")
        
        # 4. Get the data you want to encode (now all valid)
        sequences = df_valid['combined_sequence'].values
        v_genes = df_valid['combined_v_gene'].fillna('UNK').values
        j_genes = df_valid['combined_j_gene'].fillna('UNK').values
        labels = [self.label_map[antigen] for antigen in df_valid['Antigen']]
        
        # 5. Encode everything
        X_sequences = self.encode_sequences(sequences)
        X_v_genes = self.encode_v_genes(v_genes)
        X_j_genes = self.encode_j_genes(j_genes)
        
        # 6. Convert to numpy arrays
        X_sequences = np.array(X_sequences)
        X_v_genes = np.array(X_v_genes)
        X_j_genes = np.array(X_j_genes)
        y_labels = np.array(labels)
        
        # 7. Create TensorFlow dataset
        dataset = tf.data.Dataset.from_tensor_slices((
            {'cdr3_sequence': X_sequences, 'v_gene': X_v_genes, 'j_gene': X_j_genes,},
            {'labels': y_labels}
        ))
            
        # Map to the format expected by the model
        dataset = dataset.map(lambda X, y: (X, {'labels': tf.one_hot(y['labels'], len(self.label_map))}))
            
        if shuffle:
            dataset = dataset.shuffle(len(X_sequences), reshuffle_each_iteration=True)
        
        dataset = dataset.batch(batch_size, drop_remainder=True)
        dataset = dataset.prefetch(tf.data.AUTOTUNE)
        
        return dataset
    
    def get_vocab_sizes(self):
        """Return vocabulary sizes for model construction"""
        return {
            'aa_vocab_size': len(self.aa_dict) + 1,  # +1 for padding
            'v_vocab_size': len(self.v_dict) + 1,    # +1 for unknown
            'j_vocab_size': len(self.j_dict) + 1,    # +1 for unknown
            'num_classes': len(self.label_map),
            'max_length': self.max_length
        }
    
    def get_mappings(self):
        """Return the created mappings for inspection"""
        return {
            'aa_dict': self.aa_dict,
            'v_dict': self.v_dict,
            'j_dict': self.j_dict,
            'label_map': self.label_map
        }

# %%
def create_tcr_model(vocab_sizes):
    """Create a model using the Conv1D architecture from the reference"""
    # Input layers
    cdr3_input = keras.Input(shape=(vocab_sizes['max_length'],), dtype=tf.uint32, name='cdr3_sequence')
    v_gene_input = keras.Input(shape=(), dtype=tf.uint32, name='v_gene')
    j_gene_input = keras.Input(shape=(), dtype=tf.uint32, name='j_gene')
    
    # CDR3 sequence encoder (following the reference structure)
    cdr3_embed = keras.layers.Embedding(
        input_dim=vocab_sizes['aa_vocab_size'], 
        output_dim=8, 
        mask_zero=True
    )(cdr3_input)
    
    convs = [keras.layers.Conv1D(
        filters=16, 
        kernel_size=9, 
        strides=1, 
        activation=keras.activations.relu,
        padding='valid'
    )(cdr3_embed)]
    
    convs.append(keras.layers.Conv1D(
        filters=32, 
        kernel_size=7, 
        strides=2, 
        activation=keras.activations.relu,
        padding='valid'
    )(convs[-1]))
    
    # convs.append(keras.layers.Conv1D(
    #     filters=256, 
    #     kernel_size=5, 
    #     strides=1, 
    #     activation=None,
    #     padding='valid'
    # )(convs[-1]))
    
    # Take the first position output (like in reference: [:, 0, :])
    # cdr3_encoded = convs[-1][:, 0, :]

    # pooling to gain positional equivariance
    cdr3_encoded = keras.layers.GlobalMaxPooling1D()(convs[-1])
    
    # Gene embeddings
    v_embed = keras.layers.Embedding(vocab_sizes['v_vocab_size'], 16, mask_zero=True)(v_gene_input)
    j_embed = keras.layers.Embedding(vocab_sizes['j_vocab_size'], 16, mask_zero=True)(j_gene_input)
    
    # Flatten gene embeddings
    # v_flat = tf.keras.layers.Flatten()(v_embed)
    # j_flat = tf.keras.layers.Flatten()(j_embed)
    
    # Concatenate all features
    fused = keras.layers.Concatenate(axis=-1)([cdr3_encoded, v_embed, j_embed])
    
    # Classifier (following reference structure)
    dropout1 = keras.layers.Dropout(rate=0.1)(fused)
    dense1 = keras.layers.Dense(units=32, activation=keras.activations.relu)(dropout1)
    dropout2 = keras.layers.Dropout(rate=0.05)(dense1)
    dense2 = keras.layers.Dense(units=16, activation=keras.activations.relu)(dropout2)
    # output = tf.keras.layers.Dense(units=vocab_sizes['num_classes'], activation='softmax')(dense2)
    output = keras.layers.Dense(units=vocab_sizes['num_classes'], activation='sigmoid')(dense2)

    model = keras.Model(
        inputs=[cdr3_input, v_gene_input, j_gene_input],
        outputs=output
    )
    
    return model

# %%
# Initialize loader
#data_dir = './DeepTCR/Data/Murine_Antigens'
#loader = TCRDataLoader(data_dir)

# Load data
#print("Loading data...")
#dataset = loader.load_and_encode_data(batch_size=100, shuffle=True)
#print("Data loaded successfully!")

# %%
# Initialize loader
data_dir = './DeepTCR/Data/Human_Antigens'
loader = TCRDataLoader(data_dir)

# Load data
print("Loading data...")
dataset = loader.load_and_encode_data(batch_size=100, shuffle=True)
print("Data loaded successfully!")
# Out:
# Loading data...
# Combining columns:
#
# Combining sequence columns:
#   Added 2066 values from 'aminoAcid' column
#   Added 412 values from 'beta' column
#   Total combined values: 2478
#
# Combining v_gene columns:
#   Added 1874 values from 'v_beta' column
#   Total combined values: 1874
#
# Combining j_gene columns:
#   Added 2084 values from 'j_beta' column
#   Total combined values: 2084
#
# Combining counts columns:
#   Added 2478 values from 'counts' column
#   Total combined values: 2478
#
# Vocabulary built:
#   Amino acids: 20 unique
#   V genes: 62 unique
#   J genes: 13 unique
#   Max sequence length: 23
# Valid data: 2478 out of 2478 total rows
# Data loaded successfully!

# %%
loader.v_dict
# Out:
# {'TCRBV-Apr': 1,
#  'TCRBV-Dec': 2,
#  'TCRBV-May': 3,
#  'TCRBV-Oct': 4,
#  'TCRBV02-03': 5,
#  'TCRBV024/OR9-01': 6,
#  'TCRBV03-01': 7,
#  'TCRBV03-02': 8,
#  'TCRBV03-03': 9,
#  'TCRBV04-01': 10,
#  'TCRBV04-02': 11,
#  'TCRBV04-03': 12,
#  'TCRBV05-01': 13,
#  'TCRBV05-04': 14,
#  'TCRBV06-01': 15,
#  'TCRBV06-02': 16,
#  'TCRBV06-03': 17,
#  'TCRBV06-04': 18,
#  'TCRBV06-05': 19,
#  'TCRBV06-06': 20,
#  'TCRBV06-09': 21,
#  'TCRBV07-01': 22,
#  'TCRBV07-02': 23,
#  'TCRBV07-03': 24,
#  'TCRBV07-04': 25,
#  'TCRBV07-06': 26,
#  'TCRBV07-07': 27,
#  'TCRBV07-08': 28,
#  'TCRBV07-09': 29,
#  'TCRBV09-01': 30,
#  'TCRBV09-02': 31,
#  'TCRBV10-01': 32,
#  'TCRBV10-02': 33,
#  'TCRBV10-03': 34,
#  'TCRBV11-01': 35,
#  'TCRBV11-02': 36,
#  'TCRBV11-03': 37,
#  'TCRBV12-01': 38,
#  'TCRBV12-02': 39,
#  'TCRBV12-03': 40,
#  'TCRBV12-04': 41,
#  'TCRBV12-05': 42,
#  'TCRBV13-01': 43,
#  'TCRBV13-02': 44,
#  'TCRBV14-01': 45,
#  'TCRBV14-02': 46,
#  'TCRBV15-01': 47,
#  'TCRBV15-02': 48,
#  'TCRBV18-01': 49,
#  'TCRBV19-01': 50,
#  'TCRBV19-02': 51,
#  'TCRBV19-03': 52,
#  'TCRBV20-01': 53,
#  'TCRBV20-07': 54,
#  'TCRBV24-01': 55,
#  'TCRBV25-01': 56,
#  'TCRBV27-01': 57,
#  'TCRBV28-01': 58,
#  'TCRBV29-01': 59,
#  'TCRBV29-02': 60,
#  'TCRBV29-03': 61,
#  'TCRBV30-01': 62}

# %%
# Create model
vocab_sizes = loader.get_vocab_sizes()
print("Creating model...")
model = create_tcr_model(vocab_sizes)

# Compile model
model.compile(
    optimizer='adam', 
    loss='binary_crossentropy',
    metrics=['accuracy']
)

initial_weights = model.get_weights()

# Display model summary
model.summary()
# Out:
# Creating model...
# c:\Users\huang\miniconda3\envs\gpu-ml-base\Lib\site-packages\keras\src\layers\layer.py:932: UserWarning: Layer 'conv1d_2' (of type Conv1D) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ cdr3_sequence       │ (None, 23)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_3         │ (None, 23, 8)     │        168 │ cdr3_sequence[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 15, 16)    │      1,168 │ embedding_3[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_3 (Conv1D)   │ (None, 5, 32)     │      3,616 │ conv1d_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ v_gene (InputLayer) │ (None)            │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ j_gene (InputLayer) │ (None)            │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 32)        │          0 │ conv1d_3[0][0]    │
# │ (GlobalMaxPooling1… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_4         │ (None, 16)        │      1,008 │ v_gene[0][0]      │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_5         │ (None, 16)        │        224 │ j_gene[0][0]      │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 64)        │          0 │ global_max_pooli… │
# │ (Concatenate)       │                   │            │ embedding_4[0][0… │
# │                     │                   │            │ embedding_5[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 64)        │          0 │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 32)        │      2,080 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 32)        │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 16)        │        528 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 7)         │        119 │ dense_4[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 8,911 (34.81 KB)
#  Trainable params: 8,911 (34.81 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Updated data preparation using combined columns
df = loader.load_files()
df['Antigen'] = df['Antigen'].astype('category')
loader.build_vocabulary(df)

# Filter valid data using combined columns
valid_rows = df['combined_sequence'].notna()
df_valid = df[valid_rows].copy()

print(f"Valid sequences: {len(df_valid)} out of {len(df)} total")

# Encode data using combined columns
sequences = df_valid['combined_sequence'].values
v_genes = df_valid['combined_v_gene'].fillna('UNK').values
j_genes = df_valid['combined_j_gene'].fillna('UNK').values
counts = df_valid['combined_counts'].fillna(1).values  

labels = [loader.label_map[antigen] for antigen in df_valid['Antigen']]

X_sequences = loader.encode_sequences(sequences)
X_v_genes = loader.encode_v_genes(v_genes)
X_j_genes = loader.encode_j_genes(j_genes)

# Convert to numpy
X_sequences = np.array(X_sequences)
X_v_genes = np.array(X_v_genes)
X_j_genes = np.array(X_j_genes)

# Set up data for cross-validation
X = [
    np.array(X_sequences, dtype=np.int32),
    np.array(X_v_genes, dtype=np.int32),
    np.array(X_j_genes, dtype=np.int32)
]
y_true = np.array(df_valid['Antigen'].cat.codes.values, dtype=np.int32)

print(f"Final data shapes:")
print(f"  X[0] (sequences): {X[0].shape}")
print(f"  X[1] (v_genes): {X[1].shape}")
print(f"  X[2] (j_genes): {X[2].shape}")
print(f"  y_true: {y_true.shape}")
# Out:
# Combining columns:
#
# Combining sequence columns:
#   Added 2066 values from 'aminoAcid' column
#   Added 412 values from 'beta' column
#   Total combined values: 2478
#
# Combining v_gene columns:
#   Added 1874 values from 'v_beta' column
#   Total combined values: 1874
#
# Combining j_gene columns:
#   Added 2084 values from 'j_beta' column
#   Total combined values: 2084
#
# Combining counts columns:
#   Added 2478 values from 'counts' column
#   Total combined values: 2478
#
# Vocabulary built:
#   Amino acids: 20 unique
#   V genes: 62 unique
#   J genes: 13 unique
#   Max sequence length: 23
# Valid sequences: 2478 out of 2478 total
# Final data shapes:
#   X[0] (sequences): (2478, 23)
#   X[1] (v_genes): (2478,)
#   X[2] (j_genes): (2478,)
#   y_true: (2478,)
# C:\Users\huang\AppData\Local\Temp\ipykernel_57096\1068804712.py:16: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   counts = df_valid['combined_counts'].fillna(1).values

# %%
np.unique(df['aminoAcid'].astype('category').cat.codes.values)
# Out:
# array([  -1,    0,    1, ..., 1969, 1970, 1971],
#       shape=(1973,), dtype=int16)

# %%
from utils import KerasCrossValidation

# %%
df_valid
# Out:
#              aminoAcid  counts      v_beta      j_beta     Antigen beta  \
# 0      CASSYSSSSYNEQFF       1  TCRBV06-06  TCRBJ02-01   CTELKLSDY  NaN
# 1       CASSSGGPRAEQFF       1  TCRBV07-09  TCRBJ02-01   CTELKLSDY  NaN
# 2      CATSRDLSFGYGYTF       1         NaN  TCRBJ01-02   CTELKLSDY  NaN
# 3       CATSREQNNSPLHF       1         NaN  TCRBJ01-06   CTELKLSDY  NaN
# 4        CATVGGIDQPQHF       1  TCRBV10-03  TCRBJ01-05   CTELKLSDY  NaN
# ...                ...     ...         ...         ...         ...  ...
# 2473    CSARDPQGVTEAFF       1  TCRBV20-01         NaN  TPRVTGGGAM  NaN
# 2474  CSARDSSGGAKNIQYF       1  TCRBV20-01         NaN  TPRVTGGGAM  NaN
# 2475   CSASLASTSNYGYTF       1  TCRBV20-01         NaN  TPRVTGGGAM  NaN
# 2476   CSATPARASNTEAFF       1  TCRBV20-01         NaN  TPRVTGGGAM  NaN
# 2477    CSGIDKPVTDTQYF       1  TCRBV20-01         NaN  TPRVTGGGAM  NaN
#
#      combined_sequence combined_v_gene combined_j_gene combined_counts
# 0      CASSYSSSSYNEQFF      TCRBV06-06      TCRBJ02-01               1
# 1       CASSSGGPRAEQFF      TCRBV07-09      TCRBJ02-01               1
# 2      CATSRDLSFGYGYTF            None      TCRBJ01-02               1
# 3       CATSREQNNSPLHF            None      TCRBJ01-06               1
# 4        CATVGGIDQPQHF      TCRBV10-03      TCRBJ01-05               1
# ...                ...             ...             ...             ...
# 2473    CSARDPQGVTEAFF      TCRBV20-01            None               1
# 2474  CSARDSSGGAKNIQYF      TCRBV20-01            None               1
# 2475   CSASLASTSNYGYTF      TCRBV20-01            None               1
# 2476   CSATPARASNTEAFF      TCRBV20-01            None               1
# 2477    CSGIDKPVTDTQYF      TCRBV20-01            None               1
#
# [2478 rows x 10 columns]

# %%
df_valid['combined_sequence']
# Out:
# 0        CASSYSSSSYNEQFF
# 1         CASSSGGPRAEQFF
# 2        CATSRDLSFGYGYTF
# 3         CATSREQNNSPLHF
# 4          CATVGGIDQPQHF
#               ...
# 2473      CSARDPQGVTEAFF
# 2474    CSARDSSGGAKNIQYF
# 2475     CSASLASTSNYGYTF
# 2476     CSATPARASNTEAFF
# 2477      CSGIDKPVTDTQYF
# Name: combined_sequence, Length: 2478, dtype: object

# %%
df_valid['combined_v_gene']
# Out:
# 0       TCRBV06-06
# 1       TCRBV07-09
# 2             None
# 3             None
# 4       TCRBV10-03
#            ...
# 2473    TCRBV20-01
# 2474    TCRBV20-01
# 2475    TCRBV20-01
# 2476    TCRBV20-01
# 2477    TCRBV20-01
# Name: combined_v_gene, Length: 2478, dtype: object

# %%
df_valid['combined_j_gene']
# Out:
# 0       TCRBJ02-01
# 1       TCRBJ02-01
# 2       TCRBJ01-02
# 3       TCRBJ01-06
# 4       TCRBJ01-05
#            ...
# 2473          None
# 2474          None
# 2475          None
# 2476          None
# 2477          None
# Name: combined_j_gene, Length: 2478, dtype: object

# %%
# set data
X = [
        np.array(X_sequences, dtype=np.int32),
        np.array(X_v_genes, dtype=np.int32),
        np.array(X_j_genes, dtype=np.int32)
    ]
y_true = np.array(y_true, dtype=np.int32)

# %%
X[1]
# Out:
# array([20, 29,  0, ..., 53, 53, 53], shape=(2478,), dtype=int32)

# %%
import os

num_repeats = 1

# Create directory structure for saving models
for repeat in range(num_repeats):
    save_dir = f'./samlogs/fit-{repeat:02d}'
    os.makedirs(save_dir, exist_ok=True)
    print(f"Created directory: {save_dir}")

# Now run your CV loop
y_pred_all = []
y_test_all = []
history_all = []

for repeat in range(num_repeats):
    print(f"Running CV repeat {repeat + 1}/{num_repeats}")

    model.set_weights(initial_weights)

    keras_cv = KerasCrossValidation(X=X, y=y_true, keras_model=model, 
                                    save_filepath=f'./samlogs/fit-{repeat:02d}')
    
    y_pred, y_test, history = keras_cv(n_splits=7, batch_size=500, min_epochs=5, 
                                       patience=30, max_epochs=500, training_repeat=2)
    
    y_pred_all.append(y_pred)
    y_test_all.append(y_test)
    history_all.append(history)
# Out:
# Created directory: ./samlogs/fit-00
# Running CV repeat 1/1
# Epoch 1/500
# c:\Users\huang\miniconda3\envs\gpu-ml-base\Lib\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['cdr3_sequence', 'v_gene', 'j_gene']. Received: the structure of inputs=('*', '*', '*')
#   warnings.warn(
# c:\Users\huang\miniconda3\envs\gpu-ml-base\Lib\site-packages\keras\src\layers\layer.py:932: UserWarning: Layer 'conv1d_2' (of type Conv1D) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.0231 - loss: 0.6933 - val_accuracy: 0.0282 - val_loss: 0.6884
# Epoch 2/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0225 - loss: 0.6868 - val_accuracy: 0.0113 - val_loss: 0.6808
# Epoch 3/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0099 - loss: 0.6783 - val_accuracy: 0.0113 - val_loss: 0.6669
# Epoch 4/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0114 - loss: 0.6616 - val_accuracy: 0.0113 - val_loss: 0.6380
# Epoch 5/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0087 - loss: 0.6302 - val_accuracy: 0.0113 - val_loss: 0.5956
# Epoch 6/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0109 - loss: 0.5941 - val_accuracy: 0.0113 - val_loss: 0.5651
# Epoch 7/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0088 - loss: 0.5659 - val_accuracy: 0.0113 - val_loss: 0.5468
# Epoch 8/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0101 - loss: 0.5478 - val_accuracy: 0.0113 - val_loss: 0.5316
# Epoch 9/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0111 - loss: 0.5301 - val_accuracy: 0.0113 - val_loss: 0.5126
# Epoch 10/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0110 - loss: 0.5100 - val_accuracy: 0.0113 - val_loss: 0.4899
# Epoch 11/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0177 - loss: 0.4887 - val_accuracy: 0.0113 - val_loss: 0.4655
# Epoch 12/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0378 - loss: 0.4645 - val_accuracy: 0.0424 - val_loss: 0.4444
# Epoch 13/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0896 - loss: 0.4446 - val_accuracy: 0.2458 - val_loss: 0.4252
# Epoch 14/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1868 - loss: 0.4244 - val_accuracy: 0.2910 - val_loss: 0.4066
# Epoch 15/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2450 - loss: 0.4083 - val_accuracy: 0.2966 - val_loss: 0.3896
# Epoch 16/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3000 - loss: 0.3879 - val_accuracy: 0.3842 - val_loss: 0.3750
# Epoch 17/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3687 - loss: 0.3769 - val_accuracy: 0.4350 - val_loss: 0.3628
# Epoch 18/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4148 - loss: 0.3634 - val_accuracy: 0.4379 - val_loss: 0.3523
# Epoch 19/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4363 - loss: 0.3576 - val_accuracy: 0.4350 - val_loss: 0.3440
# Epoch 20/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4334 - loss: 0.3448 - val_accuracy: 0.4350 - val_loss: 0.3368
# Epoch 21/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4284 - loss: 0.3385 - val_accuracy: 0.4463 - val_loss: 0.3320
# Epoch 22/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4518 - loss: 0.3308 - val_accuracy: 0.4492 - val_loss: 0.3283
# Epoch 23/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4513 - loss: 0.3271 - val_accuracy: 0.4548 - val_loss: 0.3252
# Epoch 24/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4555 - loss: 0.3261 - val_accuracy: 0.4576 - val_loss: 0.3233
# Epoch 25/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4782 - loss: 0.3172 - val_accuracy: 0.4633 - val_loss: 0.3205
# Epoch 26/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4587 - loss: 0.3190 - val_accuracy: 0.4718 - val_loss: 0.3181
# Epoch 27/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4771 - loss: 0.3146 - val_accuracy: 0.4718 - val_loss: 0.3160
# Epoch 28/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4689 - loss: 0.3115 - val_accuracy: 0.4718 - val_loss: 0.3129
# Epoch 29/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4653 - loss: 0.3090 - val_accuracy: 0.4689 - val_loss: 0.3121
# Epoch 30/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4898 - loss: 0.3035 - val_accuracy: 0.4746 - val_loss: 0.3104
# Epoch 31/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4840 - loss: 0.3027 - val_accuracy: 0.4689 - val_loss: 0.3092
# Epoch 32/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4883 - loss: 0.2964 - val_accuracy: 0.4689 - val_loss: 0.3071
# Epoch 33/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4963 - loss: 0.2993 - val_accuracy: 0.4661 - val_loss: 0.3058
# Epoch 34/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4943 - loss: 0.2981 - val_accuracy: 0.4718 - val_loss: 0.3043
# Epoch 35/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5000 - loss: 0.2917 - val_accuracy: 0.4718 - val_loss: 0.3028
# Epoch 36/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4978 - loss: 0.2931 - val_accuracy: 0.4718 - val_loss: 0.3015
# Epoch 37/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4938 - loss: 0.2952 - val_accuracy: 0.4689 - val_loss: 0.3005
# Epoch 38/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4997 - loss: 0.2905 - val_accuracy: 0.4774 - val_loss: 0.2998
# Epoch 39/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4893 - loss: 0.2888 - val_accuracy: 0.4831 - val_loss: 0.2989
# Epoch 40/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5075 - loss: 0.2892 - val_accuracy: 0.4831 - val_loss: 0.2981
# Epoch 41/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5116 - loss: 0.2858 - val_accuracy: 0.4831 - val_loss: 0.2975
# Epoch 42/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5254 - loss: 0.2821 - val_accuracy: 0.4887 - val_loss: 0.2968
# Epoch 43/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5241 - loss: 0.2786 - val_accuracy: 0.4887 - val_loss: 0.2964
# Epoch 44/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5154 - loss: 0.2823 - val_accuracy: 0.4859 - val_loss: 0.2957
# Epoch 45/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5153 - loss: 0.2794 - val_accuracy: 0.4915 - val_loss: 0.2949
# Epoch 46/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5111 - loss: 0.2825 - val_accuracy: 0.4859 - val_loss: 0.2942
# Epoch 47/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5284 - loss: 0.2749 - val_accuracy: 0.4915 - val_loss: 0.2935
# Epoch 48/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5300 - loss: 0.2750 - val_accuracy: 0.4887 - val_loss: 0.2926
# Epoch 49/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5333 - loss: 0.2747 - val_accuracy: 0.4859 - val_loss: 0.2919
# Epoch 50/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5426 - loss: 0.2708 - val_accuracy: 0.4802 - val_loss: 0.2911
# Epoch 51/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5412 - loss: 0.2706 - val_accuracy: 0.4944 - val_loss: 0.2902
# Epoch 52/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5298 - loss: 0.2746 - val_accuracy: 0.4944 - val_loss: 0.2889
# Epoch 53/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5676 - loss: 0.2650 - val_accuracy: 0.4944 - val_loss: 0.2878
# Epoch 54/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5573 - loss: 0.2660 - val_accuracy: 0.5000 - val_loss: 0.2869
# Epoch 55/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5615 - loss: 0.2643 - val_accuracy: 0.4972 - val_loss: 0.2852
# Epoch 56/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5752 - loss: 0.2592 - val_accuracy: 0.4972 - val_loss: 0.2853
# Epoch 57/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5644 - loss: 0.2591 - val_accuracy: 0.5113 - val_loss: 0.2847
# Epoch 58/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5666 - loss: 0.2601 - val_accuracy: 0.5113 - val_loss: 0.2836
# Epoch 59/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5672 - loss: 0.2577 - val_accuracy: 0.5113 - val_loss: 0.2839
# Epoch 60/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5901 - loss: 0.2520 - val_accuracy: 0.5169 - val_loss: 0.2829
# Epoch 61/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5792 - loss: 0.2556 - val_accuracy: 0.5169 - val_loss: 0.2829
# Epoch 62/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5720 - loss: 0.2546 - val_accuracy: 0.5254 - val_loss: 0.2829
# Epoch 63/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5820 - loss: 0.2495 - val_accuracy: 0.5226 - val_loss: 0.2836
# Epoch 64/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5925 - loss: 0.2510 - val_accuracy: 0.5226 - val_loss: 0.2822
# Epoch 65/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6035 - loss: 0.2455 - val_accuracy: 0.5198 - val_loss: 0.2822
# Epoch 66/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6082 - loss: 0.2423 - val_accuracy: 0.5169 - val_loss: 0.2817
# Epoch 67/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5892 - loss: 0.2449 - val_accuracy: 0.5226 - val_loss: 0.2814
# Epoch 68/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6023 - loss: 0.2450 - val_accuracy: 0.5141 - val_loss: 0.2826
# Epoch 69/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6063 - loss: 0.2427 - val_accuracy: 0.5198 - val_loss: 0.2820
# Epoch 70/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5970 - loss: 0.2445 - val_accuracy: 0.5254 - val_loss: 0.2821
# Epoch 71/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5932 - loss: 0.2441 - val_accuracy: 0.5226 - val_loss: 0.2816
# Epoch 72/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6128 - loss: 0.2404 - val_accuracy: 0.5085 - val_loss: 0.2831
# Epoch 73/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6160 - loss: 0.2380 - val_accuracy: 0.5282 - val_loss: 0.2812
# Epoch 74/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6245 - loss: 0.2342 - val_accuracy: 0.5113 - val_loss: 0.2831
# Epoch 75/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6230 - loss: 0.2374 - val_accuracy: 0.5198 - val_loss: 0.2829
# Epoch 76/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6071 - loss: 0.2392 - val_accuracy: 0.5113 - val_loss: 0.2846
# Epoch 77/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6385 - loss: 0.2254 - val_accuracy: 0.5141 - val_loss: 0.2848
# Epoch 78/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6261 - loss: 0.2307 - val_accuracy: 0.5226 - val_loss: 0.2829
# Epoch 79/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6396 - loss: 0.2258 - val_accuracy: 0.5113 - val_loss: 0.2847
# Epoch 80/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6311 - loss: 0.2298 - val_accuracy: 0.5226 - val_loss: 0.2844
# Epoch 81/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6261 - loss: 0.2270 - val_accuracy: 0.5198 - val_loss: 0.2855
# Epoch 82/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6331 - loss: 0.2271 - val_accuracy: 0.5198 - val_loss: 0.2854
# Epoch 83/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6428 - loss: 0.2222 - val_accuracy: 0.5198 - val_loss: 0.2854
# Epoch 84/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6592 - loss: 0.2181 - val_accuracy: 0.5311 - val_loss: 0.2874
# Epoch 85/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6480 - loss: 0.2173 - val_accuracy: 0.5254 - val_loss: 0.2878
# Epoch 86/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6630 - loss: 0.2139 - val_accuracy: 0.5169 - val_loss: 0.2871
# Epoch 87/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6475 - loss: 0.2197 - val_accuracy: 0.5367 - val_loss: 0.2872
# Epoch 88/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6676 - loss: 0.2114 - val_accuracy: 0.5254 - val_loss: 0.2900
# Epoch 89/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6687 - loss: 0.2120 - val_accuracy: 0.5254 - val_loss: 0.2888
# Epoch 90/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6635 - loss: 0.2119 - val_accuracy: 0.5198 - val_loss: 0.2897
# Epoch 91/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6564 - loss: 0.2133 - val_accuracy: 0.5282 - val_loss: 0.2893
# Epoch 92/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6676 - loss: 0.2079 - val_accuracy: 0.5254 - val_loss: 0.2912
# Epoch 93/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6642 - loss: 0.2106 - val_accuracy: 0.5198 - val_loss: 0.2924
# Epoch 94/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6795 - loss: 0.2043 - val_accuracy: 0.5226 - val_loss: 0.2949
# Epoch 95/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6856 - loss: 0.1987 - val_accuracy: 0.5282 - val_loss: 0.2928
# Epoch 96/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6890 - loss: 0.1999 - val_accuracy: 0.5282 - val_loss: 0.2946
# Epoch 97/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6845 - loss: 0.2002 - val_accuracy: 0.5254 - val_loss: 0.2981
# Epoch 98/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6786 - loss: 0.2010 - val_accuracy: 0.5226 - val_loss: 0.2975
# Epoch 99/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6992 - loss: 0.1948 - val_accuracy: 0.5198 - val_loss: 0.2973
# Epoch 100/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7026 - loss: 0.1919 - val_accuracy: 0.5282 - val_loss: 0.3001
# Epoch 101/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6926 - loss: 0.1965 - val_accuracy: 0.5282 - val_loss: 0.2993
# Epoch 102/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6956 - loss: 0.1945 - val_accuracy: 0.5226 - val_loss: 0.3002
# Epoch 103/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6942 - loss: 0.1943 - val_accuracy: 0.5339 - val_loss: 0.3013
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Epoch 1/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0205 - loss: 0.6941 - val_accuracy: 0.0141 - val_loss: 0.6894
# Epoch 2/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0147 - loss: 0.6878 - val_accuracy: 0.0085 - val_loss: 0.6815
# Epoch 3/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0100 - loss: 0.6790 - val_accuracy: 0.0085 - val_loss: 0.6708
# Epoch 4/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0114 - loss: 0.6681 - val_accuracy: 0.0085 - val_loss: 0.6590
# Epoch 5/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0108 - loss: 0.6561 - val_accuracy: 0.0085 - val_loss: 0.6458
# Epoch 6/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0097 - loss: 0.6426 - val_accuracy: 0.0085 - val_loss: 0.6303
# Epoch 7/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0105 - loss: 0.6265 - val_accuracy: 0.0085 - val_loss: 0.6116
# Epoch 8/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0112 - loss: 0.6069 - val_accuracy: 0.0085 - val_loss: 0.5886
# Epoch 9/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0109 - loss: 0.5826 - val_accuracy: 0.0085 - val_loss: 0.5635
# Epoch 10/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0107 - loss: 0.5593 - val_accuracy: 0.0085 - val_loss: 0.5436
# Epoch 11/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0091 - loss: 0.5419 - val_accuracy: 0.0085 - val_loss: 0.5296
# Epoch 12/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0076 - loss: 0.5272 - val_accuracy: 0.0085 - val_loss: 0.5148
# Epoch 13/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0109 - loss: 0.5124 - val_accuracy: 0.0085 - val_loss: 0.5018
# Epoch 14/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0103 - loss: 0.5004 - val_accuracy: 0.0085 - val_loss: 0.4897
# Epoch 15/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0106 - loss: 0.4871 - val_accuracy: 0.0085 - val_loss: 0.4778
# Epoch 16/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0102 - loss: 0.4773 - val_accuracy: 0.0085 - val_loss: 0.4668
# Epoch 17/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0120 - loss: 0.4649 - val_accuracy: 0.0085 - val_loss: 0.4562
# Epoch 18/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0112 - loss: 0.4562 - val_accuracy: 0.0085 - val_loss: 0.4461
# Epoch 19/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0094 - loss: 0.4453 - val_accuracy: 0.0085 - val_loss: 0.4363
# Epoch 20/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0100 - loss: 0.4368 - val_accuracy: 0.0085 - val_loss: 0.4266
# Epoch 21/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0093 - loss: 0.4258 - val_accuracy: 0.0085 - val_loss: 0.4169
# Epoch 22/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0114 - loss: 0.4184 - val_accuracy: 0.0085 - val_loss: 0.4072
# Epoch 23/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0203 - loss: 0.4061 - val_accuracy: 0.0424 - val_loss: 0.3972
# Epoch 24/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1198 - loss: 0.3979 - val_accuracy: 0.3107 - val_loss: 0.3871
# Epoch 25/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2668 - loss: 0.3894 - val_accuracy: 0.4068 - val_loss: 0.3795
# Epoch 26/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3942 - loss: 0.3798 - val_accuracy: 0.4548 - val_loss: 0.3728
# Epoch 27/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4301 - loss: 0.3779 - val_accuracy: 0.4718 - val_loss: 0.3663
# Epoch 28/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4359 - loss: 0.3720 - val_accuracy: 0.4661 - val_loss: 0.3600
# Epoch 29/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4374 - loss: 0.3656 - val_accuracy: 0.4633 - val_loss: 0.3540
# Epoch 30/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4374 - loss: 0.3594 - val_accuracy: 0.4605 - val_loss: 0.3483
# Epoch 31/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4422 - loss: 0.3532 - val_accuracy: 0.4605 - val_loss: 0.3431
# Epoch 32/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4362 - loss: 0.3476 - val_accuracy: 0.4605 - val_loss: 0.3382
# Epoch 33/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4486 - loss: 0.3411 - val_accuracy: 0.4576 - val_loss: 0.3335
# Epoch 34/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4462 - loss: 0.3412 - val_accuracy: 0.4633 - val_loss: 0.3291
# Epoch 35/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4429 - loss: 0.3374 - val_accuracy: 0.4605 - val_loss: 0.3249
# Epoch 36/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4604 - loss: 0.3321 - val_accuracy: 0.4605 - val_loss: 0.3209
# Epoch 37/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4412 - loss: 0.3312 - val_accuracy: 0.4605 - val_loss: 0.3173
# Epoch 38/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4569 - loss: 0.3269 - val_accuracy: 0.4605 - val_loss: 0.3142
# Epoch 39/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4456 - loss: 0.3253 - val_accuracy: 0.4605 - val_loss: 0.3113
# Epoch 40/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4596 - loss: 0.3193 - val_accuracy: 0.4633 - val_loss: 0.3089
# Epoch 41/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4590 - loss: 0.3175 - val_accuracy: 0.4661 - val_loss: 0.3067
# Epoch 42/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4552 - loss: 0.3162 - val_accuracy: 0.4689 - val_loss: 0.3048
# Epoch 43/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4629 - loss: 0.3131 - val_accuracy: 0.4689 - val_loss: 0.3031
# Epoch 44/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4629 - loss: 0.3100 - val_accuracy: 0.4774 - val_loss: 0.3015
# Epoch 45/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4570 - loss: 0.3107 - val_accuracy: 0.4802 - val_loss: 0.3002
# Epoch 46/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4685 - loss: 0.3096 - val_accuracy: 0.4859 - val_loss: 0.2989
# Epoch 47/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4645 - loss: 0.3097 - val_accuracy: 0.4859 - val_loss: 0.2976
# Epoch 48/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4622 - loss: 0.3041 - val_accuracy: 0.4944 - val_loss: 0.2962
# Epoch 49/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4702 - loss: 0.3050 - val_accuracy: 0.4972 - val_loss: 0.2953
# Epoch 50/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4587 - loss: 0.3073 - val_accuracy: 0.5000 - val_loss: 0.2942
# Epoch 51/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4564 - loss: 0.3060 - val_accuracy: 0.4972 - val_loss: 0.2931
# Epoch 52/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4598 - loss: 0.3066 - val_accuracy: 0.5028 - val_loss: 0.2921
# Epoch 53/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4789 - loss: 0.2985 - val_accuracy: 0.5000 - val_loss: 0.2910
# Epoch 54/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4713 - loss: 0.3003 - val_accuracy: 0.5028 - val_loss: 0.2899
# Epoch 55/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4749 - loss: 0.2982 - val_accuracy: 0.5000 - val_loss: 0.2887
# Epoch 56/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4691 - loss: 0.3000 - val_accuracy: 0.5000 - val_loss: 0.2876
# Epoch 57/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4788 - loss: 0.2987 - val_accuracy: 0.4944 - val_loss: 0.2865
# Epoch 58/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4738 - loss: 0.2983 - val_accuracy: 0.4944 - val_loss: 0.2857
# Epoch 59/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4780 - loss: 0.2983 - val_accuracy: 0.4944 - val_loss: 0.2848
# Epoch 60/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4849 - loss: 0.2919 - val_accuracy: 0.4972 - val_loss: 0.2837
# Epoch 61/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4795 - loss: 0.2939 - val_accuracy: 0.5000 - val_loss: 0.2827
# Epoch 62/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4873 - loss: 0.2909 - val_accuracy: 0.4972 - val_loss: 0.2816
# Epoch 63/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4824 - loss: 0.2927 - val_accuracy: 0.5028 - val_loss: 0.2805
# Epoch 64/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4741 - loss: 0.2895 - val_accuracy: 0.5113 - val_loss: 0.2791
# Epoch 65/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4842 - loss: 0.2914 - val_accuracy: 0.5198 - val_loss: 0.2778
# Epoch 66/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4898 - loss: 0.2882 - val_accuracy: 0.5254 - val_loss: 0.2771
# Epoch 67/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4818 - loss: 0.2906 - val_accuracy: 0.5085 - val_loss: 0.2768
# Epoch 68/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4878 - loss: 0.2856 - val_accuracy: 0.5113 - val_loss: 0.2764
# Epoch 69/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4920 - loss: 0.2851 - val_accuracy: 0.5085 - val_loss: 0.2757
# Epoch 70/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4892 - loss: 0.2861 - val_accuracy: 0.5085 - val_loss: 0.2753
# Epoch 71/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4906 - loss: 0.2830 - val_accuracy: 0.5113 - val_loss: 0.2748
# Epoch 72/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5017 - loss: 0.2850 - val_accuracy: 0.5085 - val_loss: 0.2744
# Epoch 73/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5041 - loss: 0.2831 - val_accuracy: 0.5141 - val_loss: 0.2740
# Epoch 74/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5062 - loss: 0.2796 - val_accuracy: 0.5085 - val_loss: 0.2734
# Epoch 75/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5136 - loss: 0.2764 - val_accuracy: 0.5198 - val_loss: 0.2728
# Epoch 76/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5035 - loss: 0.2810 - val_accuracy: 0.5198 - val_loss: 0.2724
# Epoch 77/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5176 - loss: 0.2752 - val_accuracy: 0.5198 - val_loss: 0.2722
# Epoch 78/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5035 - loss: 0.2820 - val_accuracy: 0.5254 - val_loss: 0.2717
# Epoch 79/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5052 - loss: 0.2778 - val_accuracy: 0.5395 - val_loss: 0.2709
# Epoch 80/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5036 - loss: 0.2810 - val_accuracy: 0.5311 - val_loss: 0.2707
# Epoch 81/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5074 - loss: 0.2775 - val_accuracy: 0.5311 - val_loss: 0.2703
# Epoch 82/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5129 - loss: 0.2761 - val_accuracy: 0.5480 - val_loss: 0.2696
# Epoch 83/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5057 - loss: 0.2762 - val_accuracy: 0.5367 - val_loss: 0.2692
# Epoch 84/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5201 - loss: 0.2725 - val_accuracy: 0.5311 - val_loss: 0.2690
# Epoch 85/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5375 - loss: 0.2707 - val_accuracy: 0.5367 - val_loss: 0.2686
# Epoch 86/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5236 - loss: 0.2728 - val_accuracy: 0.5508 - val_loss: 0.2684
# Epoch 87/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5132 - loss: 0.2736 - val_accuracy: 0.5424 - val_loss: 0.2681
# Epoch 88/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5158 - loss: 0.2728 - val_accuracy: 0.5424 - val_loss: 0.2681
# Epoch 89/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5216 - loss: 0.2732 - val_accuracy: 0.5537 - val_loss: 0.2676
# Epoch 90/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5284 - loss: 0.2710 - val_accuracy: 0.5537 - val_loss: 0.2674
# Epoch 91/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5311 - loss: 0.2734 - val_accuracy: 0.5508 - val_loss: 0.2673
# Epoch 92/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5201 - loss: 0.2744 - val_accuracy: 0.5508 - val_loss: 0.2668
# Epoch 93/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5205 - loss: 0.2707 - val_accuracy: 0.5480 - val_loss: 0.2664
# Epoch 94/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5357 - loss: 0.2680 - val_accuracy: 0.5480 - val_loss: 0.2662
# Epoch 95/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5296 - loss: 0.2707 - val_accuracy: 0.5537 - val_loss: 0.2661
# Epoch 96/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5377 - loss: 0.2662 - val_accuracy: 0.5537 - val_loss: 0.2655
# Epoch 97/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5392 - loss: 0.2665 - val_accuracy: 0.5593 - val_loss: 0.2654
# Epoch 98/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5248 - loss: 0.2688 - val_accuracy: 0.5537 - val_loss: 0.2652
# Epoch 99/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5439 - loss: 0.2636 - val_accuracy: 0.5593 - val_loss: 0.2651
# Epoch 100/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5402 - loss: 0.2665 - val_accuracy: 0.5508 - val_loss: 0.2646
# Epoch 101/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5443 - loss: 0.2656 - val_accuracy: 0.5480 - val_loss: 0.2647
# Epoch 102/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5288 - loss: 0.2669 - val_accuracy: 0.5650 - val_loss: 0.2644
# Epoch 103/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5424 - loss: 0.2649 - val_accuracy: 0.5763 - val_loss: 0.2642
# Epoch 104/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5538 - loss: 0.2580 - val_accuracy: 0.5678 - val_loss: 0.2642
# Epoch 105/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5432 - loss: 0.2623 - val_accuracy: 0.5565 - val_loss: 0.2638
# Epoch 106/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5514 - loss: 0.2623 - val_accuracy: 0.5678 - val_loss: 0.2636
# Epoch 107/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5515 - loss: 0.2615 - val_accuracy: 0.5678 - val_loss: 0.2635
# Epoch 108/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5649 - loss: 0.2578 - val_accuracy: 0.5650 - val_loss: 0.2636
# Epoch 109/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5551 - loss: 0.2608 - val_accuracy: 0.5706 - val_loss: 0.2630
# Epoch 110/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5667 - loss: 0.2597 - val_accuracy: 0.5678 - val_loss: 0.2630
# Epoch 111/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5739 - loss: 0.2564 - val_accuracy: 0.5593 - val_loss: 0.2623
# Epoch 112/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5699 - loss: 0.2562 - val_accuracy: 0.5791 - val_loss: 0.2621
# Epoch 113/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5724 - loss: 0.2555 - val_accuracy: 0.5537 - val_loss: 0.2620
# Epoch 114/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5732 - loss: 0.2524 - val_accuracy: 0.5565 - val_loss: 0.2620
# Epoch 115/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5788 - loss: 0.2538 - val_accuracy: 0.5621 - val_loss: 0.2611
# Epoch 116/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5792 - loss: 0.2506 - val_accuracy: 0.5706 - val_loss: 0.2610
# Epoch 117/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5835 - loss: 0.2520 - val_accuracy: 0.5593 - val_loss: 0.2604
# Epoch 118/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5858 - loss: 0.2496 - val_accuracy: 0.5621 - val_loss: 0.2606
# Epoch 119/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5881 - loss: 0.2468 - val_accuracy: 0.5621 - val_loss: 0.2603
# Epoch 120/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5873 - loss: 0.2483 - val_accuracy: 0.5650 - val_loss: 0.2608
# Epoch 121/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5940 - loss: 0.2457 - val_accuracy: 0.5593 - val_loss: 0.2606
# Epoch 122/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5970 - loss: 0.2468 - val_accuracy: 0.5537 - val_loss: 0.2603
# Epoch 123/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5973 - loss: 0.2410 - val_accuracy: 0.5593 - val_loss: 0.2599
# Epoch 124/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6099 - loss: 0.2415 - val_accuracy: 0.5565 - val_loss: 0.2599
# Epoch 125/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6183 - loss: 0.2396 - val_accuracy: 0.5593 - val_loss: 0.2603
# Epoch 126/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6001 - loss: 0.2429 - val_accuracy: 0.5565 - val_loss: 0.2605
# Epoch 127/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6108 - loss: 0.2377 - val_accuracy: 0.5678 - val_loss: 0.2606
# Epoch 128/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6134 - loss: 0.2391 - val_accuracy: 0.5621 - val_loss: 0.2606
# Epoch 129/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6161 - loss: 0.2373 - val_accuracy: 0.5678 - val_loss: 0.2603
# Epoch 130/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6171 - loss: 0.2335 - val_accuracy: 0.5650 - val_loss: 0.2605
# Epoch 131/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6216 - loss: 0.2364 - val_accuracy: 0.5508 - val_loss: 0.2603
# Epoch 132/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6224 - loss: 0.2337 - val_accuracy: 0.5621 - val_loss: 0.2603
# Epoch 133/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6222 - loss: 0.2322 - val_accuracy: 0.5565 - val_loss: 0.2601
# Epoch 134/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6314 - loss: 0.2300 - val_accuracy: 0.5565 - val_loss: 0.2608
# Epoch 135/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6332 - loss: 0.2297 - val_accuracy: 0.5593 - val_loss: 0.2598
# Epoch 136/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6254 - loss: 0.2293 - val_accuracy: 0.5565 - val_loss: 0.2602
# Epoch 137/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6227 - loss: 0.2293 - val_accuracy: 0.5395 - val_loss: 0.2608
# Epoch 138/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6374 - loss: 0.2229 - val_accuracy: 0.5537 - val_loss: 0.2616
# Epoch 139/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6409 - loss: 0.2232 - val_accuracy: 0.5395 - val_loss: 0.2612
# Epoch 140/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6397 - loss: 0.2215 - val_accuracy: 0.5395 - val_loss: 0.2620
# Epoch 141/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6464 - loss: 0.2208 - val_accuracy: 0.5480 - val_loss: 0.2612
# Epoch 142/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6545 - loss: 0.2165 - val_accuracy: 0.5452 - val_loss: 0.2620
# Epoch 143/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6575 - loss: 0.2154 - val_accuracy: 0.5367 - val_loss: 0.2633
# Epoch 144/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6742 - loss: 0.2135 - val_accuracy: 0.5339 - val_loss: 0.2645
# Epoch 145/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6620 - loss: 0.2133 - val_accuracy: 0.5367 - val_loss: 0.2636
# Epoch 146/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6610 - loss: 0.2129 - val_accuracy: 0.5424 - val_loss: 0.2645
# Epoch 147/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6647 - loss: 0.2127 - val_accuracy: 0.5452 - val_loss: 0.2648
# Epoch 148/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6802 - loss: 0.2062 - val_accuracy: 0.5424 - val_loss: 0.2657
# Epoch 149/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6708 - loss: 0.2113 - val_accuracy: 0.5480 - val_loss: 0.2645
# Epoch 150/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6886 - loss: 0.2044 - val_accuracy: 0.5424 - val_loss: 0.2663
# Epoch 151/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6852 - loss: 0.2024 - val_accuracy: 0.5424 - val_loss: 0.2657
# Epoch 152/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6750 - loss: 0.2078 - val_accuracy: 0.5395 - val_loss: 0.2676
# Epoch 153/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6901 - loss: 0.2008 - val_accuracy: 0.5367 - val_loss: 0.2678
# Epoch 154/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6988 - loss: 0.1979 - val_accuracy: 0.5424 - val_loss: 0.2681
# Epoch 155/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6831 - loss: 0.2011 - val_accuracy: 0.5367 - val_loss: 0.2700
# Epoch 156/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7059 - loss: 0.1921 - val_accuracy: 0.5367 - val_loss: 0.2725
# Epoch 157/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6930 - loss: 0.1980 - val_accuracy: 0.5395 - val_loss: 0.2722
# Epoch 158/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7118 - loss: 0.1893 - val_accuracy: 0.5424 - val_loss: 0.2727
# Epoch 159/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7075 - loss: 0.1884 - val_accuracy: 0.5339 - val_loss: 0.2757
# Epoch 160/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7112 - loss: 0.1878 - val_accuracy: 0.5311 - val_loss: 0.2764
# Epoch 161/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7231 - loss: 0.1840 - val_accuracy: 0.5339 - val_loss: 0.2765
# Epoch 162/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7238 - loss: 0.1850 - val_accuracy: 0.5424 - val_loss: 0.2789
# Epoch 163/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7275 - loss: 0.1817 - val_accuracy: 0.5395 - val_loss: 0.2819
# Epoch 164/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7281 - loss: 0.1834 - val_accuracy: 0.5226 - val_loss: 0.2818
# Epoch 165/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7258 - loss: 0.1796 - val_accuracy: 0.5254 - val_loss: 0.2847
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch 1/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0206 - loss: 0.6940 - val_accuracy: 0.0113 - val_loss: 0.6888
# Epoch 2/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0076 - loss: 0.6868 - val_accuracy: 0.0113 - val_loss: 0.6792
# Epoch 3/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0110 - loss: 0.6764 - val_accuracy: 0.0113 - val_loss: 0.6669
# Epoch 4/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0098 - loss: 0.6638 - val_accuracy: 0.0113 - val_loss: 0.6530
# Epoch 5/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0093 - loss: 0.6498 - val_accuracy: 0.0113 - val_loss: 0.6376
# Epoch 6/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0105 - loss: 0.6339 - val_accuracy: 0.0113 - val_loss: 0.6199
# Epoch 7/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0109 - loss: 0.6157 - val_accuracy: 0.0113 - val_loss: 0.5986
# Epoch 8/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0092 - loss: 0.5939 - val_accuracy: 0.0113 - val_loss: 0.5726
# Epoch 9/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0085 - loss: 0.5675 - val_accuracy: 0.0113 - val_loss: 0.5439
# Epoch 10/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0087 - loss: 0.5392 - val_accuracy: 0.0113 - val_loss: 0.5181
# Epoch 11/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0095 - loss: 0.5147 - val_accuracy: 0.0113 - val_loss: 0.4928
# Epoch 12/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0087 - loss: 0.4877 - val_accuracy: 0.0113 - val_loss: 0.4658
# Epoch 13/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0108 - loss: 0.4611 - val_accuracy: 0.0113 - val_loss: 0.4383
# Epoch 14/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0086 - loss: 0.4337 - val_accuracy: 0.0113 - val_loss: 0.4098
# Epoch 15/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0509 - loss: 0.4060 - val_accuracy: 0.3475 - val_loss: 0.3834
# Epoch 16/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3505 - loss: 0.3785 - val_accuracy: 0.3475 - val_loss: 0.3555
# Epoch 17/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3683 - loss: 0.3511 - val_accuracy: 0.3475 - val_loss: 0.3431
# Epoch 18/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3560 - loss: 0.3466 - val_accuracy: 0.3588 - val_loss: 0.3422
# Epoch 19/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3682 - loss: 0.3442 - val_accuracy: 0.3983 - val_loss: 0.3401
# Epoch 20/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3677 - loss: 0.3393 - val_accuracy: 0.3644 - val_loss: 0.3381
# Epoch 21/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3722 - loss: 0.3411 - val_accuracy: 0.4068 - val_loss: 0.3369
# Epoch 22/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3859 - loss: 0.3383 - val_accuracy: 0.3842 - val_loss: 0.3354
# Epoch 23/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3824 - loss: 0.3375 - val_accuracy: 0.3531 - val_loss: 0.3340
# Epoch 24/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3695 - loss: 0.3330 - val_accuracy: 0.3955 - val_loss: 0.3325
# Epoch 25/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3982 - loss: 0.3334 - val_accuracy: 0.4237 - val_loss: 0.3307
# Epoch 26/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4142 - loss: 0.3300 - val_accuracy: 0.4209 - val_loss: 0.3289
# Epoch 27/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3932 - loss: 0.3301 - val_accuracy: 0.4096 - val_loss: 0.3270
# Epoch 28/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4101 - loss: 0.3247 - val_accuracy: 0.4068 - val_loss: 0.3251
# Epoch 29/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4421 - loss: 0.3209 - val_accuracy: 0.4040 - val_loss: 0.3229
# Epoch 30/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4410 - loss: 0.3185 - val_accuracy: 0.4040 - val_loss: 0.3209
# Epoch 31/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4398 - loss: 0.3179 - val_accuracy: 0.4040 - val_loss: 0.3181
# Epoch 32/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4508 - loss: 0.3138 - val_accuracy: 0.4011 - val_loss: 0.3153
# Epoch 33/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4502 - loss: 0.3121 - val_accuracy: 0.4237 - val_loss: 0.3132
# Epoch 34/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4612 - loss: 0.3099 - val_accuracy: 0.4294 - val_loss: 0.3112
# Epoch 35/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4541 - loss: 0.3095 - val_accuracy: 0.4266 - val_loss: 0.3092
# Epoch 36/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4656 - loss: 0.3058 - val_accuracy: 0.4181 - val_loss: 0.3073
# Epoch 37/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4767 - loss: 0.3019 - val_accuracy: 0.4407 - val_loss: 0.3062
# Epoch 38/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4697 - loss: 0.3014 - val_accuracy: 0.4322 - val_loss: 0.3049
# Epoch 39/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4773 - loss: 0.2977 - val_accuracy: 0.4209 - val_loss: 0.3035
# Epoch 40/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4619 - loss: 0.3006 - val_accuracy: 0.4237 - val_loss: 0.3026
# Epoch 41/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4773 - loss: 0.2976 - val_accuracy: 0.4322 - val_loss: 0.3017
# Epoch 42/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4738 - loss: 0.2981 - val_accuracy: 0.4322 - val_loss: 0.3009
# Epoch 43/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4657 - loss: 0.2975 - val_accuracy: 0.4322 - val_loss: 0.3003
# Epoch 44/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4813 - loss: 0.2923 - val_accuracy: 0.4379 - val_loss: 0.2993
# Epoch 45/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4728 - loss: 0.2955 - val_accuracy: 0.4350 - val_loss: 0.2987
# Epoch 46/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4935 - loss: 0.2920 - val_accuracy: 0.4379 - val_loss: 0.2979
# Epoch 47/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4926 - loss: 0.2904 - val_accuracy: 0.4379 - val_loss: 0.2970
# Epoch 48/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4773 - loss: 0.2937 - val_accuracy: 0.4463 - val_loss: 0.2964
# Epoch 49/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4903 - loss: 0.2884 - val_accuracy: 0.4435 - val_loss: 0.2956
# Epoch 50/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4923 - loss: 0.2918 - val_accuracy: 0.4492 - val_loss: 0.2951
# Epoch 51/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4753 - loss: 0.2894 - val_accuracy: 0.4520 - val_loss: 0.2946
# Epoch 52/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4940 - loss: 0.2877 - val_accuracy: 0.4520 - val_loss: 0.2938
# Epoch 53/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4855 - loss: 0.2887 - val_accuracy: 0.4520 - val_loss: 0.2932
# Epoch 54/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4924 - loss: 0.2819 - val_accuracy: 0.4463 - val_loss: 0.2926
# Epoch 55/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4961 - loss: 0.2832 - val_accuracy: 0.4492 - val_loss: 0.2921
# Epoch 56/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4950 - loss: 0.2859 - val_accuracy: 0.4435 - val_loss: 0.2917
# Epoch 57/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5163 - loss: 0.2818 - val_accuracy: 0.4435 - val_loss: 0.2912
# Epoch 58/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4903 - loss: 0.2836 - val_accuracy: 0.4463 - val_loss: 0.2912
# Epoch 59/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5027 - loss: 0.2818 - val_accuracy: 0.4350 - val_loss: 0.2909
# Epoch 60/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5082 - loss: 0.2800 - val_accuracy: 0.4492 - val_loss: 0.2905
# Epoch 61/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4912 - loss: 0.2827 - val_accuracy: 0.4492 - val_loss: 0.2905
# Epoch 62/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5027 - loss: 0.2798 - val_accuracy: 0.4379 - val_loss: 0.2903
# Epoch 63/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5017 - loss: 0.2825 - val_accuracy: 0.4463 - val_loss: 0.2902
# Epoch 64/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5039 - loss: 0.2800 - val_accuracy: 0.4548 - val_loss: 0.2898
# Epoch 65/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5113 - loss: 0.2814 - val_accuracy: 0.4661 - val_loss: 0.2895
# Epoch 66/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5113 - loss: 0.2788 - val_accuracy: 0.4605 - val_loss: 0.2893
# Epoch 67/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5047 - loss: 0.2819 - val_accuracy: 0.4746 - val_loss: 0.2888
# Epoch 68/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5136 - loss: 0.2772 - val_accuracy: 0.4576 - val_loss: 0.2891
# Epoch 69/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5145 - loss: 0.2778 - val_accuracy: 0.4661 - val_loss: 0.2888
# Epoch 70/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5108 - loss: 0.2782 - val_accuracy: 0.4633 - val_loss: 0.2884
# Epoch 71/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5068 - loss: 0.2780 - val_accuracy: 0.4576 - val_loss: 0.2884
# Epoch 72/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5147 - loss: 0.2778 - val_accuracy: 0.4605 - val_loss: 0.2884
# Epoch 73/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5254 - loss: 0.2743 - val_accuracy: 0.4605 - val_loss: 0.2883
# Epoch 74/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5091 - loss: 0.2793 - val_accuracy: 0.4689 - val_loss: 0.2881
# Epoch 75/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5188 - loss: 0.2765 - val_accuracy: 0.4576 - val_loss: 0.2882
# Epoch 76/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5173 - loss: 0.2769 - val_accuracy: 0.4548 - val_loss: 0.2884
# Epoch 77/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5191 - loss: 0.2777 - val_accuracy: 0.4661 - val_loss: 0.2880
# Epoch 78/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5125 - loss: 0.2769 - val_accuracy: 0.4689 - val_loss: 0.2878
# Epoch 79/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5415 - loss: 0.2715 - val_accuracy: 0.4605 - val_loss: 0.2876
# Epoch 80/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5135 - loss: 0.2753 - val_accuracy: 0.4633 - val_loss: 0.2876
# Epoch 81/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5138 - loss: 0.2762 - val_accuracy: 0.4831 - val_loss: 0.2874
# Epoch 82/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5211 - loss: 0.2751 - val_accuracy: 0.4746 - val_loss: 0.2875
# Epoch 83/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5333 - loss: 0.2719 - val_accuracy: 0.4746 - val_loss: 0.2877
# Epoch 84/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5295 - loss: 0.2734 - val_accuracy: 0.4718 - val_loss: 0.2872
# Epoch 85/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5334 - loss: 0.2725 - val_accuracy: 0.4802 - val_loss: 0.2869
# Epoch 86/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5359 - loss: 0.2711 - val_accuracy: 0.4831 - val_loss: 0.2872
# Epoch 87/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5405 - loss: 0.2686 - val_accuracy: 0.4746 - val_loss: 0.2867
# Epoch 88/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5411 - loss: 0.2699 - val_accuracy: 0.4746 - val_loss: 0.2866
# Epoch 89/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5298 - loss: 0.2719 - val_accuracy: 0.4746 - val_loss: 0.2864
# Epoch 90/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5432 - loss: 0.2670 - val_accuracy: 0.4746 - val_loss: 0.2863
# Epoch 91/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5382 - loss: 0.2702 - val_accuracy: 0.4718 - val_loss: 0.2861
# Epoch 92/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5259 - loss: 0.2728 - val_accuracy: 0.4746 - val_loss: 0.2862
# Epoch 93/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5293 - loss: 0.2688 - val_accuracy: 0.4718 - val_loss: 0.2857
# Epoch 94/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5352 - loss: 0.2672 - val_accuracy: 0.5056 - val_loss: 0.2855
# Epoch 95/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5438 - loss: 0.2679 - val_accuracy: 0.4859 - val_loss: 0.2853
# Epoch 96/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5455 - loss: 0.2660 - val_accuracy: 0.4915 - val_loss: 0.2855
# Epoch 97/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5443 - loss: 0.2665 - val_accuracy: 0.4831 - val_loss: 0.2849
# Epoch 98/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5472 - loss: 0.2661 - val_accuracy: 0.4887 - val_loss: 0.2845
# Epoch 99/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5370 - loss: 0.2684 - val_accuracy: 0.4972 - val_loss: 0.2840
# Epoch 100/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5393 - loss: 0.2674 - val_accuracy: 0.5000 - val_loss: 0.2834
# Epoch 101/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5379 - loss: 0.2678 - val_accuracy: 0.5085 - val_loss: 0.2835
# Epoch 102/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5466 - loss: 0.2643 - val_accuracy: 0.4887 - val_loss: 0.2836
# Epoch 103/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5620 - loss: 0.2612 - val_accuracy: 0.5085 - val_loss: 0.2832
# Epoch 104/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5456 - loss: 0.2643 - val_accuracy: 0.5169 - val_loss: 0.2829
# Epoch 105/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5406 - loss: 0.2663 - val_accuracy: 0.5000 - val_loss: 0.2829
# Epoch 106/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5352 - loss: 0.2671 - val_accuracy: 0.5056 - val_loss: 0.2825
# Epoch 107/500
# ...
# Epoch 13/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0111 - loss: 0.4953 - val_accuracy: 0.0113 - val_loss: 0.4803
# Epoch 14/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0096 - loss: 0.4789 - val_accuracy: 0.0113 - val_loss: 0.4630
# Epoch 15/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0100 - loss: 0.4629 - val_accuracy: 0.0113 - val_loss: 0.4456
# Epoch 16/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0088 - loss: 0.4434 - val_accuracy: 0.0113 - val_loss: 0.4288
# Epoch 17/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0182 - loss: 0.4266 - val_accuracy: 0.1949 - val_loss: 0.4126
# Epoch 18/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2139 - loss: 0.4125 - val_accuracy: 0.3277 - val_loss: 0.3972
# Epoch 19/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3117 - loss: 0.3980 - val_accuracy: 0.3277 - val_loss: 0.3834
# Epoch 20/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3323 - loss: 0.3849 - val_accuracy: 0.3277 - val_loss: 0.3715
# Epoch 21/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3287 - loss: 0.3745 - val_accuracy: 0.3277 - val_loss: 0.3612
# Epoch 22/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3605 - loss: 0.3628 - val_accuracy: 0.4322 - val_loss: 0.3522
# Epoch 23/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3784 - loss: 0.3574 - val_accuracy: 0.3955 - val_loss: 0.3449
# Epoch 24/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3899 - loss: 0.3508 - val_accuracy: 0.4322 - val_loss: 0.3395
# Epoch 25/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3918 - loss: 0.3462 - val_accuracy: 0.4209 - val_loss: 0.3356
# Epoch 26/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3922 - loss: 0.3423 - val_accuracy: 0.4124 - val_loss: 0.3325
# Epoch 27/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3951 - loss: 0.3407 - val_accuracy: 0.4379 - val_loss: 0.3295
# Epoch 28/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4218 - loss: 0.3346 - val_accuracy: 0.4407 - val_loss: 0.3263
# Epoch 29/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4012 - loss: 0.3336 - val_accuracy: 0.4294 - val_loss: 0.3232
# Epoch 30/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4279 - loss: 0.3279 - val_accuracy: 0.4492 - val_loss: 0.3195
# Epoch 31/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4311 - loss: 0.3264 - val_accuracy: 0.4548 - val_loss: 0.3160
# Epoch 32/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4402 - loss: 0.3268 - val_accuracy: 0.4520 - val_loss: 0.3126
# Epoch 33/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4268 - loss: 0.3232 - val_accuracy: 0.4633 - val_loss: 0.3098
# Epoch 34/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4384 - loss: 0.3193 - val_accuracy: 0.4492 - val_loss: 0.3068
# Epoch 35/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4517 - loss: 0.3112 - val_accuracy: 0.4774 - val_loss: 0.3042
# Epoch 36/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4234 - loss: 0.3141 - val_accuracy: 0.4633 - val_loss: 0.3021
# Epoch 37/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4412 - loss: 0.3116 - val_accuracy: 0.4661 - val_loss: 0.3005
# Epoch 38/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4440 - loss: 0.3116 - val_accuracy: 0.4718 - val_loss: 0.2991
# Epoch 39/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4464 - loss: 0.3057 - val_accuracy: 0.4774 - val_loss: 0.2981
# Epoch 40/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4533 - loss: 0.3072 - val_accuracy: 0.4661 - val_loss: 0.2971
# Epoch 41/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4573 - loss: 0.3060 - val_accuracy: 0.4831 - val_loss: 0.2961
# Epoch 42/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4536 - loss: 0.3043 - val_accuracy: 0.4746 - val_loss: 0.2952
# Epoch 43/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4565 - loss: 0.3039 - val_accuracy: 0.4774 - val_loss: 0.2945
# Epoch 44/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4535 - loss: 0.3030 - val_accuracy: 0.4746 - val_loss: 0.2939
# Epoch 45/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4445 - loss: 0.3050 - val_accuracy: 0.4802 - val_loss: 0.2931
# Epoch 46/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4652 - loss: 0.2992 - val_accuracy: 0.4718 - val_loss: 0.2923
# Epoch 47/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4543 - loss: 0.3023 - val_accuracy: 0.4802 - val_loss: 0.2916
# Epoch 48/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4768 - loss: 0.2965 - val_accuracy: 0.4718 - val_loss: 0.2911
# Epoch 49/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4748 - loss: 0.2977 - val_accuracy: 0.4718 - val_loss: 0.2904
# Epoch 50/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4674 - loss: 0.2972 - val_accuracy: 0.4718 - val_loss: 0.2898
# Epoch 51/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4689 - loss: 0.2982 - val_accuracy: 0.4887 - val_loss: 0.2894
# Epoch 52/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4835 - loss: 0.2908 - val_accuracy: 0.4774 - val_loss: 0.2888
# Epoch 53/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4804 - loss: 0.2924 - val_accuracy: 0.4802 - val_loss: 0.2883
# Epoch 54/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4945 - loss: 0.2887 - val_accuracy: 0.4887 - val_loss: 0.2879
# Epoch 55/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4715 - loss: 0.2920 - val_accuracy: 0.4887 - val_loss: 0.2874
# Epoch 56/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4789 - loss: 0.2926 - val_accuracy: 0.4915 - val_loss: 0.2866
# Epoch 57/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4861 - loss: 0.2917 - val_accuracy: 0.4972 - val_loss: 0.2862
# Epoch 58/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4694 - loss: 0.2911 - val_accuracy: 0.4915 - val_loss: 0.2856
# Epoch 59/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4878 - loss: 0.2881 - val_accuracy: 0.4915 - val_loss: 0.2852
# Epoch 60/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4779 - loss: 0.2915 - val_accuracy: 0.4944 - val_loss: 0.2849
# Epoch 61/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4850 - loss: 0.2869 - val_accuracy: 0.4915 - val_loss: 0.2844
# Epoch 62/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4818 - loss: 0.2863 - val_accuracy: 0.4915 - val_loss: 0.2839
# Epoch 63/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4832 - loss: 0.2849 - val_accuracy: 0.4915 - val_loss: 0.2834
# Epoch 64/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4880 - loss: 0.2854 - val_accuracy: 0.4944 - val_loss: 0.2829
# Epoch 65/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4898 - loss: 0.2860 - val_accuracy: 0.5000 - val_loss: 0.2826
# Epoch 66/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4947 - loss: 0.2814 - val_accuracy: 0.5000 - val_loss: 0.2819
# Epoch 67/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4859 - loss: 0.2868 - val_accuracy: 0.5056 - val_loss: 0.2815
# Epoch 68/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5046 - loss: 0.2812 - val_accuracy: 0.5000 - val_loss: 0.2812
# Epoch 69/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5019 - loss: 0.2780 - val_accuracy: 0.5028 - val_loss: 0.2808
# Epoch 70/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5005 - loss: 0.2797 - val_accuracy: 0.4944 - val_loss: 0.2805
# Epoch 71/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5082 - loss: 0.2800 - val_accuracy: 0.5028 - val_loss: 0.2802
# Epoch 72/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5031 - loss: 0.2794 - val_accuracy: 0.5000 - val_loss: 0.2796
# Epoch 73/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4934 - loss: 0.2829 - val_accuracy: 0.4972 - val_loss: 0.2791
# Epoch 74/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5039 - loss: 0.2799 - val_accuracy: 0.5113 - val_loss: 0.2786
# Epoch 75/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5127 - loss: 0.2769 - val_accuracy: 0.5113 - val_loss: 0.2780
# Epoch 76/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5126 - loss: 0.2774 - val_accuracy: 0.5141 - val_loss: 0.2774
# Epoch 77/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5195 - loss: 0.2749 - val_accuracy: 0.5226 - val_loss: 0.2769
# Epoch 78/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5286 - loss: 0.2730 - val_accuracy: 0.5198 - val_loss: 0.2763
# Epoch 79/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5163 - loss: 0.2742 - val_accuracy: 0.5169 - val_loss: 0.2759
# Epoch 80/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5265 - loss: 0.2686 - val_accuracy: 0.5169 - val_loss: 0.2755
# Epoch 81/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5208 - loss: 0.2732 - val_accuracy: 0.5254 - val_loss: 0.2748
# Epoch 82/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5168 - loss: 0.2738 - val_accuracy: 0.5226 - val_loss: 0.2741
# Epoch 83/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5222 - loss: 0.2746 - val_accuracy: 0.5226 - val_loss: 0.2737
# Epoch 84/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5367 - loss: 0.2686 - val_accuracy: 0.5282 - val_loss: 0.2733
# Epoch 85/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5451 - loss: 0.2666 - val_accuracy: 0.5282 - val_loss: 0.2728
# Epoch 86/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5384 - loss: 0.2699 - val_accuracy: 0.5282 - val_loss: 0.2722
# Epoch 87/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5455 - loss: 0.2625 - val_accuracy: 0.5282 - val_loss: 0.2718
# Epoch 88/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5539 - loss: 0.2629 - val_accuracy: 0.5254 - val_loss: 0.2712
# Epoch 89/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5574 - loss: 0.2662 - val_accuracy: 0.5282 - val_loss: 0.2713
# Epoch 90/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5622 - loss: 0.2647 - val_accuracy: 0.5367 - val_loss: 0.2711
# Epoch 91/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5490 - loss: 0.2638 - val_accuracy: 0.5282 - val_loss: 0.2711
# Epoch 92/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5666 - loss: 0.2592 - val_accuracy: 0.5424 - val_loss: 0.2699
# Epoch 93/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5736 - loss: 0.2606 - val_accuracy: 0.5339 - val_loss: 0.2701
# Epoch 94/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5604 - loss: 0.2591 - val_accuracy: 0.5395 - val_loss: 0.2693
# Epoch 95/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5631 - loss: 0.2593 - val_accuracy: 0.5367 - val_loss: 0.2693
# Epoch 96/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5672 - loss: 0.2583 - val_accuracy: 0.5367 - val_loss: 0.2688
# Epoch 97/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5790 - loss: 0.2530 - val_accuracy: 0.5452 - val_loss: 0.2684
# Epoch 98/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5761 - loss: 0.2545 - val_accuracy: 0.5480 - val_loss: 0.2677
# Epoch 99/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5794 - loss: 0.2525 - val_accuracy: 0.5424 - val_loss: 0.2675
# Epoch 100/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5884 - loss: 0.2504 - val_accuracy: 0.5537 - val_loss: 0.2673
# Epoch 101/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5964 - loss: 0.2510 - val_accuracy: 0.5480 - val_loss: 0.2671
# Epoch 102/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5856 - loss: 0.2530 - val_accuracy: 0.5508 - val_loss: 0.2668
# Epoch 103/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5911 - loss: 0.2487 - val_accuracy: 0.5621 - val_loss: 0.2669
# Epoch 104/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5894 - loss: 0.2469 - val_accuracy: 0.5621 - val_loss: 0.2669
# Epoch 105/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5960 - loss: 0.2431 - val_accuracy: 0.5621 - val_loss: 0.2671
# Epoch 106/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5931 - loss: 0.2434 - val_accuracy: 0.5565 - val_loss: 0.2674
# Epoch 107/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5956 - loss: 0.2441 - val_accuracy: 0.5537 - val_loss: 0.2668
# Epoch 108/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5961 - loss: 0.2471 - val_accuracy: 0.5650 - val_loss: 0.2668
# Epoch 109/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6028 - loss: 0.2365 - val_accuracy: 0.5565 - val_loss: 0.2670
# Epoch 110/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6234 - loss: 0.2366 - val_accuracy: 0.5311 - val_loss: 0.2697
# Epoch 111/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6264 - loss: 0.2321 - val_accuracy: 0.5424 - val_loss: 0.2690
# Epoch 112/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6247 - loss: 0.2362 - val_accuracy: 0.5480 - val_loss: 0.2686
# Epoch 113/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6220 - loss: 0.2338 - val_accuracy: 0.5452 - val_loss: 0.2701
# Epoch 114/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6203 - loss: 0.2344 - val_accuracy: 0.5395 - val_loss: 0.2712
# Epoch 115/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6321 - loss: 0.2284 - val_accuracy: 0.5537 - val_loss: 0.2713
# Epoch 116/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6273 - loss: 0.2318 - val_accuracy: 0.5395 - val_loss: 0.2712
# Epoch 117/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6370 - loss: 0.2270 - val_accuracy: 0.5367 - val_loss: 0.2729
# Epoch 118/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6400 - loss: 0.2286 - val_accuracy: 0.5311 - val_loss: 0.2735
# Epoch 119/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6387 - loss: 0.2259 - val_accuracy: 0.5311 - val_loss: 0.2739
# Epoch 120/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6516 - loss: 0.2215 - val_accuracy: 0.5367 - val_loss: 0.2739
# Epoch 121/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6332 - loss: 0.2266 - val_accuracy: 0.5339 - val_loss: 0.2743
# Epoch 122/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6590 - loss: 0.2180 - val_accuracy: 0.5282 - val_loss: 0.2766
# Epoch 123/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6486 - loss: 0.2216 - val_accuracy: 0.5508 - val_loss: 0.2777
# Epoch 124/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6689 - loss: 0.2126 - val_accuracy: 0.5311 - val_loss: 0.2790
# Epoch 125/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6697 - loss: 0.2136 - val_accuracy: 0.5424 - val_loss: 0.2778
# Epoch 126/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6636 - loss: 0.2131 - val_accuracy: 0.5395 - val_loss: 0.2824
# Epoch 127/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6757 - loss: 0.2069 - val_accuracy: 0.5508 - val_loss: 0.2812
# Epoch 128/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6794 - loss: 0.2052 - val_accuracy: 0.5508 - val_loss: 0.2818
# Epoch 129/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6883 - loss: 0.2064 - val_accuracy: 0.5508 - val_loss: 0.2828
# Epoch 130/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6838 - loss: 0.2044 - val_accuracy: 0.5593 - val_loss: 0.2843
# Epoch 131/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6829 - loss: 0.2027 - val_accuracy: 0.5593 - val_loss: 0.2839
# Epoch 132/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6855 - loss: 0.2030 - val_accuracy: 0.5452 - val_loss: 0.2864
# Epoch 133/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6927 - loss: 0.2000 - val_accuracy: 0.5508 - val_loss: 0.2860
# Epoch 134/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6892 - loss: 0.2004 - val_accuracy: 0.5537 - val_loss: 0.2885
# Epoch 135/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6989 - loss: 0.1949 - val_accuracy: 0.5593 - val_loss: 0.2924
# Epoch 136/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7024 - loss: 0.1940 - val_accuracy: 0.5537 - val_loss: 0.2933
# Epoch 137/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6960 - loss: 0.1945 - val_accuracy: 0.5621 - val_loss: 0.2918
# Epoch 138/500
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7049 - loss: 0.1903 - val_accuracy: 0.5424 - val_loss: 0.2939
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %%
y_pred_all = np.array(y_pred_all)
y_test_all = np.array(y_test_all)

y_pred_mean = np.mean(y_pred_all, axis=0)  
y_pred_median = np.median(y_pred_all, axis=0)  

y_test_representative = y_test_all[0]

# %%
import matplotlib.pyplot as plt
from utils import plot_classification_performance

# %%
# Plot using the averaged predictions
f, axs = plt.subplots(8, 3, figsize=(12, 3 * 8))

# Plot individual fold results using MEAN predictions
for i in range(7):
    plot_classification_performance(
        axs[i, :],
        y_true[y_test_representative[:, i]],
        y_pred_mean[y_test_representative[:, i], :],
        history_all[0][i],  # Use history from first repeat
        class_names=list(loader.label_map.keys())
    )

# Plot overall results
plot_classification_performance(
    axs[-1, :],
    y_true,
    y_pred_mean,  # Use averaged predictions
    class_names=list(loader.label_map.keys())
)

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
from sklearn.metrics import roc_auc_score

# Compute AUC scores for each repeat and each fold individually
num_repeats = y_pred_all.shape[0]  # 50 repeats
n_classes = y_pred_all.shape[-1]   # 10 antigens
n_folds = y_test_all.shape[2]      # 7 folds

auc_scores = []  # will collect all individual AUC scores
antigen_names = list(loader.label_map.keys())

print(f"Computing AUC scores for {num_repeats} repeats × {n_folds} folds × {n_classes} classes...")

for repeat in range(num_repeats):
    for fold in range(n_folds):
        # Get test indices for this fold
        test_indices = y_test_all[repeat, :, fold]
        
        for class_idx in range(n_classes):
            # Create binary labels: 1 if sample belongs to this antigen and 0 otherwise
            y_true_binary = (y_true[test_indices] == class_idx).astype(int)
            y_pred_probs = y_pred_all[repeat, test_indices, class_idx]
            
            try:
                auc_val = roc_auc_score(y_true_binary, y_pred_probs)
            except Exception as e:
                print(f"Error computing roc_auc_score for antigen {class_idx}, repeat {repeat}, fold {fold}: {e}")
                auc_val = np.nan
            
            auc_scores.append({
                'Antigen': antigen_names[class_idx],
                'AUC': auc_val,
                'Method': 'Sup-Seq-VDJ',
                'Repeat': repeat,
                'Fold': fold
            })

plot_df = pd.DataFrame(auc_scores)

# Remove any NaN values
plot_df = plot_df.dropna(subset=['AUC'])

print(f"Total AUC scores collected: {len(plot_df)}")
print(f"Expected: {num_repeats * n_folds * n_classes} (50 × 7 × 10)")
print(f"AUC scores per antigen: {len(plot_df) // n_classes}")

# Create the violin plot using all individual fold AUC scores
plt.figure(figsize=(12, 6))
ax = sns.violinplot(
    data=plot_df, 
    x="Antigen", 
    y="AUC", 
    hue="Method", 
    inner="box", 
    palette=["orange"],  # Set to orange
    scale="area"  # Makes the violins thinner
)
plt.xticks(rotation=45)
plt.ylim(0.50, 1.00)
plt.yticks(np.arange(0.50, 1.05, 0.05))  
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.title("Antigen Classification Performance (All CV Folds)")
plt.ylabel("AUC")
plt.xlabel("Antigen")
plt.legend(title="Method", loc="center left", bbox_to_anchor=(1, 0.5))  # Move legend to the right
plt.tight_layout()
plt.show()

# Print summary statistics per antigen
print("\nSummary statistics per antigen:")
summary_stats = plot_df.groupby('Antigen')['AUC'].agg(['mean', 'std', 'min', 'max', 'count'])
print(summary_stats)
# Out:
# Computing AUC scores for 1 repeats × 7 folds × 7 classes...
# Total AUC scores collected: 49
# Expected: 49 (50 × 7 × 10)
# AUC scores per antigen: 7
# C:\Users\huang\AppData\Local\Temp\ipykernel_57096\3034920285.py:49: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='area'` for the same effect.
#   ax = sns.violinplot(
# Summary statistics per antigen:
#                 mean       std       min       max  count
# Antigen
# CTELKLSDY   0.579391  0.181016  0.281102  0.808571      7
# GILGFVFTL   0.759122  0.029688  0.711294  0.796062      7
# GLCTLVAML   0.767152  0.024977  0.718741  0.795639      7
# LPRRSGAAGA  0.708024  0.026159  0.664436  0.740844      7
# NLVPMVATV   0.896620  0.041525  0.837830  0.950505      7
# TPRVTGGGAM  0.851959  0.021792  0.828986  0.893720      7
# VTEHDTLLY   0.771133  0.036626  0.711111  0.807545      7
