# %%
from glob import glob
import pandas as pd
import os
import numpy as np
import tensorflow as tf
import keras

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from glob import glob
import os

class TCRDataLoader:
    def __init__(self, data_dir):
        self.data_dir = data_dir
        self.aa_dict = None
        self.v_dict = None
        self.j_dict = None
        self.label_map = None
        self.max_length = None
        
    def combine_columns(self, df, column_variants, new_column_name):
        """Combine multiple columns that represent the same data type"""
        combined_series = pd.Series([None] * len(df), index=df.index)
        
        for variant in column_variants:
            if variant in df.columns:
                # Fill in non-null values from this column
                mask = df[variant].notna() & combined_series.isna()
                combined_series[mask] = df[variant][mask]
                print(f"  Added {mask.sum()} values from '{variant}' column")
        
        return combined_series
    
    def load_files(self):
        df_list = []
        files = glob(self.data_dir + "/*/*.tsv")
        
        for file_path in files:
            df = pd.read_csv(file_path, sep='\t')
            
            # Extract folder name from file path
            folder_name = os.path.basename(os.path.dirname(file_path))
            
            # Split folder name to get Antigen
            parts = folder_name.split('-')
            antigen = parts[-1]  # Get last part (the antigen)
            
            # Add antigen column to dataframe
            df['Antigen'] = antigen
            
            df_list.append(df)
        
        combined_df = pd.concat(df_list, ignore_index=True)
        
        # Define column candidates for each data type
        column_variants = {
            'sequence': ['aminoAcid', 'beta', 'Amino', 'sequence', 'cdr3', 'CDR3'],
            'v_gene': ['v_beta', 'vGeneName', 'v_gene', 'V_gene', 'TRBV'],
            'j_gene': ['j_beta', 'jGeneName', 'j_gene', 'J_gene', 'TRBJ'],
            'counts': ['counts', 'count', 'count (templates/reads)', 'templates', 'reads', 'frequency']
        }
        
        print("Combining columns:")
        # Combine columns for each data type
        for standard_name, variants in column_variants.items():
            print(f"\nCombining {standard_name} columns:")
            combined_series = self.combine_columns(combined_df, variants, standard_name)
            combined_df[f'combined_{standard_name}'] = combined_series
            
            # Show statistics
            total_values = combined_series.notna().sum()
            print(f"  Total combined values: {total_values}")
        
        return combined_df
    
    def build_vocabulary(self, df):
        # Use combined columns
        # Amino acids
        all_sequences = df['combined_sequence'].dropna()
        if len(all_sequences) == 0:
            raise ValueError("No sequence data found in combined columns!")
            
        giant_string = ''.join(all_sequences)
        unique_letters = sorted(set(giant_string))
        self.aa_dict = {}
        for i, letter in enumerate(unique_letters):
            self.aa_dict[letter] = i+1
        
        # V genes
        v_genes = df['combined_v_gene'].dropna().unique()
        v_genes = sorted(v_genes)
        self.v_dict = {}
        for i, gene in enumerate(v_genes):
            self.v_dict[gene] = i + 1

        # J genes
        j_genes = df['combined_j_gene'].dropna().unique()
        j_genes = sorted(j_genes)
        self.j_dict = {}
        for i, gene in enumerate(j_genes):
            self.j_dict[gene] = i + 1

        # Labels
        antigens = df['Antigen'].unique()
        self.label_map = {}
        for i, antigen in enumerate(sorted(antigens)):
            self.label_map[antigen] = i

        # Max length
        sequence_lengths = [len(seq) for seq in df['combined_sequence'].dropna()]
        self.max_length = max(sequence_lengths) if sequence_lengths else 0
        
        print(f"\nVocabulary built:")
        print(f"  Amino acids: {len(self.aa_dict)} unique")
        print(f"  V genes: {len(self.v_dict)} unique")
        print(f"  J genes: {len(self.j_dict)} unique")
        print(f"  Max sequence length: {self.max_length}")
    
    def encode_sequences(self, sequences):
        encoded_aa = []
        for sequence in sequences:
            sequence_numbers = []
            for letter in sequence:
                number = self.aa_dict.get(letter, 0)
                sequence_numbers.append(number)
            # Add padding zeros if sequence is shorter than max_length
            while len(sequence_numbers) < self.max_length:
                sequence_numbers.append(0)
            encoded_aa.append(sequence_numbers)
        return encoded_aa
    
    def encode_v_genes(self, v_genes):
        encoded_v = []
        for v_gene in v_genes:
            encoded_v.append(self.v_dict.get(v_gene, 0))
        return encoded_v
    
    def encode_j_genes(self, j_genes):
        encoded_j = []
        for j_gene in j_genes:
            encoded_j.append(self.j_dict.get(j_gene, 0))
        return encoded_j
    
    def load_and_encode_data(self, batch_size=100, shuffle=True):
        # 1. Load files and combine columns
        df = self.load_files()
        
        # 2. Build vocabularies
        self.build_vocabulary(df)
        
        # 3. Filter out rows with missing amino acid sequences
        valid_rows = df['combined_sequence'].notna()
        df_valid = df[valid_rows].copy()
        
        print(f"Valid data: {len(df_valid)} out of {len(df)} total rows")
        
        # 4. Get the data you want to encode (now all valid)
        sequences = df_valid['combined_sequence'].values
        v_genes = df_valid['combined_v_gene'].fillna('UNK').values
        j_genes = df_valid['combined_j_gene'].fillna('UNK').values
        labels = [self.label_map[antigen] for antigen in df_valid['Antigen']]
        
        # 5. Encode everything
        X_sequences = self.encode_sequences(sequences)
        X_v_genes = self.encode_v_genes(v_genes)
        X_j_genes = self.encode_j_genes(j_genes)
        
        # 6. Convert to numpy arrays
        X_sequences = np.array(X_sequences)
        X_v_genes = np.array(X_v_genes)
        X_j_genes = np.array(X_j_genes)
        y_labels = np.array(labels)
        
        # 7. Create TensorFlow dataset
        dataset = tf.data.Dataset.from_tensor_slices((
            {'cdr3_sequence': X_sequences, 'v_gene': X_v_genes, 'j_gene': X_j_genes,},
            {'labels': y_labels}
        ))
            
        # Map to the format expected by the model
        dataset = dataset.map(lambda X, y: (X, {'labels': tf.one_hot(y['labels'], len(self.label_map))}))
            
        if shuffle:
            dataset = dataset.shuffle(len(X_sequences), reshuffle_each_iteration=True)
        
        dataset = dataset.batch(batch_size, drop_remainder=True)
        dataset = dataset.prefetch(tf.data.AUTOTUNE)
        
        return dataset
    
    def get_vocab_sizes(self):
        """Return vocabulary sizes for model construction"""
        return {
            'aa_vocab_size': len(self.aa_dict) + 1,  # +1 for padding
            'v_vocab_size': len(self.v_dict) + 1,    # +1 for unknown
            'j_vocab_size': len(self.j_dict) + 1,    # +1 for unknown
            'num_classes': len(self.label_map),
            'max_length': self.max_length
        }
    
    def get_mappings(self):
        """Return the created mappings for inspection"""
        return {
            'aa_dict': self.aa_dict,
            'v_dict': self.v_dict,
            'j_dict': self.j_dict,
            'label_map': self.label_map
        }

# %%
def create_tcr_model(vocab_sizes):
    """Create a model using the Conv1D architecture from the reference"""
    # Input layers
    cdr3_input = keras.Input(shape=(vocab_sizes['max_length'],), dtype=tf.uint32, name='cdr3_sequence')
    
    # CDR3 sequence encoder (following the reference structure)
    cdr3_embed = keras.layers.Embedding(
        input_dim=vocab_sizes['aa_vocab_size'], 
        output_dim=8, 
        mask_zero=True
    )(cdr3_input)
    
    convs = [keras.layers.Conv1D(
        filters=16, 
        kernel_size=9, 
        strides=1, 
        activation=keras.activations.relu,
        padding='valid'
    )(cdr3_embed)]
    
    convs.append(keras.layers.Conv1D(
        filters=32, 
        kernel_size=7, 
        strides=2, 
        activation=keras.activations.relu,
        padding='valid'
    )(convs[-1]))
    
    # convs.append(keras.layers.Conv1D(
    #     filters=256, 
    #     kernel_size=5, 
    #     strides=1, 
    #     activation=None,
    #     padding='valid'
    # )(convs[-1]))
    
    # Take the first position output (like in reference: [:, 0, :])
    # cdr3_encoded = convs[-1][:, 0, :]

    # pooling to gain positional equivariance
    cdr3_encoded = keras.layers.GlobalMaxPooling1D()(convs[-1])
    
    # Gene embeddings
    
    # Flatten gene embeddings
    # v_flat = tf.keras.layers.Flatten()(v_embed)
    # j_flat = tf.keras.layers.Flatten()(j_embed)
    
    # Concatenate all features
    fused = keras.layers.Concatenate(axis=-1)([cdr3_encoded])
    
    # Classifier (following reference structure)
    dropout1 = keras.layers.Dropout(rate=0.1)(fused)
    dense1 = keras.layers.Dense(units=32, activation=keras.activations.relu)(dropout1)
    dropout2 = keras.layers.Dropout(rate=0.05)(dense1)
    dense2 = keras.layers.Dense(units=16, activation=keras.activations.relu)(dropout2)
    # output = tf.keras.layers.Dense(units=vocab_sizes['num_classes'], activation='softmax')(dense2)
    output = keras.layers.Dense(units=vocab_sizes['num_classes'], activation='sigmoid')(dense2)

    model = keras.Model(
        inputs=[cdr3_input],
        outputs=output
    )
    
    return model

# %%
# Initialize loader
data_dir = './DeepTCR/Data/Murine_Antigens'
loader = TCRDataLoader(data_dir)

# Load data
print("Loading data...")
dataset = loader.load_and_encode_data(batch_size=100, shuffle=True)
print("Data loaded successfully!")
# Out:
# Loading data...
# Combining columns:
#
# Combining sequence columns:
#   Added 1753 values from 'aminoAcid' column
#   Added 1924 values from 'beta' column
#   Total combined values: 3677
#
# Combining v_gene columns:
#   Added 1924 values from 'v_beta' column
#   Added 3678 values from 'vGeneName' column
#   Total combined values: 5602
#
# Combining j_gene columns:
#   Added 1924 values from 'j_beta' column
#   Added 3670 values from 'jGeneName' column
#   Total combined values: 5594
#
# Combining counts columns:
#   Added 1924 values from 'counts' column
#   Added 3679 values from 'count (templates/reads)' column
#   Total combined values: 5603
#
# Vocabulary built:
#   Amino acids: 21 unique
#   V genes: 42 unique
#   J genes: 14 unique
#   Max sequence length: 19
# Valid data: 3677 out of 5603 total rows
# Data loaded successfully!

# %%
loader.v_dict
# Out:
# {'TCRBV01-01': 1,
#  'TCRBV02-01': 2,
#  'TCRBV03-01': 3,
#  'TCRBV04-01': 4,
#  'TCRBV05-01': 5,
#  'TCRBV05-04': 6,
#  'TCRBV06-01': 7,
#  'TCRBV07-01': 8,
#  'TCRBV08-01': 9,
#  'TCRBV09-01': 10,
#  'TCRBV10-01': 11,
#  'TCRBV11-01': 12,
#  'TCRBV12-01': 13,
#  'TCRBV12-02': 14,
#  'TCRBV12-03': 15,
#  'TCRBV13-01': 16,
#  'TCRBV13-02': 17,
#  'TCRBV13-03': 18,
#  'TCRBV13-04': 19,
#  'TCRBV14-01': 20,
#  'TCRBV15-01': 21,
#  'TCRBV16-01': 22,
#  'TCRBV17-01': 23,
#  'TCRBV18-01': 24,
#  'TCRBV19-01': 25,
#  'TCRBV19-03': 26,
#  'TCRBV20-01': 27,
#  'TCRBV20-02': 28,
#  'TCRBV21-01': 29,
#  'TCRBV22-01': 30,
#  'TCRBV23-01': 31,
#  'TCRBV24-01': 32,
#  'TCRBV24-02': 33,
#  'TCRBV25-01': 34,
#  'TCRBV26-01': 35,
#  'TCRBV27-01': 36,
#  'TCRBV28-01': 37,
#  'TCRBV29-01': 38,
#  'TCRBV29-02': 39,
#  'TCRBV30-01': 40,
#  'TCRBV31-01': 41,
#  'TCRBV31-02': 42}

# %%
# Initialize loader
#data_dir = './DeepTCR/Data/Human_Antigens'
#loader = TCRDataLoader(data_dir)

# Load data
#print("Loading data...")
#dataset = loader.load_and_encode_data(batch_size=100, shuffle=True)
#print("Data loaded successfully!")

# %%
# Create model
vocab_sizes = loader.get_vocab_sizes()
print("Creating model...")
model = create_tcr_model(vocab_sizes)

# Compile model
model.compile(
    optimizer='adam', 
    # loss='categorical_crossentropy',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Display model summary
model.summary()
# Out:
# Creating model...
# c:\Users\huang\miniconda3\envs\gpu-ml-base\Lib\site-packages\keras\src\layers\layer.py:932: UserWarning: Layer 'conv1d_2' (of type Conv1D) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ cdr3_sequence (InputLayer)      │ (None, 19)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ embedding_1 (Embedding)         │ (None, 19, 8)          │           176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 11, 16)         │         1,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 3, 32)          │         3,616 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling1d_1          │ (None, 32)             │             0 │
# │ (GlobalMaxPooling1D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ concatenate_1 (Concatenate)     │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 9)              │           153 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,697 (26.16 KB)
#  Trainable params: 6,697 (26.16 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Updated data preparation using combined columns
df = loader.load_files()
df['Antigen'] = df['Antigen'].astype('category')
loader.build_vocabulary(df)

# Filter valid data using combined columns
valid_rows = df['combined_sequence'].notna()
df_valid = df[valid_rows].copy()

print(f"Valid sequences: {len(df_valid)} out of {len(df)} total")

# Encode data using combined columns
sequences = df_valid['combined_sequence'].values
counts = df_valid['combined_counts'].fillna(1).values  

labels = [loader.label_map[antigen] for antigen in df_valid['Antigen']]

X_sequences = loader.encode_sequences(sequences)

# Convert to numpy
X_sequences = np.array(X_sequences)

# Set up data for cross-validation
X = [
    np.array(X_sequences, dtype=np.int32),
]
y_true = np.array(df_valid['Antigen'].cat.codes.values, dtype=np.int32)

print(f"Final data shapes:")
print(f"  X[0] (sequences): {X[0].shape}")
print(f"  y_true: {y_true.shape}")
# Out:
# Combining columns:
#
# Combining sequence columns:
#   Added 1753 values from 'aminoAcid' column
#   Added 1924 values from 'beta' column
#   Total combined values: 3677
#
# Combining v_gene columns:
#   Added 1924 values from 'v_beta' column
#   Added 3678 values from 'vGeneName' column
#   Total combined values: 5602
#
# Combining j_gene columns:
#   Added 1924 values from 'j_beta' column
#   Added 3670 values from 'jGeneName' column
#   Total combined values: 5594
#
# Combining counts columns:
#   Added 1924 values from 'counts' column
#   Added 3679 values from 'count (templates/reads)' column
#   Total combined values: 5603
#
# Vocabulary built:
#   Amino acids: 21 unique
#   V genes: 42 unique
#   J genes: 14 unique
#   Max sequence length: 19
# Valid sequences: 3677 out of 5603 total
# Final data shapes:
#   X[0] (sequences): (3677, 19)
#   y_true: (3677,)
# C:\Users\huang\AppData\Local\Temp\ipykernel_10508\3337133004.py:14: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   counts = df_valid['combined_counts'].fillna(1).values

# %%
np.unique(df['aminoAcid'].astype('category').cat.codes.values)
# Out:
# array([  -1,    0,    1, ..., 1307, 1308, 1309],
#       shape=(1311,), dtype=int16)

# %%
from utils import KerasCrossValidation

# %%
df_valid
# Out:
#                  beta  counts      v_beta      j_beta Antigen  \
# 0       CASRTGATGQLYF     1.0  TCRBV19-03  TCRBJ02-02      F2
# 1     CASRPDISYNSPLYF     1.0  TCRBV19-03  TCRBJ01-06      F2
# 2        CAIGSNQDTQYF     1.0  TCRBV14-01  TCRBJ02-05      F2
# 3        CASSIGQDEQYF     1.0  TCRBV19-01  TCRBJ02-07      F2
# 4      CASSLFQIQDTQYF     1.0  TCRBV29-01  TCRBJ02-05      F2
# ...               ...     ...         ...         ...     ...
# 5595              NaN     NaN         NaN         NaN    TRP2
# 5597              NaN     NaN         NaN         NaN    TRP2
# 5600              NaN     NaN         NaN         NaN    TRP2
# 5601              NaN     NaN         NaN         NaN    TRP2
# 5602              NaN     NaN         NaN         NaN    TRP2
#
#             aminoAcid  count (templates/reads)   vGeneName   jGeneName  \
# 0                 NaN                      NaN         NaN         NaN
# 1                 NaN                      NaN         NaN         NaN
# 2                 NaN                      NaN         NaN         NaN
# 3                 NaN                      NaN         NaN         NaN
# 4                 NaN                      NaN         NaN         NaN
# ...               ...                      ...         ...         ...
# 5595   CTCSAGWGVYEQYF                      1.0  TCRBV01-01  TCRBJ02-07
# 5597    RSRSIWANTEVFF                      1.0  TCRBV20-01  TCRBJ01-01
# 5600   GCGLGEGTNTEVFF                      1.0  TCRBV18-01  TCRBJ01-01
# 5601   VVQHGDSPNTEVFF                      1.0  TCRBV08-01  TCRBJ01-01
# 5602  RSIAHDTISNERLFF                      1.0  TCRBV15-01  TCRBJ01-04
#
#      combined_sequence combined_v_gene combined_j_gene combined_counts
# 0        CASRTGATGQLYF      TCRBV19-03      TCRBJ02-02             1.0
# 1      CASRPDISYNSPLYF      TCRBV19-03      TCRBJ01-06             1.0
# 2         CAIGSNQDTQYF      TCRBV14-01      TCRBJ02-05             1.0
# 3         CASSIGQDEQYF      TCRBV19-01      TCRBJ02-07             1.0
# 4       CASSLFQIQDTQYF      TCRBV29-01      TCRBJ02-05             1.0
# ...                ...             ...             ...             ...
# 5595    CTCSAGWGVYEQYF      TCRBV01-01      TCRBJ02-07             1.0
# 5597     RSRSIWANTEVFF      TCRBV20-01      TCRBJ01-01             1.0
# 5600    GCGLGEGTNTEVFF      TCRBV18-01      TCRBJ01-01             1.0
# 5601    VVQHGDSPNTEVFF      TCRBV08-01      TCRBJ01-01             1.0
# 5602   RSIAHDTISNERLFF      TCRBV15-01      TCRBJ01-04             1.0
#
# [3677 rows x 13 columns]

# %%
df_valid['combined_sequence']
# Out:
# 0         CASRTGATGQLYF
# 1       CASRPDISYNSPLYF
# 2          CAIGSNQDTQYF
# 3          CASSIGQDEQYF
# 4        CASSLFQIQDTQYF
#              ...
# 5595     CTCSAGWGVYEQYF
# 5597      RSRSIWANTEVFF
# 5600     GCGLGEGTNTEVFF
# 5601     VVQHGDSPNTEVFF
# 5602    RSIAHDTISNERLFF
# Name: combined_sequence, Length: 3677, dtype: object

# %%
df_valid['combined_v_gene']
# Out:
# 0       TCRBV19-03
# 1       TCRBV19-03
# 2       TCRBV14-01
# 3       TCRBV19-01
# 4       TCRBV29-01
#            ...
# 5595    TCRBV01-01
# 5597    TCRBV20-01
# 5600    TCRBV18-01
# 5601    TCRBV08-01
# 5602    TCRBV15-01
# Name: combined_v_gene, Length: 3677, dtype: object

# %%
df_valid['combined_j_gene']
# Out:
# 0       TCRBJ02-02
# 1       TCRBJ01-06
# 2       TCRBJ02-05
# 3       TCRBJ02-07
# 4       TCRBJ02-05
#            ...
# 5595    TCRBJ02-07
# 5597    TCRBJ01-01
# 5600    TCRBJ01-01
# 5601    TCRBJ01-01
# 5602    TCRBJ01-04
# Name: combined_j_gene, Length: 3677, dtype: object

# %%
# set data
X = [
        np.array(X_sequences, dtype=np.int32),
    ]
y_true = np.array(y_true, dtype=np.int32)

# %%
from utils import KerasCrossValidation

# %%
# run cross-validation
keras_cv = KerasCrossValidation(X=X, y=y_true, keras_model=model, save_filepath='./samlogs/fit-01')
y_pred, y_test, history = keras_cv(n_splits=7, batch_size=500, min_epochs=5, patience=30, max_epochs=500, training_repeat=2)
# Out:
# Epoch 1/500
# c:\Users\huang\miniconda3\envs\gpu-ml-base\Lib\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['cdr3_sequence']. Received: the structure of inputs=('*',)
#   warnings.warn(
# c:\Users\huang\miniconda3\envs\gpu-ml-base\Lib\site-packages\keras\src\layers\layer.py:932: UserWarning: Layer 'conv1d_2' (of type Conv1D) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.2045 - loss: 0.6864 - val_accuracy: 0.1749 - val_loss: 0.6487
# Epoch 2/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1906 - loss: 0.6181 - val_accuracy: 0.2034 - val_loss: 0.4850
# Epoch 3/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2009 - loss: 0.4577 - val_accuracy: 0.1654 - val_loss: 0.3753
# Epoch 4/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2641 - loss: 0.3753 - val_accuracy: 0.3289 - val_loss: 0.3315
# Epoch 5/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3259 - loss: 0.3397 - val_accuracy: 0.3289 - val_loss: 0.3173
# Epoch 6/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3148 - loss: 0.3259 - val_accuracy: 0.3289 - val_loss: 0.3084
# Epoch 7/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3260 - loss: 0.3172 - val_accuracy: 0.3289 - val_loss: 0.3024
# Epoch 8/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3468 - loss: 0.3101 - val_accuracy: 0.4183 - val_loss: 0.2956
# Epoch 9/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3677 - loss: 0.3052 - val_accuracy: 0.4202 - val_loss: 0.2882
# Epoch 10/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3972 - loss: 0.2965 - val_accuracy: 0.4278 - val_loss: 0.2792
# Epoch 11/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4174 - loss: 0.2885 - val_accuracy: 0.4335 - val_loss: 0.2709
# Epoch 12/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4344 - loss: 0.2801 - val_accuracy: 0.4373 - val_loss: 0.2638
# Epoch 13/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4399 - loss: 0.2730 - val_accuracy: 0.4449 - val_loss: 0.2568
# Epoch 14/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4602 - loss: 0.2641 - val_accuracy: 0.5019 - val_loss: 0.2510
# Epoch 15/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4754 - loss: 0.2605 - val_accuracy: 0.5095 - val_loss: 0.2456
# Epoch 16/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4863 - loss: 0.2537 - val_accuracy: 0.5133 - val_loss: 0.2406
# Epoch 17/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5030 - loss: 0.2457 - val_accuracy: 0.5095 - val_loss: 0.2353
# Epoch 18/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5135 - loss: 0.2426 - val_accuracy: 0.5152 - val_loss: 0.2302
# Epoch 19/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5119 - loss: 0.2381 - val_accuracy: 0.5342 - val_loss: 0.2242
# Epoch 20/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5414 - loss: 0.2306 - val_accuracy: 0.5532 - val_loss: 0.2192
# Epoch 21/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5501 - loss: 0.2256 - val_accuracy: 0.5856 - val_loss: 0.2144
# Epoch 22/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5702 - loss: 0.2207 - val_accuracy: 0.5970 - val_loss: 0.2109
# Epoch 23/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5807 - loss: 0.2156 - val_accuracy: 0.6103 - val_loss: 0.2074
# Epoch 24/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5960 - loss: 0.2141 - val_accuracy: 0.6141 - val_loss: 0.2047
# Epoch 25/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6124 - loss: 0.2064 - val_accuracy: 0.6160 - val_loss: 0.2024
# Epoch 26/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6094 - loss: 0.2035 - val_accuracy: 0.6122 - val_loss: 0.2003
# Epoch 27/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6118 - loss: 0.2020 - val_accuracy: 0.6236 - val_loss: 0.1984
# Epoch 28/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6237 - loss: 0.2009 - val_accuracy: 0.6217 - val_loss: 0.1961
# Epoch 29/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6298 - loss: 0.1944 - val_accuracy: 0.6255 - val_loss: 0.1946
# Epoch 30/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6414 - loss: 0.1926 - val_accuracy: 0.6255 - val_loss: 0.1933
# Epoch 31/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6337 - loss: 0.1922 - val_accuracy: 0.6255 - val_loss: 0.1925
# Epoch 32/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6412 - loss: 0.1889 - val_accuracy: 0.6312 - val_loss: 0.1909
# Epoch 33/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6469 - loss: 0.1847 - val_accuracy: 0.6369 - val_loss: 0.1895
# Epoch 34/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6573 - loss: 0.1821 - val_accuracy: 0.6388 - val_loss: 0.1895
# Epoch 35/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6558 - loss: 0.1822 - val_accuracy: 0.6312 - val_loss: 0.1883
# Epoch 36/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6659 - loss: 0.1780 - val_accuracy: 0.6312 - val_loss: 0.1874
# Epoch 37/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6601 - loss: 0.1774 - val_accuracy: 0.6426 - val_loss: 0.1863
# Epoch 38/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6764 - loss: 0.1731 - val_accuracy: 0.6388 - val_loss: 0.1864
# Epoch 39/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6680 - loss: 0.1738 - val_accuracy: 0.6407 - val_loss: 0.1860
# Epoch 40/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6643 - loss: 0.1740 - val_accuracy: 0.6407 - val_loss: 0.1858
# Epoch 41/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6759 - loss: 0.1702 - val_accuracy: 0.6445 - val_loss: 0.1856
# Epoch 42/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6740 - loss: 0.1693 - val_accuracy: 0.6483 - val_loss: 0.1848
# Epoch 43/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6898 - loss: 0.1661 - val_accuracy: 0.6483 - val_loss: 0.1844
# Epoch 44/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6807 - loss: 0.1660 - val_accuracy: 0.6483 - val_loss: 0.1839
# Epoch 45/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6879 - loss: 0.1641 - val_accuracy: 0.6483 - val_loss: 0.1837
# Epoch 46/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6944 - loss: 0.1630 - val_accuracy: 0.6578 - val_loss: 0.1832
# Epoch 47/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6938 - loss: 0.1628 - val_accuracy: 0.6540 - val_loss: 0.1834
# Epoch 48/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6994 - loss: 0.1585 - val_accuracy: 0.6559 - val_loss: 0.1828
# Epoch 49/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7033 - loss: 0.1576 - val_accuracy: 0.6559 - val_loss: 0.1832
# Epoch 50/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6999 - loss: 0.1561 - val_accuracy: 0.6578 - val_loss: 0.1824
# Epoch 51/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7046 - loss: 0.1574 - val_accuracy: 0.6502 - val_loss: 0.1828
# Epoch 52/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7086 - loss: 0.1535 - val_accuracy: 0.6540 - val_loss: 0.1830
# Epoch 53/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7109 - loss: 0.1513 - val_accuracy: 0.6559 - val_loss: 0.1824
# Epoch 54/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7037 - loss: 0.1547 - val_accuracy: 0.6521 - val_loss: 0.1820
# Epoch 55/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7143 - loss: 0.1513 - val_accuracy: 0.6464 - val_loss: 0.1832
# Epoch 56/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7131 - loss: 0.1522 - val_accuracy: 0.6483 - val_loss: 0.1820
# Epoch 57/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7221 - loss: 0.1480 - val_accuracy: 0.6502 - val_loss: 0.1822
# Epoch 58/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7198 - loss: 0.1489 - val_accuracy: 0.6445 - val_loss: 0.1823
# Epoch 59/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7258 - loss: 0.1468 - val_accuracy: 0.6597 - val_loss: 0.1821
# Epoch 60/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7252 - loss: 0.1453 - val_accuracy: 0.6597 - val_loss: 0.1824
# Epoch 61/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7223 - loss: 0.1487 - val_accuracy: 0.6521 - val_loss: 0.1826
# Epoch 62/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7372 - loss: 0.1428 - val_accuracy: 0.6445 - val_loss: 0.1821
# Epoch 63/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7459 - loss: 0.1398 - val_accuracy: 0.6483 - val_loss: 0.1827
# Epoch 64/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7479 - loss: 0.1390 - val_accuracy: 0.6426 - val_loss: 0.1835
# Epoch 65/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7501 - loss: 0.1378 - val_accuracy: 0.6540 - val_loss: 0.1819
# Epoch 66/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7508 - loss: 0.1379 - val_accuracy: 0.6540 - val_loss: 0.1827
# Epoch 67/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7517 - loss: 0.1362 - val_accuracy: 0.6597 - val_loss: 0.1823
# Epoch 68/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7481 - loss: 0.1364 - val_accuracy: 0.6502 - val_loss: 0.1833
# Epoch 69/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7554 - loss: 0.1344 - val_accuracy: 0.6559 - val_loss: 0.1842
# Epoch 70/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7632 - loss: 0.1308 - val_accuracy: 0.6597 - val_loss: 0.1833
# Epoch 71/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7607 - loss: 0.1314 - val_accuracy: 0.6502 - val_loss: 0.1846
# Epoch 72/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7618 - loss: 0.1313 - val_accuracy: 0.6502 - val_loss: 0.1834
# Epoch 73/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7709 - loss: 0.1295 - val_accuracy: 0.6559 - val_loss: 0.1846
# Epoch 74/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7780 - loss: 0.1290 - val_accuracy: 0.6578 - val_loss: 0.1840
# Epoch 75/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7738 - loss: 0.1262 - val_accuracy: 0.6635 - val_loss: 0.1876
# Epoch 76/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7671 - loss: 0.1279 - val_accuracy: 0.6692 - val_loss: 0.1874
# Epoch 77/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7697 - loss: 0.1260 - val_accuracy: 0.6578 - val_loss: 0.1881
# Epoch 78/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7787 - loss: 0.1217 - val_accuracy: 0.6654 - val_loss: 0.1874
# Epoch 79/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7839 - loss: 0.1235 - val_accuracy: 0.6616 - val_loss: 0.1863
# Epoch 80/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7834 - loss: 0.1220 - val_accuracy: 0.6654 - val_loss: 0.1867
# Epoch 81/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7797 - loss: 0.1221 - val_accuracy: 0.6730 - val_loss: 0.1869
# Epoch 82/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7824 - loss: 0.1233 - val_accuracy: 0.6635 - val_loss: 0.1862
# Epoch 83/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7944 - loss: 0.1167 - val_accuracy: 0.6673 - val_loss: 0.1894
# Epoch 84/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7889 - loss: 0.1187 - val_accuracy: 0.6635 - val_loss: 0.1884
# Epoch 85/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7852 - loss: 0.1208 - val_accuracy: 0.6673 - val_loss: 0.1903
# Epoch 86/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7950 - loss: 0.1187 - val_accuracy: 0.6730 - val_loss: 0.1908
# Epoch 87/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7888 - loss: 0.1166 - val_accuracy: 0.6730 - val_loss: 0.1907
# Epoch 88/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7953 - loss: 0.1153 - val_accuracy: 0.6749 - val_loss: 0.1918
# Epoch 89/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7961 - loss: 0.1168 - val_accuracy: 0.6806 - val_loss: 0.1927
# Epoch 90/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8048 - loss: 0.1119 - val_accuracy: 0.6825 - val_loss: 0.1941
# Epoch 91/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8040 - loss: 0.1131 - val_accuracy: 0.6654 - val_loss: 0.1942
# Epoch 92/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8002 - loss: 0.1136 - val_accuracy: 0.6692 - val_loss: 0.1938
# Epoch 93/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8038 - loss: 0.1123 - val_accuracy: 0.6616 - val_loss: 0.1933
# Epoch 94/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8011 - loss: 0.1115 - val_accuracy: 0.6787 - val_loss: 0.1938
# Epoch 95/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8079 - loss: 0.1106 - val_accuracy: 0.6806 - val_loss: 0.1951
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Epoch 1/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1849 - loss: 0.6891 - val_accuracy: 0.1749 - val_loss: 0.6702
# Epoch 2/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1750 - loss: 0.6608 - val_accuracy: 0.1787 - val_loss: 0.6277
# Epoch 3/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1848 - loss: 0.6138 - val_accuracy: 0.1464 - val_loss: 0.5568
# Epoch 4/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1626 - loss: 0.5271 - val_accuracy: 0.1464 - val_loss: 0.4149
# Epoch 5/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1795 - loss: 0.3934 - val_accuracy: 0.3289 - val_loss: 0.3418
# Epoch 6/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3142 - loss: 0.3405 - val_accuracy: 0.3289 - val_loss: 0.3166
# Epoch 7/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3246 - loss: 0.3202 - val_accuracy: 0.3289 - val_loss: 0.3111
# Epoch 8/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3235 - loss: 0.3148 - val_accuracy: 0.3289 - val_loss: 0.3100
# Epoch 9/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3065 - loss: 0.3151 - val_accuracy: 0.3289 - val_loss: 0.3095
# Epoch 10/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3270 - loss: 0.3131 - val_accuracy: 0.3289 - val_loss: 0.3087
# Epoch 11/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3322 - loss: 0.3121 - val_accuracy: 0.3289 - val_loss: 0.3081
# Epoch 12/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3246 - loss: 0.3109 - val_accuracy: 0.3289 - val_loss: 0.3073
# Epoch 13/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3371 - loss: 0.3092 - val_accuracy: 0.3289 - val_loss: 0.3064
# Epoch 14/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3330 - loss: 0.3077 - val_accuracy: 0.3289 - val_loss: 0.3053
# Epoch 15/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3273 - loss: 0.3090 - val_accuracy: 0.3289 - val_loss: 0.3040
# Epoch 16/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3351 - loss: 0.3069 - val_accuracy: 0.3289 - val_loss: 0.3024
# Epoch 17/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3351 - loss: 0.3043 - val_accuracy: 0.3289 - val_loss: 0.3003
# Epoch 18/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3439 - loss: 0.3024 - val_accuracy: 0.3935 - val_loss: 0.2975
# Epoch 19/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3799 - loss: 0.2986 - val_accuracy: 0.4278 - val_loss: 0.2942
# Epoch 20/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4079 - loss: 0.2956 - val_accuracy: 0.4316 - val_loss: 0.2898
# Epoch 21/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4104 - loss: 0.2928 - val_accuracy: 0.4411 - val_loss: 0.2853
# Epoch 22/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4308 - loss: 0.2841 - val_accuracy: 0.4373 - val_loss: 0.2803
# Epoch 23/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4428 - loss: 0.2785 - val_accuracy: 0.4373 - val_loss: 0.2758
# Epoch 24/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4322 - loss: 0.2766 - val_accuracy: 0.4411 - val_loss: 0.2721
# Epoch 25/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4460 - loss: 0.2708 - val_accuracy: 0.4373 - val_loss: 0.2691
# Epoch 26/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4514 - loss: 0.2668 - val_accuracy: 0.4411 - val_loss: 0.2662
# Epoch 27/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4490 - loss: 0.2655 - val_accuracy: 0.4487 - val_loss: 0.2637
# Epoch 28/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4531 - loss: 0.2638 - val_accuracy: 0.4506 - val_loss: 0.2617
# Epoch 29/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4536 - loss: 0.2619 - val_accuracy: 0.4544 - val_loss: 0.2596
# Epoch 30/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4631 - loss: 0.2581 - val_accuracy: 0.4582 - val_loss: 0.2578
# Epoch 31/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4590 - loss: 0.2600 - val_accuracy: 0.4582 - val_loss: 0.2565
# Epoch 32/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4617 - loss: 0.2589 - val_accuracy: 0.4734 - val_loss: 0.2547
# Epoch 33/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4698 - loss: 0.2535 - val_accuracy: 0.4677 - val_loss: 0.2531
# Epoch 34/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4725 - loss: 0.2547 - val_accuracy: 0.4734 - val_loss: 0.2515
# Epoch 35/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4726 - loss: 0.2522 - val_accuracy: 0.4867 - val_loss: 0.2497
# Epoch 36/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4823 - loss: 0.2487 - val_accuracy: 0.5038 - val_loss: 0.2481
# Epoch 37/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4907 - loss: 0.2492 - val_accuracy: 0.5019 - val_loss: 0.2459
# Epoch 38/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4976 - loss: 0.2454 - val_accuracy: 0.5038 - val_loss: 0.2440
# Epoch 39/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5014 - loss: 0.2452 - val_accuracy: 0.5114 - val_loss: 0.2414
# Epoch 40/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5048 - loss: 0.2389 - val_accuracy: 0.5114 - val_loss: 0.2387
# Epoch 41/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5045 - loss: 0.2380 - val_accuracy: 0.5152 - val_loss: 0.2361
# Epoch 42/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5173 - loss: 0.2371 - val_accuracy: 0.5266 - val_loss: 0.2330
# Epoch 43/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5272 - loss: 0.2328 - val_accuracy: 0.5494 - val_loss: 0.2298
# Epoch 44/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5376 - loss: 0.2287 - val_accuracy: 0.5570 - val_loss: 0.2271
# Epoch 45/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5594 - loss: 0.2266 - val_accuracy: 0.5570 - val_loss: 0.2247
# Epoch 46/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5512 - loss: 0.2240 - val_accuracy: 0.5627 - val_loss: 0.2223
# Epoch 47/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5647 - loss: 0.2225 - val_accuracy: 0.5608 - val_loss: 0.2198
# Epoch 48/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5761 - loss: 0.2199 - val_accuracy: 0.5684 - val_loss: 0.2180
# Epoch 49/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5834 - loss: 0.2170 - val_accuracy: 0.5703 - val_loss: 0.2160
# Epoch 50/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5812 - loss: 0.2140 - val_accuracy: 0.5684 - val_loss: 0.2144
# Epoch 51/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5892 - loss: 0.2132 - val_accuracy: 0.5684 - val_loss: 0.2128
# Epoch 52/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5983 - loss: 0.2099 - val_accuracy: 0.5798 - val_loss: 0.2116
# Epoch 53/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5927 - loss: 0.2114 - val_accuracy: 0.5779 - val_loss: 0.2106
# Epoch 54/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5966 - loss: 0.2089 - val_accuracy: 0.5779 - val_loss: 0.2093
# Epoch 55/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6058 - loss: 0.2053 - val_accuracy: 0.5970 - val_loss: 0.2075
# Epoch 56/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6222 - loss: 0.2026 - val_accuracy: 0.5989 - val_loss: 0.2063
# Epoch 57/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6124 - loss: 0.2025 - val_accuracy: 0.5951 - val_loss: 0.2052
# Epoch 58/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6136 - loss: 0.2008 - val_accuracy: 0.5932 - val_loss: 0.2043
# Epoch 59/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6207 - loss: 0.1973 - val_accuracy: 0.5932 - val_loss: 0.2032
# Epoch 60/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6346 - loss: 0.1941 - val_accuracy: 0.5951 - val_loss: 0.2024
# Epoch 61/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6320 - loss: 0.1944 - val_accuracy: 0.6008 - val_loss: 0.2016
# Epoch 62/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6267 - loss: 0.1942 - val_accuracy: 0.6046 - val_loss: 0.2005
# Epoch 63/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6386 - loss: 0.1928 - val_accuracy: 0.6103 - val_loss: 0.1990
# Epoch 64/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6351 - loss: 0.1918 - val_accuracy: 0.6122 - val_loss: 0.1980
# Epoch 65/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6459 - loss: 0.1854 - val_accuracy: 0.6160 - val_loss: 0.1974
# Epoch 66/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6500 - loss: 0.1865 - val_accuracy: 0.6160 - val_loss: 0.1968
# Epoch 67/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6507 - loss: 0.1861 - val_accuracy: 0.6141 - val_loss: 0.1962
# Epoch 68/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6464 - loss: 0.1860 - val_accuracy: 0.6236 - val_loss: 0.1952
# Epoch 69/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6432 - loss: 0.1861 - val_accuracy: 0.6217 - val_loss: 0.1948
# Epoch 70/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6471 - loss: 0.1856 - val_accuracy: 0.6274 - val_loss: 0.1937
# Epoch 71/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6582 - loss: 0.1779 - val_accuracy: 0.6255 - val_loss: 0.1933
# Epoch 72/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6612 - loss: 0.1784 - val_accuracy: 0.6350 - val_loss: 0.1925
# Epoch 73/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6646 - loss: 0.1773 - val_accuracy: 0.6369 - val_loss: 0.1913
# Epoch 74/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6627 - loss: 0.1759 - val_accuracy: 0.6388 - val_loss: 0.1913
# Epoch 75/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6670 - loss: 0.1755 - val_accuracy: 0.6388 - val_loss: 0.1900
# Epoch 76/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6745 - loss: 0.1734 - val_accuracy: 0.6369 - val_loss: 0.1898
# Epoch 77/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6745 - loss: 0.1736 - val_accuracy: 0.6426 - val_loss: 0.1894
# Epoch 78/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6738 - loss: 0.1713 - val_accuracy: 0.6426 - val_loss: 0.1886
# Epoch 79/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6758 - loss: 0.1695 - val_accuracy: 0.6407 - val_loss: 0.1886
# Epoch 80/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6814 - loss: 0.1687 - val_accuracy: 0.6464 - val_loss: 0.1879
# Epoch 81/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6926 - loss: 0.1670 - val_accuracy: 0.6426 - val_loss: 0.1878
# Epoch 82/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6881 - loss: 0.1688 - val_accuracy: 0.6521 - val_loss: 0.1879
# Epoch 83/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6892 - loss: 0.1645 - val_accuracy: 0.6426 - val_loss: 0.1868
# Epoch 84/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6922 - loss: 0.1642 - val_accuracy: 0.6559 - val_loss: 0.1862
# Epoch 85/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6962 - loss: 0.1630 - val_accuracy: 0.6578 - val_loss: 0.1861
# Epoch 86/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6922 - loss: 0.1640 - val_accuracy: 0.6559 - val_loss: 0.1863
# Epoch 87/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7006 - loss: 0.1610 - val_accuracy: 0.6597 - val_loss: 0.1857
# Epoch 88/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7066 - loss: 0.1598 - val_accuracy: 0.6616 - val_loss: 0.1857
# Epoch 89/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7023 - loss: 0.1600 - val_accuracy: 0.6521 - val_loss: 0.1861
# Epoch 90/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7090 - loss: 0.1571 - val_accuracy: 0.6483 - val_loss: 0.1858
# Epoch 91/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7085 - loss: 0.1580 - val_accuracy: 0.6540 - val_loss: 0.1862
# Epoch 92/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7167 - loss: 0.1567 - val_accuracy: 0.6502 - val_loss: 0.1855
# Epoch 93/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7072 - loss: 0.1591 - val_accuracy: 0.6502 - val_loss: 0.1858
# Epoch 94/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7157 - loss: 0.1532 - val_accuracy: 0.6502 - val_loss: 0.1854
# Epoch 95/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7211 - loss: 0.1524 - val_accuracy: 0.6445 - val_loss: 0.1859
# Epoch 96/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7191 - loss: 0.1552 - val_accuracy: 0.6483 - val_loss: 0.1844
# Epoch 97/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7261 - loss: 0.1503 - val_accuracy: 0.6540 - val_loss: 0.1851
# Epoch 98/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7290 - loss: 0.1509 - val_accuracy: 0.6483 - val_loss: 0.1859
# Epoch 99/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7238 - loss: 0.1507 - val_accuracy: 0.6578 - val_loss: 0.1844
# Epoch 100/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7222 - loss: 0.1505 - val_accuracy: 0.6540 - val_loss: 0.1846
# Epoch 101/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7345 - loss: 0.1482 - val_accuracy: 0.6464 - val_loss: 0.1859
# Epoch 102/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7329 - loss: 0.1457 - val_accuracy: 0.6540 - val_loss: 0.1860
# Epoch 103/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7230 - loss: 0.1484 - val_accuracy: 0.6559 - val_loss: 0.1855
# Epoch 104/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7415 - loss: 0.1425 - val_accuracy: 0.6540 - val_loss: 0.1860
# Epoch 105/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7470 - loss: 0.1433 - val_accuracy: 0.6559 - val_loss: 0.1854
# Epoch 106/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7475 - loss: 0.1426 - val_accuracy: 0.6559 - val_loss: 0.1851
# Epoch 107/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7457 - loss: 0.1408 - val_accuracy: 0.6559 - val_loss: 0.1859
# Epoch 108/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7446 - loss: 0.1429 - val_accuracy: 0.6597 - val_loss: 0.1857
# Epoch 109/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7487 - loss: 0.1417 - val_accuracy: 0.6559 - val_loss: 0.1869
# Epoch 110/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7547 - loss: 0.1374 - val_accuracy: 0.6540 - val_loss: 0.1864
# Epoch 111/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7557 - loss: 0.1356 - val_accuracy: 0.6502 - val_loss: 0.1869
# Epoch 112/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7491 - loss: 0.1391 - val_accuracy: 0.6559 - val_loss: 0.1855
# Epoch 113/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7585 - loss: 0.1370 - val_accuracy: 0.6540 - val_loss: 0.1874
# Epoch 114/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7562 - loss: 0.1350 - val_accuracy: 0.6597 - val_loss: 0.1876
# Epoch 115/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7630 - loss: 0.1346 - val_accuracy: 0.6483 - val_loss: 0.1889
# Epoch 116/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7656 - loss: 0.1331 - val_accuracy: 0.6502 - val_loss: 0.1877
# Epoch 117/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7589 - loss: 0.1323 - val_accuracy: 0.6616 - val_loss: 0.1878
# Epoch 118/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7627 - loss: 0.1311 - val_accuracy: 0.6559 - val_loss: 0.1899
# Epoch 119/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7649 - loss: 0.1311 - val_accuracy: 0.6502 - val_loss: 0.1884
# Epoch 120/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7705 - loss: 0.1271 - val_accuracy: 0.6502 - val_loss: 0.1885
# Epoch 121/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7770 - loss: 0.1294 - val_accuracy: 0.6578 - val_loss: 0.1887
# Epoch 122/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7714 - loss: 0.1293 - val_accuracy: 0.6616 - val_loss: 0.1896
# Epoch 123/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7784 - loss: 0.1250 - val_accuracy: 0.6635 - val_loss: 0.1888
# Epoch 124/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7918 - loss: 0.1214 - val_accuracy: 0.6578 - val_loss: 0.1907
# Epoch 125/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7794 - loss: 0.1241 - val_accuracy: 0.6616 - val_loss: 0.1904
# Epoch 126/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7765 - loss: 0.1253 - val_accuracy: 0.6540 - val_loss: 0.1913
# Epoch 127/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7867 - loss: 0.1200 - val_accuracy: 0.6673 - val_loss: 0.1901
# Epoch 128/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7825 - loss: 0.1229 - val_accuracy: 0.6464 - val_loss: 0.1929
# Epoch 129/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7939 - loss: 0.1199 - val_accuracy: 0.6578 - val_loss: 0.1920
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 1/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1768 - loss: 0.6892 - val_accuracy: 0.1733 - val_loss: 0.6699
# Epoch 2/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1757 - loss: 0.6598 - val_accuracy: 0.1467 - val_loss: 0.6246
# Epoch 3/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1577 - loss: 0.6103 - val_accuracy: 0.1467 - val_loss: 0.5547
# Epoch 4/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1574 - loss: 0.5290 - val_accuracy: 0.1467 - val_loss: 0.4296
# Epoch 5/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1545 - loss: 0.4003 - val_accuracy: 0.3295 - val_loss: 0.3421
# Epoch 6/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3201 - loss: 0.3414 - val_accuracy: 0.3295 - val_loss: 0.3180
# Epoch 7/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3299 - loss: 0.3189 - val_accuracy: 0.3295 - val_loss: 0.3147
# Epoch 8/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3243 - loss: 0.3174 - val_accuracy: 0.3295 - val_loss: 0.3111
# Epoch 9/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3273 - loss: 0.3137 - val_accuracy: 0.3295 - val_loss: 0.3107
# Epoch 10/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3324 - loss: 0.3125 - val_accuracy: 0.3295 - val_loss: 0.3102
# Epoch 11/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3262 - loss: 0.3128 - val_accuracy: 0.3295 - val_loss: 0.3098
# Epoch 12/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3274 - loss: 0.3118 - val_accuracy: 0.3295 - val_loss: 0.3093
# Epoch 13/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3297 - loss: 0.3104 - val_accuracy: 0.3295 - val_loss: 0.3088
# Epoch 14/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3296 - loss: 0.3106 - val_accuracy: 0.3295 - val_loss: 0.3082
# Epoch 15/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3245 - loss: 0.3114 - val_accuracy: 0.3295 - val_loss: 0.3073
# Epoch 16/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3289 - loss: 0.3090 - val_accuracy: 0.3295 - val_loss: 0.3059
# Epoch 17/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3361 - loss: 0.3070 - val_accuracy: 0.3295 - val_loss: 0.3039
# Epoch 18/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3413 - loss: 0.3059 - val_accuracy: 0.3295 - val_loss: 0.3014
# Epoch 19/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3691 - loss: 0.3015 - val_accuracy: 0.4286 - val_loss: 0.2977
# Epoch 20/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4077 - loss: 0.2991 - val_accuracy: 0.4286 - val_loss: 0.2922
# Epoch 21/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4269 - loss: 0.2932 - val_accuracy: 0.4533 - val_loss: 0.2854
# Epoch 22/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4359 - loss: 0.2891 - val_accuracy: 0.4457 - val_loss: 0.2790
# Epoch 23/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4434 - loss: 0.2798 - val_accuracy: 0.4438 - val_loss: 0.2732
# Epoch 24/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4461 - loss: 0.2758 - val_accuracy: 0.4438 - val_loss: 0.2690
# Epoch 25/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4477 - loss: 0.2716 - val_accuracy: 0.4514 - val_loss: 0.2663
# Epoch 26/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4571 - loss: 0.2682 - val_accuracy: 0.4495 - val_loss: 0.2644
# Epoch 27/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4657 - loss: 0.2635 - val_accuracy: 0.4476 - val_loss: 0.2630
# Epoch 28/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4605 - loss: 0.2628 - val_accuracy: 0.4476 - val_loss: 0.2617
# Epoch 29/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4565 - loss: 0.2630 - val_accuracy: 0.4495 - val_loss: 0.2605
# Epoch 30/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4541 - loss: 0.2602 - val_accuracy: 0.4495 - val_loss: 0.2594
# Epoch 31/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4625 - loss: 0.2605 - val_accuracy: 0.4514 - val_loss: 0.2582
# Epoch 32/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4646 - loss: 0.2557 - val_accuracy: 0.4533 - val_loss: 0.2569
# Epoch 33/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4542 - loss: 0.2574 - val_accuracy: 0.4495 - val_loss: 0.2559
# Epoch 34/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4540 - loss: 0.2557 - val_accuracy: 0.4514 - val_loss: 0.2544
# Epoch 35/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4725 - loss: 0.2489 - val_accuracy: 0.4495 - val_loss: 0.2534
# Epoch 36/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4620 - loss: 0.2525 - val_accuracy: 0.4533 - val_loss: 0.2516
# Epoch 37/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4660 - loss: 0.2503 - val_accuracy: 0.4590 - val_loss: 0.2502
# Epoch 38/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4687 - loss: 0.2487 - val_accuracy: 0.4648 - val_loss: 0.2485
# Epoch 39/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4833 - loss: 0.2450 - val_accuracy: 0.4667 - val_loss: 0.2455
# Epoch 40/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4901 - loss: 0.2428 - val_accuracy: 0.4610 - val_loss: 0.2438
# Epoch 41/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4869 - loss: 0.2399 - val_accuracy: 0.4648 - val_loss: 0.2410
# Epoch 42/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5000 - loss: 0.2389 - val_accuracy: 0.4876 - val_loss: 0.2387
# Epoch 43/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5157 - loss: 0.2330 - val_accuracy: 0.4933 - val_loss: 0.2360
# Epoch 44/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5337 - loss: 0.2319 - val_accuracy: 0.4952 - val_loss: 0.2331
# Epoch 45/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5336 - loss: 0.2291 - val_accuracy: 0.5295 - val_loss: 0.2300
# Epoch 46/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5539 - loss: 0.2263 - val_accuracy: 0.5448 - val_loss: 0.2268
# Epoch 47/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5538 - loss: 0.2246 - val_accuracy: 0.5657 - val_loss: 0.2236
# Epoch 48/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5647 - loss: 0.2207 - val_accuracy: 0.5676 - val_loss: 0.2202
# Epoch 49/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5897 - loss: 0.2148 - val_accuracy: 0.5714 - val_loss: 0.2170
# Epoch 50/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5780 - loss: 0.2134 - val_accuracy: 0.5790 - val_loss: 0.2139
# Epoch 51/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5983 - loss: 0.2105 - val_accuracy: 0.5905 - val_loss: 0.2113
# Epoch 52/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6005 - loss: 0.2090 - val_accuracy: 0.5943 - val_loss: 0.2092
# Epoch 53/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6085 - loss: 0.2058 - val_accuracy: 0.5962 - val_loss: 0.2070
# Epoch 54/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6066 - loss: 0.2049 - val_accuracy: 0.6000 - val_loss: 0.2051
# Epoch 55/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6126 - loss: 0.2013 - val_accuracy: 0.6000 - val_loss: 0.2038
# Epoch 56/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6073 - loss: 0.2024 - val_accuracy: 0.6114 - val_loss: 0.2020
# Epoch 57/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6233 - loss: 0.1982 - val_accuracy: 0.6152 - val_loss: 0.2005
# Epoch 58/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6191 - loss: 0.1997 - val_accuracy: 0.6114 - val_loss: 0.1993
# Epoch 59/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6257 - loss: 0.1950 - val_accuracy: 0.6171 - val_loss: 0.1982
# Epoch 60/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6234 - loss: 0.1956 - val_accuracy: 0.6190 - val_loss: 0.1975
# Epoch 61/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6379 - loss: 0.1889 - val_accuracy: 0.6171 - val_loss: 0.1957
# Epoch 62/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6458 - loss: 0.1895 - val_accuracy: 0.6286 - val_loss: 0.1950
# Epoch 63/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6380 - loss: 0.1883 - val_accuracy: 0.6248 - val_loss: 0.1944
# Epoch 64/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6410 - loss: 0.1882 - val_accuracy: 0.6210 - val_loss: 0.1932
# Epoch 65/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6426 - loss: 0.1848 - val_accuracy: 0.6248 - val_loss: 0.1922
# Epoch 66/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6497 - loss: 0.1828 - val_accuracy: 0.6248 - val_loss: 0.1911
# Epoch 67/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6472 - loss: 0.1819 - val_accuracy: 0.6248 - val_loss: 0.1901
# Epoch 68/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6477 - loss: 0.1818 - val_accuracy: 0.6305 - val_loss: 0.1894
# Epoch 69/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6526 - loss: 0.1794 - val_accuracy: 0.6267 - val_loss: 0.1884
# Epoch 70/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6571 - loss: 0.1787 - val_accuracy: 0.6229 - val_loss: 0.1883
# Epoch 71/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6623 - loss: 0.1759 - val_accuracy: 0.6286 - val_loss: 0.1878
# Epoch 72/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6816 - loss: 0.1714 - val_accuracy: 0.6286 - val_loss: 0.1872
# Epoch 73/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6620 - loss: 0.1749 - val_accuracy: 0.6248 - val_loss: 0.1859
# Epoch 74/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6647 - loss: 0.1717 - val_accuracy: 0.6305 - val_loss: 0.1852
# Epoch 75/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6739 - loss: 0.1710 - val_accuracy: 0.6362 - val_loss: 0.1850
# Epoch 76/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6800 - loss: 0.1685 - val_accuracy: 0.6324 - val_loss: 0.1843
# Epoch 77/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6756 - loss: 0.1685 - val_accuracy: 0.6362 - val_loss: 0.1835
# Epoch 78/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6867 - loss: 0.1665 - val_accuracy: 0.6457 - val_loss: 0.1832
# Epoch 79/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6892 - loss: 0.1634 - val_accuracy: 0.6438 - val_loss: 0.1821
# Epoch 80/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6927 - loss: 0.1640 - val_accuracy: 0.6381 - val_loss: 0.1817
# Epoch 81/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6899 - loss: 0.1657 - val_accuracy: 0.6495 - val_loss: 0.1808
# Epoch 82/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6956 - loss: 0.1618 - val_accuracy: 0.6514 - val_loss: 0.1808
# Epoch 83/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7030 - loss: 0.1587 - val_accuracy: 0.6495 - val_loss: 0.1800
# Epoch 84/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7020 - loss: 0.1591 - val_accuracy: 0.6533 - val_loss: 0.1795
# Epoch 85/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7104 - loss: 0.1573 - val_accuracy: 0.6457 - val_loss: 0.1786
# Epoch 86/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7137 - loss: 0.1562 - val_accuracy: 0.6514 - val_loss: 0.1785
# Epoch 87/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7114 - loss: 0.1551 - val_accuracy: 0.6514 - val_loss: 0.1784
# Epoch 88/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7106 - loss: 0.1574 - val_accuracy: 0.6514 - val_loss: 0.1776
# Epoch 89/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7209 - loss: 0.1522 - val_accuracy: 0.6476 - val_loss: 0.1777
# Epoch 90/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7224 - loss: 0.1498 - val_accuracy: 0.6476 - val_loss: 0.1775
# Epoch 91/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7223 - loss: 0.1516 - val_accuracy: 0.6495 - val_loss: 0.1771
# Epoch 92/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7292 - loss: 0.1505 - val_accuracy: 0.6457 - val_loss: 0.1768
# Epoch 93/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7270 - loss: 0.1492 - val_accuracy: 0.6457 - val_loss: 0.1770
# Epoch 94/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7318 - loss: 0.1473 - val_accuracy: 0.6419 - val_loss: 0.1768
# Epoch 95/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7245 - loss: 0.1469 - val_accuracy: 0.6343 - val_loss: 0.1771
# Epoch 96/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7339 - loss: 0.1468 - val_accuracy: 0.6457 - val_loss: 0.1777
# Epoch 97/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7355 - loss: 0.1474 - val_accuracy: 0.6495 - val_loss: 0.1772
# Epoch 98/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7478 - loss: 0.1442 - val_accuracy: 0.6495 - val_loss: 0.1760
# Epoch 99/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7365 - loss: 0.1463 - val_accuracy: 0.6419 - val_loss: 0.1773
# Epoch 100/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7392 - loss: 0.1452 - val_accuracy: 0.6362 - val_loss: 0.1776
# Epoch 101/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7455 - loss: 0.1432 - val_accuracy: 0.6514 - val_loss: 0.1773
# Epoch 102/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7526 - loss: 0.1381 - val_accuracy: 0.6495 - val_loss: 0.1762
# Epoch 103/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7479 - loss: 0.1390 - val_accuracy: 0.6495 - val_loss: 0.1765
# Epoch 104/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7519 - loss: 0.1409 - val_accuracy: 0.6476 - val_loss: 0.1767
# Epoch 105/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7601 - loss: 0.1353 - val_accuracy: 0.6476 - val_loss: 0.1759
# Epoch 106/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7710 - loss: 0.1340 - val_accuracy: 0.6457 - val_loss: 0.1765
# Epoch 107/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7625 - loss: 0.1338 - val_accuracy: 0.6514 - val_loss: 0.1763
# Epoch 108/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7772 - loss: 0.1298 - val_accuracy: 0.6495 - val_loss: 0.1766
# Epoch 109/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7661 - loss: 0.1325 - val_accuracy: 0.6400 - val_loss: 0.1769
# Epoch 110/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7784 - loss: 0.1292 - val_accuracy: 0.6476 - val_loss: 0.1773
# Epoch 111/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7647 - loss: 0.1332 - val_accuracy: 0.6495 - val_loss: 0.1765
# Epoch 112/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7859 - loss: 0.1280 - val_accuracy: 0.6419 - val_loss: 0.1776
# Epoch 113/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7770 - loss: 0.1299 - val_accuracy: 0.6476 - val_loss: 0.1777
# Epoch 114/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7799 - loss: 0.1256 - val_accuracy: 0.6610 - val_loss: 0.1784
# Epoch 115/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7688 - loss: 0.1323 - val_accuracy: 0.6476 - val_loss: 0.1778
# Epoch 116/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7812 - loss: 0.1251 - val_accuracy: 0.6514 - val_loss: 0.1791
# Epoch 117/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7775 - loss: 0.1253 - val_accuracy: 0.6476 - val_loss: 0.1774
# Epoch 118/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7839 - loss: 0.1257 - val_accuracy: 0.6476 - val_loss: 0.1784
# Epoch 119/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7782 - loss: 0.1252 - val_accuracy: 0.6571 - val_loss: 0.1778
# Epoch 120/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7863 - loss: 0.1231 - val_accuracy: 0.6571 - val_loss: 0.1780
# Epoch 121/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7931 - loss: 0.1186 - val_accuracy: 0.6552 - val_loss: 0.1782
# Epoch 122/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7905 - loss: 0.1197 - val_accuracy: 0.6533 - val_loss: 0.1789
# Epoch 123/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7967 - loss: 0.1179 - val_accuracy: 0.6457 - val_loss: 0.1792
# Epoch 124/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7965 - loss: 0.1198 - val_accuracy: 0.6571 - val_loss: 0.1783
# Epoch 125/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7999 - loss: 0.1181 - val_accuracy: 0.6571 - val_loss: 0.1805
# Epoch 126/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7974 - loss: 0.1175 - val_accuracy: 0.6533 - val_loss: 0.1793
# Epoch 127/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8056 - loss: 0.1137 - val_accuracy: 0.6533 - val_loss: 0.1799
# Epoch 128/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8006 - loss: 0.1160 - val_accuracy: 0.6629 - val_loss: 0.1796
# Epoch 129/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8074 - loss: 0.1129 - val_accuracy: 0.6571 - val_loss: 0.1807
# Epoch 130/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8076 - loss: 0.1121 - val_accuracy: 0.6629 - val_loss: 0.1801
# Epoch 131/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8135 - loss: 0.1128 - val_accuracy: 0.6686 - val_loss: 0.1794
# Epoch 132/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8134 - loss: 0.1101 - val_accuracy: 0.6686 - val_loss: 0.1817
# Epoch 133/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8199 - loss: 0.1079 - val_accuracy: 0.6667 - val_loss: 0.1806
# Epoch 134/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8186 - loss: 0.1081 - val_accuracy: 0.6648 - val_loss: 0.1812
# Epoch 135/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8171 - loss: 0.1087 - val_accuracy: 0.6629 - val_loss: 0.1813
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 1/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1615 - loss: 0.6891 - val_accuracy: 0.1752 - val_loss: 0.6696
# Epoch 2/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1762 - loss: 0.6595 - val_accuracy: 0.1981 - val_loss: 0.6237
# Epoch 3/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1630 - loss: 0.6081 - val_accuracy: 0.1467 - val_loss: 0.5486
# Epoch 4/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1504 - loss: 0.5207 - val_accuracy: 0.1467 - val_loss: 0.4134
# Epoch 5/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1609 - loss: 0.3873 - val_accuracy: 0.3295 - val_loss: 0.3401
# Epoch 6/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3145 - loss: 0.3384 - val_accuracy: 0.3295 - val_loss: 0.3152
# Epoch 7/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3291 - loss: 0.3168 - val_accuracy: 0.3295 - val_loss: 0.3143
# Epoch 8/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3329 - loss: 0.3145 - val_accuracy: 0.3295 - val_loss: 0.3112
# Epoch 9/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3239 - loss: 0.3142 - val_accuracy: 0.3295 - val_loss: 0.3107
# Epoch 10/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3283 - loss: 0.3129 - val_accuracy: 0.3295 - val_loss: 0.3105
# Epoch 11/500
# ...
# Epoch 121/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7949 - loss: 0.1145 - val_accuracy: 0.6267 - val_loss: 0.1986
# Epoch 122/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7879 - loss: 0.1158 - val_accuracy: 0.6324 - val_loss: 0.1982
# Epoch 123/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7975 - loss: 0.1133 - val_accuracy: 0.6400 - val_loss: 0.1980
# Epoch 124/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8001 - loss: 0.1127 - val_accuracy: 0.6419 - val_loss: 0.1996
# Epoch 125/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7949 - loss: 0.1136 - val_accuracy: 0.6343 - val_loss: 0.1996
# Epoch 126/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7997 - loss: 0.1110 - val_accuracy: 0.6362 - val_loss: 0.2014
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 1/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1614 - loss: 0.6894 - val_accuracy: 0.1752 - val_loss: 0.6713
# Epoch 2/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1758 - loss: 0.6617 - val_accuracy: 0.1752 - val_loss: 0.6281
# Epoch 3/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1790 - loss: 0.6135 - val_accuracy: 0.2000 - val_loss: 0.5568
# Epoch 4/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1732 - loss: 0.5290 - val_accuracy: 0.1467 - val_loss: 0.4174
# Epoch 5/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1896 - loss: 0.3867 - val_accuracy: 0.3295 - val_loss: 0.3376
# Epoch 6/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3287 - loss: 0.3359 - val_accuracy: 0.3295 - val_loss: 0.3144
# Epoch 7/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3345 - loss: 0.3157 - val_accuracy: 0.3295 - val_loss: 0.3143
# Epoch 8/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3354 - loss: 0.3158 - val_accuracy: 0.3295 - val_loss: 0.3110
# Epoch 9/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3311 - loss: 0.3133 - val_accuracy: 0.3295 - val_loss: 0.3106
# Epoch 10/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3255 - loss: 0.3138 - val_accuracy: 0.3295 - val_loss: 0.3102
# Epoch 11/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3249 - loss: 0.3126 - val_accuracy: 0.3295 - val_loss: 0.3099
# Epoch 12/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3346 - loss: 0.3114 - val_accuracy: 0.3295 - val_loss: 0.3095
# Epoch 13/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3248 - loss: 0.3122 - val_accuracy: 0.3295 - val_loss: 0.3092
# Epoch 14/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3376 - loss: 0.3103 - val_accuracy: 0.3295 - val_loss: 0.3088
# Epoch 15/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3350 - loss: 0.3107 - val_accuracy: 0.3295 - val_loss: 0.3082
# Epoch 16/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3285 - loss: 0.3107 - val_accuracy: 0.3295 - val_loss: 0.3073
# Epoch 17/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3276 - loss: 0.3099 - val_accuracy: 0.3295 - val_loss: 0.3063
# Epoch 18/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3317 - loss: 0.3082 - val_accuracy: 0.3295 - val_loss: 0.3050
# Epoch 19/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3392 - loss: 0.3066 - val_accuracy: 0.3295 - val_loss: 0.3032
# Epoch 20/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3542 - loss: 0.3051 - val_accuracy: 0.4114 - val_loss: 0.3005
# Epoch 21/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3908 - loss: 0.3021 - val_accuracy: 0.4190 - val_loss: 0.2966
# Epoch 22/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4121 - loss: 0.2986 - val_accuracy: 0.4152 - val_loss: 0.2910
# Epoch 23/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4359 - loss: 0.2910 - val_accuracy: 0.4495 - val_loss: 0.2840
# Epoch 24/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4336 - loss: 0.2877 - val_accuracy: 0.4476 - val_loss: 0.2774
# Epoch 25/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4546 - loss: 0.2771 - val_accuracy: 0.4438 - val_loss: 0.2724
# Epoch 26/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4438 - loss: 0.2761 - val_accuracy: 0.4476 - val_loss: 0.2688
# Epoch 27/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4523 - loss: 0.2706 - val_accuracy: 0.4514 - val_loss: 0.2663
# Epoch 28/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4519 - loss: 0.2687 - val_accuracy: 0.4476 - val_loss: 0.2643
# Epoch 29/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4576 - loss: 0.2662 - val_accuracy: 0.4514 - val_loss: 0.2626
# Epoch 30/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4559 - loss: 0.2647 - val_accuracy: 0.4514 - val_loss: 0.2611
# Epoch 31/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4575 - loss: 0.2631 - val_accuracy: 0.4514 - val_loss: 0.2596
# Epoch 32/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4633 - loss: 0.2606 - val_accuracy: 0.4514 - val_loss: 0.2582
# Epoch 33/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4635 - loss: 0.2576 - val_accuracy: 0.4552 - val_loss: 0.2565
# Epoch 34/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4673 - loss: 0.2562 - val_accuracy: 0.4552 - val_loss: 0.2549
# Epoch 35/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4668 - loss: 0.2556 - val_accuracy: 0.4552 - val_loss: 0.2530
# Epoch 36/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4596 - loss: 0.2553 - val_accuracy: 0.4552 - val_loss: 0.2510
# Epoch 37/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4698 - loss: 0.2512 - val_accuracy: 0.4533 - val_loss: 0.2493
# Epoch 38/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4710 - loss: 0.2499 - val_accuracy: 0.4743 - val_loss: 0.2463
# Epoch 39/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4789 - loss: 0.2485 - val_accuracy: 0.4876 - val_loss: 0.2439
# Epoch 40/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4870 - loss: 0.2474 - val_accuracy: 0.4971 - val_loss: 0.2415
# Epoch 41/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4948 - loss: 0.2452 - val_accuracy: 0.4990 - val_loss: 0.2384
# Epoch 42/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5043 - loss: 0.2404 - val_accuracy: 0.5010 - val_loss: 0.2358
# Epoch 43/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5131 - loss: 0.2361 - val_accuracy: 0.5276 - val_loss: 0.2328
# Epoch 44/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5170 - loss: 0.2361 - val_accuracy: 0.5295 - val_loss: 0.2296
# Epoch 45/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5225 - loss: 0.2327 - val_accuracy: 0.5238 - val_loss: 0.2266
# Epoch 46/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5183 - loss: 0.2304 - val_accuracy: 0.5314 - val_loss: 0.2233
# Epoch 47/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5442 - loss: 0.2260 - val_accuracy: 0.5410 - val_loss: 0.2200
# Epoch 48/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5587 - loss: 0.2236 - val_accuracy: 0.5467 - val_loss: 0.2171
# Epoch 49/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5674 - loss: 0.2201 - val_accuracy: 0.5581 - val_loss: 0.2142
# Epoch 50/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5820 - loss: 0.2159 - val_accuracy: 0.5695 - val_loss: 0.2117
# Epoch 51/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5835 - loss: 0.2143 - val_accuracy: 0.5848 - val_loss: 0.2092
# Epoch 52/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5938 - loss: 0.2103 - val_accuracy: 0.5886 - val_loss: 0.2068
# Epoch 53/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6020 - loss: 0.2084 - val_accuracy: 0.5867 - val_loss: 0.2056
# Epoch 54/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5995 - loss: 0.2061 - val_accuracy: 0.5867 - val_loss: 0.2036
# Epoch 55/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6037 - loss: 0.2051 - val_accuracy: 0.5943 - val_loss: 0.2023
# Epoch 56/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6082 - loss: 0.2033 - val_accuracy: 0.5924 - val_loss: 0.2011
# Epoch 57/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6129 - loss: 0.2008 - val_accuracy: 0.5962 - val_loss: 0.2003
# Epoch 58/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6151 - loss: 0.2011 - val_accuracy: 0.6000 - val_loss: 0.1989
# Epoch 59/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6175 - loss: 0.2010 - val_accuracy: 0.6038 - val_loss: 0.1979
# Epoch 60/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6304 - loss: 0.1934 - val_accuracy: 0.6000 - val_loss: 0.1971
# Epoch 61/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6318 - loss: 0.1924 - val_accuracy: 0.6000 - val_loss: 0.1962
# Epoch 62/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6253 - loss: 0.1925 - val_accuracy: 0.6019 - val_loss: 0.1955
# Epoch 63/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6349 - loss: 0.1913 - val_accuracy: 0.5943 - val_loss: 0.1958
# Epoch 64/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6430 - loss: 0.1862 - val_accuracy: 0.6019 - val_loss: 0.1943
# Epoch 65/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6480 - loss: 0.1843 - val_accuracy: 0.6095 - val_loss: 0.1936
# Epoch 66/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6407 - loss: 0.1883 - val_accuracy: 0.6057 - val_loss: 0.1930
# Epoch 67/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6494 - loss: 0.1834 - val_accuracy: 0.6095 - val_loss: 0.1927
# Epoch 68/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6558 - loss: 0.1798 - val_accuracy: 0.6152 - val_loss: 0.1917
# Epoch 69/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6477 - loss: 0.1827 - val_accuracy: 0.6229 - val_loss: 0.1910
# Epoch 70/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6587 - loss: 0.1801 - val_accuracy: 0.6171 - val_loss: 0.1902
# Epoch 71/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6648 - loss: 0.1782 - val_accuracy: 0.6229 - val_loss: 0.1898
# Epoch 72/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6617 - loss: 0.1763 - val_accuracy: 0.6229 - val_loss: 0.1895
# Epoch 73/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6641 - loss: 0.1744 - val_accuracy: 0.6229 - val_loss: 0.1896
# Epoch 74/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6765 - loss: 0.1710 - val_accuracy: 0.6248 - val_loss: 0.1897
# Epoch 75/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6668 - loss: 0.1720 - val_accuracy: 0.6248 - val_loss: 0.1885
# Epoch 76/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6742 - loss: 0.1717 - val_accuracy: 0.6267 - val_loss: 0.1882
# Epoch 77/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6860 - loss: 0.1651 - val_accuracy: 0.6286 - val_loss: 0.1881
# Epoch 78/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6791 - loss: 0.1674 - val_accuracy: 0.6324 - val_loss: 0.1873
# Epoch 79/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6813 - loss: 0.1654 - val_accuracy: 0.6305 - val_loss: 0.1867
# Epoch 80/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6957 - loss: 0.1637 - val_accuracy: 0.6324 - val_loss: 0.1864
# Epoch 81/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6898 - loss: 0.1637 - val_accuracy: 0.6267 - val_loss: 0.1860
# Epoch 82/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6941 - loss: 0.1622 - val_accuracy: 0.6267 - val_loss: 0.1872
# Epoch 83/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6944 - loss: 0.1604 - val_accuracy: 0.6343 - val_loss: 0.1860
# Epoch 84/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7080 - loss: 0.1564 - val_accuracy: 0.6286 - val_loss: 0.1860
# Epoch 85/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6952 - loss: 0.1602 - val_accuracy: 0.6286 - val_loss: 0.1860
# Epoch 86/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7065 - loss: 0.1570 - val_accuracy: 0.6362 - val_loss: 0.1856
# Epoch 87/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7097 - loss: 0.1546 - val_accuracy: 0.6362 - val_loss: 0.1860
# Epoch 88/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7120 - loss: 0.1554 - val_accuracy: 0.6286 - val_loss: 0.1855
# Epoch 89/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7226 - loss: 0.1495 - val_accuracy: 0.6305 - val_loss: 0.1863
# Epoch 90/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7234 - loss: 0.1526 - val_accuracy: 0.6362 - val_loss: 0.1866
# Epoch 91/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7226 - loss: 0.1504 - val_accuracy: 0.6419 - val_loss: 0.1859
# Epoch 92/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7343 - loss: 0.1441 - val_accuracy: 0.6286 - val_loss: 0.1863
# Epoch 93/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7273 - loss: 0.1490 - val_accuracy: 0.6381 - val_loss: 0.1858
# Epoch 94/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7272 - loss: 0.1467 - val_accuracy: 0.6476 - val_loss: 0.1855
# Epoch 95/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7263 - loss: 0.1490 - val_accuracy: 0.6514 - val_loss: 0.1862
# Epoch 96/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7382 - loss: 0.1436 - val_accuracy: 0.6495 - val_loss: 0.1865
# Epoch 97/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7425 - loss: 0.1414 - val_accuracy: 0.6495 - val_loss: 0.1881
# Epoch 98/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7482 - loss: 0.1396 - val_accuracy: 0.6400 - val_loss: 0.1870
# Epoch 99/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7540 - loss: 0.1346 - val_accuracy: 0.6457 - val_loss: 0.1873
# Epoch 100/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7501 - loss: 0.1382 - val_accuracy: 0.6419 - val_loss: 0.1859
# Epoch 101/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7590 - loss: 0.1369 - val_accuracy: 0.6495 - val_loss: 0.1877
# Epoch 102/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7594 - loss: 0.1353 - val_accuracy: 0.6514 - val_loss: 0.1883
# Epoch 103/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7602 - loss: 0.1344 - val_accuracy: 0.6533 - val_loss: 0.1876
# Epoch 104/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7636 - loss: 0.1327 - val_accuracy: 0.6457 - val_loss: 0.1894
# Epoch 105/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7687 - loss: 0.1316 - val_accuracy: 0.6438 - val_loss: 0.1898
# Epoch 106/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7671 - loss: 0.1301 - val_accuracy: 0.6533 - val_loss: 0.1919
# Epoch 107/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7709 - loss: 0.1284 - val_accuracy: 0.6533 - val_loss: 0.1908
# Epoch 108/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7773 - loss: 0.1266 - val_accuracy: 0.6514 - val_loss: 0.1917
# Epoch 109/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7772 - loss: 0.1263 - val_accuracy: 0.6514 - val_loss: 0.1907
# Epoch 110/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7854 - loss: 0.1274 - val_accuracy: 0.6533 - val_loss: 0.1911
# Epoch 111/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7847 - loss: 0.1239 - val_accuracy: 0.6400 - val_loss: 0.1921
# Epoch 112/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7813 - loss: 0.1238 - val_accuracy: 0.6457 - val_loss: 0.1936
# Epoch 113/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7903 - loss: 0.1209 - val_accuracy: 0.6381 - val_loss: 0.1937
# Epoch 114/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7865 - loss: 0.1216 - val_accuracy: 0.6419 - val_loss: 0.1939
# Epoch 115/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7895 - loss: 0.1216 - val_accuracy: 0.6476 - val_loss: 0.1959
# Epoch 116/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8061 - loss: 0.1165 - val_accuracy: 0.6419 - val_loss: 0.1976
# Epoch 117/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7939 - loss: 0.1174 - val_accuracy: 0.6495 - val_loss: 0.1959
# Epoch 118/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7985 - loss: 0.1163 - val_accuracy: 0.6457 - val_loss: 0.1971
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step

# %%
import matplotlib.pyplot as plt
from utils import plot_classification_performance

# %%
# Fix the plotting code - add training history for the overall plot
f, axs = plt.subplots(8, 3, figsize=(12, 3 * 8))

# Plot individual fold results
for i in range(7):
    plot_classification_performance(
        axs[i, :],
        y_true[y_test[:, i]],
        y_pred[y_test[:, i], :],
        history[i]  # This has training history for each fold
    )

# Fix the overall plot - combine all training histories
combined_history = {}
if history:  # Make sure history exists
    # Average the training histories across all folds
    all_keys = set()
    for h in history:
        all_keys.update(h.keys())
    
    for key in all_keys:
        values = []
        for h in history:
            if key in h:
                values.append(h[key])
        if values:
            # Take the mean across folds for each epoch
            max_epochs = max(len(v) for v in values)
            combined_values = []
            for epoch in range(max_epochs):
                epoch_values = [v[epoch] for v in values if epoch < len(v)]
                combined_values.append(np.mean(epoch_values))
            combined_history[key] = combined_values

# Plot overall results with combined training history
plot_classification_performance(
    axs[-1, :],
    y_true,
    y_pred,
    combined_history  # Pass the combined training history
)

plt.tight_layout()
plt.show()

# %%
f, axs = plt.subplots(8, 3, figsize=(12, 3 * 8))
for i in range(7):
    plot_classification_performance(
        axs[i, :],
        y_true[y_test[:, i]],
        y_pred[y_test[:, i], :],
        history[i]
    )
plot_classification_performance(
    axs[-1, :],
    y_true,
    y_pred
)

# %%
# Get the antigen names from your loader
antigen_names = list(loader.label_map.keys())
print("Antigen names:", antigen_names)

# Fix the plotting code - add training history for the overall plot
f, axs = plt.subplots(8, 3, figsize=(12, 3 * 8))

# Plot individual fold results
for i in range(7):
    plot_classification_performance(
        axs[i, :],
        y_true[y_test[:, i]],
        y_pred[y_test[:, i], :],
        history[i],
        class_names=antigen_names  # Add this parameter
    )

# Fix the overall plot - combine all training histories
combined_history = {}
if history:  # Make sure history exists
    # Average the training histories across all folds
    all_keys = set()
    for h in history:
        all_keys.update(h.keys())
    
    for key in all_keys:
        values = []
        for h in history:
            if key in h:
                values.append(h[key])
        if values:
            # Take the mean across folds for each epoch
            max_epochs = max(len(v) for v in values)
            combined_values = []
            for epoch in range(max_epochs):
                epoch_values = [v[epoch] for v in values if epoch < len(v)]
                combined_values.append(np.mean(epoch_values))
            combined_history[key] = combined_values

# Plot overall results with combined training history
plot_classification_performance(
    axs[-1, :],
    y_true,
    y_pred,
    combined_history,
    class_names=antigen_names  # Add this parameter
)

plt.tight_layout()
plt.show()
# Out:
# Antigen names: ['F2', 'M38', 'M45', 'NP', 'PA', 'PB1', 'SIY', 'TRP2', 'm139']
