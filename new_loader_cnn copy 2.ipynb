# %%
from glob import glob
import pandas as pd
import os
import numpy as np
import tensorflow as tf
import keras
# Out:
# c:\Users\huang\miniconda3\envs\gpu-ml-base\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# c:\Users\huang\miniconda3\envs\gpu-ml-base\Lib\site-packages\h5py\__init__.py:36: UserWarning: h5py is running against HDF5 1.14.6 when it was built against 1.14.5, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from glob import glob
import os

class TCRDataLoader:
    def __init__(self, data_dir):
        self.data_dir = data_dir
        self.aa_dict = None
        self.v_dict = None
        self.j_dict = None
        self.label_map = None
        self.max_length = None
        
    def combine_columns(self, df, column_variants, new_column_name):
        """Combine multiple columns that represent the same data type"""
        combined_series = pd.Series([None] * len(df), index=df.index)
        
        for variant in column_variants:
            if variant in df.columns:
                # Fill in non-null values from this column
                mask = df[variant].notna() & combined_series.isna()
                combined_series[mask] = df[variant][mask]
                print(f"  Added {mask.sum()} values from '{variant}' column")
        
        return combined_series
    
    def load_files(self):
        df_list = []
        files = glob(self.data_dir + "/*/*.tsv")
        
        for file_path in files:
            df = pd.read_csv(file_path, sep='\t')
            
            # Extract folder name from file path
            folder_name = os.path.basename(os.path.dirname(file_path))
            
            # Split folder name to get Antigen
            parts = folder_name.split('-')
            antigen = parts[-1]  # Get last part (the antigen)
            
            # Add antigen column to dataframe
            df['Antigen'] = antigen
            
            df_list.append(df)
        
        combined_df = pd.concat(df_list, ignore_index=True)
        
        # Define column candidates for each data type
        column_variants = {
            'sequence': ['aminoAcid', 'beta', 'Amino', 'sequence', 'cdr3', 'CDR3'],
            'v_gene': ['v_beta', 'vGeneName', 'v_gene', 'V_gene', 'TRBV'],
            'j_gene': ['j_beta', 'jGeneName', 'j_gene', 'J_gene', 'TRBJ'],
            'counts': ['counts', 'count', 'count (templates/reads)', 'templates', 'reads', 'frequency']
        }
        
        print("Combining columns:")
        # Combine columns for each data type
        for standard_name, variants in column_variants.items():
            print(f"\nCombining {standard_name} columns:")
            combined_series = self.combine_columns(combined_df, variants, standard_name)
            combined_df[f'combined_{standard_name}'] = combined_series
            
            # Show statistics
            total_values = combined_series.notna().sum()
            print(f"  Total combined values: {total_values}")
        
        return combined_df
    
    def build_vocabulary(self, df):
        # Use combined columns
        # Amino acids
        all_sequences = df['combined_sequence'].dropna()
        if len(all_sequences) == 0:
            raise ValueError("No sequence data found in combined columns!")
            
        giant_string = ''.join(all_sequences)
        unique_letters = sorted(set(giant_string))
        self.aa_dict = {}
        for i, letter in enumerate(unique_letters):
            self.aa_dict[letter] = i+1
        
        # V genes
        v_genes = df['combined_v_gene'].dropna().unique()
        v_genes = sorted(v_genes)
        self.v_dict = {}
        for i, gene in enumerate(v_genes):
            self.v_dict[gene] = i + 1

        # J genes
        j_genes = df['combined_j_gene'].dropna().unique()
        j_genes = sorted(j_genes)
        self.j_dict = {}
        for i, gene in enumerate(j_genes):
            self.j_dict[gene] = i + 1

        # Labels
        antigens = df['Antigen'].unique()
        self.label_map = {}
        for i, antigen in enumerate(sorted(antigens)):
            self.label_map[antigen] = i

        # Max length
        sequence_lengths = [len(seq) for seq in df['combined_sequence'].dropna()]
        self.max_length = max(sequence_lengths) if sequence_lengths else 0
        
        print(f"\nVocabulary built:")
        print(f"  Amino acids: {len(self.aa_dict)} unique")
        print(f"  V genes: {len(self.v_dict)} unique")
        print(f"  J genes: {len(self.j_dict)} unique")
        print(f"  Max sequence length: {self.max_length}")
    
    def encode_sequences(self, sequences):
        encoded_aa = []
        for sequence in sequences:
            sequence_numbers = []
            for letter in sequence:
                number = self.aa_dict.get(letter, 0)
                sequence_numbers.append(number)
            # Add padding zeros if sequence is shorter than max_length
            while len(sequence_numbers) < self.max_length:
                sequence_numbers.append(0)
            encoded_aa.append(sequence_numbers)
        return encoded_aa
    
    def encode_v_genes(self, v_genes):
        encoded_v = []
        for v_gene in v_genes:
            encoded_v.append(self.v_dict.get(v_gene, 0))
        return encoded_v
    
    def encode_j_genes(self, j_genes):
        encoded_j = []
        for j_gene in j_genes:
            encoded_j.append(self.j_dict.get(j_gene, 0))
        return encoded_j
    
    def load_and_encode_data(self, batch_size=100, shuffle=True):
        # 1. Load files and combine columns
        df = self.load_files()
        
        # 2. Build vocabularies
        self.build_vocabulary(df)
        
        # 3. Filter out rows with missing amino acid sequences
        valid_rows = df['combined_sequence'].notna()
        df_valid = df[valid_rows].copy()
        
        print(f"Valid data: {len(df_valid)} out of {len(df)} total rows")
        
        # 4. Get the data you want to encode (now all valid)
        sequences = df_valid['combined_sequence'].values
        v_genes = df_valid['combined_v_gene'].fillna('UNK').values
        j_genes = df_valid['combined_j_gene'].fillna('UNK').values
        labels = [self.label_map[antigen] for antigen in df_valid['Antigen']]
        
        # 5. Encode everything
        X_sequences = self.encode_sequences(sequences)
        X_v_genes = self.encode_v_genes(v_genes)
        X_j_genes = self.encode_j_genes(j_genes)
        
        # 6. Convert to numpy arrays
        X_sequences = np.array(X_sequences)
        X_v_genes = np.array(X_v_genes)
        X_j_genes = np.array(X_j_genes)
        y_labels = np.array(labels)
        
        # 7. Create TensorFlow dataset
        dataset = tf.data.Dataset.from_tensor_slices((
            {'cdr3_sequence': X_sequences, 'v_gene': X_v_genes, 'j_gene': X_j_genes,},
            {'labels': y_labels}
        ))
            
        # Map to the format expected by the model
        dataset = dataset.map(lambda X, y: (X, {'labels': tf.one_hot(y['labels'], len(self.label_map))}))
            
        if shuffle:
            dataset = dataset.shuffle(len(X_sequences), reshuffle_each_iteration=True)
        
        dataset = dataset.batch(batch_size, drop_remainder=True)
        dataset = dataset.prefetch(tf.data.AUTOTUNE)
        
        return dataset
    
    def get_vocab_sizes(self):
        """Return vocabulary sizes for model construction"""
        return {
            'aa_vocab_size': len(self.aa_dict) + 1,  # +1 for padding
            'v_vocab_size': len(self.v_dict) + 1,    # +1 for unknown
            'j_vocab_size': len(self.j_dict) + 1,    # +1 for unknown
            'num_classes': len(self.label_map),
            'max_length': self.max_length
        }
    
    def get_mappings(self):
        """Return the created mappings for inspection"""
        return {
            'aa_dict': self.aa_dict,
            'v_dict': self.v_dict,
            'j_dict': self.j_dict,
            'label_map': self.label_map
        }

# %%
def create_tcr_model(vocab_sizes):
    """Create a model using the Conv1D architecture from the reference"""
    # Input layers
    cdr3_input = keras.Input(shape=(vocab_sizes['max_length'],), dtype=tf.uint32, name='cdr3_sequence')
    v_gene_input = keras.Input(shape=(), dtype=tf.uint32, name='v_gene')
    j_gene_input = keras.Input(shape=(), dtype=tf.uint32, name='j_gene')
    
    # CDR3 sequence encoder (following the reference structure)
    cdr3_embed = keras.layers.Embedding(
        input_dim=vocab_sizes['aa_vocab_size'], 
        output_dim=8, 
        mask_zero=True
    )(cdr3_input)
    
    convs = [keras.layers.Conv1D(
        filters=16, 
        kernel_size=9, 
        strides=1, 
        activation=keras.activations.relu,
        padding='valid'
    )(cdr3_embed)]
    
    convs.append(keras.layers.Conv1D(
        filters=32, 
        kernel_size=7, 
        strides=2, 
        activation=keras.activations.relu,
        padding='valid'
    )(convs[-1]))
    
    # convs.append(keras.layers.Conv1D(
    #     filters=256, 
    #     kernel_size=5, 
    #     strides=1, 
    #     activation=None,
    #     padding='valid'
    # )(convs[-1]))
    
    # Take the first position output (like in reference: [:, 0, :])
    # cdr3_encoded = convs[-1][:, 0, :]

    # pooling to gain positional equivariance
    cdr3_encoded = keras.layers.GlobalMaxPooling1D()(convs[-1])
    
    # Gene embeddings
    v_embed = keras.layers.Embedding(vocab_sizes['v_vocab_size'], 16, mask_zero=True)(v_gene_input)
    j_embed = keras.layers.Embedding(vocab_sizes['j_vocab_size'], 16, mask_zero=True)(j_gene_input)
    
    # Flatten gene embeddings
    # v_flat = tf.keras.layers.Flatten()(v_embed)
    # j_flat = tf.keras.layers.Flatten()(j_embed)
    
    # Concatenate all features
    fused = keras.layers.Concatenate(axis=-1)([cdr3_encoded, v_embed, j_embed])
    
    # Classifier (following reference structure)
    dropout1 = keras.layers.Dropout(rate=0.1)(fused)
    dense1 = keras.layers.Dense(units=32, activation=keras.activations.relu)(dropout1)
    dropout2 = keras.layers.Dropout(rate=0.05)(dense1)
    dense2 = keras.layers.Dense(units=16, activation=keras.activations.relu)(dropout2)
    # output = tf.keras.layers.Dense(units=vocab_sizes['num_classes'], activation='softmax')(dense2)
    output = keras.layers.Dense(units=vocab_sizes['num_classes'], activation='sigmoid')(dense2)

    model = keras.Model(
        inputs=[cdr3_input, v_gene_input, j_gene_input],
        outputs=output
    )
    
    return model

# %%
# Initialize loader
data_dir = './DeepTCR/Data/Murine_Antigens'
loader = TCRDataLoader(data_dir)

# Load data
print("Loading data...")
dataset = loader.load_and_encode_data(batch_size=100, shuffle=True)
print("Data loaded successfully!")
# Out:
# Loading data...
# Combining columns:
#
# Combining sequence columns:
#   Added 1753 values from 'aminoAcid' column
#   Added 1924 values from 'beta' column
#   Total combined values: 3677
#
# Combining v_gene columns:
#   Added 1924 values from 'v_beta' column
#   Added 3678 values from 'vGeneName' column
#   Total combined values: 5602
#
# Combining j_gene columns:
#   Added 1924 values from 'j_beta' column
#   Added 3670 values from 'jGeneName' column
#   Total combined values: 5594
#
# Combining counts columns:
#   Added 1924 values from 'counts' column
#   Added 3679 values from 'count (templates/reads)' column
#   Total combined values: 5603
#
# Vocabulary built:
#   Amino acids: 21 unique
#   V genes: 42 unique
#   J genes: 14 unique
#   Max sequence length: 19
# Valid data: 3677 out of 5603 total rows
# Data loaded successfully!

# %%
loader.v_dict
# Out:
# {'TCRBV01-01': 1,
#  'TCRBV02-01': 2,
#  'TCRBV03-01': 3,
#  'TCRBV04-01': 4,
#  'TCRBV05-01': 5,
#  'TCRBV05-04': 6,
#  'TCRBV06-01': 7,
#  'TCRBV07-01': 8,
#  'TCRBV08-01': 9,
#  'TCRBV09-01': 10,
#  'TCRBV10-01': 11,
#  'TCRBV11-01': 12,
#  'TCRBV12-01': 13,
#  'TCRBV12-02': 14,
#  'TCRBV12-03': 15,
#  'TCRBV13-01': 16,
#  'TCRBV13-02': 17,
#  'TCRBV13-03': 18,
#  'TCRBV13-04': 19,
#  'TCRBV14-01': 20,
#  'TCRBV15-01': 21,
#  'TCRBV16-01': 22,
#  'TCRBV17-01': 23,
#  'TCRBV18-01': 24,
#  'TCRBV19-01': 25,
#  'TCRBV19-03': 26,
#  'TCRBV20-01': 27,
#  'TCRBV20-02': 28,
#  'TCRBV21-01': 29,
#  'TCRBV22-01': 30,
#  'TCRBV23-01': 31,
#  'TCRBV24-01': 32,
#  'TCRBV24-02': 33,
#  'TCRBV25-01': 34,
#  'TCRBV26-01': 35,
#  'TCRBV27-01': 36,
#  'TCRBV28-01': 37,
#  'TCRBV29-01': 38,
#  'TCRBV29-02': 39,
#  'TCRBV30-01': 40,
#  'TCRBV31-01': 41,
#  'TCRBV31-02': 42}

# %%
# Initialize loader
#data_dir = './DeepTCR/Data/Human_Antigens'
#loader = TCRDataLoader(data_dir)

# Load data
#print("Loading data...")
#dataset = loader.load_and_encode_data(batch_size=100, shuffle=True)
#print("Data loaded successfully!")

# %%
# Create model
vocab_sizes = loader.get_vocab_sizes()
print("Creating model...")
model = create_tcr_model(vocab_sizes)

# Compile model
model.compile(
    optimizer='adam', 
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Display model summary
model.summary()
# Out:
# Creating model...
# c:\Users\huang\miniconda3\envs\gpu-ml-base\Lib\site-packages\keras\src\layers\layer.py:932: UserWarning: Layer 'conv1d_4' (of type Conv1D) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ cdr3_sequence       │ (None, 19)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_6         │ (None, 19, 8)     │        176 │ cdr3_sequence[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_4 (Conv1D)   │ (None, 11, 16)    │      1,168 │ embedding_6[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_5 (Conv1D)   │ (None, 3, 32)     │      3,616 │ conv1d_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ v_gene (InputLayer) │ (None)            │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ j_gene (InputLayer) │ (None)            │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 32)        │          0 │ conv1d_5[0][0]    │
# │ (GlobalMaxPooling1… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_7         │ (None, 16)        │        688 │ v_gene[0][0]      │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_8         │ (None, 16)        │        240 │ j_gene[0][0]      │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 64)        │          0 │ global_max_pooli… │
# │ (Concatenate)       │                   │            │ embedding_7[0][0… │
# │                     │                   │            │ embedding_8[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 64)        │          0 │ concatenate_4[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 32)        │      2,080 │ dropout_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 32)        │          0 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 16)        │        528 │ dropout_5[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 9)         │        153 │ dense_7[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 8,649 (33.79 KB)
#  Trainable params: 8,649 (33.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Updated data preparation using combined columns
df = loader.load_files()
df['Antigen'] = df['Antigen'].astype('category')
loader.build_vocabulary(df)

# Filter valid data using combined columns
valid_rows = df['combined_sequence'].notna()
df_valid = df[valid_rows].copy()

print(f"Valid sequences: {len(df_valid)} out of {len(df)} total")

# Encode data using combined columns
sequences = df_valid['combined_sequence'].values
v_genes = df_valid['combined_v_gene'].fillna('UNK').values
j_genes = df_valid['combined_j_gene'].fillna('UNK').values
counts = df_valid['combined_counts'].fillna(1).values  

labels = [loader.label_map[antigen] for antigen in df_valid['Antigen']]

X_sequences = loader.encode_sequences(sequences)
X_v_genes = loader.encode_v_genes(v_genes)
X_j_genes = loader.encode_j_genes(j_genes)

# Convert to numpy
X_sequences = np.array(X_sequences)
X_v_genes = np.array(X_v_genes)
X_j_genes = np.array(X_j_genes)

# Set up data for cross-validation
X = [
    np.array(X_sequences, dtype=np.int32),
    np.array(X_v_genes, dtype=np.int32),
    np.array(X_j_genes, dtype=np.int32)
]
y_true = np.array(df_valid['Antigen'].cat.codes.values, dtype=np.int32)

print(f"Final data shapes:")
print(f"  X[0] (sequences): {X[0].shape}")
print(f"  X[1] (v_genes): {X[1].shape}")
print(f"  X[2] (j_genes): {X[2].shape}")
print(f"  y_true: {y_true.shape}")
# Out:
# Combining columns:
#
# Combining sequence columns:
#   Added 1753 values from 'aminoAcid' column
#   Added 1924 values from 'beta' column
#   Total combined values: 3677
#
# Combining v_gene columns:
#   Added 1924 values from 'v_beta' column
#   Added 3678 values from 'vGeneName' column
#   Total combined values: 5602
#
# Combining j_gene columns:
#   Added 1924 values from 'j_beta' column
#   Added 3670 values from 'jGeneName' column
#   Total combined values: 5594
#
# Combining counts columns:
#   Added 1924 values from 'counts' column
#   Added 3679 values from 'count (templates/reads)' column
#   Total combined values: 5603
#
# Vocabulary built:
#   Amino acids: 21 unique
#   V genes: 42 unique
#   J genes: 14 unique
#   Max sequence length: 19
# Valid sequences: 3677 out of 5603 total
# Final data shapes:
#   X[0] (sequences): (3677, 19)
#   X[1] (v_genes): (3677,)
#   X[2] (j_genes): (3677,)
#   y_true: (3677,)
# C:\Users\huang\AppData\Local\Temp\ipykernel_18128\1068804712.py:16: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   counts = df_valid['combined_counts'].fillna(1).values

# %%
np.unique(df['aminoAcid'].astype('category').cat.codes.values)
# Out:
# array([  -1,    0,    1, ..., 1307, 1308, 1309],
#       shape=(1311,), dtype=int16)

# %%
from utils import KerasCrossValidation

# %%
df_valid
# Out:
#                  beta  counts      v_beta      j_beta Antigen  \
# 0       CASRTGATGQLYF     1.0  TCRBV19-03  TCRBJ02-02      F2
# 1     CASRPDISYNSPLYF     1.0  TCRBV19-03  TCRBJ01-06      F2
# 2        CAIGSNQDTQYF     1.0  TCRBV14-01  TCRBJ02-05      F2
# 3        CASSIGQDEQYF     1.0  TCRBV19-01  TCRBJ02-07      F2
# 4      CASSLFQIQDTQYF     1.0  TCRBV29-01  TCRBJ02-05      F2
# ...               ...     ...         ...         ...     ...
# 5595              NaN     NaN         NaN         NaN    TRP2
# 5597              NaN     NaN         NaN         NaN    TRP2
# 5600              NaN     NaN         NaN         NaN    TRP2
# 5601              NaN     NaN         NaN         NaN    TRP2
# 5602              NaN     NaN         NaN         NaN    TRP2
#
#             aminoAcid  count (templates/reads)   vGeneName   jGeneName  \
# 0                 NaN                      NaN         NaN         NaN
# 1                 NaN                      NaN         NaN         NaN
# 2                 NaN                      NaN         NaN         NaN
# 3                 NaN                      NaN         NaN         NaN
# 4                 NaN                      NaN         NaN         NaN
# ...               ...                      ...         ...         ...
# 5595   CTCSAGWGVYEQYF                      1.0  TCRBV01-01  TCRBJ02-07
# 5597    RSRSIWANTEVFF                      1.0  TCRBV20-01  TCRBJ01-01
# 5600   GCGLGEGTNTEVFF                      1.0  TCRBV18-01  TCRBJ01-01
# 5601   VVQHGDSPNTEVFF                      1.0  TCRBV08-01  TCRBJ01-01
# 5602  RSIAHDTISNERLFF                      1.0  TCRBV15-01  TCRBJ01-04
#
#      combined_sequence combined_v_gene combined_j_gene combined_counts
# 0        CASRTGATGQLYF      TCRBV19-03      TCRBJ02-02             1.0
# 1      CASRPDISYNSPLYF      TCRBV19-03      TCRBJ01-06             1.0
# 2         CAIGSNQDTQYF      TCRBV14-01      TCRBJ02-05             1.0
# 3         CASSIGQDEQYF      TCRBV19-01      TCRBJ02-07             1.0
# 4       CASSLFQIQDTQYF      TCRBV29-01      TCRBJ02-05             1.0
# ...                ...             ...             ...             ...
# 5595    CTCSAGWGVYEQYF      TCRBV01-01      TCRBJ02-07             1.0
# 5597     RSRSIWANTEVFF      TCRBV20-01      TCRBJ01-01             1.0
# 5600    GCGLGEGTNTEVFF      TCRBV18-01      TCRBJ01-01             1.0
# 5601    VVQHGDSPNTEVFF      TCRBV08-01      TCRBJ01-01             1.0
# 5602   RSIAHDTISNERLFF      TCRBV15-01      TCRBJ01-04             1.0
#
# [3677 rows x 13 columns]

# %%
df_valid['combined_sequence']
# Out:
# 0         CASRTGATGQLYF
# 1       CASRPDISYNSPLYF
# 2          CAIGSNQDTQYF
# 3          CASSIGQDEQYF
# 4        CASSLFQIQDTQYF
#              ...
# 5595     CTCSAGWGVYEQYF
# 5597      RSRSIWANTEVFF
# 5600     GCGLGEGTNTEVFF
# 5601     VVQHGDSPNTEVFF
# 5602    RSIAHDTISNERLFF
# Name: combined_sequence, Length: 3677, dtype: object

# %%
df_valid['combined_v_gene']
# Out:
# 0       TCRBV19-03
# 1       TCRBV19-03
# 2       TCRBV14-01
# 3       TCRBV19-01
# 4       TCRBV29-01
#            ...
# 5595    TCRBV01-01
# 5597    TCRBV20-01
# 5600    TCRBV18-01
# 5601    TCRBV08-01
# 5602    TCRBV15-01
# Name: combined_v_gene, Length: 3677, dtype: object

# %%
df_valid['combined_j_gene']
# Out:
# 0       TCRBJ02-02
# 1       TCRBJ01-06
# 2       TCRBJ02-05
# 3       TCRBJ02-07
# 4       TCRBJ02-05
#            ...
# 5595    TCRBJ02-07
# 5597    TCRBJ01-01
# 5600    TCRBJ01-01
# 5601    TCRBJ01-01
# 5602    TCRBJ01-04
# Name: combined_j_gene, Length: 3677, dtype: object

# %%
# set data
X = [
        np.array(X_sequences, dtype=np.int32),
        np.array(X_v_genes, dtype=np.int32),
        np.array(X_j_genes, dtype=np.int32)
    ]
y_true = np.array(y_true, dtype=np.int32)

# %%
X[1]
# Out:
# array([26, 26, 20, ..., 24,  9, 21], shape=(3677,), dtype=int32)

# %%
import os

num_repeats = 50

# Create directory structure for saving models
for repeat in range(num_repeats):
    save_dir = f'./samlogs/fit-{repeat:02d}'
    os.makedirs(save_dir, exist_ok=True)
    print(f"Created directory: {save_dir}")

# Now run your CV loop
y_pred_all = []
y_test_all = []
history_all = []

for repeat in range(num_repeats):
    print(f"Running CV repeat {repeat + 1}/{num_repeats}")

    vocab_sizes = loader.get_vocab_sizes()
    model = create_tcr_model(vocab_sizes)
    model.compile(
        optimizer='adam', 
        loss='binary_crossentropy', 
        metrics=['accuracy']
    )
    
    keras_cv = KerasCrossValidation(X=X, y=y_true, keras_model=model, 
                                    save_filepath=f'./samlogs/fit-{repeat:02d}')
    
    y_pred, y_test, history = keras_cv(n_splits=7, batch_size=500, min_epochs=5, 
                                       patience=30, max_epochs=500, training_repeat=2)
    
    y_pred_all.append(y_pred)
    y_test_all.append(y_test)
    history_all.append(history)
# Out:
# Created directory: ./samlogs/fit-00
# Created directory: ./samlogs/fit-01
# Created directory: ./samlogs/fit-02
# Running CV repeat 1/3
# Epoch 1/500
# c:\Users\huang\miniconda3\envs\gpu-ml-base\Lib\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['cdr3_sequence', 'v_gene', 'j_gene']. Received: the structure of inputs=('*', '*', '*')
#   warnings.warn(
# c:\Users\huang\miniconda3\envs\gpu-ml-base\Lib\site-packages\keras\src\layers\layer.py:932: UserWarning: Layer 'conv1d_4' (of type Conv1D) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.2262 - loss: 0.6791 - val_accuracy: 0.3289 - val_loss: 0.6145
# Epoch 2/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3245 - loss: 0.5732 - val_accuracy: 0.3289 - val_loss: 0.4391
# Epoch 3/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3284 - loss: 0.4300 - val_accuracy: 0.3289 - val_loss: 0.4086
# Epoch 4/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3244 - loss: 0.3999 - val_accuracy: 0.3289 - val_loss: 0.3715
# Epoch 5/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3283 - loss: 0.3669 - val_accuracy: 0.3289 - val_loss: 0.3427
# Epoch 6/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3258 - loss: 0.3418 - val_accuracy: 0.3289 - val_loss: 0.3224
# Epoch 7/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3317 - loss: 0.3227 - val_accuracy: 0.3289 - val_loss: 0.3071
# Epoch 8/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3627 - loss: 0.3089 - val_accuracy: 0.4563 - val_loss: 0.2927
# Epoch 9/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4317 - loss: 0.2949 - val_accuracy: 0.4582 - val_loss: 0.2777
# Epoch 10/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4679 - loss: 0.2835 - val_accuracy: 0.5171 - val_loss: 0.2652
# Epoch 11/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4902 - loss: 0.2718 - val_accuracy: 0.5152 - val_loss: 0.2552
# Epoch 12/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4991 - loss: 0.2634 - val_accuracy: 0.5266 - val_loss: 0.2464
# Epoch 13/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5099 - loss: 0.2537 - val_accuracy: 0.5247 - val_loss: 0.2391
# Epoch 14/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5189 - loss: 0.2457 - val_accuracy: 0.5361 - val_loss: 0.2331
# Epoch 15/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5189 - loss: 0.2419 - val_accuracy: 0.5380 - val_loss: 0.2281
# Epoch 16/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5237 - loss: 0.2363 - val_accuracy: 0.5380 - val_loss: 0.2238
# Epoch 17/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5270 - loss: 0.2315 - val_accuracy: 0.5456 - val_loss: 0.2203
# Epoch 18/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5307 - loss: 0.2262 - val_accuracy: 0.5437 - val_loss: 0.2171
# Epoch 19/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5429 - loss: 0.2247 - val_accuracy: 0.5570 - val_loss: 0.2143
# Epoch 20/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5551 - loss: 0.2218 - val_accuracy: 0.5741 - val_loss: 0.2115
# Epoch 21/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5588 - loss: 0.2213 - val_accuracy: 0.5722 - val_loss: 0.2088
# Epoch 22/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5701 - loss: 0.2134 - val_accuracy: 0.5875 - val_loss: 0.2056
# Epoch 23/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5830 - loss: 0.2138 - val_accuracy: 0.5970 - val_loss: 0.2027
# Epoch 24/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5961 - loss: 0.2085 - val_accuracy: 0.6198 - val_loss: 0.2004
# Epoch 25/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6120 - loss: 0.2059 - val_accuracy: 0.6198 - val_loss: 0.1981
# Epoch 26/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6212 - loss: 0.2032 - val_accuracy: 0.6293 - val_loss: 0.1962
# Epoch 27/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6248 - loss: 0.2008 - val_accuracy: 0.6407 - val_loss: 0.1940
# Epoch 28/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6363 - loss: 0.1980 - val_accuracy: 0.6464 - val_loss: 0.1921
# Epoch 29/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6418 - loss: 0.1934 - val_accuracy: 0.6407 - val_loss: 0.1903
# Epoch 30/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6467 - loss: 0.1906 - val_accuracy: 0.6559 - val_loss: 0.1893
# Epoch 31/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6447 - loss: 0.1916 - val_accuracy: 0.6540 - val_loss: 0.1876
# Epoch 32/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6555 - loss: 0.1891 - val_accuracy: 0.6578 - val_loss: 0.1856
# Epoch 33/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6619 - loss: 0.1842 - val_accuracy: 0.6559 - val_loss: 0.1841
# Epoch 34/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6701 - loss: 0.1847 - val_accuracy: 0.6597 - val_loss: 0.1830
# Epoch 35/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6677 - loss: 0.1792 - val_accuracy: 0.6616 - val_loss: 0.1819
# Epoch 36/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6758 - loss: 0.1780 - val_accuracy: 0.6597 - val_loss: 0.1803
# Epoch 37/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6777 - loss: 0.1739 - val_accuracy: 0.6654 - val_loss: 0.1794
# Epoch 38/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6832 - loss: 0.1745 - val_accuracy: 0.6825 - val_loss: 0.1784
# Epoch 39/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6820 - loss: 0.1713 - val_accuracy: 0.6825 - val_loss: 0.1773
# Epoch 40/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6974 - loss: 0.1672 - val_accuracy: 0.6787 - val_loss: 0.1761
# Epoch 41/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6991 - loss: 0.1672 - val_accuracy: 0.6920 - val_loss: 0.1754
# Epoch 42/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6997 - loss: 0.1650 - val_accuracy: 0.6863 - val_loss: 0.1747
# Epoch 43/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6961 - loss: 0.1641 - val_accuracy: 0.6939 - val_loss: 0.1733
# Epoch 44/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7051 - loss: 0.1629 - val_accuracy: 0.6825 - val_loss: 0.1726
# Epoch 45/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7064 - loss: 0.1612 - val_accuracy: 0.6806 - val_loss: 0.1721
# Epoch 46/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7252 - loss: 0.1572 - val_accuracy: 0.6844 - val_loss: 0.1710
# Epoch 47/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7138 - loss: 0.1577 - val_accuracy: 0.6882 - val_loss: 0.1706
# Epoch 48/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7111 - loss: 0.1578 - val_accuracy: 0.6863 - val_loss: 0.1693
# Epoch 49/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7176 - loss: 0.1561 - val_accuracy: 0.6882 - val_loss: 0.1687
# Epoch 50/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7189 - loss: 0.1531 - val_accuracy: 0.6863 - val_loss: 0.1685
# Epoch 51/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7255 - loss: 0.1512 - val_accuracy: 0.6920 - val_loss: 0.1673
# Epoch 52/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7268 - loss: 0.1519 - val_accuracy: 0.6958 - val_loss: 0.1667
# Epoch 53/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7233 - loss: 0.1509 - val_accuracy: 0.6939 - val_loss: 0.1654
# Epoch 54/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7357 - loss: 0.1476 - val_accuracy: 0.6901 - val_loss: 0.1656
# Epoch 55/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7273 - loss: 0.1459 - val_accuracy: 0.6977 - val_loss: 0.1653
# Epoch 56/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7338 - loss: 0.1446 - val_accuracy: 0.7015 - val_loss: 0.1650
# Epoch 57/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7429 - loss: 0.1420 - val_accuracy: 0.6977 - val_loss: 0.1640
# Epoch 58/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7444 - loss: 0.1441 - val_accuracy: 0.7015 - val_loss: 0.1640
# Epoch 59/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7460 - loss: 0.1397 - val_accuracy: 0.7091 - val_loss: 0.1631
# Epoch 60/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7434 - loss: 0.1386 - val_accuracy: 0.7072 - val_loss: 0.1623
# Epoch 61/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7549 - loss: 0.1347 - val_accuracy: 0.7148 - val_loss: 0.1618
# Epoch 62/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7652 - loss: 0.1357 - val_accuracy: 0.7110 - val_loss: 0.1619
# Epoch 63/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7568 - loss: 0.1345 - val_accuracy: 0.7129 - val_loss: 0.1616
# Epoch 64/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7637 - loss: 0.1314 - val_accuracy: 0.7091 - val_loss: 0.1613
# Epoch 65/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7576 - loss: 0.1343 - val_accuracy: 0.7148 - val_loss: 0.1613
# Epoch 66/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7647 - loss: 0.1304 - val_accuracy: 0.7129 - val_loss: 0.1616
# Epoch 67/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7762 - loss: 0.1277 - val_accuracy: 0.7186 - val_loss: 0.1613
# Epoch 68/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7660 - loss: 0.1291 - val_accuracy: 0.7148 - val_loss: 0.1612
# Epoch 69/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7820 - loss: 0.1236 - val_accuracy: 0.7110 - val_loss: 0.1625
# Epoch 70/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7733 - loss: 0.1257 - val_accuracy: 0.7186 - val_loss: 0.1613
# Epoch 71/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7813 - loss: 0.1232 - val_accuracy: 0.7224 - val_loss: 0.1607
# Epoch 72/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7805 - loss: 0.1241 - val_accuracy: 0.7205 - val_loss: 0.1608
# Epoch 73/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7880 - loss: 0.1205 - val_accuracy: 0.7243 - val_loss: 0.1611
# Epoch 74/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7834 - loss: 0.1203 - val_accuracy: 0.7224 - val_loss: 0.1616
# Epoch 75/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7858 - loss: 0.1205 - val_accuracy: 0.7224 - val_loss: 0.1618
# Epoch 76/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7933 - loss: 0.1180 - val_accuracy: 0.7224 - val_loss: 0.1606
# Epoch 77/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8054 - loss: 0.1143 - val_accuracy: 0.7110 - val_loss: 0.1631
# Epoch 78/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7914 - loss: 0.1205 - val_accuracy: 0.7148 - val_loss: 0.1615
# Epoch 79/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7988 - loss: 0.1145 - val_accuracy: 0.7243 - val_loss: 0.1617
# Epoch 80/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8031 - loss: 0.1124 - val_accuracy: 0.7186 - val_loss: 0.1628
# Epoch 81/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8081 - loss: 0.1121 - val_accuracy: 0.7186 - val_loss: 0.1630
# Epoch 82/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8044 - loss: 0.1134 - val_accuracy: 0.7205 - val_loss: 0.1629
# Epoch 83/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8050 - loss: 0.1099 - val_accuracy: 0.7205 - val_loss: 0.1637
# Epoch 84/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8074 - loss: 0.1110 - val_accuracy: 0.7186 - val_loss: 0.1632
# Epoch 85/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8150 - loss: 0.1079 - val_accuracy: 0.7205 - val_loss: 0.1647
# Epoch 86/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8162 - loss: 0.1069 - val_accuracy: 0.7129 - val_loss: 0.1637
# Epoch 87/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8161 - loss: 0.1048 - val_accuracy: 0.7167 - val_loss: 0.1656
# Epoch 88/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8105 - loss: 0.1090 - val_accuracy: 0.7224 - val_loss: 0.1648
# Epoch 89/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8127 - loss: 0.1065 - val_accuracy: 0.7243 - val_loss: 0.1639
# Epoch 90/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8209 - loss: 0.1048 - val_accuracy: 0.7110 - val_loss: 0.1650
# Epoch 91/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8238 - loss: 0.1030 - val_accuracy: 0.7110 - val_loss: 0.1647
# Epoch 92/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8288 - loss: 0.1019 - val_accuracy: 0.7110 - val_loss: 0.1660
# Epoch 93/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8238 - loss: 0.1032 - val_accuracy: 0.7129 - val_loss: 0.1654
# Epoch 94/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8325 - loss: 0.1004 - val_accuracy: 0.7091 - val_loss: 0.1662
# Epoch 95/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8333 - loss: 0.1012 - val_accuracy: 0.7129 - val_loss: 0.1677
# Epoch 96/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8366 - loss: 0.0962 - val_accuracy: 0.7129 - val_loss: 0.1667
# Epoch 97/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8270 - loss: 0.0983 - val_accuracy: 0.7129 - val_loss: 0.1689
# Epoch 98/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8388 - loss: 0.0956 - val_accuracy: 0.7110 - val_loss: 0.1663
# Epoch 99/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8332 - loss: 0.0974 - val_accuracy: 0.7148 - val_loss: 0.1701
# Epoch 100/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8386 - loss: 0.0957 - val_accuracy: 0.7110 - val_loss: 0.1675
# Epoch 101/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8432 - loss: 0.0918 - val_accuracy: 0.7186 - val_loss: 0.1703
# Epoch 102/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8457 - loss: 0.0931 - val_accuracy: 0.7167 - val_loss: 0.1704
# Epoch 103/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8488 - loss: 0.0929 - val_accuracy: 0.7110 - val_loss: 0.1713
# Epoch 104/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8415 - loss: 0.0928 - val_accuracy: 0.7167 - val_loss: 0.1719
# Epoch 105/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8515 - loss: 0.0898 - val_accuracy: 0.7129 - val_loss: 0.1721
# Epoch 106/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8474 - loss: 0.0920 - val_accuracy: 0.7129 - val_loss: 0.1740
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 325ms/step
# Epoch 1/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.1870 - loss: 0.6849 - val_accuracy: 0.3289 - val_loss: 0.6494
# Epoch 2/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3359 - loss: 0.6301 - val_accuracy: 0.3289 - val_loss: 0.5582
# Epoch 3/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3296 - loss: 0.5227 - val_accuracy: 0.3289 - val_loss: 0.4147
# Epoch 4/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3311 - loss: 0.4045 - val_accuracy: 0.3289 - val_loss: 0.3743
# Epoch 5/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3326 - loss: 0.3621 - val_accuracy: 0.3289 - val_loss: 0.3315
# Epoch 6/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3258 - loss: 0.3273 - val_accuracy: 0.3289 - val_loss: 0.3055
# Epoch 7/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3500 - loss: 0.3064 - val_accuracy: 0.4449 - val_loss: 0.2920
# Epoch 8/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4289 - loss: 0.2945 - val_accuracy: 0.4563 - val_loss: 0.2825
# Epoch 9/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4442 - loss: 0.2856 - val_accuracy: 0.4563 - val_loss: 0.2752
# Epoch 10/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4473 - loss: 0.2794 - val_accuracy: 0.4563 - val_loss: 0.2705
# Epoch 11/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4507 - loss: 0.2750 - val_accuracy: 0.4563 - val_loss: 0.2665
# Epoch 12/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4484 - loss: 0.2716 - val_accuracy: 0.4620 - val_loss: 0.2626
# Epoch 13/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4611 - loss: 0.2664 - val_accuracy: 0.4867 - val_loss: 0.2585
# Epoch 14/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4886 - loss: 0.2617 - val_accuracy: 0.5190 - val_loss: 0.2548
# Epoch 15/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4950 - loss: 0.2600 - val_accuracy: 0.5190 - val_loss: 0.2510
# Epoch 16/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5030 - loss: 0.2557 - val_accuracy: 0.5209 - val_loss: 0.2475
# Epoch 17/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5079 - loss: 0.2528 - val_accuracy: 0.5190 - val_loss: 0.2443
# Epoch 18/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5119 - loss: 0.2500 - val_accuracy: 0.5190 - val_loss: 0.2413
# Epoch 19/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5139 - loss: 0.2464 - val_accuracy: 0.5190 - val_loss: 0.2384
# Epoch 20/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5173 - loss: 0.2422 - val_accuracy: 0.5171 - val_loss: 0.2357
# Epoch 21/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5094 - loss: 0.2411 - val_accuracy: 0.5152 - val_loss: 0.2329
# Epoch 22/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5127 - loss: 0.2386 - val_accuracy: 0.5095 - val_loss: 0.2303
# Epoch 23/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5248 - loss: 0.2340 - val_accuracy: 0.5057 - val_loss: 0.2279
# Epoch 24/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5284 - loss: 0.2317 - val_accuracy: 0.5076 - val_loss: 0.2255
# Epoch 25/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5276 - loss: 0.2296 - val_accuracy: 0.5304 - val_loss: 0.2233
# Epoch 26/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5385 - loss: 0.2294 - val_accuracy: 0.5304 - val_loss: 0.2210
# Epoch 27/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5559 - loss: 0.2265 - val_accuracy: 0.5323 - val_loss: 0.2190
# Epoch 28/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5553 - loss: 0.2253 - val_accuracy: 0.5418 - val_loss: 0.2169
# Epoch 29/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5624 - loss: 0.2209 - val_accuracy: 0.5380 - val_loss: 0.2148
# Epoch 30/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5736 - loss: 0.2189 - val_accuracy: 0.5779 - val_loss: 0.2127
# Epoch 31/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5970 - loss: 0.2159 - val_accuracy: 0.6084 - val_loss: 0.2107
# Epoch 32/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6054 - loss: 0.2119 - val_accuracy: 0.6122 - val_loss: 0.2084
# Epoch 33/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6075 - loss: 0.2106 - val_accuracy: 0.6198 - val_loss: 0.2067
# Epoch 34/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6104 - loss: 0.2097 - val_accuracy: 0.6255 - val_loss: 0.2046
# Epoch 35/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6235 - loss: 0.2067 - val_accuracy: 0.6198 - val_loss: 0.2027
# Epoch 36/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6182 - loss: 0.2067 - val_accuracy: 0.6407 - val_loss: 0.2004
# Epoch 37/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6326 - loss: 0.2013 - val_accuracy: 0.6407 - val_loss: 0.1984
# Epoch 38/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6289 - loss: 0.2014 - val_accuracy: 0.6388 - val_loss: 0.1962
# Epoch 39/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6317 - loss: 0.1988 - val_accuracy: 0.6388 - val_loss: 0.1941
# Epoch 40/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6356 - loss: 0.1978 - val_accuracy: 0.6426 - val_loss: 0.1919
# Epoch 41/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6455 - loss: 0.1910 - val_accuracy: 0.6426 - val_loss: 0.1901
# Epoch 42/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6507 - loss: 0.1927 - val_accuracy: 0.6540 - val_loss: 0.1880
# Epoch 43/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6441 - loss: 0.1902 - val_accuracy: 0.6521 - val_loss: 0.1860
# Epoch 44/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6456 - loss: 0.1903 - val_accuracy: 0.6578 - val_loss: 0.1841
# Epoch 45/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6481 - loss: 0.1884 - val_accuracy: 0.6559 - val_loss: 0.1825
# Epoch 46/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6517 - loss: 0.1846 - val_accuracy: 0.6597 - val_loss: 0.1809
# Epoch 47/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6608 - loss: 0.1810 - val_accuracy: 0.6616 - val_loss: 0.1794
# Epoch 48/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6595 - loss: 0.1793 - val_accuracy: 0.6616 - val_loss: 0.1779
# Epoch 49/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6636 - loss: 0.1783 - val_accuracy: 0.6654 - val_loss: 0.1767
# Epoch 50/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6626 - loss: 0.1791 - val_accuracy: 0.6654 - val_loss: 0.1754
# Epoch 51/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6708 - loss: 0.1741 - val_accuracy: 0.6654 - val_loss: 0.1742
# Epoch 52/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6733 - loss: 0.1715 - val_accuracy: 0.6711 - val_loss: 0.1729
# Epoch 53/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6725 - loss: 0.1725 - val_accuracy: 0.6711 - val_loss: 0.1721
# Epoch 54/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6740 - loss: 0.1711 - val_accuracy: 0.6711 - val_loss: 0.1710
# Epoch 55/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6737 - loss: 0.1706 - val_accuracy: 0.6749 - val_loss: 0.1704
# Epoch 56/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6787 - loss: 0.1714 - val_accuracy: 0.6768 - val_loss: 0.1692
# Epoch 57/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6898 - loss: 0.1651 - val_accuracy: 0.6730 - val_loss: 0.1680
# Epoch 58/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6854 - loss: 0.1686 - val_accuracy: 0.6730 - val_loss: 0.1674
# Epoch 59/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6901 - loss: 0.1644 - val_accuracy: 0.6806 - val_loss: 0.1662
# Epoch 60/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6852 - loss: 0.1663 - val_accuracy: 0.6825 - val_loss: 0.1654
# Epoch 61/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6951 - loss: 0.1613 - val_accuracy: 0.6806 - val_loss: 0.1652
# Epoch 62/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6855 - loss: 0.1629 - val_accuracy: 0.6901 - val_loss: 0.1638
# Epoch 63/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7042 - loss: 0.1596 - val_accuracy: 0.6844 - val_loss: 0.1624
# Epoch 64/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7023 - loss: 0.1578 - val_accuracy: 0.6863 - val_loss: 0.1616
# Epoch 65/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7055 - loss: 0.1571 - val_accuracy: 0.6844 - val_loss: 0.1612
# Epoch 66/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7073 - loss: 0.1561 - val_accuracy: 0.6901 - val_loss: 0.1600
# Epoch 67/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7138 - loss: 0.1536 - val_accuracy: 0.6939 - val_loss: 0.1592
# Epoch 68/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7159 - loss: 0.1527 - val_accuracy: 0.6920 - val_loss: 0.1584
# Epoch 69/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7105 - loss: 0.1542 - val_accuracy: 0.6958 - val_loss: 0.1578
# Epoch 70/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7215 - loss: 0.1525 - val_accuracy: 0.6958 - val_loss: 0.1571
# Epoch 71/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7243 - loss: 0.1485 - val_accuracy: 0.6958 - val_loss: 0.1562
# Epoch 72/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7280 - loss: 0.1462 - val_accuracy: 0.6996 - val_loss: 0.1555
# Epoch 73/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7383 - loss: 0.1457 - val_accuracy: 0.7053 - val_loss: 0.1550
# Epoch 74/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7232 - loss: 0.1496 - val_accuracy: 0.6996 - val_loss: 0.1547
# Epoch 75/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7304 - loss: 0.1456 - val_accuracy: 0.7034 - val_loss: 0.1539
# Epoch 76/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7293 - loss: 0.1474 - val_accuracy: 0.7205 - val_loss: 0.1529
# Epoch 77/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7342 - loss: 0.1431 - val_accuracy: 0.7091 - val_loss: 0.1527
# Epoch 78/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7261 - loss: 0.1450 - val_accuracy: 0.7129 - val_loss: 0.1524
# Epoch 79/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7318 - loss: 0.1460 - val_accuracy: 0.7110 - val_loss: 0.1524
# Epoch 80/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7438 - loss: 0.1412 - val_accuracy: 0.7129 - val_loss: 0.1521
# Epoch 81/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7327 - loss: 0.1427 - val_accuracy: 0.7148 - val_loss: 0.1515
# Epoch 82/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7424 - loss: 0.1381 - val_accuracy: 0.7243 - val_loss: 0.1519
# Epoch 83/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7436 - loss: 0.1392 - val_accuracy: 0.7224 - val_loss: 0.1511
# Epoch 84/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7530 - loss: 0.1377 - val_accuracy: 0.7262 - val_loss: 0.1511
# Epoch 85/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7510 - loss: 0.1355 - val_accuracy: 0.7243 - val_loss: 0.1506
# Epoch 86/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7529 - loss: 0.1331 - val_accuracy: 0.7262 - val_loss: 0.1501
# Epoch 87/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7577 - loss: 0.1319 - val_accuracy: 0.7281 - val_loss: 0.1500
# Epoch 88/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7441 - loss: 0.1364 - val_accuracy: 0.7262 - val_loss: 0.1498
# Epoch 89/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7568 - loss: 0.1333 - val_accuracy: 0.7300 - val_loss: 0.1493
# Epoch 90/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7591 - loss: 0.1298 - val_accuracy: 0.7281 - val_loss: 0.1491
# Epoch 91/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7679 - loss: 0.1313 - val_accuracy: 0.7281 - val_loss: 0.1493
# Epoch 92/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7567 - loss: 0.1304 - val_accuracy: 0.7262 - val_loss: 0.1485
# Epoch 93/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7674 - loss: 0.1275 - val_accuracy: 0.7243 - val_loss: 0.1489
# Epoch 94/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7685 - loss: 0.1294 - val_accuracy: 0.7281 - val_loss: 0.1495
# Epoch 95/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7605 - loss: 0.1286 - val_accuracy: 0.7300 - val_loss: 0.1489
# Epoch 96/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7704 - loss: 0.1272 - val_accuracy: 0.7338 - val_loss: 0.1490
# Epoch 97/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7785 - loss: 0.1241 - val_accuracy: 0.7357 - val_loss: 0.1488
# Epoch 98/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7765 - loss: 0.1232 - val_accuracy: 0.7300 - val_loss: 0.1492
# Epoch 99/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7820 - loss: 0.1228 - val_accuracy: 0.7300 - val_loss: 0.1488
# Epoch 100/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7834 - loss: 0.1214 - val_accuracy: 0.7376 - val_loss: 0.1485
# Epoch 101/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7814 - loss: 0.1204 - val_accuracy: 0.7395 - val_loss: 0.1490
# Epoch 102/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7829 - loss: 0.1197 - val_accuracy: 0.7300 - val_loss: 0.1487
# Epoch 103/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7829 - loss: 0.1204 - val_accuracy: 0.7319 - val_loss: 0.1497
# Epoch 104/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7793 - loss: 0.1195 - val_accuracy: 0.7300 - val_loss: 0.1494
# Epoch 105/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7849 - loss: 0.1177 - val_accuracy: 0.7281 - val_loss: 0.1488
# Epoch 106/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7823 - loss: 0.1199 - val_accuracy: 0.7319 - val_loss: 0.1498
# Epoch 107/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8005 - loss: 0.1131 - val_accuracy: 0.7281 - val_loss: 0.1500
# Epoch 108/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8021 - loss: 0.1108 - val_accuracy: 0.7319 - val_loss: 0.1503
# Epoch 109/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7962 - loss: 0.1131 - val_accuracy: 0.7319 - val_loss: 0.1497
# Epoch 110/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7984 - loss: 0.1129 - val_accuracy: 0.7338 - val_loss: 0.1515
# Epoch 111/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8048 - loss: 0.1111 - val_accuracy: 0.7319 - val_loss: 0.1521
# Epoch 112/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8060 - loss: 0.1111 - val_accuracy: 0.7300 - val_loss: 0.1507
# Epoch 113/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8041 - loss: 0.1090 - val_accuracy: 0.7319 - val_loss: 0.1514
# Epoch 114/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8074 - loss: 0.1091 - val_accuracy: 0.7395 - val_loss: 0.1515
# Epoch 115/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8094 - loss: 0.1091 - val_accuracy: 0.7300 - val_loss: 0.1520
# Epoch 116/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8164 - loss: 0.1059 - val_accuracy: 0.7376 - val_loss: 0.1525
# Epoch 117/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8204 - loss: 0.1044 - val_accuracy: 0.7414 - val_loss: 0.1523
# Epoch 118/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8241 - loss: 0.1030 - val_accuracy: 0.7395 - val_loss: 0.1535
# Epoch 119/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8125 - loss: 0.1056 - val_accuracy: 0.7300 - val_loss: 0.1535
# Epoch 120/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8175 - loss: 0.1042 - val_accuracy: 0.7357 - val_loss: 0.1536
# Epoch 121/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8219 - loss: 0.1016 - val_accuracy: 0.7395 - val_loss: 0.1557
# Epoch 122/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8197 - loss: 0.1005 - val_accuracy: 0.7319 - val_loss: 0.1558
# Epoch 123/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8260 - loss: 0.0996 - val_accuracy: 0.7357 - val_loss: 0.1545
# Epoch 124/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8266 - loss: 0.0982 - val_accuracy: 0.7357 - val_loss: 0.1574
# Epoch 125/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8231 - loss: 0.0981 - val_accuracy: 0.7357 - val_loss: 0.1553
# Epoch 126/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8347 - loss: 0.1001 - val_accuracy: 0.7395 - val_loss: 0.1570
# Epoch 127/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8273 - loss: 0.0957 - val_accuracy: 0.7357 - val_loss: 0.1563
# Epoch 128/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8374 - loss: 0.0947 - val_accuracy: 0.7376 - val_loss: 0.1582
# Epoch 129/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8407 - loss: 0.0943 - val_accuracy: 0.7414 - val_loss: 0.1564
# Epoch 130/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8375 - loss: 0.0942 - val_accuracy: 0.7319 - val_loss: 0.1586
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Epoch 1/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1764 - loss: 0.6853 - val_accuracy: 0.3295 - val_loss: 0.6507
# Epoch 2/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3298 - loss: 0.6318 - val_accuracy: 0.3295 - val_loss: 0.5630
# Epoch 3/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3272 - loss: 0.5302 - val_accuracy: 0.3295 - val_loss: 0.4196
# Epoch 4/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3249 - loss: 0.4023 - val_accuracy: 0.3295 - val_loss: 0.3721
# Epoch 5/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3286 - loss: 0.3614 - val_accuracy: 0.3295 - val_loss: 0.3272
# Epoch 6/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3237 - loss: 0.3274 - val_accuracy: 0.3295 - val_loss: 0.3149
# Epoch 7/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3306 - loss: 0.3148 - val_accuracy: 0.3295 - val_loss: 0.3071
# Epoch 8/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3283 - loss: 0.3075 - val_accuracy: 0.3295 - val_loss: 0.3016
# Epoch 9/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3298 - loss: 0.3021 - val_accuracy: 0.3295 - val_loss: 0.2959
# Epoch 10/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3602 - loss: 0.2974 - val_accuracy: 0.4457 - val_loss: 0.2883
# Epoch 11/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4430 - loss: 0.2895 - val_accuracy: 0.4457 - val_loss: 0.2795
# Epoch 12/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4481 - loss: 0.2803 - val_accuracy: 0.4457 - val_loss: 0.2727
# Epoch 13/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4593 - loss: 0.2719 - val_accuracy: 0.4457 - val_loss: 0.2671
# Epoch 14/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4550 - loss: 0.2666 - val_accuracy: 0.4990 - val_loss: 0.2618
# Epoch 15/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4964 - loss: 0.2610 - val_accuracy: 0.4990 - val_loss: 0.2567
# Epoch 16/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5077 - loss: 0.2549 - val_accuracy: 0.4990 - val_loss: 0.2517
# Epoch 17/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5014 - loss: 0.2528 - val_accuracy: 0.4990 - val_loss: 0.2474
# Epoch 18/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5100 - loss: 0.2466 - val_accuracy: 0.4933 - val_loss: 0.2439
# Epoch 19/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5013 - loss: 0.2440 - val_accuracy: 0.4952 - val_loss: 0.2410
# Epoch 20/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5164 - loss: 0.2398 - val_accuracy: 0.5010 - val_loss: 0.2385
# Epoch 21/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5156 - loss: 0.2375 - val_accuracy: 0.4971 - val_loss: 0.2362
# Epoch 22/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5168 - loss: 0.2355 - val_accuracy: 0.4933 - val_loss: 0.2340
# Epoch 23/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5211 - loss: 0.2351 - val_accuracy: 0.4952 - val_loss: 0.2320
# Epoch 24/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5157 - loss: 0.2333 - val_accuracy: 0.4933 - val_loss: 0.2299
# Epoch 25/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5217 - loss: 0.2319 - val_accuracy: 0.4971 - val_loss: 0.2281
# Epoch 26/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5329 - loss: 0.2268 - val_accuracy: 0.4990 - val_loss: 0.2260
# Epoch 27/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5257 - loss: 0.2284 - val_accuracy: 0.4990 - val_loss: 0.2242
# Epoch 28/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5431 - loss: 0.2243 - val_accuracy: 0.5029 - val_loss: 0.2221
# Epoch 29/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5563 - loss: 0.2218 - val_accuracy: 0.5467 - val_loss: 0.2202
# Epoch 30/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5656 - loss: 0.2205 - val_accuracy: 0.5524 - val_loss: 0.2182
# Epoch 31/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5867 - loss: 0.2173 - val_accuracy: 0.5829 - val_loss: 0.2161
# Epoch 32/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5727 - loss: 0.2190 - val_accuracy: 0.5981 - val_loss: 0.2143
# Epoch 33/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5922 - loss: 0.2171 - val_accuracy: 0.6019 - val_loss: 0.2126
# Epoch 34/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5996 - loss: 0.2164 - val_accuracy: 0.6152 - val_loss: 0.2107
# Epoch 35/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6122 - loss: 0.2116 - val_accuracy: 0.6190 - val_loss: 0.2090
# Epoch 36/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6104 - loss: 0.2104 - val_accuracy: 0.6152 - val_loss: 0.2074
# Epoch 37/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6187 - loss: 0.2103 - val_accuracy: 0.6190 - val_loss: 0.2056
# Epoch 38/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6209 - loss: 0.2089 - val_accuracy: 0.6248 - val_loss: 0.2040
# Epoch 39/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6334 - loss: 0.2011 - val_accuracy: 0.6248 - val_loss: 0.2024
# Epoch 40/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6183 - loss: 0.2050 - val_accuracy: 0.6305 - val_loss: 0.2007
# Epoch 41/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6437 - loss: 0.1992 - val_accuracy: 0.6343 - val_loss: 0.1992
# Epoch 42/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6277 - loss: 0.2021 - val_accuracy: 0.6476 - val_loss: 0.1977
# Epoch 43/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6410 - loss: 0.1987 - val_accuracy: 0.6438 - val_loss: 0.1964
# Epoch 44/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6381 - loss: 0.1957 - val_accuracy: 0.6419 - val_loss: 0.1948
# Epoch 45/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6337 - loss: 0.1968 - val_accuracy: 0.6438 - val_loss: 0.1936
# Epoch 46/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6468 - loss: 0.1940 - val_accuracy: 0.6438 - val_loss: 0.1925
# Epoch 47/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6591 - loss: 0.1899 - val_accuracy: 0.6514 - val_loss: 0.1911
# Epoch 48/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6517 - loss: 0.1900 - val_accuracy: 0.6495 - val_loss: 0.1902
# Epoch 49/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6509 - loss: 0.1886 - val_accuracy: 0.6476 - val_loss: 0.1886
# Epoch 50/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6598 - loss: 0.1869 - val_accuracy: 0.6552 - val_loss: 0.1876
# Epoch 51/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6560 - loss: 0.1851 - val_accuracy: 0.6533 - val_loss: 0.1866
# Epoch 52/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6740 - loss: 0.1828 - val_accuracy: 0.6533 - val_loss: 0.1855
# Epoch 53/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6750 - loss: 0.1800 - val_accuracy: 0.6590 - val_loss: 0.1845
# Epoch 54/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6685 - loss: 0.1824 - val_accuracy: 0.6571 - val_loss: 0.1837
# Epoch 55/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6687 - loss: 0.1817 - val_accuracy: 0.6590 - val_loss: 0.1824
# Epoch 56/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6758 - loss: 0.1778 - val_accuracy: 0.6610 - val_loss: 0.1817
# Epoch 57/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6699 - loss: 0.1793 - val_accuracy: 0.6571 - val_loss: 0.1806
# Epoch 58/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6821 - loss: 0.1754 - val_accuracy: 0.6648 - val_loss: 0.1798
# Epoch 59/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6800 - loss: 0.1754 - val_accuracy: 0.6705 - val_loss: 0.1789
# Epoch 60/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6805 - loss: 0.1746 - val_accuracy: 0.6743 - val_loss: 0.1780
# Epoch 61/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6781 - loss: 0.1738 - val_accuracy: 0.6762 - val_loss: 0.1776
# Epoch 62/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6819 - loss: 0.1747 - val_accuracy: 0.6724 - val_loss: 0.1768
# Epoch 63/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6830 - loss: 0.1717 - val_accuracy: 0.6819 - val_loss: 0.1759
# Epoch 64/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6906 - loss: 0.1695 - val_accuracy: 0.6819 - val_loss: 0.1751
# Epoch 65/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7036 - loss: 0.1660 - val_accuracy: 0.6857 - val_loss: 0.1744
# Epoch 66/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6898 - loss: 0.1690 - val_accuracy: 0.6838 - val_loss: 0.1738
# Epoch 67/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7002 - loss: 0.1648 - val_accuracy: 0.6800 - val_loss: 0.1730
# Epoch 68/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7099 - loss: 0.1622 - val_accuracy: 0.6838 - val_loss: 0.1726
# Epoch 69/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6999 - loss: 0.1632 - val_accuracy: 0.6743 - val_loss: 0.1719
# Epoch 70/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6981 - loss: 0.1629 - val_accuracy: 0.6857 - val_loss: 0.1713
# Epoch 71/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7038 - loss: 0.1625 - val_accuracy: 0.6819 - val_loss: 0.1706
# Epoch 72/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7010 - loss: 0.1623 - val_accuracy: 0.6819 - val_loss: 0.1701
# Epoch 73/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7018 - loss: 0.1603 - val_accuracy: 0.6857 - val_loss: 0.1700
# Epoch 74/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7144 - loss: 0.1588 - val_accuracy: 0.6762 - val_loss: 0.1693
# Epoch 75/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7016 - loss: 0.1606 - val_accuracy: 0.6838 - val_loss: 0.1688
# Epoch 76/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6990 - loss: 0.1611 - val_accuracy: 0.6857 - val_loss: 0.1682
# Epoch 77/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7134 - loss: 0.1579 - val_accuracy: 0.6876 - val_loss: 0.1678
# Epoch 78/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7107 - loss: 0.1551 - val_accuracy: 0.6895 - val_loss: 0.1672
# Epoch 79/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7090 - loss: 0.1583 - val_accuracy: 0.6933 - val_loss: 0.1667
# Epoch 80/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7093 - loss: 0.1549 - val_accuracy: 0.6952 - val_loss: 0.1663
# Epoch 81/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7209 - loss: 0.1516 - val_accuracy: 0.6952 - val_loss: 0.1658
# Epoch 82/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7116 - loss: 0.1536 - val_accuracy: 0.6933 - val_loss: 0.1650
# Epoch 83/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7200 - loss: 0.1507 - val_accuracy: 0.7010 - val_loss: 0.1647
# Epoch 84/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7214 - loss: 0.1534 - val_accuracy: 0.6990 - val_loss: 0.1646
# Epoch 85/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7190 - loss: 0.1502 - val_accuracy: 0.7067 - val_loss: 0.1644
# Epoch 86/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7165 - loss: 0.1522 - val_accuracy: 0.7048 - val_loss: 0.1639
# Epoch 87/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7180 - loss: 0.1485 - val_accuracy: 0.6990 - val_loss: 0.1635
# Epoch 88/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7241 - loss: 0.1486 - val_accuracy: 0.7067 - val_loss: 0.1628
# Epoch 89/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7300 - loss: 0.1431 - val_accuracy: 0.7010 - val_loss: 0.1626
# Epoch 90/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7206 - loss: 0.1487 - val_accuracy: 0.7029 - val_loss: 0.1619
# Epoch 91/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7325 - loss: 0.1462 - val_accuracy: 0.7010 - val_loss: 0.1614
# Epoch 92/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7296 - loss: 0.1452 - val_accuracy: 0.7067 - val_loss: 0.1612
# Epoch 93/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7310 - loss: 0.1453 - val_accuracy: 0.7067 - val_loss: 0.1610
# Epoch 94/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7298 - loss: 0.1423 - val_accuracy: 0.7105 - val_loss: 0.1609
# Epoch 95/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7392 - loss: 0.1420 - val_accuracy: 0.7067 - val_loss: 0.1604
# Epoch 96/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7460 - loss: 0.1402 - val_accuracy: 0.7067 - val_loss: 0.1600
# Epoch 97/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7405 - loss: 0.1399 - val_accuracy: 0.7124 - val_loss: 0.1600
# Epoch 98/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7491 - loss: 0.1360 - val_accuracy: 0.7086 - val_loss: 0.1597
# Epoch 99/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7517 - loss: 0.1371 - val_accuracy: 0.7105 - val_loss: 0.1592
# Epoch 100/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7461 - loss: 0.1368 - val_accuracy: 0.7124 - val_loss: 0.1589
# Epoch 101/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7522 - loss: 0.1360 - val_accuracy: 0.7143 - val_loss: 0.1586
# Epoch 102/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7466 - loss: 0.1373 - val_accuracy: 0.7086 - val_loss: 0.1582
# Epoch 103/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7516 - loss: 0.1344 - val_accuracy: 0.7105 - val_loss: 0.1581
# Epoch 104/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7635 - loss: 0.1324 - val_accuracy: 0.7010 - val_loss: 0.1586
# Epoch 105/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7595 - loss: 0.1301 - val_accuracy: 0.7124 - val_loss: 0.1585
# Epoch 106/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7535 - loss: 0.1347 - val_accuracy: 0.7124 - val_loss: 0.1580
# Epoch 107/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7703 - loss: 0.1266 - val_accuracy: 0.7124 - val_loss: 0.1579
# Epoch 108/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7640 - loss: 0.1300 - val_accuracy: 0.7143 - val_loss: 0.1578
# Epoch 109/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7657 - loss: 0.1284 - val_accuracy: 0.7200 - val_loss: 0.1574
# Epoch 110/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7702 - loss: 0.1283 - val_accuracy: 0.7181 - val_loss: 0.1571
# Epoch 111/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7752 - loss: 0.1261 - val_accuracy: 0.7219 - val_loss: 0.1571
# Epoch 112/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7673 - loss: 0.1275 - val_accuracy: 0.7162 - val_loss: 0.1570
# Epoch 113/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7693 - loss: 0.1265 - val_accuracy: 0.7295 - val_loss: 0.1569
# Epoch 114/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7739 - loss: 0.1257 - val_accuracy: 0.7238 - val_loss: 0.1566
# Epoch 115/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7740 - loss: 0.1237 - val_accuracy: 0.7276 - val_loss: 0.1564
# Epoch 116/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7788 - loss: 0.1213 - val_accuracy: 0.7238 - val_loss: 0.1575
# Epoch 117/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7751 - loss: 0.1235 - val_accuracy: 0.7295 - val_loss: 0.1569
# Epoch 118/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7912 - loss: 0.1206 - val_accuracy: 0.7238 - val_loss: 0.1579
# Epoch 119/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7897 - loss: 0.1206 - val_accuracy: 0.7276 - val_loss: 0.1575
# Epoch 120/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7849 - loss: 0.1196 - val_accuracy: 0.7200 - val_loss: 0.1572
# Epoch 121/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7870 - loss: 0.1189 - val_accuracy: 0.7219 - val_loss: 0.1583
# Epoch 122/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7960 - loss: 0.1153 - val_accuracy: 0.7276 - val_loss: 0.1581
# Epoch 123/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7917 - loss: 0.1178 - val_accuracy: 0.7295 - val_loss: 0.1584
# Epoch 124/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7844 - loss: 0.1170 - val_accuracy: 0.7257 - val_loss: 0.1575
# Epoch 125/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7993 - loss: 0.1143 - val_accuracy: 0.7181 - val_loss: 0.1577
# Epoch 126/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8017 - loss: 0.1130 - val_accuracy: 0.7257 - val_loss: 0.1582
# Epoch 127/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8094 - loss: 0.1114 - val_accuracy: 0.7181 - val_loss: 0.1588
# Epoch 128/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7993 - loss: 0.1133 - val_accuracy: 0.7333 - val_loss: 0.1583
# Epoch 129/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8058 - loss: 0.1105 - val_accuracy: 0.7276 - val_loss: 0.1582
# Epoch 130/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8057 - loss: 0.1091 - val_accuracy: 0.7314 - val_loss: 0.1592
# Epoch 131/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8084 - loss: 0.1085 - val_accuracy: 0.7276 - val_loss: 0.1588
# Epoch 132/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8092 - loss: 0.1076 - val_accuracy: 0.7200 - val_loss: 0.1595
# Epoch 133/500
# ...
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7978 - loss: 0.1123 - val_accuracy: 0.7257 - val_loss: 0.1423
# Epoch 23/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8002 - loss: 0.1120 - val_accuracy: 0.7219 - val_loss: 0.1419
# Epoch 24/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7979 - loss: 0.1114 - val_accuracy: 0.7238 - val_loss: 0.1421
# Epoch 25/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7999 - loss: 0.1102 - val_accuracy: 0.7219 - val_loss: 0.1426
# Epoch 26/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8067 - loss: 0.1065 - val_accuracy: 0.7181 - val_loss: 0.1436
# Epoch 27/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8116 - loss: 0.1067 - val_accuracy: 0.7181 - val_loss: 0.1432
# Epoch 28/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8138 - loss: 0.1039 - val_accuracy: 0.7200 - val_loss: 0.1439
# Epoch 29/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8149 - loss: 0.1036 - val_accuracy: 0.7200 - val_loss: 0.1450
# Epoch 30/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8103 - loss: 0.1041 - val_accuracy: 0.7181 - val_loss: 0.1437
# Epoch 31/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8200 - loss: 0.1039 - val_accuracy: 0.7295 - val_loss: 0.1445
# Epoch 32/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8200 - loss: 0.1014 - val_accuracy: 0.7181 - val_loss: 0.1462
# Epoch 33/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8235 - loss: 0.1022 - val_accuracy: 0.7200 - val_loss: 0.1456
# Epoch 34/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8293 - loss: 0.0999 - val_accuracy: 0.7200 - val_loss: 0.1466
# Epoch 35/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8235 - loss: 0.0989 - val_accuracy: 0.7181 - val_loss: 0.1476
# Epoch 36/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8295 - loss: 0.0966 - val_accuracy: 0.7295 - val_loss: 0.1476
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 1/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7448 - loss: 0.1373 - val_accuracy: 0.7524 - val_loss: 0.1302
# Epoch 2/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7408 - loss: 0.1374 - val_accuracy: 0.7390 - val_loss: 0.1322
# Epoch 3/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7393 - loss: 0.1356 - val_accuracy: 0.7429 - val_loss: 0.1323
# Epoch 4/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7516 - loss: 0.1320 - val_accuracy: 0.7467 - val_loss: 0.1335
# Epoch 5/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7543 - loss: 0.1312 - val_accuracy: 0.7371 - val_loss: 0.1337
# Epoch 6/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7613 - loss: 0.1278 - val_accuracy: 0.7390 - val_loss: 0.1345
# Epoch 7/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7687 - loss: 0.1266 - val_accuracy: 0.7390 - val_loss: 0.1343
# Epoch 8/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7560 - loss: 0.1282 - val_accuracy: 0.7371 - val_loss: 0.1348
# Epoch 9/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7665 - loss: 0.1252 - val_accuracy: 0.7314 - val_loss: 0.1354
# Epoch 10/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7742 - loss: 0.1234 - val_accuracy: 0.7390 - val_loss: 0.1358
# Epoch 11/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7705 - loss: 0.1238 - val_accuracy: 0.7295 - val_loss: 0.1360
# Epoch 12/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7775 - loss: 0.1227 - val_accuracy: 0.7333 - val_loss: 0.1359
# Epoch 13/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7754 - loss: 0.1213 - val_accuracy: 0.7352 - val_loss: 0.1365
# Epoch 14/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7769 - loss: 0.1199 - val_accuracy: 0.7295 - val_loss: 0.1367
# Epoch 15/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7785 - loss: 0.1198 - val_accuracy: 0.7295 - val_loss: 0.1365
# Epoch 16/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7790 - loss: 0.1185 - val_accuracy: 0.7352 - val_loss: 0.1376
# Epoch 17/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7907 - loss: 0.1173 - val_accuracy: 0.7352 - val_loss: 0.1377
# Epoch 18/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7752 - loss: 0.1196 - val_accuracy: 0.7390 - val_loss: 0.1382
# Epoch 19/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7852 - loss: 0.1157 - val_accuracy: 0.7429 - val_loss: 0.1378
# Epoch 20/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7877 - loss: 0.1152 - val_accuracy: 0.7390 - val_loss: 0.1386
# Epoch 21/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7870 - loss: 0.1129 - val_accuracy: 0.7371 - val_loss: 0.1387
# Epoch 22/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7900 - loss: 0.1135 - val_accuracy: 0.7390 - val_loss: 0.1392
# Epoch 23/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7940 - loss: 0.1127 - val_accuracy: 0.7448 - val_loss: 0.1399
# Epoch 24/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8028 - loss: 0.1085 - val_accuracy: 0.7352 - val_loss: 0.1396
# Epoch 25/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7969 - loss: 0.1108 - val_accuracy: 0.7429 - val_loss: 0.1389
# Epoch 26/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8006 - loss: 0.1091 - val_accuracy: 0.7390 - val_loss: 0.1395
# Epoch 27/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8027 - loss: 0.1101 - val_accuracy: 0.7448 - val_loss: 0.1405
# Epoch 28/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8001 - loss: 0.1106 - val_accuracy: 0.7467 - val_loss: 0.1393
# Epoch 29/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8067 - loss: 0.1060 - val_accuracy: 0.7410 - val_loss: 0.1390
# Epoch 30/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8030 - loss: 0.1070 - val_accuracy: 0.7467 - val_loss: 0.1416
# Epoch 31/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8137 - loss: 0.1052 - val_accuracy: 0.7467 - val_loss: 0.1411
# Epoch 32/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8112 - loss: 0.1040 - val_accuracy: 0.7486 - val_loss: 0.1403
# Epoch 33/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8148 - loss: 0.1026 - val_accuracy: 0.7352 - val_loss: 0.1424
# Epoch 34/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8226 - loss: 0.0979 - val_accuracy: 0.7467 - val_loss: 0.1430
# Epoch 35/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8161 - loss: 0.1023 - val_accuracy: 0.7486 - val_loss: 0.1447
# Epoch 36/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8245 - loss: 0.1004 - val_accuracy: 0.7505 - val_loss: 0.1445
# Epoch 37/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8285 - loss: 0.0978 - val_accuracy: 0.7448 - val_loss: 0.1462
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 1/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7564 - loss: 0.1313 - val_accuracy: 0.7657 - val_loss: 0.1253
# Epoch 2/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7650 - loss: 0.1287 - val_accuracy: 0.7638 - val_loss: 0.1264
# Epoch 3/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7582 - loss: 0.1309 - val_accuracy: 0.7600 - val_loss: 0.1273
# Epoch 4/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7624 - loss: 0.1311 - val_accuracy: 0.7638 - val_loss: 0.1284
# Epoch 5/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7710 - loss: 0.1244 - val_accuracy: 0.7505 - val_loss: 0.1288
# Epoch 6/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7660 - loss: 0.1261 - val_accuracy: 0.7467 - val_loss: 0.1290
# Epoch 7/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7659 - loss: 0.1266 - val_accuracy: 0.7505 - val_loss: 0.1295
# Epoch 8/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7709 - loss: 0.1231 - val_accuracy: 0.7448 - val_loss: 0.1295
# Epoch 9/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7713 - loss: 0.1239 - val_accuracy: 0.7467 - val_loss: 0.1301
# Epoch 10/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7767 - loss: 0.1233 - val_accuracy: 0.7390 - val_loss: 0.1306
# Epoch 11/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7800 - loss: 0.1214 - val_accuracy: 0.7467 - val_loss: 0.1305
# Epoch 12/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7797 - loss: 0.1198 - val_accuracy: 0.7448 - val_loss: 0.1311
# Epoch 13/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7764 - loss: 0.1196 - val_accuracy: 0.7486 - val_loss: 0.1313
# Epoch 14/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7814 - loss: 0.1167 - val_accuracy: 0.7410 - val_loss: 0.1321
# Epoch 15/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7820 - loss: 0.1175 - val_accuracy: 0.7467 - val_loss: 0.1323
# Epoch 16/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7939 - loss: 0.1162 - val_accuracy: 0.7486 - val_loss: 0.1324
# Epoch 17/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7931 - loss: 0.1156 - val_accuracy: 0.7467 - val_loss: 0.1328
# Epoch 18/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7857 - loss: 0.1154 - val_accuracy: 0.7429 - val_loss: 0.1331
# Epoch 19/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7895 - loss: 0.1148 - val_accuracy: 0.7429 - val_loss: 0.1326
# Epoch 20/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8026 - loss: 0.1108 - val_accuracy: 0.7429 - val_loss: 0.1333
# Epoch 21/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8015 - loss: 0.1105 - val_accuracy: 0.7352 - val_loss: 0.1336
# Epoch 22/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8060 - loss: 0.1091 - val_accuracy: 0.7410 - val_loss: 0.1345
# Epoch 23/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8034 - loss: 0.1091 - val_accuracy: 0.7486 - val_loss: 0.1341
# Epoch 24/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8033 - loss: 0.1086 - val_accuracy: 0.7543 - val_loss: 0.1346
# Epoch 25/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8118 - loss: 0.1067 - val_accuracy: 0.7429 - val_loss: 0.1346
# Epoch 26/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8113 - loss: 0.1064 - val_accuracy: 0.7410 - val_loss: 0.1353
# Epoch 27/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8143 - loss: 0.1059 - val_accuracy: 0.7390 - val_loss: 0.1363
# Epoch 28/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8105 - loss: 0.1062 - val_accuracy: 0.7486 - val_loss: 0.1363
# Epoch 29/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8136 - loss: 0.1050 - val_accuracy: 0.7467 - val_loss: 0.1373
# Epoch 30/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8206 - loss: 0.1020 - val_accuracy: 0.7371 - val_loss: 0.1372
# Epoch 31/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8198 - loss: 0.1028 - val_accuracy: 0.7352 - val_loss: 0.1368
# Epoch 32/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8148 - loss: 0.1010 - val_accuracy: 0.7333 - val_loss: 0.1379
# Epoch 33/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8305 - loss: 0.0991 - val_accuracy: 0.7390 - val_loss: 0.1382
# Epoch 34/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8298 - loss: 0.0971 - val_accuracy: 0.7257 - val_loss: 0.1393
# Epoch 35/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8202 - loss: 0.1002 - val_accuracy: 0.7238 - val_loss: 0.1393
# Epoch 36/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8346 - loss: 0.0961 - val_accuracy: 0.7276 - val_loss: 0.1404
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Epoch 1/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7549 - loss: 0.1329 - val_accuracy: 0.7162 - val_loss: 0.1372
# Epoch 2/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7494 - loss: 0.1315 - val_accuracy: 0.7181 - val_loss: 0.1386
# Epoch 3/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7560 - loss: 0.1303 - val_accuracy: 0.7162 - val_loss: 0.1399
# Epoch 4/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7648 - loss: 0.1279 - val_accuracy: 0.7105 - val_loss: 0.1410
# Epoch 5/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7546 - loss: 0.1295 - val_accuracy: 0.7200 - val_loss: 0.1410
# Epoch 6/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7800 - loss: 0.1245 - val_accuracy: 0.7143 - val_loss: 0.1418
# Epoch 7/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7723 - loss: 0.1270 - val_accuracy: 0.7105 - val_loss: 0.1422
# Epoch 8/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7759 - loss: 0.1216 - val_accuracy: 0.7086 - val_loss: 0.1428
# Epoch 9/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7664 - loss: 0.1237 - val_accuracy: 0.7181 - val_loss: 0.1428
# Epoch 10/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7810 - loss: 0.1231 - val_accuracy: 0.7143 - val_loss: 0.1436
# Epoch 11/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7827 - loss: 0.1218 - val_accuracy: 0.7105 - val_loss: 0.1439
# Epoch 12/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7831 - loss: 0.1209 - val_accuracy: 0.7067 - val_loss: 0.1449
# Epoch 13/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7834 - loss: 0.1172 - val_accuracy: 0.7143 - val_loss: 0.1451
# Epoch 14/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7875 - loss: 0.1174 - val_accuracy: 0.7124 - val_loss: 0.1449
# Epoch 15/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7902 - loss: 0.1165 - val_accuracy: 0.7124 - val_loss: 0.1455
# Epoch 16/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7947 - loss: 0.1145 - val_accuracy: 0.7143 - val_loss: 0.1461
# Epoch 17/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7997 - loss: 0.1124 - val_accuracy: 0.7124 - val_loss: 0.1473
# Epoch 18/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7851 - loss: 0.1166 - val_accuracy: 0.7143 - val_loss: 0.1473
# Epoch 19/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7876 - loss: 0.1158 - val_accuracy: 0.7124 - val_loss: 0.1478
# Epoch 20/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7925 - loss: 0.1133 - val_accuracy: 0.7086 - val_loss: 0.1484
# Epoch 21/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7955 - loss: 0.1117 - val_accuracy: 0.7143 - val_loss: 0.1489
# Epoch 22/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8037 - loss: 0.1113 - val_accuracy: 0.7105 - val_loss: 0.1490
# Epoch 23/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8076 - loss: 0.1100 - val_accuracy: 0.7105 - val_loss: 0.1492
# Epoch 24/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8071 - loss: 0.1110 - val_accuracy: 0.7105 - val_loss: 0.1495
# Epoch 25/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8045 - loss: 0.1080 - val_accuracy: 0.7105 - val_loss: 0.1517
# Epoch 26/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8034 - loss: 0.1095 - val_accuracy: 0.7143 - val_loss: 0.1509
# Epoch 27/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8077 - loss: 0.1054 - val_accuracy: 0.7086 - val_loss: 0.1516
# Epoch 28/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8105 - loss: 0.1066 - val_accuracy: 0.7124 - val_loss: 0.1530
# Epoch 29/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8199 - loss: 0.1022 - val_accuracy: 0.7067 - val_loss: 0.1547
# Epoch 30/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8180 - loss: 0.1033 - val_accuracy: 0.7067 - val_loss: 0.1550
# Epoch 31/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8230 - loss: 0.1028 - val_accuracy: 0.7086 - val_loss: 0.1562
# Epoch 32/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8190 - loss: 0.1012 - val_accuracy: 0.7124 - val_loss: 0.1559
# Epoch 33/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8265 - loss: 0.0999 - val_accuracy: 0.7181 - val_loss: 0.1569
# Epoch 34/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8266 - loss: 0.1000 - val_accuracy: 0.7086 - val_loss: 0.1568
# Epoch 35/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8231 - loss: 0.1000 - val_accuracy: 0.7086 - val_loss: 0.1580
# Epoch 36/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8230 - loss: 0.0987 - val_accuracy: 0.7067 - val_loss: 0.1589
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
y_pred_all = np.array(y_pred_all)
y_test_all = np.array(y_test_all)

y_pred_mean = np.mean(y_pred_all, axis=0)  
y_pred_median = np.median(y_pred_all, axis=0)  

y_test_representative = y_test_all[0]

# %%
import matplotlib.pyplot as plt
from utils import plot_classification_performance

# %%
# Plot using the averaged predictions
f, axs = plt.subplots(8, 3, figsize=(12, 3 * 8))

# Plot individual fold results using MEAN predictions
for i in range(7):
    plot_classification_performance(
        axs[i, :],
        y_true[y_test_representative[:, i]],
        y_pred_mean[y_test_representative[:, i], :],
        history_all[0][i],  # Use history from first repeat
        class_names=list(loader.label_map.keys())
    )

# Plot overall results
plot_classification_performance(
    axs[-1, :],
    y_true,
    y_pred_mean,  # Use averaged predictions
    class_names=list(loader.label_map.keys())
)

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
from sklearn.metrics import roc_auc_score

# Compute AUC scores per antigen for each repeat
num_repeats = y_pred_all.shape[0]  # number of CV repeats (e.g., 3)
n_classes = y_pred_all.shape[-1]   # number of antigens

auc_scores = []  # will be a list with shape (num_repeats, n_classes)
for repeat in range(num_repeats):
    repeat_auc = []
    for class_idx in range(n_classes):
        # Create binary labels: 1 if sample belongs to this antigen and 0 otherwise
        y_true_binary = (y_true == class_idx).astype(int)
        y_pred_probs = y_pred_all[repeat, :, class_idx]
        try:
            auc_val = roc_auc_score(y_true_binary, y_pred_probs)
        except Exception as e:
            print(f"Error computing roc_auc_score for antigen {class_idx} in repeat {repeat}: {e}")
            auc_val = np.nan
        repeat_auc.append(auc_val)
    auc_scores.append(repeat_auc)
auc_scores = np.array(auc_scores)  # shape: (num_repeats, n_classes)

# Prepare a long-format DataFrame for seaborn violinplot
antigen_names = list(loader.label_map.keys())
plot_data = []
for class_idx, antigen_name in enumerate(antigen_names):
    for repeat in range(num_repeats):
        plot_data.append({
            'Antigen': antigen_name,
            'AUC': auc_scores[repeat, class_idx],
            'Method': 'Sup-Seq-VDJ'  # Label for the method
        })

plot_df = pd.DataFrame(plot_data)

# Create the violin plot with thinner plots, orange color, and legend moved to the right
plt.figure(figsize=(12, 6))
sns.violinplot(
    data=plot_df, 
    x="Antigen", 
    y="AUC", 
    hue="Method", 
    inner="box", 
    palette=["orange"],  # Set to orange
    scale="area"  # Makes the violins thinner
)
plt.xticks(rotation=45)
plt.ylim(0.60, 1.00)  # Set y-axis range from 0.60 to 1.00
plt.title("Antigen Classification Performance")
plt.ylabel("AUC")
plt.xlabel("Antigen")
plt.legend(title="Method", loc="center left", bbox_to_anchor=(1, 0.5))  # Move legend to the right
plt.tight_layout()
plt.show()
# Out:
# C:\Users\huang\AppData\Local\Temp\ipykernel_18128\2280660428.py:39: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='area'` for the same effect.
#   sns.violinplot(
