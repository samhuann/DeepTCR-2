# %%
from glob import glob
import pandas as pd
import os
import numpy as np
import tensorflow as tf
import keras

# %%
# Replace your TCRDataLoader class with this updated version that combines columns
import pandas as pd
import numpy as np
import tensorflow as tf
from glob import glob
import os

class TCRDataLoader:
    def __init__(self, data_dir):
        self.data_dir = data_dir
        self.aa_dict = None
        self.v_dict = None
        self.j_dict = None
        self.label_map = None
        self.max_length = None
        
    def combine_columns(self, df, column_variants, new_column_name):
        """Combine multiple columns that represent the same data type"""
        combined_series = pd.Series([None] * len(df), index=df.index)
        
        for variant in column_variants:
            if variant in df.columns:
                # Fill in non-null values from this column
                mask = df[variant].notna() & combined_series.isna()
                combined_series[mask] = df[variant][mask]
                print(f"  Added {mask.sum()} values from '{variant}' column")
        
        return combined_series
    
    def load_files(self):
        df_list = []
        files = glob(self.data_dir + "/*/*.tsv")
        
        for file_path in files:
            df = pd.read_csv(file_path, sep='\t')
            
            # Extract folder name from file path
            folder_name = os.path.basename(os.path.dirname(file_path))
            
            # Split folder name to get Antigen
            parts = folder_name.split('-')
            antigen = parts[-1]  # Get last part (the antigen)
            
            # Add antigen column to dataframe
            df['Antigen'] = antigen
            
            df_list.append(df)
        
        combined_df = pd.concat(df_list, ignore_index=True)
        
        # Define column candidates for each data type
        column_variants = {
            'sequence': ['aminoAcid', 'beta', 'Amino', 'sequence', 'cdr3', 'CDR3'],
            'v_gene': ['v_beta', 'vGeneName', 'v_gene', 'V_gene', 'TRBV'],
            'j_gene': ['j_beta', 'jGeneName', 'j_gene', 'J_gene', 'TRBJ'],
            'counts': ['counts', 'count', 'count (templates/reads)', 'templates', 'reads', 'frequency']
        }
        
        print("Combining columns:")
        # Combine columns for each data type
        for standard_name, variants in column_variants.items():
            print(f"\nCombining {standard_name} columns:")
            combined_series = self.combine_columns(combined_df, variants, standard_name)
            combined_df[f'combined_{standard_name}'] = combined_series
            
            # Show statistics
            total_values = combined_series.notna().sum()
            print(f"  Total combined values: {total_values}")
        
        return combined_df
    
    def build_vocabulary(self, df):
        # Use combined columns
        # Amino acids
        all_sequences = df['combined_sequence'].dropna()
        if len(all_sequences) == 0:
            raise ValueError("No sequence data found in combined columns!")
            
        giant_string = ''.join(all_sequences)
        unique_letters = sorted(set(giant_string))
        self.aa_dict = {}
        for i, letter in enumerate(unique_letters):
            self.aa_dict[letter] = i+1
        
        # V genes
        v_genes = df['combined_v_gene'].dropna().unique()
        v_genes = sorted(v_genes)
        self.v_dict = {}
        for i, gene in enumerate(v_genes):
            self.v_dict[gene] = i + 1

        # J genes
        j_genes = df['combined_j_gene'].dropna().unique()
        j_genes = sorted(j_genes)
        self.j_dict = {}
        for i, gene in enumerate(j_genes):
            self.j_dict[gene] = i + 1

        # Labels
        antigens = df['Antigen'].unique()
        self.label_map = {}
        for i, antigen in enumerate(sorted(antigens)):
            self.label_map[antigen] = i

        # Max length
        sequence_lengths = [len(seq) for seq in df['combined_sequence'].dropna()]
        self.max_length = max(sequence_lengths) if sequence_lengths else 0
        
        print(f"\nVocabulary built:")
        print(f"  Amino acids: {len(self.aa_dict)} unique")
        print(f"  V genes: {len(self.v_dict)} unique")
        print(f"  J genes: {len(self.j_dict)} unique")
        print(f"  Max sequence length: {self.max_length}")
    
    def encode_sequences(self, sequences):
        encoded_aa = []
        for sequence in sequences:
            sequence_numbers = []
            for letter in sequence:
                number = self.aa_dict.get(letter, 0)
                sequence_numbers.append(number)
            # Add padding zeros if sequence is shorter than max_length
            while len(sequence_numbers) < self.max_length:
                sequence_numbers.append(0)
            encoded_aa.append(sequence_numbers)
        return encoded_aa
    
    def encode_v_genes(self, v_genes):
        encoded_v = []
        for v_gene in v_genes:
            encoded_v.append(self.v_dict.get(v_gene, 0))
        return encoded_v
    
    def encode_j_genes(self, j_genes):
        encoded_j = []
        for j_gene in j_genes:
            encoded_j.append(self.j_dict.get(j_gene, 0))
        return encoded_j
    
    def load_and_encode_data(self, batch_size=100, shuffle=True):
        # 1. Load files and combine columns
        df = self.load_files()
        
        # 2. Build vocabularies
        self.build_vocabulary(df)
        
        # 3. Filter out rows with missing amino acid sequences
        valid_rows = df['combined_sequence'].notna()
        df_valid = df[valid_rows].copy()
        
        print(f"Valid data: {len(df_valid)} out of {len(df)} total rows")
        
        # 4. Get the data you want to encode (now all valid)
        sequences = df_valid['combined_sequence'].values
        v_genes = df_valid['combined_v_gene'].fillna('UNK').values
        j_genes = df_valid['combined_j_gene'].fillna('UNK').values
        labels = [self.label_map[antigen] for antigen in df_valid['Antigen']]
        
        # 5. Encode everything
        X_sequences = self.encode_sequences(sequences)
        X_v_genes = self.encode_v_genes(v_genes)
        X_j_genes = self.encode_j_genes(j_genes)
        
        # 6. Convert to numpy arrays
        X_sequences = np.array(X_sequences)
        X_v_genes = np.array(X_v_genes)
        X_j_genes = np.array(X_j_genes)
        y_labels = np.array(labels)
        
        # 7. Create TensorFlow dataset
        dataset = tf.data.Dataset.from_tensor_slices((
            {'cdr3_sequence': X_sequences, 'v_gene': X_v_genes, 'j_gene': X_j_genes,},
            {'labels': y_labels}
        ))
            
        # Map to the format expected by the model
        dataset = dataset.map(lambda X, y: (X, {'labels': tf.one_hot(y['labels'], len(self.label_map))}))
            
        if shuffle:
            dataset = dataset.shuffle(len(X_sequences), reshuffle_each_iteration=True)
        
        dataset = dataset.batch(batch_size, drop_remainder=True)
        dataset = dataset.prefetch(tf.data.AUTOTUNE)
        
        return dataset
    
    def get_vocab_sizes(self):
        """Return vocabulary sizes for model construction"""
        return {
            'aa_vocab_size': len(self.aa_dict) + 1,  # +1 for padding
            'v_vocab_size': len(self.v_dict) + 1,    # +1 for unknown
            'j_vocab_size': len(self.j_dict) + 1,    # +1 for unknown
            'num_classes': len(self.label_map),
            'max_length': self.max_length
        }
    
    def get_mappings(self):
        """Return the created mappings for inspection"""
        return {
            'aa_dict': self.aa_dict,
            'v_dict': self.v_dict,
            'j_dict': self.j_dict,
            'label_map': self.label_map
        }
# Out:
# 2025-07-01 13:27:36.618132: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-07-01 13:27:36.661698: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-07-01 13:27:36.661721: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-07-01 13:27:36.662649: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-01 13:27:36.668255: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def create_tcr_model(vocab_sizes):
    """Create a model using the Conv1D architecture from the reference"""
    # Input layers
    cdr3_input = keras.Input(shape=(vocab_sizes['max_length'],), dtype=tf.uint32, name='cdr3_sequence')
    v_gene_input = keras.Input(shape=(), dtype=tf.uint32, name='v_gene')
    j_gene_input = keras.Input(shape=(), dtype=tf.uint32, name='j_gene')
    
    # CDR3 sequence encoder (following the reference structure)
    cdr3_embed = keras.layers.Embedding(
        input_dim=vocab_sizes['aa_vocab_size'], 
        output_dim=8, 
        mask_zero=True
    )(cdr3_input)
    
    convs = [keras.layers.Conv1D(
        filters=16, 
        kernel_size=9, 
        strides=1, 
        activation=keras.activations.relu,
        padding='valid'
    )(cdr3_embed)]
    
    convs.append(keras.layers.Conv1D(
        filters=32, 
        kernel_size=7, 
        strides=2, 
        activation=keras.activations.relu,
        padding='valid'
    )(convs[-1]))
    
    # convs.append(keras.layers.Conv1D(
    #     filters=256, 
    #     kernel_size=5, 
    #     strides=1, 
    #     activation=None,
    #     padding='valid'
    # )(convs[-1]))
    
    # Take the first position output (like in reference: [:, 0, :])
    # cdr3_encoded = convs[-1][:, 0, :]

    # pooling to gain positional equivariance
    cdr3_encoded = keras.layers.GlobalMaxPooling1D()(convs[-1])
    
    # Gene embeddings
    v_embed = keras.layers.Embedding(vocab_sizes['v_vocab_size'], 16, mask_zero=True)(v_gene_input)
    j_embed = keras.layers.Embedding(vocab_sizes['j_vocab_size'], 16, mask_zero=True)(j_gene_input)
    
    # Flatten gene embeddings
    # v_flat = tf.keras.layers.Flatten()(v_embed)
    # j_flat = tf.keras.layers.Flatten()(j_embed)
    
    # Concatenate all features
    fused = keras.layers.Concatenate(axis=-1)([cdr3_encoded, v_embed, j_embed])
    
    # Classifier (following reference structure)
    dropout1 = keras.layers.Dropout(rate=0.1)(fused)
    dense1 = keras.layers.Dense(units=32, activation=keras.activations.relu)(dropout1)
    dropout2 = keras.layers.Dropout(rate=0.05)(dense1)
    dense2 = keras.layers.Dense(units=16, activation=keras.activations.relu)(dropout2)
    # output = tf.keras.layers.Dense(units=vocab_sizes['num_classes'], activation='softmax')(dense2)
    output = keras.layers.Dense(units=vocab_sizes['num_classes'], activation='sigmoid')(dense2)

    model = keras.Model(
        inputs=[cdr3_input, v_gene_input, j_gene_input],
        outputs=output
    )
    
    return model

# %%
# Initialize loader
data_dir = './DeepTCR/Data/Murine_Antigens'
loader = TCRDataLoader(data_dir)

# Load data
print("Loading data...")
dataset = loader.load_and_encode_data(batch_size=100, shuffle=True)
print("Data loaded successfully!")
# Out:
# Loading data...
# Combining columns:
#
# Combining sequence columns:
#   Added 1753 values from 'aminoAcid' column
#   Added 1924 values from 'beta' column
#   Total combined values: 3677
#
# Combining v_gene columns:
#   Added 1924 values from 'v_beta' column
#   Added 3678 values from 'vGeneName' column
#   Total combined values: 5602
#
# Combining j_gene columns:
#   Added 1924 values from 'j_beta' column
#   Added 3670 values from 'jGeneName' column
#   Total combined values: 5594
#
# Combining counts columns:
#   Added 1924 values from 'counts' column
#   Added 3679 values from 'count (templates/reads)' column
#   Total combined values: 5603
#
# Vocabulary built:
#   Amino acids: 21 unique
#   V genes: 42 unique
#   J genes: 14 unique
#   Max sequence length: 19
# Valid data: 3677 out of 5603 total rows
# Data loaded successfully!
# 2025-07-01 13:28:58.758113: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 78763 MB memory:  -> device: 0, name: NVIDIA H100 80GB HBM3, pci bus id: 0000:cb:00.0, compute capability: 9.0

# %%
loader.v_dict
# Out:
# {'TCRBV01-01': 1,
#  'TCRBV02-01': 2,
#  'TCRBV03-01': 3,
#  'TCRBV04-01': 4,
#  'TCRBV05-01': 5,
#  'TCRBV05-04': 6,
#  'TCRBV06-01': 7,
#  'TCRBV07-01': 8,
#  'TCRBV08-01': 9,
#  'TCRBV09-01': 10,
#  'TCRBV10-01': 11,
#  'TCRBV11-01': 12,
#  'TCRBV12-01': 13,
#  'TCRBV12-02': 14,
#  'TCRBV12-03': 15,
#  'TCRBV13-01': 16,
#  'TCRBV13-02': 17,
#  'TCRBV13-03': 18,
#  'TCRBV13-04': 19,
#  'TCRBV14-01': 20,
#  'TCRBV15-01': 21,
#  'TCRBV16-01': 22,
#  'TCRBV17-01': 23,
#  'TCRBV18-01': 24,
#  'TCRBV19-01': 25,
#  'TCRBV19-03': 26,
#  'TCRBV20-01': 27,
#  'TCRBV20-02': 28,
#  'TCRBV21-01': 29,
#  'TCRBV22-01': 30,
#  'TCRBV23-01': 31,
#  'TCRBV24-01': 32,
#  'TCRBV24-02': 33,
#  'TCRBV25-01': 34,
#  'TCRBV26-01': 35,
#  'TCRBV27-01': 36,
#  'TCRBV28-01': 37,
#  'TCRBV29-01': 38,
#  'TCRBV29-02': 39,
#  'TCRBV30-01': 40,
#  'TCRBV31-01': 41,
#  'TCRBV31-02': 42}

# %%
# Initialize loader
data_dir = './DeepTCR/Data/Human_Antigens'
loader = TCRDataLoader(data_dir)

# Load data
print("Loading data...")
dataset = loader.load_and_encode_data(batch_size=100, shuffle=True)
print("Data loaded successfully!")
# Out:
# Loading data...
# Combining columns:
#
# Combining sequence columns:
#   Added 2066 values from 'aminoAcid' column
#   Added 412 values from 'beta' column
#   Total combined values: 2478
#
# Combining v_gene columns:
#   Added 1874 values from 'v_beta' column
#   Total combined values: 1874
#
# Combining j_gene columns:
#   Added 2084 values from 'j_beta' column
#   Total combined values: 2084
#
# Combining counts columns:
#   Added 2478 values from 'counts' column
#   Total combined values: 2478
#
# Vocabulary built:
#   Amino acids: 20 unique
#   V genes: 62 unique
#   J genes: 13 unique
#   Max sequence length: 23
# Valid data: 2478 out of 2478 total rows
# Data loaded successfully!

# %%
# Create model
vocab_sizes = loader.get_vocab_sizes()
print("Creating model...")
model = create_tcr_model(vocab_sizes)

# Compile model
model.compile(
    optimizer='adam', 
    # loss='categorical_crossentropy',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Display model summary
model.summary()
# Out:
# Creating model...
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  cdr3_sequence (InputLayer)  [(None, 19)]                 0         []
#
#  embedding (Embedding)       (None, 19, 8)                176       ['cdr3_sequence[0][0]']
#
#  conv1d (Conv1D)             (None, 11, 16)               1168      ['embedding[0][0]']
#
#  conv1d_1 (Conv1D)           (None, 3, 32)                3616      ['conv1d[0][0]']
#
#  v_gene (InputLayer)         [(None,)]                    0         []
#
#  j_gene (InputLayer)         [(None,)]                    0         []
#
#  global_max_pooling1d (Glob  (None, 32)                   0         ['conv1d_1[0][0]']
#  alMaxPooling1D)
#
#  embedding_1 (Embedding)     (None, 16)                   688       ['v_gene[0][0]']
#
#  embedding_2 (Embedding)     (None, 16)                   240       ['j_gene[0][0]']
#
#  concatenate (Concatenate)   (None, 64)                   0         ['global_max_pooling1d[0][0]',
#                                                                      'embedding_1[0][0]',
#                                                                      'embedding_2[0][0]']
#
#  dropout (Dropout)           (None, 64)                   0         ['concatenate[0][0]']
#
#  dense (Dense)               (None, 32)                   2080      ['dropout[0][0]']
#
#  dropout_1 (Dropout)         (None, 32)                   0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 16)                   528       ['dropout_1[0][0]']
#
#  dense_2 (Dense)             (None, 9)                    153       ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 8649 (33.79 KB)
# Trainable params: 8649 (33.79 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
np.unique(df['aminoAcid'].astype('category').cat.codes.values)
# Out:
# array([  -1,    0,    1, ..., 1307, 1308, 1309], dtype=int16)

# %%
# Updated data preparation using combined columns
df = loader.load_files()
df['Antigen'] = df['Antigen'].astype('category')
loader.build_vocabulary(df)

# Filter valid data using combined columns
valid_rows = df['combined_sequence'].notna()
df_valid = df[valid_rows].copy()

print(f"Valid sequences: {len(df_valid)} out of {len(df)} total")

# Encode data using combined columns
sequences = df_valid['combined_sequence'].values
v_genes = df_valid['combined_v_gene'].fillna('UNK').values
j_genes = df_valid['combined_j_gene'].fillna('UNK').values
counts = df_valid['combined_counts'].fillna(1).values  

labels = [loader.label_map[antigen] for antigen in df_valid['Antigen']]

X_sequences = loader.encode_sequences(sequences)
X_v_genes = loader.encode_v_genes(v_genes)
X_j_genes = loader.encode_j_genes(j_genes)

# Convert to numpy
X_sequences = np.array(X_sequences)
X_v_genes = np.array(X_v_genes)
X_j_genes = np.array(X_j_genes)

# Set up data for cross-validation
X = [
    np.array(X_sequences, dtype=np.int32),
    np.array(X_v_genes, dtype=np.int32),
    np.array(X_j_genes, dtype=np.int32)
]
y_true = np.array(df_valid['Antigen'].cat.codes.values, dtype=np.int32)

print(f"Final data shapes:")
print(f"  X[0] (sequences): {X[0].shape}")
print(f"  X[1] (v_genes): {X[1].shape}")
print(f"  X[2] (j_genes): {X[2].shape}")
print(f"  y_true: {y_true.shape}")
# Out:
# Combining columns:
#
# Combining sequence columns:
#   Added 1753 values from 'aminoAcid' column
#   Added 1924 values from 'beta' column
#   Total combined values: 3677
#
# Combining v_gene columns:
#   Added 1924 values from 'v_beta' column
#   Added 3678 values from 'vGeneName' column
#   Total combined values: 5602
#
# Combining j_gene columns:
#   Added 1924 values from 'j_beta' column
#   Added 3670 values from 'jGeneName' column
#   Total combined values: 5594
#
# Combining counts columns:
#   Added 1924 values from 'counts' column
#   Added 3679 values from 'count (templates/reads)' column
#   Total combined values: 5603
#
# Vocabulary built:
#   Amino acids: 21 unique
#   V genes: 42 unique
#   J genes: 14 unique
#   Max sequence length: 19
# Valid sequences: 3677 out of 5603 total
# Final data shapes:
#   X[0] (sequences): (3677, 19)
#   X[1] (v_genes): (3677,)
#   X[2] (j_genes): (3677,)
#   y_true: (3677,)
# /local/shuan143/1506218/ipykernel_1273130/1068804712.py:16: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   counts = df_valid['combined_counts'].fillna(1).values

# %%
from utils import KerasCrossValidation

# %%
df
# Out:
#                  beta  counts      v_beta      j_beta Antigen  \
# 0      CASSYQGDYAEQFF     1.0  TCRBV29-01  TCRBJ02-01     M45
# 1     CASSRLGTSAETLYF     1.0  TCRBV17-01  TCRBJ02-03     M45
# 2      CASSRTGDYAEQFF     1.0  TCRBV12-01  TCRBJ02-01     M45
# 3     CASSELGSSAETLYF     1.0  TCRBV17-01  TCRBJ02-03     M45
# 4      CASIPGQANTEVFF     1.0  TCRBV13-01  TCRBJ01-01     M45
# ...               ...     ...         ...         ...     ...
# 5598              NaN     NaN         NaN         NaN    TRP2
# 5599              NaN     NaN         NaN         NaN    TRP2
# 5600              NaN     NaN         NaN         NaN    TRP2
# 5601              NaN     NaN         NaN         NaN    TRP2
# 5602              NaN     NaN         NaN         NaN    TRP2
#
#             aminoAcid  count (templates/reads)   vGeneName   jGeneName  \
# 0                 NaN                      NaN         NaN         NaN
# 1                 NaN                      NaN         NaN         NaN
# 2                 NaN                      NaN         NaN         NaN
# 3                 NaN                      NaN         NaN         NaN
# 4                 NaN                      NaN         NaN         NaN
# ...               ...                      ...         ...         ...
# 5598              NaN                      1.0  TCRBV13-03  TCRBJ01-01
# 5599              NaN                      1.0  TCRBV03-01  TCRBJ02-01
# 5600   GCGLGEGTNTEVFF                      1.0  TCRBV18-01  TCRBJ01-01
# 5601   VVQHGDSPNTEVFF                      1.0  TCRBV08-01  TCRBJ01-01
# 5602  RSIAHDTISNERLFF                      1.0  TCRBV15-01  TCRBJ01-04
#
#      combined_sequence combined_v_gene combined_j_gene combined_counts
# 0       CASSYQGDYAEQFF      TCRBV29-01      TCRBJ02-01             1.0
# 1      CASSRLGTSAETLYF      TCRBV17-01      TCRBJ02-03             1.0
# 2       CASSRTGDYAEQFF      TCRBV12-01      TCRBJ02-01             1.0
# 3      CASSELGSSAETLYF      TCRBV17-01      TCRBJ02-03             1.0
# 4       CASIPGQANTEVFF      TCRBV13-01      TCRBJ01-01             1.0
# ...                ...             ...             ...             ...
# 5598              None      TCRBV13-03      TCRBJ01-01             1.0
# 5599              None      TCRBV03-01      TCRBJ02-01             1.0
# 5600    GCGLGEGTNTEVFF      TCRBV18-01      TCRBJ01-01             1.0
# 5601    VVQHGDSPNTEVFF      TCRBV08-01      TCRBJ01-01             1.0
# 5602   RSIAHDTISNERLFF      TCRBV15-01      TCRBJ01-04             1.0
#
# [5603 rows x 13 columns]

# %%
df_valid = df.loc[df['aminoAcid'].isna()]
df_valid
# Out:
#                  beta  counts      v_beta      j_beta Antigen aminoAcid  \
# 0      CASSYQGDYAEQFF     1.0  TCRBV29-01  TCRBJ02-01     M45       NaN
# 1     CASSRLGTSAETLYF     1.0  TCRBV17-01  TCRBJ02-03     M45       NaN
# 2      CASSRTGDYAEQFF     1.0  TCRBV12-01  TCRBJ02-01     M45       NaN
# 3     CASSELGSSAETLYF     1.0  TCRBV17-01  TCRBJ02-03     M45       NaN
# 4      CASIPGQANTEVFF     1.0  TCRBV13-01  TCRBJ01-01     M45       NaN
# ...               ...     ...         ...         ...     ...       ...
# 5592              NaN     NaN         NaN         NaN    TRP2       NaN
# 5594              NaN     NaN         NaN         NaN    TRP2       NaN
# 5596              NaN     NaN         NaN         NaN    TRP2       NaN
# 5598              NaN     NaN         NaN         NaN    TRP2       NaN
# 5599              NaN     NaN         NaN         NaN    TRP2       NaN
#
#       count (templates/reads)   vGeneName   jGeneName combined_sequence  \
# 0                         NaN         NaN         NaN    CASSYQGDYAEQFF
# 1                         NaN         NaN         NaN   CASSRLGTSAETLYF
# 2                         NaN         NaN         NaN    CASSRTGDYAEQFF
# 3                         NaN         NaN         NaN   CASSELGSSAETLYF
# 4                         NaN         NaN         NaN    CASIPGQANTEVFF
# ...                       ...         ...         ...               ...
# 5592                      1.0  TCRBV29-01  TCRBJ01-01              None
# 5594                      1.0  TCRBV12-03  TCRBJ01-01              None
# 5596                      1.0  TCRBV13-02  TCRBJ02-03              None
# 5598                      1.0  TCRBV13-03  TCRBJ01-01              None
# 5599                      1.0  TCRBV03-01  TCRBJ02-01              None
#
#      combined_v_gene combined_j_gene combined_counts
# 0         TCRBV29-01      TCRBJ02-01             1.0
# 1         TCRBV17-01      TCRBJ02-03             1.0
# 2         TCRBV12-01      TCRBJ02-01             1.0
# 3         TCRBV17-01      TCRBJ02-03             1.0
# 4         TCRBV13-01      TCRBJ01-01             1.0
# ...              ...             ...             ...
# 5592      TCRBV29-01      TCRBJ01-01             1.0
# 5594      TCRBV12-03      TCRBJ01-01             1.0
# 5596      TCRBV13-02      TCRBJ02-03             1.0
# 5598      TCRBV13-03      TCRBJ01-01             1.0
# 5599      TCRBV03-01      TCRBJ02-01             1.0
#
# [3850 rows x 13 columns]

# %%
# set data
X = [
        np.array(X_sequences, dtype=np.int32),
        np.array(X_v_genes, dtype=np.int32),
        np.array(X_j_genes, dtype=np.int32)
    ]
y_true = np.array(y_true, dtype=np.int32)

# %%
X[1]
# Out:
# array([38, 23, 13, ..., 24,  9, 21], dtype=int32)

# %%
# run cross-validation
keras_cv = KerasCrossValidation(X=X, y=y_true, keras_model=model, save_filepath='./samlogs/fit-01')
y_pred, y_test, history = keras_cv(n_splits=7, batch_size=500, min_epochs=5, patience=30, max_epochs=500, training_repeat=2)
# Out:
# Epoch 1/500
# 2025-07-01 13:33:13.723439: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2025-07-01 13:33:14.810298: I external/local_xla/xla/service/service.cc:168] XLA service 0x153d1b5f8930 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-07-01 13:33:14.810323: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA H100 80GB HBM3, Compute Capability 9.0
# 2025-07-01 13:33:14.814874: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1751391194.911192 1273688 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 10/10 [==============================] - 4s 105ms/step - loss: 0.6896 - accuracy: 0.1890 - val_loss: 0.6830 - val_accuracy: 0.2495
# Epoch 2/500
# 10/10 [==============================] - 1s 42ms/step - loss: 0.6759 - accuracy: 0.2110 - val_loss: 0.6652 - val_accuracy: 0.2038
# Epoch 3/500
# 10/10 [==============================] - 0s 30ms/step - loss: 0.6499 - accuracy: 0.1871 - val_loss: 0.6255 - val_accuracy: 0.1752
# Epoch 4/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5928 - accuracy: 0.1775 - val_loss: 0.5459 - val_accuracy: 0.1752
# Epoch 5/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5097 - accuracy: 0.1746 - val_loss: 0.4628 - val_accuracy: 0.1752
# Epoch 6/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4348 - accuracy: 0.1750 - val_loss: 0.3954 - val_accuracy: 0.1752
# Epoch 7/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3794 - accuracy: 0.2424 - val_loss: 0.3558 - val_accuracy: 0.3276
# Epoch 8/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3492 - accuracy: 0.3206 - val_loss: 0.3367 - val_accuracy: 0.3276
# Epoch 9/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3340 - accuracy: 0.3307 - val_loss: 0.3246 - val_accuracy: 0.3276
# Epoch 10/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3224 - accuracy: 0.3360 - val_loss: 0.3163 - val_accuracy: 0.3276
# Epoch 11/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3161 - accuracy: 0.3351 - val_loss: 0.3097 - val_accuracy: 0.3276
# Epoch 12/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3094 - accuracy: 0.3399 - val_loss: 0.3040 - val_accuracy: 0.3276
# Epoch 13/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3041 - accuracy: 0.3424 - val_loss: 0.2988 - val_accuracy: 0.3410
# Epoch 14/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2976 - accuracy: 0.3760 - val_loss: 0.2937 - val_accuracy: 0.4000
# Epoch 15/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2928 - accuracy: 0.4062 - val_loss: 0.2869 - val_accuracy: 0.4381
# Epoch 16/500
# 10/10 [==============================] - 0s 18ms/step - loss: 0.2864 - accuracy: 0.4344 - val_loss: 0.2810 - val_accuracy: 0.4514
# Epoch 17/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2814 - accuracy: 0.4461 - val_loss: 0.2759 - val_accuracy: 0.4495
# Epoch 18/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2766 - accuracy: 0.4464 - val_loss: 0.2710 - val_accuracy: 0.4533
# Epoch 19/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2709 - accuracy: 0.4504 - val_loss: 0.2663 - val_accuracy: 0.4571
# Epoch 20/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2659 - accuracy: 0.4581 - val_loss: 0.2606 - val_accuracy: 0.4590
# Epoch 21/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2609 - accuracy: 0.4571 - val_loss: 0.2554 - val_accuracy: 0.4590
# Epoch 22/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2560 - accuracy: 0.4587 - val_loss: 0.2505 - val_accuracy: 0.4629
# Epoch 23/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2518 - accuracy: 0.4627 - val_loss: 0.2459 - val_accuracy: 0.4648
# Epoch 24/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2465 - accuracy: 0.4801 - val_loss: 0.2413 - val_accuracy: 0.4838
# Epoch 25/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2411 - accuracy: 0.5014 - val_loss: 0.2367 - val_accuracy: 0.5029
# Epoch 26/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2356 - accuracy: 0.5236 - val_loss: 0.2325 - val_accuracy: 0.5219
# Epoch 27/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2312 - accuracy: 0.5419 - val_loss: 0.2279 - val_accuracy: 0.5600
# Epoch 28/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2233 - accuracy: 0.5649 - val_loss: 0.2239 - val_accuracy: 0.5638
# Epoch 29/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2196 - accuracy: 0.5793 - val_loss: 0.2198 - val_accuracy: 0.5790
# Epoch 30/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2145 - accuracy: 0.5912 - val_loss: 0.2157 - val_accuracy: 0.5867
# Epoch 31/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2093 - accuracy: 0.5985 - val_loss: 0.2119 - val_accuracy: 0.5886
# Epoch 32/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2063 - accuracy: 0.6074 - val_loss: 0.2080 - val_accuracy: 0.6114
# Epoch 33/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2012 - accuracy: 0.6220 - val_loss: 0.2043 - val_accuracy: 0.6210
# Epoch 34/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1981 - accuracy: 0.6392 - val_loss: 0.2017 - val_accuracy: 0.6229
# Epoch 35/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1934 - accuracy: 0.6483 - val_loss: 0.1985 - val_accuracy: 0.6267
# Epoch 36/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1901 - accuracy: 0.6585 - val_loss: 0.1961 - val_accuracy: 0.6343
# Epoch 37/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1855 - accuracy: 0.6659 - val_loss: 0.1943 - val_accuracy: 0.6362
# Epoch 38/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1821 - accuracy: 0.6709 - val_loss: 0.1929 - val_accuracy: 0.6381
# Epoch 39/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1808 - accuracy: 0.6701 - val_loss: 0.1905 - val_accuracy: 0.6343
# Epoch 40/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1786 - accuracy: 0.6776 - val_loss: 0.1890 - val_accuracy: 0.6400
# Epoch 41/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1759 - accuracy: 0.6752 - val_loss: 0.1875 - val_accuracy: 0.6362
# Epoch 42/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1740 - accuracy: 0.6868 - val_loss: 0.1861 - val_accuracy: 0.6457
# Epoch 43/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1701 - accuracy: 0.6849 - val_loss: 0.1844 - val_accuracy: 0.6552
# Epoch 44/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1690 - accuracy: 0.6907 - val_loss: 0.1835 - val_accuracy: 0.6533
# Epoch 45/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1674 - accuracy: 0.6916 - val_loss: 0.1820 - val_accuracy: 0.6552
# Epoch 46/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1657 - accuracy: 0.6994 - val_loss: 0.1811 - val_accuracy: 0.6610
# Epoch 47/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1659 - accuracy: 0.6946 - val_loss: 0.1795 - val_accuracy: 0.6533
# Epoch 48/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1622 - accuracy: 0.7044 - val_loss: 0.1788 - val_accuracy: 0.6686
# Epoch 49/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1597 - accuracy: 0.7089 - val_loss: 0.1776 - val_accuracy: 0.6705
# Epoch 50/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1579 - accuracy: 0.7081 - val_loss: 0.1762 - val_accuracy: 0.6800
# Epoch 51/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1559 - accuracy: 0.7156 - val_loss: 0.1757 - val_accuracy: 0.6762
# Epoch 52/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1534 - accuracy: 0.7254 - val_loss: 0.1748 - val_accuracy: 0.6857
# Epoch 53/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1525 - accuracy: 0.7249 - val_loss: 0.1740 - val_accuracy: 0.6933
# Epoch 54/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1508 - accuracy: 0.7216 - val_loss: 0.1730 - val_accuracy: 0.6914
# Epoch 55/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1482 - accuracy: 0.7267 - val_loss: 0.1725 - val_accuracy: 0.7010
# Epoch 56/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1488 - accuracy: 0.7301 - val_loss: 0.1719 - val_accuracy: 0.6952
# Epoch 57/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1463 - accuracy: 0.7330 - val_loss: 0.1711 - val_accuracy: 0.7067
# Epoch 58/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1447 - accuracy: 0.7379 - val_loss: 0.1707 - val_accuracy: 0.6952
# Epoch 59/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1426 - accuracy: 0.7424 - val_loss: 0.1705 - val_accuracy: 0.6990
# Epoch 60/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1417 - accuracy: 0.7463 - val_loss: 0.1704 - val_accuracy: 0.6971
# Epoch 61/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1393 - accuracy: 0.7510 - val_loss: 0.1697 - val_accuracy: 0.6952
# Epoch 62/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1393 - accuracy: 0.7478 - val_loss: 0.1700 - val_accuracy: 0.6933
# Epoch 63/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1369 - accuracy: 0.7559 - val_loss: 0.1695 - val_accuracy: 0.6895
# Epoch 64/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1365 - accuracy: 0.7580 - val_loss: 0.1688 - val_accuracy: 0.6914
# Epoch 65/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1352 - accuracy: 0.7554 - val_loss: 0.1686 - val_accuracy: 0.6895
# Epoch 66/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1336 - accuracy: 0.7615 - val_loss: 0.1690 - val_accuracy: 0.6971
# Epoch 67/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1328 - accuracy: 0.7586 - val_loss: 0.1692 - val_accuracy: 0.6914
# Epoch 68/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1313 - accuracy: 0.7637 - val_loss: 0.1685 - val_accuracy: 0.6895
# Epoch 69/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1296 - accuracy: 0.7685 - val_loss: 0.1689 - val_accuracy: 0.6952
# Epoch 70/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1271 - accuracy: 0.7755 - val_loss: 0.1692 - val_accuracy: 0.6952
# Epoch 71/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1267 - accuracy: 0.7772 - val_loss: 0.1694 - val_accuracy: 0.6895
# Epoch 72/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1258 - accuracy: 0.7775 - val_loss: 0.1701 - val_accuracy: 0.6952
# Epoch 73/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1246 - accuracy: 0.7803 - val_loss: 0.1708 - val_accuracy: 0.6914
# Epoch 74/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1241 - accuracy: 0.7844 - val_loss: 0.1698 - val_accuracy: 0.6933
# Epoch 75/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1222 - accuracy: 0.7819 - val_loss: 0.1706 - val_accuracy: 0.6876
# Epoch 76/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1221 - accuracy: 0.7860 - val_loss: 0.1719 - val_accuracy: 0.6933
# Epoch 77/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1202 - accuracy: 0.7923 - val_loss: 0.1720 - val_accuracy: 0.6933
# Epoch 78/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1189 - accuracy: 0.7901 - val_loss: 0.1720 - val_accuracy: 0.6914
# Epoch 79/500
# 10/10 [==============================] - 0s 18ms/step - loss: 0.1177 - accuracy: 0.7935 - val_loss: 0.1721 - val_accuracy: 0.6876
# Epoch 80/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1169 - accuracy: 0.7944 - val_loss: 0.1724 - val_accuracy: 0.6895
# Epoch 81/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1156 - accuracy: 0.8006 - val_loss: 0.1735 - val_accuracy: 0.6914
# Epoch 82/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1133 - accuracy: 0.8064 - val_loss: 0.1736 - val_accuracy: 0.6914
# Epoch 83/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1125 - accuracy: 0.8046 - val_loss: 0.1751 - val_accuracy: 0.6933
# Epoch 84/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1120 - accuracy: 0.8048 - val_loss: 0.1743 - val_accuracy: 0.6914
# Epoch 85/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1108 - accuracy: 0.8126 - val_loss: 0.1747 - val_accuracy: 0.6781
# Epoch 86/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1088 - accuracy: 0.8122 - val_loss: 0.1751 - val_accuracy: 0.6838
# Epoch 87/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1090 - accuracy: 0.8133 - val_loss: 0.1747 - val_accuracy: 0.6800
# Epoch 88/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1082 - accuracy: 0.8160 - val_loss: 0.1753 - val_accuracy: 0.6876
# Epoch 89/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1066 - accuracy: 0.8175 - val_loss: 0.1770 - val_accuracy: 0.6857
# Epoch 90/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1043 - accuracy: 0.8295 - val_loss: 0.1775 - val_accuracy: 0.6819
# Epoch 91/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1037 - accuracy: 0.8271 - val_loss: 0.1776 - val_accuracy: 0.6933
# Epoch 92/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1030 - accuracy: 0.8256 - val_loss: 0.1776 - val_accuracy: 0.6933
# Epoch 93/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1019 - accuracy: 0.8268 - val_loss: 0.1784 - val_accuracy: 0.6914
# Epoch 94/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1014 - accuracy: 0.8303 - val_loss: 0.1796 - val_accuracy: 0.6838
# Epoch 95/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0999 - accuracy: 0.8345 - val_loss: 0.1798 - val_accuracy: 0.6819
# Epoch 96/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0989 - accuracy: 0.8357 - val_loss: 0.1801 - val_accuracy: 0.6838
# Epoch 97/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0975 - accuracy: 0.8367 - val_loss: 0.1803 - val_accuracy: 0.6857
# Epoch 98/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0984 - accuracy: 0.8353 - val_loss: 0.1807 - val_accuracy: 0.6819
# 2/2 [==============================] - 0s 2ms/step
# Epoch 1/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6895 - accuracy: 0.1633 - val_loss: 0.6802 - val_accuracy: 0.1832
# Epoch 2/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6707 - accuracy: 0.1845 - val_loss: 0.6582 - val_accuracy: 0.1756
# Epoch 3/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6466 - accuracy: 0.1757 - val_loss: 0.6315 - val_accuracy: 0.1756
# Epoch 4/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6173 - accuracy: 0.1751 - val_loss: 0.5978 - val_accuracy: 0.1756
# Epoch 5/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5783 - accuracy: 0.1755 - val_loss: 0.5525 - val_accuracy: 0.1756
# Epoch 6/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5278 - accuracy: 0.1733 - val_loss: 0.4961 - val_accuracy: 0.1756
# Epoch 7/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4692 - accuracy: 0.1747 - val_loss: 0.4350 - val_accuracy: 0.1756
# Epoch 8/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4090 - accuracy: 0.2210 - val_loss: 0.3771 - val_accuracy: 0.4141
# Epoch 9/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3596 - accuracy: 0.3795 - val_loss: 0.3415 - val_accuracy: 0.4332
# Epoch 10/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3329 - accuracy: 0.3945 - val_loss: 0.3234 - val_accuracy: 0.4351
# Epoch 11/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3177 - accuracy: 0.3865 - val_loss: 0.3109 - val_accuracy: 0.3645
# Epoch 12/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3076 - accuracy: 0.3803 - val_loss: 0.3028 - val_accuracy: 0.3588
# Epoch 13/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2997 - accuracy: 0.3980 - val_loss: 0.2950 - val_accuracy: 0.4332
# Epoch 14/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2926 - accuracy: 0.4361 - val_loss: 0.2878 - val_accuracy: 0.4370
# Epoch 15/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2868 - accuracy: 0.4477 - val_loss: 0.2821 - val_accuracy: 0.4389
# Epoch 16/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2802 - accuracy: 0.4526 - val_loss: 0.2776 - val_accuracy: 0.4389
# Epoch 17/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2755 - accuracy: 0.4509 - val_loss: 0.2736 - val_accuracy: 0.4408
# Epoch 18/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2716 - accuracy: 0.4528 - val_loss: 0.2702 - val_accuracy: 0.4389
# Epoch 19/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2671 - accuracy: 0.4544 - val_loss: 0.2676 - val_accuracy: 0.4389
# Epoch 20/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2665 - accuracy: 0.4498 - val_loss: 0.2651 - val_accuracy: 0.4389
# Epoch 21/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2632 - accuracy: 0.4542 - val_loss: 0.2629 - val_accuracy: 0.4427
# Epoch 22/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2612 - accuracy: 0.4514 - val_loss: 0.2610 - val_accuracy: 0.4408
# Epoch 23/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2585 - accuracy: 0.4528 - val_loss: 0.2590 - val_accuracy: 0.4427
# Epoch 24/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2575 - accuracy: 0.4562 - val_loss: 0.2571 - val_accuracy: 0.4408
# Epoch 25/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2550 - accuracy: 0.4536 - val_loss: 0.2553 - val_accuracy: 0.4408
# Epoch 26/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2531 - accuracy: 0.4558 - val_loss: 0.2533 - val_accuracy: 0.4427
# Epoch 27/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2513 - accuracy: 0.4580 - val_loss: 0.2515 - val_accuracy: 0.4447
# Epoch 28/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2487 - accuracy: 0.4846 - val_loss: 0.2495 - val_accuracy: 0.4981
# Epoch 29/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2473 - accuracy: 0.5026 - val_loss: 0.2477 - val_accuracy: 0.4943
# Epoch 30/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2449 - accuracy: 0.5062 - val_loss: 0.2459 - val_accuracy: 0.5000
# Epoch 31/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2421 - accuracy: 0.5137 - val_loss: 0.2440 - val_accuracy: 0.5095
# Epoch 32/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2425 - accuracy: 0.5125 - val_loss: 0.2419 - val_accuracy: 0.5191
# Epoch 33/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2391 - accuracy: 0.5168 - val_loss: 0.2397 - val_accuracy: 0.5172
# Epoch 34/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2370 - accuracy: 0.5242 - val_loss: 0.2372 - val_accuracy: 0.5191
# Epoch 35/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2346 - accuracy: 0.5228 - val_loss: 0.2347 - val_accuracy: 0.5172
# Epoch 36/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2320 - accuracy: 0.5306 - val_loss: 0.2321 - val_accuracy: 0.5515
# Epoch 37/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2289 - accuracy: 0.5457 - val_loss: 0.2296 - val_accuracy: 0.5592
# Epoch 38/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2279 - accuracy: 0.5509 - val_loss: 0.2273 - val_accuracy: 0.5611
# Epoch 39/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2239 - accuracy: 0.5560 - val_loss: 0.2251 - val_accuracy: 0.5592
# Epoch 40/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2226 - accuracy: 0.5620 - val_loss: 0.2228 - val_accuracy: 0.5592
# Epoch 41/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2201 - accuracy: 0.5651 - val_loss: 0.2203 - val_accuracy: 0.5763
# Epoch 42/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2174 - accuracy: 0.5763 - val_loss: 0.2177 - val_accuracy: 0.5763
# Epoch 43/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2149 - accuracy: 0.5763 - val_loss: 0.2154 - val_accuracy: 0.5744
# Epoch 44/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2125 - accuracy: 0.5837 - val_loss: 0.2128 - val_accuracy: 0.5763
# Epoch 45/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2104 - accuracy: 0.5877 - val_loss: 0.2105 - val_accuracy: 0.5821
# Epoch 46/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2074 - accuracy: 0.5937 - val_loss: 0.2085 - val_accuracy: 0.5859
# Epoch 47/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2050 - accuracy: 0.5937 - val_loss: 0.2065 - val_accuracy: 0.5840
# Epoch 48/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2034 - accuracy: 0.5959 - val_loss: 0.2046 - val_accuracy: 0.5973
# Epoch 49/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2016 - accuracy: 0.6049 - val_loss: 0.2029 - val_accuracy: 0.5935
# Epoch 50/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1989 - accuracy: 0.6101 - val_loss: 0.2017 - val_accuracy: 0.5973
# Epoch 51/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1974 - accuracy: 0.6193 - val_loss: 0.2004 - val_accuracy: 0.6202
# Epoch 52/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1959 - accuracy: 0.6251 - val_loss: 0.1991 - val_accuracy: 0.6202
# Epoch 53/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1934 - accuracy: 0.6343 - val_loss: 0.1979 - val_accuracy: 0.6260
# Epoch 54/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1918 - accuracy: 0.6385 - val_loss: 0.1966 - val_accuracy: 0.6202
# Epoch 55/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1888 - accuracy: 0.6435 - val_loss: 0.1956 - val_accuracy: 0.6279
# Epoch 56/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1870 - accuracy: 0.6511 - val_loss: 0.1945 - val_accuracy: 0.6221
# Epoch 57/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1856 - accuracy: 0.6521 - val_loss: 0.1927 - val_accuracy: 0.6240
# Epoch 58/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1836 - accuracy: 0.6579 - val_loss: 0.1919 - val_accuracy: 0.6260
# Epoch 59/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1810 - accuracy: 0.6623 - val_loss: 0.1910 - val_accuracy: 0.6336
# Epoch 60/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1810 - accuracy: 0.6649 - val_loss: 0.1897 - val_accuracy: 0.6298
# Epoch 61/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1799 - accuracy: 0.6613 - val_loss: 0.1884 - val_accuracy: 0.6298
# Epoch 62/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1763 - accuracy: 0.6713 - val_loss: 0.1874 - val_accuracy: 0.6336
# Epoch 63/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1755 - accuracy: 0.6763 - val_loss: 0.1870 - val_accuracy: 0.6393
# Epoch 64/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1730 - accuracy: 0.6842 - val_loss: 0.1867 - val_accuracy: 0.6393
# Epoch 65/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1723 - accuracy: 0.6789 - val_loss: 0.1853 - val_accuracy: 0.6527
# Epoch 66/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1710 - accuracy: 0.6837 - val_loss: 0.1854 - val_accuracy: 0.6527
# Epoch 67/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1678 - accuracy: 0.6882 - val_loss: 0.1850 - val_accuracy: 0.6489
# Epoch 68/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1665 - accuracy: 0.6946 - val_loss: 0.1839 - val_accuracy: 0.6508
# Epoch 69/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1659 - accuracy: 0.6966 - val_loss: 0.1844 - val_accuracy: 0.6469
# Epoch 70/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1643 - accuracy: 0.7010 - val_loss: 0.1831 - val_accuracy: 0.6431
# Epoch 71/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1628 - accuracy: 0.6978 - val_loss: 0.1828 - val_accuracy: 0.6450
# Epoch 72/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1618 - accuracy: 0.7056 - val_loss: 0.1825 - val_accuracy: 0.6489
# Epoch 73/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1592 - accuracy: 0.7060 - val_loss: 0.1816 - val_accuracy: 0.6431
# Epoch 74/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1592 - accuracy: 0.7118 - val_loss: 0.1815 - val_accuracy: 0.6431
# Epoch 75/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1581 - accuracy: 0.7104 - val_loss: 0.1813 - val_accuracy: 0.6508
# Epoch 76/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1547 - accuracy: 0.7228 - val_loss: 0.1811 - val_accuracy: 0.6469
# Epoch 77/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1562 - accuracy: 0.7128 - val_loss: 0.1803 - val_accuracy: 0.6527
# Epoch 78/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1546 - accuracy: 0.7234 - val_loss: 0.1801 - val_accuracy: 0.6489
# Epoch 79/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1524 - accuracy: 0.7292 - val_loss: 0.1801 - val_accuracy: 0.6489
# Epoch 80/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1505 - accuracy: 0.7280 - val_loss: 0.1799 - val_accuracy: 0.6489
# Epoch 81/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1506 - accuracy: 0.7264 - val_loss: 0.1793 - val_accuracy: 0.6489
# Epoch 82/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1485 - accuracy: 0.7286 - val_loss: 0.1792 - val_accuracy: 0.6489
# Epoch 83/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1480 - accuracy: 0.7278 - val_loss: 0.1788 - val_accuracy: 0.6546
# Epoch 84/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1474 - accuracy: 0.7298 - val_loss: 0.1793 - val_accuracy: 0.6469
# Epoch 85/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1456 - accuracy: 0.7358 - val_loss: 0.1790 - val_accuracy: 0.6565
# Epoch 86/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1444 - accuracy: 0.7374 - val_loss: 0.1792 - val_accuracy: 0.6527
# Epoch 87/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1440 - accuracy: 0.7370 - val_loss: 0.1787 - val_accuracy: 0.6584
# Epoch 88/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1418 - accuracy: 0.7418 - val_loss: 0.1780 - val_accuracy: 0.6603
# Epoch 89/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1427 - accuracy: 0.7408 - val_loss: 0.1789 - val_accuracy: 0.6489
# Epoch 90/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1406 - accuracy: 0.7418 - val_loss: 0.1793 - val_accuracy: 0.6603
# Epoch 91/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1397 - accuracy: 0.7466 - val_loss: 0.1789 - val_accuracy: 0.6546
# Epoch 92/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1393 - accuracy: 0.7436 - val_loss: 0.1778 - val_accuracy: 0.6622
# Epoch 93/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1374 - accuracy: 0.7510 - val_loss: 0.1779 - val_accuracy: 0.6641
# Epoch 94/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1352 - accuracy: 0.7540 - val_loss: 0.1780 - val_accuracy: 0.6679
# Epoch 95/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1354 - accuracy: 0.7553 - val_loss: 0.1785 - val_accuracy: 0.6622
# Epoch 96/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1333 - accuracy: 0.7571 - val_loss: 0.1790 - val_accuracy: 0.6718
# Epoch 97/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1342 - accuracy: 0.7550 - val_loss: 0.1789 - val_accuracy: 0.6698
# Epoch 98/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1317 - accuracy: 0.7579 - val_loss: 0.1803 - val_accuracy: 0.6813
# Epoch 99/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1293 - accuracy: 0.7656 - val_loss: 0.1785 - val_accuracy: 0.6756
# Epoch 100/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1287 - accuracy: 0.7667 - val_loss: 0.1782 - val_accuracy: 0.6718
# Epoch 101/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1280 - accuracy: 0.7680 - val_loss: 0.1797 - val_accuracy: 0.6756
# Epoch 102/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1267 - accuracy: 0.7746 - val_loss: 0.1800 - val_accuracy: 0.6718
# Epoch 103/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1268 - accuracy: 0.7696 - val_loss: 0.1785 - val_accuracy: 0.6756
# Epoch 104/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1254 - accuracy: 0.7738 - val_loss: 0.1782 - val_accuracy: 0.6775
# Epoch 105/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1248 - accuracy: 0.7762 - val_loss: 0.1788 - val_accuracy: 0.6775
# Epoch 106/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1236 - accuracy: 0.7806 - val_loss: 0.1801 - val_accuracy: 0.6756
# Epoch 107/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1223 - accuracy: 0.7776 - val_loss: 0.1791 - val_accuracy: 0.6756
# Epoch 108/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1221 - accuracy: 0.7836 - val_loss: 0.1789 - val_accuracy: 0.6813
# Epoch 109/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1207 - accuracy: 0.7822 - val_loss: 0.1796 - val_accuracy: 0.6775
# Epoch 110/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1218 - accuracy: 0.7833 - val_loss: 0.1779 - val_accuracy: 0.6908
# Epoch 111/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1203 - accuracy: 0.7831 - val_loss: 0.1788 - val_accuracy: 0.6794
# Epoch 112/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1178 - accuracy: 0.7948 - val_loss: 0.1793 - val_accuracy: 0.6832
# Epoch 113/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1163 - accuracy: 0.7927 - val_loss: 0.1790 - val_accuracy: 0.6870
# Epoch 114/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1176 - accuracy: 0.7910 - val_loss: 0.1816 - val_accuracy: 0.6889
# Epoch 115/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1149 - accuracy: 0.7956 - val_loss: 0.1797 - val_accuracy: 0.6947
# Epoch 116/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1141 - accuracy: 0.7992 - val_loss: 0.1808 - val_accuracy: 0.6985
# Epoch 117/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1122 - accuracy: 0.8038 - val_loss: 0.1810 - val_accuracy: 0.6947
# Epoch 118/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1118 - accuracy: 0.8021 - val_loss: 0.1802 - val_accuracy: 0.6927
# Epoch 119/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1104 - accuracy: 0.8062 - val_loss: 0.1808 - val_accuracy: 0.6985
# Epoch 120/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1110 - accuracy: 0.8020 - val_loss: 0.1808 - val_accuracy: 0.6966
# Epoch 121/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1084 - accuracy: 0.8101 - val_loss: 0.1840 - val_accuracy: 0.6947
# Epoch 122/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1093 - accuracy: 0.8110 - val_loss: 0.1836 - val_accuracy: 0.6908
# 2/2 [==============================] - 0s 2ms/step
# Epoch 1/500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.6891 - accuracy: 0.1720 - val_loss: 0.6791 - val_accuracy: 0.1855
# Epoch 2/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6685 - accuracy: 0.1785 - val_loss: 0.6544 - val_accuracy: 0.1759
# Epoch 3/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6412 - accuracy: 0.1727 - val_loss: 0.6237 - val_accuracy: 0.1759
# Epoch 4/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6070 - accuracy: 0.1745 - val_loss: 0.5839 - val_accuracy: 0.1759
# Epoch 5/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.5606 - accuracy: 0.1735 - val_loss: 0.5282 - val_accuracy: 0.1759
# Epoch 6/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4986 - accuracy: 0.1741 - val_loss: 0.4601 - val_accuracy: 0.1759
# Epoch 7/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4296 - accuracy: 0.1751 - val_loss: 0.3927 - val_accuracy: 0.1759
# Epoch 8/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3689 - accuracy: 0.2152 - val_loss: 0.3438 - val_accuracy: 0.4015
# Epoch 9/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3325 - accuracy: 0.3771 - val_loss: 0.3213 - val_accuracy: 0.3270
# Epoch 10/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3156 - accuracy: 0.3428 - val_loss: 0.3094 - val_accuracy: 0.3270
# Epoch 11/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3053 - accuracy: 0.3400 - val_loss: 0.3007 - val_accuracy: 0.3403
# Epoch 12/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2967 - accuracy: 0.3989 - val_loss: 0.2935 - val_accuracy: 0.4532
# Epoch 13/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2899 - accuracy: 0.4415 - val_loss: 0.2870 - val_accuracy: 0.4532
# Epoch 14/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2837 - accuracy: 0.4510 - val_loss: 0.2811 - val_accuracy: 0.4608
# Epoch 15/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2786 - accuracy: 0.4514 - val_loss: 0.2754 - val_accuracy: 0.4570
# Epoch 16/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2722 - accuracy: 0.4556 - val_loss: 0.2691 - val_accuracy: 0.4685
# Epoch 17/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2669 - accuracy: 0.4770 - val_loss: 0.2637 - val_accuracy: 0.5124
# Epoch 18/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2623 - accuracy: 0.4972 - val_loss: 0.2594 - val_accuracy: 0.5143
# Epoch 19/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2580 - accuracy: 0.5011 - val_loss: 0.2558 - val_accuracy: 0.5163
# Epoch 20/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2548 - accuracy: 0.5023 - val_loss: 0.2527 - val_accuracy: 0.5143
# Epoch 21/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2514 - accuracy: 0.5041 - val_loss: 0.2501 - val_accuracy: 0.5258
# Epoch 22/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2492 - accuracy: 0.5054 - val_loss: 0.2477 - val_accuracy: 0.5163
# Epoch 23/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2469 - accuracy: 0.5053 - val_loss: 0.2456 - val_accuracy: 0.5124
# Epoch 24/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2448 - accuracy: 0.5100 - val_loss: 0.2435 - val_accuracy: 0.5105
# Epoch 25/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2423 - accuracy: 0.5084 - val_loss: 0.2415 - val_accuracy: 0.5086
# Epoch 26/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2409 - accuracy: 0.5088 - val_loss: 0.2397 - val_accuracy: 0.5048
# Epoch 27/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2386 - accuracy: 0.5160 - val_loss: 0.2383 - val_accuracy: 0.5105
# Epoch 28/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2375 - accuracy: 0.5189 - val_loss: 0.2371 - val_accuracy: 0.5086
# Epoch 29/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2350 - accuracy: 0.5267 - val_loss: 0.2358 - val_accuracy: 0.5067
# Epoch 30/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2338 - accuracy: 0.5294 - val_loss: 0.2345 - val_accuracy: 0.5067
# Epoch 31/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2318 - accuracy: 0.5335 - val_loss: 0.2334 - val_accuracy: 0.5449
# Epoch 32/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2296 - accuracy: 0.5386 - val_loss: 0.2321 - val_accuracy: 0.5449
# Epoch 33/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2282 - accuracy: 0.5470 - val_loss: 0.2310 - val_accuracy: 0.5488
# Epoch 34/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2274 - accuracy: 0.5493 - val_loss: 0.2301 - val_accuracy: 0.5507
# Epoch 35/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2257 - accuracy: 0.5538 - val_loss: 0.2286 - val_accuracy: 0.5507
# Epoch 36/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2248 - accuracy: 0.5564 - val_loss: 0.2274 - val_accuracy: 0.5373
# Epoch 37/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2220 - accuracy: 0.5693 - val_loss: 0.2260 - val_accuracy: 0.5602
# Epoch 38/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2221 - accuracy: 0.5670 - val_loss: 0.2243 - val_accuracy: 0.5717
# Epoch 39/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2213 - accuracy: 0.5736 - val_loss: 0.2226 - val_accuracy: 0.5774
# Epoch 40/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2182 - accuracy: 0.5769 - val_loss: 0.2209 - val_accuracy: 0.5793
# Epoch 41/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2176 - accuracy: 0.5853 - val_loss: 0.2188 - val_accuracy: 0.5774
# Epoch 42/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2136 - accuracy: 0.5887 - val_loss: 0.2166 - val_accuracy: 0.5813
# Epoch 43/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2118 - accuracy: 0.5897 - val_loss: 0.2142 - val_accuracy: 0.5813
# Epoch 44/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2107 - accuracy: 0.5920 - val_loss: 0.2117 - val_accuracy: 0.5813
# Epoch 45/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2084 - accuracy: 0.5984 - val_loss: 0.2095 - val_accuracy: 0.5755
# Epoch 46/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2068 - accuracy: 0.5972 - val_loss: 0.2075 - val_accuracy: 0.5774
# Epoch 47/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2045 - accuracy: 0.5992 - val_loss: 0.2051 - val_accuracy: 0.5832
# Epoch 48/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2018 - accuracy: 0.6065 - val_loss: 0.2033 - val_accuracy: 0.5755
# Epoch 49/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2002 - accuracy: 0.6052 - val_loss: 0.2014 - val_accuracy: 0.5832
# Epoch 50/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1979 - accuracy: 0.6135 - val_loss: 0.1997 - val_accuracy: 0.5832
# Epoch 51/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1979 - accuracy: 0.6103 - val_loss: 0.1983 - val_accuracy: 0.5889
# Epoch 52/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1958 - accuracy: 0.6174 - val_loss: 0.1967 - val_accuracy: 0.6004
# Epoch 53/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1937 - accuracy: 0.6260 - val_loss: 0.1955 - val_accuracy: 0.6157
# Epoch 54/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1907 - accuracy: 0.6376 - val_loss: 0.1940 - val_accuracy: 0.6233
# Epoch 55/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1885 - accuracy: 0.6430 - val_loss: 0.1927 - val_accuracy: 0.6252
# Epoch 56/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1876 - accuracy: 0.6425 - val_loss: 0.1916 - val_accuracy: 0.6272
# Epoch 57/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1843 - accuracy: 0.6514 - val_loss: 0.1903 - val_accuracy: 0.6291
# Epoch 58/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1832 - accuracy: 0.6580 - val_loss: 0.1895 - val_accuracy: 0.6329
# Epoch 59/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1826 - accuracy: 0.6577 - val_loss: 0.1883 - val_accuracy: 0.6252
# Epoch 60/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1792 - accuracy: 0.6706 - val_loss: 0.1873 - val_accuracy: 0.6310
# Epoch 61/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1786 - accuracy: 0.6731 - val_loss: 0.1864 - val_accuracy: 0.6329
# Epoch 62/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1767 - accuracy: 0.6738 - val_loss: 0.1862 - val_accuracy: 0.6252
# Epoch 63/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1760 - accuracy: 0.6827 - val_loss: 0.1850 - val_accuracy: 0.6291
# Epoch 64/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1740 - accuracy: 0.6808 - val_loss: 0.1842 - val_accuracy: 0.6367
# Epoch 65/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1717 - accuracy: 0.6835 - val_loss: 0.1834 - val_accuracy: 0.6329
# Epoch 66/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1722 - accuracy: 0.6909 - val_loss: 0.1829 - val_accuracy: 0.6291
# Epoch 67/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1688 - accuracy: 0.6970 - val_loss: 0.1819 - val_accuracy: 0.6367
# Epoch 68/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1663 - accuracy: 0.6984 - val_loss: 0.1813 - val_accuracy: 0.6348
# Epoch 69/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1665 - accuracy: 0.6980 - val_loss: 0.1799 - val_accuracy: 0.6405
# Epoch 70/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1637 - accuracy: 0.7008 - val_loss: 0.1799 - val_accuracy: 0.6386
# Epoch 71/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1642 - accuracy: 0.7048 - val_loss: 0.1789 - val_accuracy: 0.6386
# Epoch 72/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1628 - accuracy: 0.7014 - val_loss: 0.1784 - val_accuracy: 0.6463
# Epoch 73/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1615 - accuracy: 0.7030 - val_loss: 0.1778 - val_accuracy: 0.6463
# Epoch 74/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1587 - accuracy: 0.7047 - val_loss: 0.1766 - val_accuracy: 0.6520
# Epoch 75/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1581 - accuracy: 0.7114 - val_loss: 0.1765 - val_accuracy: 0.6501
# Epoch 76/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1543 - accuracy: 0.7144 - val_loss: 0.1755 - val_accuracy: 0.6501
# Epoch 77/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1552 - accuracy: 0.7183 - val_loss: 0.1747 - val_accuracy: 0.6520
# Epoch 78/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1548 - accuracy: 0.7176 - val_loss: 0.1745 - val_accuracy: 0.6577
# Epoch 79/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1519 - accuracy: 0.7211 - val_loss: 0.1729 - val_accuracy: 0.6501
# Epoch 80/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1513 - accuracy: 0.7255 - val_loss: 0.1730 - val_accuracy: 0.6520
# Epoch 81/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1490 - accuracy: 0.7221 - val_loss: 0.1722 - val_accuracy: 0.6520
# Epoch 82/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1479 - accuracy: 0.7296 - val_loss: 0.1725 - val_accuracy: 0.6482
# Epoch 83/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1464 - accuracy: 0.7268 - val_loss: 0.1714 - val_accuracy: 0.6501
# Epoch 84/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1472 - accuracy: 0.7285 - val_loss: 0.1700 - val_accuracy: 0.6577
# Epoch 85/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1453 - accuracy: 0.7319 - val_loss: 0.1697 - val_accuracy: 0.6520
# Epoch 86/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1431 - accuracy: 0.7357 - val_loss: 0.1693 - val_accuracy: 0.6558
# Epoch 87/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1419 - accuracy: 0.7413 - val_loss: 0.1688 - val_accuracy: 0.6520
# Epoch 88/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1417 - accuracy: 0.7377 - val_loss: 0.1681 - val_accuracy: 0.6539
# Epoch 89/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1397 - accuracy: 0.7440 - val_loss: 0.1677 - val_accuracy: 0.6558
# Epoch 90/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1379 - accuracy: 0.7455 - val_loss: 0.1683 - val_accuracy: 0.6558
# Epoch 91/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1378 - accuracy: 0.7439 - val_loss: 0.1674 - val_accuracy: 0.6577
# Epoch 92/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1370 - accuracy: 0.7479 - val_loss: 0.1668 - val_accuracy: 0.6558
# Epoch 93/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1354 - accuracy: 0.7491 - val_loss: 0.1674 - val_accuracy: 0.6520
# Epoch 94/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1330 - accuracy: 0.7596 - val_loss: 0.1672 - val_accuracy: 0.6558
# Epoch 95/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1329 - accuracy: 0.7562 - val_loss: 0.1670 - val_accuracy: 0.6597
# Epoch 96/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1318 - accuracy: 0.7577 - val_loss: 0.1668 - val_accuracy: 0.6577
# Epoch 97/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1320 - accuracy: 0.7614 - val_loss: 0.1656 - val_accuracy: 0.6673
# Epoch 98/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1283 - accuracy: 0.7655 - val_loss: 0.1670 - val_accuracy: 0.6654
# Epoch 99/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1290 - accuracy: 0.7654 - val_loss: 0.1659 - val_accuracy: 0.6692
# Epoch 100/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1281 - accuracy: 0.7675 - val_loss: 0.1662 - val_accuracy: 0.6769
# Epoch 101/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1254 - accuracy: 0.7758 - val_loss: 0.1653 - val_accuracy: 0.6864
# Epoch 102/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1253 - accuracy: 0.7732 - val_loss: 0.1663 - val_accuracy: 0.6750
# Epoch 103/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1223 - accuracy: 0.7814 - val_loss: 0.1654 - val_accuracy: 0.6826
# Epoch 104/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1231 - accuracy: 0.7798 - val_loss: 0.1663 - val_accuracy: 0.6864
# Epoch 105/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1218 - accuracy: 0.7810 - val_loss: 0.1660 - val_accuracy: 0.6922
# Epoch 106/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1208 - accuracy: 0.7776 - val_loss: 0.1658 - val_accuracy: 0.6922
# Epoch 107/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1202 - accuracy: 0.7826 - val_loss: 0.1676 - val_accuracy: 0.6807
# Epoch 108/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1187 - accuracy: 0.7914 - val_loss: 0.1663 - val_accuracy: 0.6845
# Epoch 109/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1182 - accuracy: 0.7888 - val_loss: 0.1672 - val_accuracy: 0.6883
# Epoch 110/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1152 - accuracy: 0.7954 - val_loss: 0.1681 - val_accuracy: 0.6864
# Epoch 111/500
# ...
# Epoch 21/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2476 - accuracy: 0.5092 - val_loss: 0.2475 - val_accuracy: 0.5086
# Epoch 22/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2440 - accuracy: 0.5141 - val_loss: 0.2457 - val_accuracy: 0.5086
# Epoch 23/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2427 - accuracy: 0.5151 - val_loss: 0.2442 - val_accuracy: 0.5086
# Epoch 24/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2410 - accuracy: 0.5175 - val_loss: 0.2428 - val_accuracy: 0.5067
# Epoch 25/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2375 - accuracy: 0.5210 - val_loss: 0.2416 - val_accuracy: 0.5086
# Epoch 26/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2365 - accuracy: 0.5231 - val_loss: 0.2405 - val_accuracy: 0.5067
# Epoch 27/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2345 - accuracy: 0.5255 - val_loss: 0.2396 - val_accuracy: 0.5162
# Epoch 28/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2331 - accuracy: 0.5254 - val_loss: 0.2387 - val_accuracy: 0.5200
# Epoch 29/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2321 - accuracy: 0.5323 - val_loss: 0.2378 - val_accuracy: 0.5181
# Epoch 30/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2308 - accuracy: 0.5351 - val_loss: 0.2369 - val_accuracy: 0.5181
# Epoch 31/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2289 - accuracy: 0.5405 - val_loss: 0.2361 - val_accuracy: 0.5162
# Epoch 32/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2294 - accuracy: 0.5368 - val_loss: 0.2351 - val_accuracy: 0.5162
# Epoch 33/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2275 - accuracy: 0.5388 - val_loss: 0.2342 - val_accuracy: 0.5162
# Epoch 34/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2267 - accuracy: 0.5411 - val_loss: 0.2333 - val_accuracy: 0.5257
# Epoch 35/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2253 - accuracy: 0.5532 - val_loss: 0.2322 - val_accuracy: 0.5314
# Epoch 36/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2239 - accuracy: 0.5538 - val_loss: 0.2310 - val_accuracy: 0.5276
# Epoch 37/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2221 - accuracy: 0.5687 - val_loss: 0.2299 - val_accuracy: 0.5486
# Epoch 38/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2218 - accuracy: 0.5673 - val_loss: 0.2286 - val_accuracy: 0.5600
# Epoch 39/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2203 - accuracy: 0.5698 - val_loss: 0.2274 - val_accuracy: 0.5562
# Epoch 40/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2189 - accuracy: 0.5803 - val_loss: 0.2261 - val_accuracy: 0.5581
# Epoch 41/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2163 - accuracy: 0.5856 - val_loss: 0.2247 - val_accuracy: 0.5543
# Epoch 42/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2150 - accuracy: 0.5864 - val_loss: 0.2232 - val_accuracy: 0.5619
# Epoch 43/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2136 - accuracy: 0.5915 - val_loss: 0.2217 - val_accuracy: 0.5638
# Epoch 44/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2123 - accuracy: 0.5925 - val_loss: 0.2200 - val_accuracy: 0.5657
# Epoch 45/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2087 - accuracy: 0.6005 - val_loss: 0.2182 - val_accuracy: 0.5695
# Epoch 46/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2098 - accuracy: 0.5973 - val_loss: 0.2166 - val_accuracy: 0.5752
# Epoch 47/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2069 - accuracy: 0.6060 - val_loss: 0.2144 - val_accuracy: 0.5714
# Epoch 48/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2043 - accuracy: 0.6106 - val_loss: 0.2126 - val_accuracy: 0.5790
# Epoch 49/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2031 - accuracy: 0.6076 - val_loss: 0.2106 - val_accuracy: 0.5790
# Epoch 50/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2015 - accuracy: 0.6140 - val_loss: 0.2087 - val_accuracy: 0.5848
# Epoch 51/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1985 - accuracy: 0.6210 - val_loss: 0.2066 - val_accuracy: 0.5867
# Epoch 52/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1970 - accuracy: 0.6195 - val_loss: 0.2049 - val_accuracy: 0.5829
# Epoch 53/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1956 - accuracy: 0.6194 - val_loss: 0.2029 - val_accuracy: 0.5905
# Epoch 54/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1925 - accuracy: 0.6309 - val_loss: 0.2009 - val_accuracy: 0.5924
# Epoch 55/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1902 - accuracy: 0.6321 - val_loss: 0.1990 - val_accuracy: 0.5962
# Epoch 56/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1895 - accuracy: 0.6417 - val_loss: 0.1973 - val_accuracy: 0.6095
# Epoch 57/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1876 - accuracy: 0.6463 - val_loss: 0.1956 - val_accuracy: 0.6267
# Epoch 58/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1854 - accuracy: 0.6528 - val_loss: 0.1939 - val_accuracy: 0.6400
# Epoch 59/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1818 - accuracy: 0.6582 - val_loss: 0.1923 - val_accuracy: 0.6362
# Epoch 60/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1829 - accuracy: 0.6658 - val_loss: 0.1910 - val_accuracy: 0.6362
# Epoch 61/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1801 - accuracy: 0.6666 - val_loss: 0.1893 - val_accuracy: 0.6362
# Epoch 62/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1772 - accuracy: 0.6717 - val_loss: 0.1880 - val_accuracy: 0.6514
# Epoch 63/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1748 - accuracy: 0.6779 - val_loss: 0.1866 - val_accuracy: 0.6495
# Epoch 64/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1748 - accuracy: 0.6806 - val_loss: 0.1852 - val_accuracy: 0.6571
# Epoch 65/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1715 - accuracy: 0.6851 - val_loss: 0.1839 - val_accuracy: 0.6610
# Epoch 66/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1710 - accuracy: 0.6906 - val_loss: 0.1831 - val_accuracy: 0.6648
# Epoch 67/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1696 - accuracy: 0.6896 - val_loss: 0.1818 - val_accuracy: 0.6705
# Epoch 68/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1687 - accuracy: 0.6869 - val_loss: 0.1806 - val_accuracy: 0.6724
# Epoch 69/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1640 - accuracy: 0.7018 - val_loss: 0.1795 - val_accuracy: 0.6724
# Epoch 70/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1655 - accuracy: 0.6949 - val_loss: 0.1784 - val_accuracy: 0.6762
# Epoch 71/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1623 - accuracy: 0.7034 - val_loss: 0.1776 - val_accuracy: 0.6781
# Epoch 72/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1624 - accuracy: 0.7035 - val_loss: 0.1766 - val_accuracy: 0.6819
# Epoch 73/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1615 - accuracy: 0.6998 - val_loss: 0.1756 - val_accuracy: 0.6838
# Epoch 74/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1609 - accuracy: 0.7004 - val_loss: 0.1744 - val_accuracy: 0.6781
# Epoch 75/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1570 - accuracy: 0.7073 - val_loss: 0.1734 - val_accuracy: 0.6743
# Epoch 76/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1561 - accuracy: 0.7081 - val_loss: 0.1724 - val_accuracy: 0.6781
# Epoch 77/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1558 - accuracy: 0.7101 - val_loss: 0.1720 - val_accuracy: 0.6781
# Epoch 78/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1556 - accuracy: 0.7079 - val_loss: 0.1711 - val_accuracy: 0.6819
# Epoch 79/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1531 - accuracy: 0.7143 - val_loss: 0.1703 - val_accuracy: 0.6800
# Epoch 80/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1500 - accuracy: 0.7209 - val_loss: 0.1699 - val_accuracy: 0.6781
# Epoch 81/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1498 - accuracy: 0.7176 - val_loss: 0.1689 - val_accuracy: 0.6838
# Epoch 82/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1499 - accuracy: 0.7183 - val_loss: 0.1680 - val_accuracy: 0.6724
# Epoch 83/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1477 - accuracy: 0.7227 - val_loss: 0.1672 - val_accuracy: 0.6800
# Epoch 84/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1461 - accuracy: 0.7263 - val_loss: 0.1674 - val_accuracy: 0.6857
# Epoch 85/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1464 - accuracy: 0.7238 - val_loss: 0.1669 - val_accuracy: 0.6800
# Epoch 86/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1454 - accuracy: 0.7293 - val_loss: 0.1656 - val_accuracy: 0.6838
# Epoch 87/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1447 - accuracy: 0.7260 - val_loss: 0.1645 - val_accuracy: 0.6819
# Epoch 88/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1424 - accuracy: 0.7319 - val_loss: 0.1641 - val_accuracy: 0.6781
# Epoch 89/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1407 - accuracy: 0.7382 - val_loss: 0.1636 - val_accuracy: 0.6781
# Epoch 90/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1413 - accuracy: 0.7383 - val_loss: 0.1629 - val_accuracy: 0.6800
# Epoch 91/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1387 - accuracy: 0.7417 - val_loss: 0.1621 - val_accuracy: 0.6762
# Epoch 92/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1384 - accuracy: 0.7376 - val_loss: 0.1635 - val_accuracy: 0.6686
# Epoch 93/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1365 - accuracy: 0.7476 - val_loss: 0.1622 - val_accuracy: 0.6743
# Epoch 94/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1350 - accuracy: 0.7506 - val_loss: 0.1616 - val_accuracy: 0.6743
# Epoch 95/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1334 - accuracy: 0.7498 - val_loss: 0.1618 - val_accuracy: 0.6762
# Epoch 96/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1349 - accuracy: 0.7492 - val_loss: 0.1610 - val_accuracy: 0.6819
# Epoch 97/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1319 - accuracy: 0.7514 - val_loss: 0.1610 - val_accuracy: 0.6857
# Epoch 98/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1301 - accuracy: 0.7613 - val_loss: 0.1612 - val_accuracy: 0.6819
# Epoch 99/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1321 - accuracy: 0.7493 - val_loss: 0.1604 - val_accuracy: 0.6876
# Epoch 100/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1307 - accuracy: 0.7623 - val_loss: 0.1599 - val_accuracy: 0.6800
# Epoch 101/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1287 - accuracy: 0.7639 - val_loss: 0.1593 - val_accuracy: 0.6838
# Epoch 102/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1265 - accuracy: 0.7703 - val_loss: 0.1590 - val_accuracy: 0.6819
# Epoch 103/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1258 - accuracy: 0.7681 - val_loss: 0.1597 - val_accuracy: 0.6895
# Epoch 104/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1250 - accuracy: 0.7719 - val_loss: 0.1593 - val_accuracy: 0.6895
# Epoch 105/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1243 - accuracy: 0.7731 - val_loss: 0.1596 - val_accuracy: 0.6914
# Epoch 106/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1229 - accuracy: 0.7805 - val_loss: 0.1596 - val_accuracy: 0.6952
# Epoch 107/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1213 - accuracy: 0.7823 - val_loss: 0.1591 - val_accuracy: 0.6914
# Epoch 108/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1221 - accuracy: 0.7760 - val_loss: 0.1595 - val_accuracy: 0.6857
# Epoch 109/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1207 - accuracy: 0.7829 - val_loss: 0.1592 - val_accuracy: 0.6895
# Epoch 110/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1180 - accuracy: 0.7906 - val_loss: 0.1596 - val_accuracy: 0.6838
# Epoch 111/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1179 - accuracy: 0.7943 - val_loss: 0.1600 - val_accuracy: 0.6914
# Epoch 112/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1172 - accuracy: 0.7899 - val_loss: 0.1592 - val_accuracy: 0.6990
# Epoch 113/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1153 - accuracy: 0.7996 - val_loss: 0.1591 - val_accuracy: 0.7010
# Epoch 114/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1143 - accuracy: 0.8004 - val_loss: 0.1592 - val_accuracy: 0.6914
# Epoch 115/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1138 - accuracy: 0.8022 - val_loss: 0.1601 - val_accuracy: 0.6952
# Epoch 116/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1126 - accuracy: 0.8032 - val_loss: 0.1607 - val_accuracy: 0.6933
# Epoch 117/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1120 - accuracy: 0.8028 - val_loss: 0.1594 - val_accuracy: 0.7010
# Epoch 118/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1096 - accuracy: 0.8150 - val_loss: 0.1604 - val_accuracy: 0.6990
# Epoch 119/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1084 - accuracy: 0.8154 - val_loss: 0.1605 - val_accuracy: 0.7048
# Epoch 120/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1090 - accuracy: 0.8116 - val_loss: 0.1607 - val_accuracy: 0.7105
# Epoch 121/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1072 - accuracy: 0.8164 - val_loss: 0.1617 - val_accuracy: 0.7105
# Epoch 122/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1060 - accuracy: 0.8237 - val_loss: 0.1606 - val_accuracy: 0.7010
# Epoch 123/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1048 - accuracy: 0.8224 - val_loss: 0.1609 - val_accuracy: 0.6990
# Epoch 124/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1042 - accuracy: 0.8267 - val_loss: 0.1617 - val_accuracy: 0.7010
# Epoch 125/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1031 - accuracy: 0.8247 - val_loss: 0.1613 - val_accuracy: 0.7105
# Epoch 126/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1011 - accuracy: 0.8311 - val_loss: 0.1632 - val_accuracy: 0.7029
# Epoch 127/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1015 - accuracy: 0.8307 - val_loss: 0.1633 - val_accuracy: 0.6990
# Epoch 128/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0998 - accuracy: 0.8329 - val_loss: 0.1638 - val_accuracy: 0.7048
# Epoch 129/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0994 - accuracy: 0.8377 - val_loss: 0.1639 - val_accuracy: 0.7067
# Epoch 130/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0976 - accuracy: 0.8381 - val_loss: 0.1641 - val_accuracy: 0.7086
# Epoch 131/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0955 - accuracy: 0.8419 - val_loss: 0.1666 - val_accuracy: 0.6990
# Epoch 132/500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0957 - accuracy: 0.8429 - val_loss: 0.1653 - val_accuracy: 0.7067
# 2/2 [==============================] - 0s 1ms/step

# %%
import matplotlib.pyplot as plt
from utils import plot_classification_performance

# %%
f, axs = plt.subplots(8, 3, figsize=(12, 3 * 8))
for i in range(7):
    plot_classification_performance(
        axs[i, :],
        y_true[y_test[:, i]],
        y_pred[y_test[:, i], :],
        history[i]
    )
plot_classification_performance(
    axs[-1, :],
    y_true,
    y_pred
)
