# %%
from glob import glob
import pandas as pd
import os
import numpy as np
import tensorflow as tf
import keras
# Out:
# c:\Users\huang\miniconda3\envs\gpu-ml-base\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# c:\Users\huang\miniconda3\envs\gpu-ml-base\Lib\site-packages\h5py\__init__.py:36: UserWarning: h5py is running against HDF5 1.14.6 when it was built against 1.14.5, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "

# %%
# Replace your TCRDataLoader class with this updated version that combines columns
import pandas as pd
import numpy as np
import tensorflow as tf
from glob import glob
import os

class TCRDataLoader:
    def __init__(self, data_dir):
        self.data_dir = data_dir
        self.aa_dict = None
        self.v_dict = None
        self.j_dict = None
        self.label_map = None
        self.max_length = None
        
    def combine_columns(self, df, column_variants, new_column_name):
        """Combine multiple columns that represent the same data type"""
        combined_series = pd.Series([None] * len(df), index=df.index)
        
        for variant in column_variants:
            if variant in df.columns:
                # Fill in non-null values from this column
                mask = df[variant].notna() & combined_series.isna()
                combined_series[mask] = df[variant][mask]
                print(f"  Added {mask.sum()} values from '{variant}' column")
        
        return combined_series
    
    def load_files(self):
        df_list = []
        files = glob(self.data_dir + "/*/*.tsv")
        
        for file_path in files:
            df = pd.read_csv(file_path, sep='\t')
            
            # Extract folder name from file path
            folder_name = os.path.basename(os.path.dirname(file_path))
            
            # Split folder name to get Antigen
            parts = folder_name.split('-')
            antigen = parts[-1]  # Get last part (the antigen)
            
            # Add antigen column to dataframe
            df['Antigen'] = antigen
            
            df_list.append(df)
        
        combined_df = pd.concat(df_list, ignore_index=True)
        
        # Define column candidates for each data type
        column_variants = {
            'sequence': ['aminoAcid', 'beta', 'Amino', 'sequence', 'cdr3', 'CDR3'],
            'v_gene': ['v_beta', 'vGeneName', 'v_gene', 'V_gene', 'TRBV'],
            'j_gene': ['j_beta', 'jGeneName', 'j_gene', 'J_gene', 'TRBJ'],
            'counts': ['counts', 'count', 'count (templates/reads)', 'templates', 'reads', 'frequency']
        }
        
        print("Combining columns:")
        # Combine columns for each data type
        for standard_name, variants in column_variants.items():
            print(f"\nCombining {standard_name} columns:")
            combined_series = self.combine_columns(combined_df, variants, standard_name)
            combined_df[f'combined_{standard_name}'] = combined_series
            
            # Show statistics
            total_values = combined_series.notna().sum()
            print(f"  Total combined values: {total_values}")
        
        return combined_df
    
    def build_vocabulary(self, df):
        # Use combined columns
        # Amino acids
        all_sequences = df['combined_sequence'].dropna()
        if len(all_sequences) == 0:
            raise ValueError("No sequence data found in combined columns!")
            
        giant_string = ''.join(all_sequences)
        unique_letters = sorted(set(giant_string))
        self.aa_dict = {}
        for i, letter in enumerate(unique_letters):
            self.aa_dict[letter] = i+1
        
        # V genes
        v_genes = df['combined_v_gene'].dropna().unique()
        v_genes = sorted(v_genes)
        self.v_dict = {}
        for i, gene in enumerate(v_genes):
            self.v_dict[gene] = i + 1

        # J genes
        j_genes = df['combined_j_gene'].dropna().unique()
        j_genes = sorted(j_genes)
        self.j_dict = {}
        for i, gene in enumerate(j_genes):
            self.j_dict[gene] = i + 1

        # Labels
        antigens = df['Antigen'].unique()
        self.label_map = {}
        for i, antigen in enumerate(sorted(antigens)):
            self.label_map[antigen] = i

        # Max length
        sequence_lengths = [len(seq) for seq in df['combined_sequence'].dropna()]
        self.max_length = max(sequence_lengths) if sequence_lengths else 0
        
        print(f"\nVocabulary built:")
        print(f"  Amino acids: {len(self.aa_dict)} unique")
        print(f"  V genes: {len(self.v_dict)} unique")
        print(f"  J genes: {len(self.j_dict)} unique")
        print(f"  Max sequence length: {self.max_length}")
    
    def encode_sequences(self, sequences):
        encoded_aa = []
        for sequence in sequences:
            sequence_numbers = []
            for letter in sequence:
                number = self.aa_dict.get(letter, 0)
                sequence_numbers.append(number)
            # Add padding zeros if sequence is shorter than max_length
            while len(sequence_numbers) < self.max_length:
                sequence_numbers.append(0)
            encoded_aa.append(sequence_numbers)
        return encoded_aa
    
    def encode_v_genes(self, v_genes):
        encoded_v = []
        for v_gene in v_genes:
            encoded_v.append(self.v_dict.get(v_gene, 0))
        return encoded_v
    
    def encode_j_genes(self, j_genes):
        encoded_j = []
        for j_gene in j_genes:
            encoded_j.append(self.j_dict.get(j_gene, 0))
        return encoded_j
    
    def load_and_encode_data(self, batch_size=100, shuffle=True):
        # 1. Load files and combine columns
        df = self.load_files()
        
        # 2. Build vocabularies
        self.build_vocabulary(df)
        
        # 3. Filter out rows with missing amino acid sequences
        valid_rows = df['combined_sequence'].notna()
        df_valid = df[valid_rows].copy()
        
        print(f"Valid data: {len(df_valid)} out of {len(df)} total rows")
        
        # 4. Get the data you want to encode (now all valid)
        sequences = df_valid['combined_sequence'].values
        v_genes = df_valid['combined_v_gene'].fillna('UNK').values
        j_genes = df_valid['combined_j_gene'].fillna('UNK').values
        labels = [self.label_map[antigen] for antigen in df_valid['Antigen']]
        
        # 5. Encode everything
        X_sequences = self.encode_sequences(sequences)
        X_v_genes = self.encode_v_genes(v_genes)
        X_j_genes = self.encode_j_genes(j_genes)
        
        # 6. Convert to numpy arrays
        X_sequences = np.array(X_sequences)
        X_v_genes = np.array(X_v_genes)
        X_j_genes = np.array(X_j_genes)
        y_labels = np.array(labels)
        
        # 7. Create TensorFlow dataset
        dataset = tf.data.Dataset.from_tensor_slices((
            {'cdr3_sequence': X_sequences, 'v_gene': X_v_genes, 'j_gene': X_j_genes,},
            {'labels': y_labels}
        ))
            
        # Map to the format expected by the model
        dataset = dataset.map(lambda X, y: (X, {'labels': tf.one_hot(y['labels'], len(self.label_map))}))
            
        if shuffle:
            dataset = dataset.shuffle(len(X_sequences), reshuffle_each_iteration=True)
        
        dataset = dataset.batch(batch_size, drop_remainder=True)
        dataset = dataset.prefetch(tf.data.AUTOTUNE)
        
        return dataset
    
    def get_vocab_sizes(self):
        """Return vocabulary sizes for model construction"""
        return {
            'aa_vocab_size': len(self.aa_dict) + 1,  # +1 for padding
            'v_vocab_size': len(self.v_dict) + 1,    # +1 for unknown
            'j_vocab_size': len(self.j_dict) + 1,    # +1 for unknown
            'num_classes': len(self.label_map),
            'max_length': self.max_length
        }
    
    def get_mappings(self):
        """Return the created mappings for inspection"""
        return {
            'aa_dict': self.aa_dict,
            'v_dict': self.v_dict,
            'j_dict': self.j_dict,
            'label_map': self.label_map
        }

# %%
def create_tcr_model(vocab_sizes):
    """Create a model using the Conv1D architecture from the reference"""
    # Input layers
    cdr3_input = keras.Input(shape=(vocab_sizes['max_length'],), dtype=tf.uint32, name='cdr3_sequence')
    v_gene_input = keras.Input(shape=(), dtype=tf.uint32, name='v_gene')
    j_gene_input = keras.Input(shape=(), dtype=tf.uint32, name='j_gene')
    
    # CDR3 sequence encoder (following the reference structure)
    cdr3_embed = keras.layers.Embedding(
        input_dim=vocab_sizes['aa_vocab_size'], 
        output_dim=8, 
        mask_zero=True
    )(cdr3_input)
    
    convs = [keras.layers.Conv1D(
        filters=16, 
        kernel_size=9, 
        strides=1, 
        activation=keras.activations.relu,
        padding='valid'
    )(cdr3_embed)]
    
    convs.append(keras.layers.Conv1D(
        filters=32, 
        kernel_size=7, 
        strides=2, 
        activation=keras.activations.relu,
        padding='valid'
    )(convs[-1]))
    
    # convs.append(keras.layers.Conv1D(
    #     filters=256, 
    #     kernel_size=5, 
    #     strides=1, 
    #     activation=None,
    #     padding='valid'
    # )(convs[-1]))
    
    # Take the first position output (like in reference: [:, 0, :])
    # cdr3_encoded = convs[-1][:, 0, :]

    # pooling to gain positional equivariance
    cdr3_encoded = keras.layers.GlobalMaxPooling1D()(convs[-1])
    
    # Gene embeddings
    v_embed = keras.layers.Embedding(vocab_sizes['v_vocab_size'], 16, mask_zero=True)(v_gene_input)
    j_embed = keras.layers.Embedding(vocab_sizes['j_vocab_size'], 16, mask_zero=True)(j_gene_input)
    
    # Flatten gene embeddings
    # v_flat = tf.keras.layers.Flatten()(v_embed)
    # j_flat = tf.keras.layers.Flatten()(j_embed)
    
    # Concatenate all features
    fused = keras.layers.Concatenate(axis=-1)([cdr3_encoded, v_embed, j_embed])
    
    # Classifier (following reference structure)
    dropout1 = keras.layers.Dropout(rate=0.1)(fused)
    dense1 = keras.layers.Dense(units=32, activation=keras.activations.relu)(dropout1)
    dropout2 = keras.layers.Dropout(rate=0.05)(dense1)
    dense2 = keras.layers.Dense(units=16, activation=keras.activations.relu)(dropout2)
    # output = tf.keras.layers.Dense(units=vocab_sizes['num_classes'], activation='softmax')(dense2)
    output = keras.layers.Dense(units=vocab_sizes['num_classes'], activation='sigmoid')(dense2)

    model = keras.Model(
        inputs=[cdr3_input, v_gene_input, j_gene_input],
        outputs=output
    )
    
    return model

# %%
# Initialize loader
data_dir = './DeepTCR/Data/Murine_Antigens'
loader = TCRDataLoader(data_dir)

# Load data
print("Loading data...")
dataset = loader.load_and_encode_data(batch_size=100, shuffle=True)
print("Data loaded successfully!")
# Out:
# Loading data...
# Combining columns:
#
# Combining sequence columns:
#   Added 1753 values from 'aminoAcid' column
#   Added 1924 values from 'beta' column
#   Total combined values: 3677
#
# Combining v_gene columns:
#   Added 1924 values from 'v_beta' column
#   Added 3678 values from 'vGeneName' column
#   Total combined values: 5602
#
# Combining j_gene columns:
#   Added 1924 values from 'j_beta' column
#   Added 3670 values from 'jGeneName' column
#   Total combined values: 5594
#
# Combining counts columns:
#   Added 1924 values from 'counts' column
#   Added 3679 values from 'count (templates/reads)' column
#   Total combined values: 5603
#
# Vocabulary built:
#   Amino acids: 21 unique
#   V genes: 42 unique
#   J genes: 14 unique
#   Max sequence length: 19
# Valid data: 3677 out of 5603 total rows
# Data loaded successfully!

# %%
loader.v_dict
# Out:
# {'TCRBV01-01': 1,
#  'TCRBV02-01': 2,
#  'TCRBV03-01': 3,
#  'TCRBV04-01': 4,
#  'TCRBV05-01': 5,
#  'TCRBV05-04': 6,
#  'TCRBV06-01': 7,
#  'TCRBV07-01': 8,
#  'TCRBV08-01': 9,
#  'TCRBV09-01': 10,
#  'TCRBV10-01': 11,
#  'TCRBV11-01': 12,
#  'TCRBV12-01': 13,
#  'TCRBV12-02': 14,
#  'TCRBV12-03': 15,
#  'TCRBV13-01': 16,
#  'TCRBV13-02': 17,
#  'TCRBV13-03': 18,
#  'TCRBV13-04': 19,
#  'TCRBV14-01': 20,
#  'TCRBV15-01': 21,
#  'TCRBV16-01': 22,
#  'TCRBV17-01': 23,
#  'TCRBV18-01': 24,
#  'TCRBV19-01': 25,
#  'TCRBV19-03': 26,
#  'TCRBV20-01': 27,
#  'TCRBV20-02': 28,
#  'TCRBV21-01': 29,
#  'TCRBV22-01': 30,
#  'TCRBV23-01': 31,
#  'TCRBV24-01': 32,
#  'TCRBV24-02': 33,
#  'TCRBV25-01': 34,
#  'TCRBV26-01': 35,
#  'TCRBV27-01': 36,
#  'TCRBV28-01': 37,
#  'TCRBV29-01': 38,
#  'TCRBV29-02': 39,
#  'TCRBV30-01': 40,
#  'TCRBV31-01': 41,
#  'TCRBV31-02': 42}

# %%
# Initialize loader
data_dir = './DeepTCR/Data/Human_Antigens'
loader = TCRDataLoader(data_dir)

# Load data
print("Loading data...")
dataset = loader.load_and_encode_data(batch_size=100, shuffle=True)
print("Data loaded successfully!")
# Out:
# Loading data...
# Combining columns:
#
# Combining sequence columns:
#   Added 2066 values from 'aminoAcid' column
#   Added 412 values from 'beta' column
#   Total combined values: 2478
#
# Combining v_gene columns:
#   Added 1874 values from 'v_beta' column
#   Total combined values: 1874
#
# Combining j_gene columns:
#   Added 2084 values from 'j_beta' column
#   Total combined values: 2084
#
# Combining counts columns:
#   Added 2478 values from 'counts' column
#   Total combined values: 2478
#
# Vocabulary built:
#   Amino acids: 20 unique
#   V genes: 62 unique
#   J genes: 13 unique
#   Max sequence length: 23
# Valid data: 2478 out of 2478 total rows
# Data loaded successfully!

# %%
# Create model
vocab_sizes = loader.get_vocab_sizes()
print("Creating model...")
model = create_tcr_model(vocab_sizes)

# Compile model
model.compile(
    optimizer='adam', 
    # loss='categorical_crossentropy',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# Display model summary
model.summary()
# Out:
# Creating model...
# c:\Users\huang\miniconda3\envs\gpu-ml-base\Lib\site-packages\keras\src\layers\layer.py:932: UserWarning: Layer 'conv1d' (of type Conv1D) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ cdr3_sequence       │ (None, 19)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 19, 8)     │        176 │ cdr3_sequence[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 11, 16)    │      1,168 │ embedding[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 3, 32)     │      3,616 │ conv1d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ v_gene (InputLayer) │ (None)            │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ j_gene (InputLayer) │ (None)            │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 32)        │          0 │ conv1d_1[0][0]    │
# │ (GlobalMaxPooling1… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_1         │ (None, 16)        │        688 │ v_gene[0][0]      │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_2         │ (None, 16)        │        240 │ j_gene[0][0]      │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 64)        │          0 │ global_max_pooli… │
# │ (Concatenate)       │                   │            │ embedding_1[0][0… │
# │                     │                   │            │ embedding_2[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 64)        │          0 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 32)        │      2,080 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 32)        │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 16)        │        528 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 9)         │        153 │ dense_1[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 8,649 (33.79 KB)
#  Trainable params: 8,649 (33.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
np.unique(df['aminoAcid'].astype('category').cat.codes.values)
# Out:
# array([  -1,    0,    1, ..., 1307, 1308, 1309],
#       shape=(1311,), dtype=int16)

# %%
# Updated data preparation using combined columns
df = loader.load_files()
df['Antigen'] = df['Antigen'].astype('category')
loader.build_vocabulary(df)

# Filter valid data using combined columns
valid_rows = df['combined_sequence'].notna()
df_valid = df[valid_rows].copy()

print(f"Valid sequences: {len(df_valid)} out of {len(df)} total")

# Encode data using combined columns
sequences = df_valid['combined_sequence'].values
v_genes = df_valid['combined_v_gene'].fillna('UNK').values
j_genes = df_valid['combined_j_gene'].fillna('UNK').values
counts = df_valid['combined_counts'].fillna(1).values  

labels = [loader.label_map[antigen] for antigen in df_valid['Antigen']]

X_sequences = loader.encode_sequences(sequences)
X_v_genes = loader.encode_v_genes(v_genes)
X_j_genes = loader.encode_j_genes(j_genes)

# Convert to numpy
X_sequences = np.array(X_sequences)
X_v_genes = np.array(X_v_genes)
X_j_genes = np.array(X_j_genes)

# Set up data for cross-validation
X = [
    np.array(X_sequences, dtype=np.int32),
    np.array(X_v_genes, dtype=np.int32),
    np.array(X_j_genes, dtype=np.int32)
]
y_true = np.array(df_valid['Antigen'].cat.codes.values, dtype=np.int32)

print(f"Final data shapes:")
print(f"  X[0] (sequences): {X[0].shape}")
print(f"  X[1] (v_genes): {X[1].shape}")
print(f"  X[2] (j_genes): {X[2].shape}")
print(f"  y_true: {y_true.shape}")
# Out:
# Combining columns:
#
# Combining sequence columns:
#   Added 1753 values from 'aminoAcid' column
#   Added 1924 values from 'beta' column
#   Total combined values: 3677
#
# Combining v_gene columns:
#   Added 1924 values from 'v_beta' column
#   Added 3678 values from 'vGeneName' column
#   Total combined values: 5602
#
# Combining j_gene columns:
#   Added 1924 values from 'j_beta' column
#   Added 3670 values from 'jGeneName' column
#   Total combined values: 5594
#
# Combining counts columns:
#   Added 1924 values from 'counts' column
#   Added 3679 values from 'count (templates/reads)' column
#   Total combined values: 5603
#
# Vocabulary built:
#   Amino acids: 21 unique
#   V genes: 42 unique
#   J genes: 14 unique
#   Max sequence length: 19
# Valid sequences: 3677 out of 5603 total
# Final data shapes:
#   X[0] (sequences): (3677, 19)
#   X[1] (v_genes): (3677,)
#   X[2] (j_genes): (3677,)
#   y_true: (3677,)
# C:\Users\huang\AppData\Local\Temp\ipykernel_33568\4032558431.py:16: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   counts = df_valid['combined_counts'].fillna(1).values  # Now you can use counts too!

# %%
from utils import KerasCrossValidation

# %%
df_valid = df.loc[df['aminoAcid'].isna()]
df_valid
# Out:
#                  beta  counts      v_beta      j_beta Antigen aminoAcid  \
# 0       CASRTGATGQLYF     1.0  TCRBV19-03  TCRBJ02-02      F2       NaN
# 1     CASRPDISYNSPLYF     1.0  TCRBV19-03  TCRBJ01-06      F2       NaN
# 2        CAIGSNQDTQYF     1.0  TCRBV14-01  TCRBJ02-05      F2       NaN
# 3        CASSIGQDEQYF     1.0  TCRBV19-01  TCRBJ02-07      F2       NaN
# 4      CASSLFQIQDTQYF     1.0  TCRBV29-01  TCRBJ02-05      F2       NaN
# ...               ...     ...         ...         ...     ...       ...
# 5592              NaN     NaN         NaN         NaN    TRP2       NaN
# 5594              NaN     NaN         NaN         NaN    TRP2       NaN
# 5596              NaN     NaN         NaN         NaN    TRP2       NaN
# 5598              NaN     NaN         NaN         NaN    TRP2       NaN
# 5599              NaN     NaN         NaN         NaN    TRP2       NaN
#
#       count (templates/reads)   vGeneName   jGeneName combined_sequence  \
# 0                         NaN         NaN         NaN     CASRTGATGQLYF
# 1                         NaN         NaN         NaN   CASRPDISYNSPLYF
# 2                         NaN         NaN         NaN      CAIGSNQDTQYF
# 3                         NaN         NaN         NaN      CASSIGQDEQYF
# 4                         NaN         NaN         NaN    CASSLFQIQDTQYF
# ...                       ...         ...         ...               ...
# 5592                      1.0  TCRBV29-01  TCRBJ01-01              None
# 5594                      1.0  TCRBV12-03  TCRBJ01-01              None
# 5596                      1.0  TCRBV13-02  TCRBJ02-03              None
# 5598                      1.0  TCRBV13-03  TCRBJ01-01              None
# 5599                      1.0  TCRBV03-01  TCRBJ02-01              None
#
#      combined_v_gene combined_j_gene combined_counts
# 0         TCRBV19-03      TCRBJ02-02             1.0
# 1         TCRBV19-03      TCRBJ01-06             1.0
# 2         TCRBV14-01      TCRBJ02-05             1.0
# 3         TCRBV19-01      TCRBJ02-07             1.0
# 4         TCRBV29-01      TCRBJ02-05             1.0
# ...              ...             ...             ...
# 5592      TCRBV29-01      TCRBJ01-01             1.0
# 5594      TCRBV12-03      TCRBJ01-01             1.0
# 5596      TCRBV13-02      TCRBJ02-03             1.0
# 5598      TCRBV13-03      TCRBJ01-01             1.0
# 5599      TCRBV03-01      TCRBJ02-01             1.0
#
# [3850 rows x 13 columns]

# %%
# set data
X = [
        np.array(X_sequences, dtype=np.int32),
        np.array(X_v_genes, dtype=np.int32),
        np.array(X_j_genes, dtype=np.int32)
    ]
y_true = np.array(y_true, dtype=np.int32)

# %%
X[1]
# Out:
# array([26, 26, 20, ..., 24,  9, 21], shape=(3677,), dtype=int32)

# %%
# run cross-validation
keras_cv = KerasCrossValidation(X=X, y=y_true, keras_model=model, save_filepath='./logs/fit-01')
y_pred, y_test, history = keras_cv(n_splits=7, batch_size=500, min_epochs=5, patience=30, max_epochs=500, training_repeat=2)
# Out:
# Epoch 1/500
# c:\Users\huang\miniconda3\envs\gpu-ml-base\Lib\site-packages\keras\src\models\functional.py:225: UserWarning: The structure of `inputs` doesn't match the expected structure: ['cdr3_sequence', 'v_gene', 'j_gene']. Received: the structure of inputs=('*', '*', '*')
#   warnings.warn(
# c:\Users\huang\miniconda3\envs\gpu-ml-base\Lib\site-packages\keras\src\layers\layer.py:932: UserWarning: Layer 'conv1d' (of type Conv1D) was passed an input with a mask attached to it. However, this layer does not support masking and will therefore destroy the mask information. Downstream layers will not see the mask.
#   warnings.warn(
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 59ms/step - accuracy: 0.0417 - loss: 0.6918 - val_accuracy: 0.0247 - val_loss: 0.6778
# Epoch 2/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0255 - loss: 0.6707 - val_accuracy: 0.0228 - val_loss: 0.6388
# Epoch 3/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0251 - loss: 0.6237 - val_accuracy: 0.0228 - val_loss: 0.5644
# Epoch 4/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0241 - loss: 0.5597 - val_accuracy: 0.0228 - val_loss: 0.5253
# Epoch 5/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0251 - loss: 0.5263 - val_accuracy: 0.0228 - val_loss: 0.5032
# Epoch 6/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0252 - loss: 0.5013 - val_accuracy: 0.0228 - val_loss: 0.4802
# Epoch 7/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0273 - loss: 0.4761 - val_accuracy: 0.0228 - val_loss: 0.4409
# Epoch 8/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0257 - loss: 0.4317 - val_accuracy: 0.0323 - val_loss: 0.3690
# Epoch 9/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2209 - loss: 0.3659 - val_accuracy: 0.4221 - val_loss: 0.3132
# Epoch 10/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3727 - loss: 0.3180 - val_accuracy: 0.4487 - val_loss: 0.2916
# Epoch 11/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4057 - loss: 0.3001 - val_accuracy: 0.4525 - val_loss: 0.2791
# Epoch 12/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4406 - loss: 0.2874 - val_accuracy: 0.4715 - val_loss: 0.2683
# Epoch 13/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4614 - loss: 0.2768 - val_accuracy: 0.4734 - val_loss: 0.2602
# Epoch 14/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4854 - loss: 0.2658 - val_accuracy: 0.4753 - val_loss: 0.2531
# Epoch 15/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4825 - loss: 0.2598 - val_accuracy: 0.4791 - val_loss: 0.2462
# Epoch 16/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5019 - loss: 0.2516 - val_accuracy: 0.4905 - val_loss: 0.2394
# Epoch 17/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5283 - loss: 0.2448 - val_accuracy: 0.5342 - val_loss: 0.2320
# Epoch 18/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5468 - loss: 0.2401 - val_accuracy: 0.5532 - val_loss: 0.2251
# Epoch 19/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5694 - loss: 0.2303 - val_accuracy: 0.5665 - val_loss: 0.2192
# Epoch 20/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5813 - loss: 0.2251 - val_accuracy: 0.5798 - val_loss: 0.2128
# Epoch 21/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5850 - loss: 0.2200 - val_accuracy: 0.5951 - val_loss: 0.2080
# Epoch 22/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6146 - loss: 0.2143 - val_accuracy: 0.6103 - val_loss: 0.2039
# Epoch 23/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6224 - loss: 0.2066 - val_accuracy: 0.6198 - val_loss: 0.2001
# Epoch 24/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6247 - loss: 0.2034 - val_accuracy: 0.6350 - val_loss: 0.1970
# Epoch 25/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6301 - loss: 0.2035 - val_accuracy: 0.6407 - val_loss: 0.1945
# Epoch 26/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6307 - loss: 0.1991 - val_accuracy: 0.6464 - val_loss: 0.1922
# Epoch 27/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6351 - loss: 0.1959 - val_accuracy: 0.6502 - val_loss: 0.1904
# Epoch 28/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6396 - loss: 0.1934 - val_accuracy: 0.6540 - val_loss: 0.1882
# Epoch 29/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6435 - loss: 0.1892 - val_accuracy: 0.6673 - val_loss: 0.1861
# Epoch 30/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6524 - loss: 0.1868 - val_accuracy: 0.6578 - val_loss: 0.1850
# Epoch 31/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6538 - loss: 0.1858 - val_accuracy: 0.6616 - val_loss: 0.1837
# Epoch 32/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6614 - loss: 0.1804 - val_accuracy: 0.6635 - val_loss: 0.1818
# Epoch 33/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6601 - loss: 0.1811 - val_accuracy: 0.6597 - val_loss: 0.1802
# Epoch 34/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6648 - loss: 0.1780 - val_accuracy: 0.6673 - val_loss: 0.1785
# Epoch 35/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6793 - loss: 0.1732 - val_accuracy: 0.6730 - val_loss: 0.1767
# Epoch 36/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6763 - loss: 0.1733 - val_accuracy: 0.6673 - val_loss: 0.1749
# Epoch 37/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6774 - loss: 0.1710 - val_accuracy: 0.6768 - val_loss: 0.1732
# Epoch 38/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6886 - loss: 0.1640 - val_accuracy: 0.6749 - val_loss: 0.1721
# Epoch 39/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6931 - loss: 0.1649 - val_accuracy: 0.6730 - val_loss: 0.1709
# Epoch 40/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6985 - loss: 0.1630 - val_accuracy: 0.6806 - val_loss: 0.1699
# Epoch 41/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6882 - loss: 0.1614 - val_accuracy: 0.6749 - val_loss: 0.1686
# Epoch 42/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6925 - loss: 0.1609 - val_accuracy: 0.6787 - val_loss: 0.1676
# Epoch 43/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7089 - loss: 0.1578 - val_accuracy: 0.6768 - val_loss: 0.1655
# Epoch 44/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7045 - loss: 0.1579 - val_accuracy: 0.6806 - val_loss: 0.1651
# Epoch 45/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7155 - loss: 0.1531 - val_accuracy: 0.6825 - val_loss: 0.1638
# Epoch 46/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7119 - loss: 0.1540 - val_accuracy: 0.6882 - val_loss: 0.1630
# Epoch 47/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7140 - loss: 0.1534 - val_accuracy: 0.6882 - val_loss: 0.1626
# Epoch 48/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7247 - loss: 0.1472 - val_accuracy: 0.6901 - val_loss: 0.1622
# Epoch 49/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7243 - loss: 0.1459 - val_accuracy: 0.6939 - val_loss: 0.1610
# Epoch 50/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7338 - loss: 0.1443 - val_accuracy: 0.7034 - val_loss: 0.1606
# Epoch 51/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7340 - loss: 0.1424 - val_accuracy: 0.6977 - val_loss: 0.1600
# Epoch 52/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7383 - loss: 0.1408 - val_accuracy: 0.7072 - val_loss: 0.1591
# Epoch 53/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7403 - loss: 0.1386 - val_accuracy: 0.6939 - val_loss: 0.1581
# Epoch 54/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7512 - loss: 0.1370 - val_accuracy: 0.6939 - val_loss: 0.1574
# Epoch 55/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7502 - loss: 0.1393 - val_accuracy: 0.6977 - val_loss: 0.1581
# Epoch 56/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7544 - loss: 0.1340 - val_accuracy: 0.6977 - val_loss: 0.1566
# Epoch 57/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7519 - loss: 0.1336 - val_accuracy: 0.6958 - val_loss: 0.1578
# Epoch 58/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7492 - loss: 0.1327 - val_accuracy: 0.6996 - val_loss: 0.1568
# Epoch 59/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7600 - loss: 0.1293 - val_accuracy: 0.7034 - val_loss: 0.1553
# Epoch 60/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7606 - loss: 0.1290 - val_accuracy: 0.7053 - val_loss: 0.1565
# Epoch 61/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7712 - loss: 0.1277 - val_accuracy: 0.7053 - val_loss: 0.1570
# Epoch 62/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7616 - loss: 0.1275 - val_accuracy: 0.7110 - val_loss: 0.1556
# Epoch 63/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7706 - loss: 0.1230 - val_accuracy: 0.7091 - val_loss: 0.1554
# Epoch 64/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7789 - loss: 0.1244 - val_accuracy: 0.7072 - val_loss: 0.1566
# Epoch 65/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7702 - loss: 0.1229 - val_accuracy: 0.7091 - val_loss: 0.1558
# Epoch 66/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7682 - loss: 0.1222 - val_accuracy: 0.7148 - val_loss: 0.1555
# Epoch 67/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7751 - loss: 0.1203 - val_accuracy: 0.7167 - val_loss: 0.1568
# Epoch 68/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7780 - loss: 0.1191 - val_accuracy: 0.7167 - val_loss: 0.1555
# Epoch 69/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7737 - loss: 0.1221 - val_accuracy: 0.7186 - val_loss: 0.1558
# Epoch 70/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7851 - loss: 0.1164 - val_accuracy: 0.7148 - val_loss: 0.1565
# Epoch 71/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7929 - loss: 0.1150 - val_accuracy: 0.7167 - val_loss: 0.1568
# Epoch 72/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7887 - loss: 0.1158 - val_accuracy: 0.7167 - val_loss: 0.1570
# Epoch 73/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8021 - loss: 0.1125 - val_accuracy: 0.7224 - val_loss: 0.1547
# Epoch 74/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7981 - loss: 0.1138 - val_accuracy: 0.7205 - val_loss: 0.1558
# Epoch 75/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7966 - loss: 0.1119 - val_accuracy: 0.7167 - val_loss: 0.1560
# Epoch 76/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7932 - loss: 0.1124 - val_accuracy: 0.7262 - val_loss: 0.1567
# Epoch 77/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8034 - loss: 0.1074 - val_accuracy: 0.7186 - val_loss: 0.1569
# Epoch 78/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8133 - loss: 0.1065 - val_accuracy: 0.7205 - val_loss: 0.1571
# Epoch 79/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8046 - loss: 0.1086 - val_accuracy: 0.7243 - val_loss: 0.1581
# Epoch 80/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8108 - loss: 0.1060 - val_accuracy: 0.7224 - val_loss: 0.1594
# Epoch 81/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8203 - loss: 0.1050 - val_accuracy: 0.7205 - val_loss: 0.1581
# Epoch 82/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8165 - loss: 0.1052 - val_accuracy: 0.7205 - val_loss: 0.1596
# Epoch 83/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8178 - loss: 0.1040 - val_accuracy: 0.7243 - val_loss: 0.1603
# Epoch 84/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8127 - loss: 0.1027 - val_accuracy: 0.7262 - val_loss: 0.1615
# Epoch 85/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8164 - loss: 0.1032 - val_accuracy: 0.7243 - val_loss: 0.1603
# Epoch 86/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8180 - loss: 0.1019 - val_accuracy: 0.7243 - val_loss: 0.1606
# Epoch 87/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8300 - loss: 0.0985 - val_accuracy: 0.7167 - val_loss: 0.1613
# Epoch 88/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8192 - loss: 0.1024 - val_accuracy: 0.7148 - val_loss: 0.1617
# Epoch 89/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8235 - loss: 0.1000 - val_accuracy: 0.7243 - val_loss: 0.1606
# Epoch 90/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8221 - loss: 0.0996 - val_accuracy: 0.7148 - val_loss: 0.1627
# Epoch 91/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8343 - loss: 0.0967 - val_accuracy: 0.7205 - val_loss: 0.1635
# Epoch 92/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8327 - loss: 0.0946 - val_accuracy: 0.7224 - val_loss: 0.1628
# Epoch 93/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8321 - loss: 0.0968 - val_accuracy: 0.7167 - val_loss: 0.1634
# Epoch 94/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8366 - loss: 0.0953 - val_accuracy: 0.7224 - val_loss: 0.1670
# Epoch 95/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8349 - loss: 0.0947 - val_accuracy: 0.7224 - val_loss: 0.1672
# Epoch 96/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8413 - loss: 0.0932 - val_accuracy: 0.7224 - val_loss: 0.1683
# Epoch 97/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8404 - loss: 0.0923 - val_accuracy: 0.7224 - val_loss: 0.1687
# Epoch 98/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8375 - loss: 0.0933 - val_accuracy: 0.7186 - val_loss: 0.1684
# Epoch 99/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8448 - loss: 0.0901 - val_accuracy: 0.7186 - val_loss: 0.1683
# Epoch 100/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8491 - loss: 0.0891 - val_accuracy: 0.7300 - val_loss: 0.1696
# Epoch 101/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8413 - loss: 0.0914 - val_accuracy: 0.7186 - val_loss: 0.1701
# Epoch 102/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8440 - loss: 0.0892 - val_accuracy: 0.7224 - val_loss: 0.1688
# Epoch 103/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8429 - loss: 0.0875 - val_accuracy: 0.7186 - val_loss: 0.1682
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# Epoch 1/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0492 - loss: 0.6925 - val_accuracy: 0.0228 - val_loss: 0.6769
# Epoch 2/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0262 - loss: 0.6699 - val_accuracy: 0.0228 - val_loss: 0.6454
# Epoch 3/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0246 - loss: 0.6367 - val_accuracy: 0.0228 - val_loss: 0.6035
# Epoch 4/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0235 - loss: 0.5922 - val_accuracy: 0.0228 - val_loss: 0.5479
# Epoch 5/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0246 - loss: 0.5382 - val_accuracy: 0.0228 - val_loss: 0.5089
# Epoch 6/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0231 - loss: 0.5055 - val_accuracy: 0.0228 - val_loss: 0.4818
# Epoch 7/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0231 - loss: 0.4789 - val_accuracy: 0.0228 - val_loss: 0.4600
# Epoch 8/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0243 - loss: 0.4569 - val_accuracy: 0.0228 - val_loss: 0.4395
# Epoch 9/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0241 - loss: 0.4367 - val_accuracy: 0.0228 - val_loss: 0.4208
# Epoch 10/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0255 - loss: 0.4191 - val_accuracy: 0.0228 - val_loss: 0.4030
# Epoch 11/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0253 - loss: 0.4000 - val_accuracy: 0.0228 - val_loss: 0.3854
# Epoch 12/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0237 - loss: 0.3842 - val_accuracy: 0.0228 - val_loss: 0.3684
# Epoch 13/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0293 - loss: 0.3665 - val_accuracy: 0.0494 - val_loss: 0.3520
# Epoch 14/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.2074 - loss: 0.3507 - val_accuracy: 0.4506 - val_loss: 0.3347
# Epoch 15/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4303 - loss: 0.3343 - val_accuracy: 0.4506 - val_loss: 0.3207
# Epoch 16/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4445 - loss: 0.3201 - val_accuracy: 0.4506 - val_loss: 0.3091
# Epoch 17/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4453 - loss: 0.3110 - val_accuracy: 0.4506 - val_loss: 0.2996
# Epoch 18/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4513 - loss: 0.3009 - val_accuracy: 0.4487 - val_loss: 0.2914
# Epoch 19/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4491 - loss: 0.2934 - val_accuracy: 0.4506 - val_loss: 0.2851
# Epoch 20/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4499 - loss: 0.2870 - val_accuracy: 0.4506 - val_loss: 0.2799
# Epoch 21/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4528 - loss: 0.2799 - val_accuracy: 0.4525 - val_loss: 0.2754
# Epoch 22/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4493 - loss: 0.2769 - val_accuracy: 0.4506 - val_loss: 0.2722
# Epoch 23/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4520 - loss: 0.2735 - val_accuracy: 0.4506 - val_loss: 0.2695
# Epoch 24/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4545 - loss: 0.2703 - val_accuracy: 0.4525 - val_loss: 0.2666
# Epoch 25/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4526 - loss: 0.2692 - val_accuracy: 0.4506 - val_loss: 0.2637
# Epoch 26/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4480 - loss: 0.2675 - val_accuracy: 0.4506 - val_loss: 0.2608
# Epoch 27/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4569 - loss: 0.2630 - val_accuracy: 0.4677 - val_loss: 0.2577
# Epoch 28/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4729 - loss: 0.2594 - val_accuracy: 0.4753 - val_loss: 0.2544
# Epoch 29/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4786 - loss: 0.2556 - val_accuracy: 0.4905 - val_loss: 0.2511
# Epoch 30/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4972 - loss: 0.2520 - val_accuracy: 0.4943 - val_loss: 0.2476
# Epoch 31/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5021 - loss: 0.2509 - val_accuracy: 0.5152 - val_loss: 0.2442
# Epoch 32/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5169 - loss: 0.2478 - val_accuracy: 0.5266 - val_loss: 0.2403
# Epoch 33/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5315 - loss: 0.2449 - val_accuracy: 0.5323 - val_loss: 0.2366
# Epoch 34/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5378 - loss: 0.2412 - val_accuracy: 0.5456 - val_loss: 0.2332
# Epoch 35/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5540 - loss: 0.2361 - val_accuracy: 0.5494 - val_loss: 0.2299
# Epoch 36/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5543 - loss: 0.2334 - val_accuracy: 0.5494 - val_loss: 0.2269
# Epoch 37/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5650 - loss: 0.2294 - val_accuracy: 0.5570 - val_loss: 0.2240
# Epoch 38/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5695 - loss: 0.2249 - val_accuracy: 0.5513 - val_loss: 0.2214
# Epoch 39/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5756 - loss: 0.2234 - val_accuracy: 0.5589 - val_loss: 0.2188
# Epoch 40/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5725 - loss: 0.2213 - val_accuracy: 0.5627 - val_loss: 0.2167
# Epoch 41/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5727 - loss: 0.2235 - val_accuracy: 0.5627 - val_loss: 0.2145
# Epoch 42/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5800 - loss: 0.2172 - val_accuracy: 0.5665 - val_loss: 0.2126
# Epoch 43/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5880 - loss: 0.2139 - val_accuracy: 0.5665 - val_loss: 0.2108
# Epoch 44/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5838 - loss: 0.2125 - val_accuracy: 0.5722 - val_loss: 0.2087
# Epoch 45/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5841 - loss: 0.2112 - val_accuracy: 0.5703 - val_loss: 0.2069
# Epoch 46/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5912 - loss: 0.2081 - val_accuracy: 0.5760 - val_loss: 0.2053
# Epoch 47/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5881 - loss: 0.2084 - val_accuracy: 0.5760 - val_loss: 0.2035
# Epoch 48/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5951 - loss: 0.2050 - val_accuracy: 0.5989 - val_loss: 0.2018
# Epoch 49/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5974 - loss: 0.2039 - val_accuracy: 0.6122 - val_loss: 0.2002
# Epoch 50/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6167 - loss: 0.2016 - val_accuracy: 0.6198 - val_loss: 0.1989
# Epoch 51/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6239 - loss: 0.1982 - val_accuracy: 0.6350 - val_loss: 0.1972
# Epoch 52/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6297 - loss: 0.1986 - val_accuracy: 0.6388 - val_loss: 0.1960
# Epoch 53/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6374 - loss: 0.1964 - val_accuracy: 0.6369 - val_loss: 0.1947
# Epoch 54/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6437 - loss: 0.1954 - val_accuracy: 0.6407 - val_loss: 0.1932
# Epoch 55/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6466 - loss: 0.1916 - val_accuracy: 0.6426 - val_loss: 0.1922
# Epoch 56/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6561 - loss: 0.1887 - val_accuracy: 0.6502 - val_loss: 0.1910
# Epoch 57/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6473 - loss: 0.1909 - val_accuracy: 0.6521 - val_loss: 0.1900
# Epoch 58/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6568 - loss: 0.1854 - val_accuracy: 0.6483 - val_loss: 0.1890
# Epoch 59/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6636 - loss: 0.1849 - val_accuracy: 0.6540 - val_loss: 0.1881
# Epoch 60/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6667 - loss: 0.1832 - val_accuracy: 0.6540 - val_loss: 0.1874
# Epoch 61/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6636 - loss: 0.1829 - val_accuracy: 0.6521 - val_loss: 0.1863
# Epoch 62/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6660 - loss: 0.1832 - val_accuracy: 0.6578 - val_loss: 0.1858
# Epoch 63/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6743 - loss: 0.1781 - val_accuracy: 0.6540 - val_loss: 0.1848
# Epoch 64/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6809 - loss: 0.1810 - val_accuracy: 0.6597 - val_loss: 0.1843
# Epoch 65/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6923 - loss: 0.1752 - val_accuracy: 0.6597 - val_loss: 0.1835
# Epoch 66/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6835 - loss: 0.1761 - val_accuracy: 0.6521 - val_loss: 0.1827
# Epoch 67/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6815 - loss: 0.1755 - val_accuracy: 0.6559 - val_loss: 0.1818
# Epoch 68/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6857 - loss: 0.1729 - val_accuracy: 0.6578 - val_loss: 0.1812
# Epoch 69/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6945 - loss: 0.1699 - val_accuracy: 0.6597 - val_loss: 0.1807
# Epoch 70/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6857 - loss: 0.1725 - val_accuracy: 0.6616 - val_loss: 0.1797
# Epoch 71/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6894 - loss: 0.1710 - val_accuracy: 0.6616 - val_loss: 0.1789
# Epoch 72/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6988 - loss: 0.1674 - val_accuracy: 0.6673 - val_loss: 0.1783
# Epoch 73/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7021 - loss: 0.1680 - val_accuracy: 0.6616 - val_loss: 0.1775
# Epoch 74/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6964 - loss: 0.1647 - val_accuracy: 0.6616 - val_loss: 0.1767
# Epoch 75/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7020 - loss: 0.1636 - val_accuracy: 0.6654 - val_loss: 0.1758
# Epoch 76/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7083 - loss: 0.1617 - val_accuracy: 0.6635 - val_loss: 0.1749
# Epoch 77/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7066 - loss: 0.1616 - val_accuracy: 0.6673 - val_loss: 0.1745
# Epoch 78/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7136 - loss: 0.1597 - val_accuracy: 0.6654 - val_loss: 0.1737
# Epoch 79/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7107 - loss: 0.1597 - val_accuracy: 0.6654 - val_loss: 0.1731
# Epoch 80/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7053 - loss: 0.1601 - val_accuracy: 0.6559 - val_loss: 0.1721
# Epoch 81/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7214 - loss: 0.1557 - val_accuracy: 0.6673 - val_loss: 0.1715
# Epoch 82/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7106 - loss: 0.1579 - val_accuracy: 0.6673 - val_loss: 0.1710
# Epoch 83/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7173 - loss: 0.1549 - val_accuracy: 0.6692 - val_loss: 0.1703
# Epoch 84/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7123 - loss: 0.1557 - val_accuracy: 0.6749 - val_loss: 0.1700
# Epoch 85/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7147 - loss: 0.1534 - val_accuracy: 0.6692 - val_loss: 0.1693
# Epoch 86/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7253 - loss: 0.1520 - val_accuracy: 0.6730 - val_loss: 0.1689
# Epoch 87/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7222 - loss: 0.1522 - val_accuracy: 0.6806 - val_loss: 0.1679
# Epoch 88/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7395 - loss: 0.1483 - val_accuracy: 0.6749 - val_loss: 0.1677
# Epoch 89/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7210 - loss: 0.1483 - val_accuracy: 0.6806 - val_loss: 0.1673
# Epoch 90/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7213 - loss: 0.1499 - val_accuracy: 0.6749 - val_loss: 0.1669
# Epoch 91/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7298 - loss: 0.1499 - val_accuracy: 0.6806 - val_loss: 0.1665
# Epoch 92/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7410 - loss: 0.1436 - val_accuracy: 0.6768 - val_loss: 0.1658
# Epoch 93/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7359 - loss: 0.1449 - val_accuracy: 0.6768 - val_loss: 0.1653
# Epoch 94/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7414 - loss: 0.1428 - val_accuracy: 0.6787 - val_loss: 0.1653
# Epoch 95/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7405 - loss: 0.1430 - val_accuracy: 0.6768 - val_loss: 0.1652
# Epoch 96/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7338 - loss: 0.1431 - val_accuracy: 0.6825 - val_loss: 0.1644
# Epoch 97/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7358 - loss: 0.1442 - val_accuracy: 0.6768 - val_loss: 0.1636
# Epoch 98/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7478 - loss: 0.1385 - val_accuracy: 0.6768 - val_loss: 0.1639
# Epoch 99/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7372 - loss: 0.1421 - val_accuracy: 0.6806 - val_loss: 0.1634
# Epoch 100/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7416 - loss: 0.1417 - val_accuracy: 0.6768 - val_loss: 0.1627
# Epoch 101/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7491 - loss: 0.1362 - val_accuracy: 0.6806 - val_loss: 0.1632
# Epoch 102/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7477 - loss: 0.1370 - val_accuracy: 0.6768 - val_loss: 0.1628
# Epoch 103/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7429 - loss: 0.1371 - val_accuracy: 0.6806 - val_loss: 0.1628
# Epoch 104/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7469 - loss: 0.1364 - val_accuracy: 0.6825 - val_loss: 0.1623
# Epoch 105/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7493 - loss: 0.1367 - val_accuracy: 0.6806 - val_loss: 0.1631
# Epoch 106/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7581 - loss: 0.1350 - val_accuracy: 0.6806 - val_loss: 0.1618
# Epoch 107/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7629 - loss: 0.1326 - val_accuracy: 0.6806 - val_loss: 0.1613
# Epoch 108/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7663 - loss: 0.1302 - val_accuracy: 0.6787 - val_loss: 0.1621
# Epoch 109/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7633 - loss: 0.1306 - val_accuracy: 0.6844 - val_loss: 0.1618
# Epoch 110/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7575 - loss: 0.1322 - val_accuracy: 0.6901 - val_loss: 0.1616
# Epoch 111/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7678 - loss: 0.1284 - val_accuracy: 0.6825 - val_loss: 0.1614
# Epoch 112/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7731 - loss: 0.1284 - val_accuracy: 0.6920 - val_loss: 0.1614
# Epoch 113/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7712 - loss: 0.1269 - val_accuracy: 0.6863 - val_loss: 0.1617
# Epoch 114/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7718 - loss: 0.1278 - val_accuracy: 0.6863 - val_loss: 0.1625
# Epoch 115/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7740 - loss: 0.1250 - val_accuracy: 0.6863 - val_loss: 0.1618
# Epoch 116/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7734 - loss: 0.1244 - val_accuracy: 0.6939 - val_loss: 0.1611
# Epoch 117/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7762 - loss: 0.1238 - val_accuracy: 0.6977 - val_loss: 0.1618
# Epoch 118/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7738 - loss: 0.1249 - val_accuracy: 0.7015 - val_loss: 0.1620
# Epoch 119/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7815 - loss: 0.1218 - val_accuracy: 0.7015 - val_loss: 0.1617
# Epoch 120/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7676 - loss: 0.1241 - val_accuracy: 0.6977 - val_loss: 0.1617
# Epoch 121/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7868 - loss: 0.1207 - val_accuracy: 0.6977 - val_loss: 0.1622
# Epoch 122/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7679 - loss: 0.1213 - val_accuracy: 0.6996 - val_loss: 0.1624
# Epoch 123/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7876 - loss: 0.1172 - val_accuracy: 0.7015 - val_loss: 0.1616
# Epoch 124/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7977 - loss: 0.1165 - val_accuracy: 0.7015 - val_loss: 0.1633
# Epoch 125/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7917 - loss: 0.1173 - val_accuracy: 0.7053 - val_loss: 0.1626
# Epoch 126/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7896 - loss: 0.1170 - val_accuracy: 0.7034 - val_loss: 0.1629
# Epoch 127/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7943 - loss: 0.1143 - val_accuracy: 0.7072 - val_loss: 0.1625
# Epoch 128/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7966 - loss: 0.1145 - val_accuracy: 0.7091 - val_loss: 0.1625
# Epoch 129/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7960 - loss: 0.1154 - val_accuracy: 0.7015 - val_loss: 0.1634
# Epoch 130/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8004 - loss: 0.1124 - val_accuracy: 0.7072 - val_loss: 0.1631
# Epoch 131/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8087 - loss: 0.1109 - val_accuracy: 0.7110 - val_loss: 0.1634
# Epoch 132/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8046 - loss: 0.1104 - val_accuracy: 0.7091 - val_loss: 0.1640
# Epoch 133/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8036 - loss: 0.1101 - val_accuracy: 0.7148 - val_loss: 0.1654
# Epoch 134/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8074 - loss: 0.1098 - val_accuracy: 0.7091 - val_loss: 0.1651
# Epoch 135/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8078 - loss: 0.1084 - val_accuracy: 0.7072 - val_loss: 0.1656
# Epoch 136/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8164 - loss: 0.1073 - val_accuracy: 0.7015 - val_loss: 0.1656
# Epoch 137/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8100 - loss: 0.1062 - val_accuracy: 0.7053 - val_loss: 0.1663
# Epoch 138/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8113 - loss: 0.1069 - val_accuracy: 0.7072 - val_loss: 0.1655
# Epoch 139/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8139 - loss: 0.1045 - val_accuracy: 0.7034 - val_loss: 0.1657
# Epoch 140/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8190 - loss: 0.1046 - val_accuracy: 0.7034 - val_loss: 0.1677
# Epoch 141/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8172 - loss: 0.1015 - val_accuracy: 0.7034 - val_loss: 0.1678
# Epoch 142/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8202 - loss: 0.1024 - val_accuracy: 0.6996 - val_loss: 0.1674
# Epoch 143/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8262 - loss: 0.1009 - val_accuracy: 0.6996 - val_loss: 0.1674
# Epoch 144/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8289 - loss: 0.1013 - val_accuracy: 0.6958 - val_loss: 0.1685
# Epoch 145/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8258 - loss: 0.1009 - val_accuracy: 0.6939 - val_loss: 0.1692
# Epoch 146/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8362 - loss: 0.0981 - val_accuracy: 0.6977 - val_loss: 0.1699
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Epoch 1/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.0487 - loss: 0.6922 - val_accuracy: 0.0286 - val_loss: 0.6751
# Epoch 2/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.0248 - loss: 0.6677 - val_accuracy: 0.0248 - val_loss: 0.6420
# Epoch 3/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0233 - loss: 0.6334 - val_accuracy: 0.0248 - val_loss: 0.6022
# Epoch 4/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0251 - loss: 0.5919 - val_accuracy: 0.0248 - val_loss: 0.5513
# Epoch 5/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0248 - loss: 0.5374 - val_accuracy: 0.0248 - val_loss: 0.4859
# Epoch 6/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0236 - loss: 0.4723 - val_accuracy: 0.0248 - val_loss: 0.4206
# Epoch 7/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0272 - loss: 0.4083 - val_accuracy: 0.3276 - val_loss: 0.3618
# Epoch 8/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2992 - loss: 0.3544 - val_accuracy: 0.3295 - val_loss: 0.3248
# Epoch 9/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3227 - loss: 0.3242 - val_accuracy: 0.3295 - val_loss: 0.3104
# Epoch 10/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3347 - loss: 0.3135 - val_accuracy: 0.3295 - val_loss: 0.3054
# Epoch 11/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3430 - loss: 0.3082 - val_accuracy: 0.3295 - val_loss: 0.3018
# Epoch 12/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3492 - loss: 0.3050 - val_accuracy: 0.4552 - val_loss: 0.2969
# Epoch 13/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4219 - loss: 0.3004 - val_accuracy: 0.4590 - val_loss: 0.2908
# Epoch 14/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4527 - loss: 0.2918 - val_accuracy: 0.4629 - val_loss: 0.2838
# Epoch 15/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4440 - loss: 0.2882 - val_accuracy: 0.4629 - val_loss: 0.2776
# Epoch 16/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4427 - loss: 0.2849 - val_accuracy: 0.4648 - val_loss: 0.2727
# Epoch 17/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4486 - loss: 0.2799 - val_accuracy: 0.4667 - val_loss: 0.2688
# Epoch 18/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4461 - loss: 0.2754 - val_accuracy: 0.4667 - val_loss: 0.2655
# Epoch 19/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4497 - loss: 0.2719 - val_accuracy: 0.4667 - val_loss: 0.2626
# Epoch 20/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4408 - loss: 0.2715 - val_accuracy: 0.4667 - val_loss: 0.2598
# Epoch 21/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4439 - loss: 0.2687 - val_accuracy: 0.4686 - val_loss: 0.2566
# Epoch 22/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4672 - loss: 0.2644 - val_accuracy: 0.5143 - val_loss: 0.2532
# Epoch 23/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4869 - loss: 0.2587 - val_accuracy: 0.5162 - val_loss: 0.2495
# Epoch 24/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5009 - loss: 0.2555 - val_accuracy: 0.5143 - val_loss: 0.2463
# Epoch 25/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5072 - loss: 0.2511 - val_accuracy: 0.5143 - val_loss: 0.2431
# Epoch 26/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5082 - loss: 0.2477 - val_accuracy: 0.5200 - val_loss: 0.2401
# Epoch 27/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5049 - loss: 0.2443 - val_accuracy: 0.5219 - val_loss: 0.2372
# Epoch 28/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5206 - loss: 0.2404 - val_accuracy: 0.5352 - val_loss: 0.2344
# Epoch 29/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5350 - loss: 0.2371 - val_accuracy: 0.5371 - val_loss: 0.2320
# Epoch 30/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5370 - loss: 0.2346 - val_accuracy: 0.5410 - val_loss: 0.2298
# Epoch 31/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5365 - loss: 0.2347 - val_accuracy: 0.5467 - val_loss: 0.2276
# Epoch 32/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5362 - loss: 0.2324 - val_accuracy: 0.5543 - val_loss: 0.2255
# Epoch 33/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5526 - loss: 0.2286 - val_accuracy: 0.5752 - val_loss: 0.2234
# Epoch 34/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5567 - loss: 0.2259 - val_accuracy: 0.5733 - val_loss: 0.2215
# Epoch 35/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5597 - loss: 0.2251 - val_accuracy: 0.5810 - val_loss: 0.2196
# Epoch 36/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5666 - loss: 0.2208 - val_accuracy: 0.5733 - val_loss: 0.2179
# Epoch 37/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5737 - loss: 0.2186 - val_accuracy: 0.5771 - val_loss: 0.2162
# Epoch 38/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5744 - loss: 0.2171 - val_accuracy: 0.5695 - val_loss: 0.2142
# Epoch 39/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5725 - loss: 0.2156 - val_accuracy: 0.5752 - val_loss: 0.2123
# Epoch 40/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5763 - loss: 0.2146 - val_accuracy: 0.5695 - val_loss: 0.2103
# Epoch 41/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5809 - loss: 0.2117 - val_accuracy: 0.5752 - val_loss: 0.2087
# Epoch 42/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5876 - loss: 0.2096 - val_accuracy: 0.5771 - val_loss: 0.2072
# Epoch 43/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5876 - loss: 0.2100 - val_accuracy: 0.5886 - val_loss: 0.2058
# Epoch 44/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5946 - loss: 0.2052 - val_accuracy: 0.5905 - val_loss: 0.2044
# Epoch 45/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6113 - loss: 0.2021 - val_accuracy: 0.5981 - val_loss: 0.2030
# Epoch 46/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6059 - loss: 0.2007 - val_accuracy: 0.6114 - val_loss: 0.2017
# Epoch 47/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6053 - loss: 0.2032 - val_accuracy: 0.6019 - val_loss: 0.2006
# Epoch 48/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6086 - loss: 0.1998 - val_accuracy: 0.6114 - val_loss: 0.1996
# Epoch 49/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6286 - loss: 0.1966 - val_accuracy: 0.6343 - val_loss: 0.1984
# Epoch 50/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6179 - loss: 0.1961 - val_accuracy: 0.6324 - val_loss: 0.1972
# Epoch 51/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6191 - loss: 0.1983 - val_accuracy: 0.6419 - val_loss: 0.1961
# Epoch 52/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6361 - loss: 0.1951 - val_accuracy: 0.6476 - val_loss: 0.1950
# Epoch 53/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6281 - loss: 0.1927 - val_accuracy: 0.6438 - val_loss: 0.1940
# Epoch 54/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6425 - loss: 0.1926 - val_accuracy: 0.6457 - val_loss: 0.1928
# Epoch 55/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6379 - loss: 0.1904 - val_accuracy: 0.6457 - val_loss: 0.1919
# Epoch 56/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6452 - loss: 0.1886 - val_accuracy: 0.6476 - val_loss: 0.1904
# Epoch 57/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6530 - loss: 0.1857 - val_accuracy: 0.6533 - val_loss: 0.1891
# Epoch 58/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6501 - loss: 0.1851 - val_accuracy: 0.6533 - val_loss: 0.1877
# Epoch 59/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6449 - loss: 0.1852 - val_accuracy: 0.6495 - val_loss: 0.1865
# Epoch 60/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6609 - loss: 0.1807 - val_accuracy: 0.6533 - val_loss: 0.1853
# Epoch 61/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6674 - loss: 0.1785 - val_accuracy: 0.6571 - val_loss: 0.1840
# Epoch 62/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6664 - loss: 0.1766 - val_accuracy: 0.6552 - val_loss: 0.1833
# Epoch 63/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6662 - loss: 0.1777 - val_accuracy: 0.6571 - val_loss: 0.1821
# Epoch 64/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6672 - loss: 0.1768 - val_accuracy: 0.6629 - val_loss: 0.1807
# Epoch 65/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6710 - loss: 0.1757 - val_accuracy: 0.6686 - val_loss: 0.1799
# Epoch 66/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6793 - loss: 0.1730 - val_accuracy: 0.6629 - val_loss: 0.1788
# Epoch 67/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6767 - loss: 0.1725 - val_accuracy: 0.6648 - val_loss: 0.1780
# Epoch 68/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6658 - loss: 0.1734 - val_accuracy: 0.6686 - val_loss: 0.1770
# Epoch 69/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6776 - loss: 0.1683 - val_accuracy: 0.6667 - val_loss: 0.1761
# Epoch 70/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6752 - loss: 0.1689 - val_accuracy: 0.6686 - val_loss: 0.1754
# Epoch 71/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6716 - loss: 0.1659 - val_accuracy: 0.6743 - val_loss: 0.1746
# Epoch 72/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6833 - loss: 0.1653 - val_accuracy: 0.6705 - val_loss: 0.1743
# Epoch 73/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6868 - loss: 0.1644 - val_accuracy: 0.6819 - val_loss: 0.1726
# Epoch 74/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6893 - loss: 0.1621 - val_accuracy: 0.6819 - val_loss: 0.1723
# Epoch 75/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6931 - loss: 0.1606 - val_accuracy: 0.6781 - val_loss: 0.1717
# Epoch 76/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6972 - loss: 0.1599 - val_accuracy: 0.6800 - val_loss: 0.1714
# Epoch 77/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7066 - loss: 0.1578 - val_accuracy: 0.6781 - val_loss: 0.1707
# Epoch 78/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7020 - loss: 0.1564 - val_accuracy: 0.6800 - val_loss: 0.1696
# Epoch 79/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6932 - loss: 0.1577 - val_accuracy: 0.6800 - val_loss: 0.1697
# Epoch 80/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7067 - loss: 0.1541 - val_accuracy: 0.6800 - val_loss: 0.1685
# Epoch 81/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7076 - loss: 0.1535 - val_accuracy: 0.6800 - val_loss: 0.1687
# Epoch 82/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7127 - loss: 0.1497 - val_accuracy: 0.6800 - val_loss: 0.1684
# Epoch 83/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7195 - loss: 0.1500 - val_accuracy: 0.6743 - val_loss: 0.1677
# Epoch 84/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7254 - loss: 0.1480 - val_accuracy: 0.6781 - val_loss: 0.1671
# Epoch 85/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7248 - loss: 0.1463 - val_accuracy: 0.6781 - val_loss: 0.1664
# Epoch 86/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7239 - loss: 0.1439 - val_accuracy: 0.6762 - val_loss: 0.1659
# Epoch 87/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7187 - loss: 0.1478 - val_accuracy: 0.6819 - val_loss: 0.1659
# Epoch 88/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7243 - loss: 0.1439 - val_accuracy: 0.6819 - val_loss: 0.1660
# Epoch 89/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7356 - loss: 0.1415 - val_accuracy: 0.6819 - val_loss: 0.1649
# Epoch 90/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7290 - loss: 0.1427 - val_accuracy: 0.6857 - val_loss: 0.1652
# Epoch 91/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7305 - loss: 0.1434 - val_accuracy: 0.6876 - val_loss: 0.1653
# Epoch 92/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7373 - loss: 0.1422 - val_accuracy: 0.6895 - val_loss: 0.1644
# Epoch 93/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7323 - loss: 0.1403 - val_accuracy: 0.6895 - val_loss: 0.1642
# Epoch 94/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7398 - loss: 0.1377 - val_accuracy: 0.6838 - val_loss: 0.1640
# Epoch 95/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7395 - loss: 0.1376 - val_accuracy: 0.6838 - val_loss: 0.1645
# Epoch 96/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7410 - loss: 0.1377 - val_accuracy: 0.6914 - val_loss: 0.1642
# Epoch 97/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7529 - loss: 0.1327 - val_accuracy: 0.6933 - val_loss: 0.1637
# Epoch 98/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7497 - loss: 0.1342 - val_accuracy: 0.6876 - val_loss: 0.1639
# Epoch 99/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7544 - loss: 0.1314 - val_accuracy: 0.6914 - val_loss: 0.1641
# Epoch 100/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7595 - loss: 0.1311 - val_accuracy: 0.6895 - val_loss: 0.1635
# Epoch 101/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7570 - loss: 0.1294 - val_accuracy: 0.6857 - val_loss: 0.1645
# Epoch 102/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7568 - loss: 0.1323 - val_accuracy: 0.6971 - val_loss: 0.1638
# Epoch 103/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7583 - loss: 0.1314 - val_accuracy: 0.6990 - val_loss: 0.1637
# Epoch 104/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7696 - loss: 0.1268 - val_accuracy: 0.6952 - val_loss: 0.1644
# Epoch 105/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7715 - loss: 0.1248 - val_accuracy: 0.6876 - val_loss: 0.1638
# Epoch 106/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7724 - loss: 0.1248 - val_accuracy: 0.6952 - val_loss: 0.1641
# Epoch 107/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7685 - loss: 0.1235 - val_accuracy: 0.6933 - val_loss: 0.1642
# Epoch 108/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7865 - loss: 0.1212 - val_accuracy: 0.6895 - val_loss: 0.1645
# Epoch 109/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7822 - loss: 0.1231 - val_accuracy: 0.6990 - val_loss: 0.1640
# Epoch 110/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7818 - loss: 0.1204 - val_accuracy: 0.6971 - val_loss: 0.1650
# Epoch 111/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7834 - loss: 0.1186 - val_accuracy: 0.7048 - val_loss: 0.1646
# Epoch 112/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7834 - loss: 0.1199 - val_accuracy: 0.7048 - val_loss: 0.1648
# Epoch 113/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7868 - loss: 0.1174 - val_accuracy: 0.7048 - val_loss: 0.1652
# Epoch 114/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7861 - loss: 0.1178 - val_accuracy: 0.6990 - val_loss: 0.1648
# Epoch 115/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7965 - loss: 0.1167 - val_accuracy: 0.7029 - val_loss: 0.1657
# Epoch 116/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7945 - loss: 0.1151 - val_accuracy: 0.7048 - val_loss: 0.1662
# Epoch 117/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7903 - loss: 0.1151 - val_accuracy: 0.7067 - val_loss: 0.1655
# Epoch 118/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7946 - loss: 0.1170 - val_accuracy: 0.7086 - val_loss: 0.1672
# Epoch 119/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8083 - loss: 0.1111 - val_accuracy: 0.6952 - val_loss: 0.1678
# Epoch 120/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8003 - loss: 0.1127 - val_accuracy: 0.7048 - val_loss: 0.1677
# Epoch 121/500
# ...
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4740 - loss: 0.2591 - val_accuracy: 0.4686 - val_loss: 0.2557
# Epoch 30/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4958 - loss: 0.2538 - val_accuracy: 0.5181 - val_loss: 0.2542
# Epoch 31/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5026 - loss: 0.2520 - val_accuracy: 0.5124 - val_loss: 0.2521
# Epoch 32/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5084 - loss: 0.2495 - val_accuracy: 0.5162 - val_loss: 0.2500
# Epoch 33/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5095 - loss: 0.2492 - val_accuracy: 0.5295 - val_loss: 0.2477
# Epoch 34/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5148 - loss: 0.2480 - val_accuracy: 0.5371 - val_loss: 0.2456
# Epoch 35/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5255 - loss: 0.2439 - val_accuracy: 0.5314 - val_loss: 0.2431
# Epoch 36/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5263 - loss: 0.2422 - val_accuracy: 0.5314 - val_loss: 0.2408
# Epoch 37/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5179 - loss: 0.2412 - val_accuracy: 0.5295 - val_loss: 0.2385
# Epoch 38/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5304 - loss: 0.2384 - val_accuracy: 0.5295 - val_loss: 0.2360
# Epoch 39/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5261 - loss: 0.2360 - val_accuracy: 0.5295 - val_loss: 0.2335
# Epoch 40/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5263 - loss: 0.2327 - val_accuracy: 0.5314 - val_loss: 0.2309
# Epoch 41/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5319 - loss: 0.2290 - val_accuracy: 0.5333 - val_loss: 0.2282
# Epoch 42/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5389 - loss: 0.2249 - val_accuracy: 0.5371 - val_loss: 0.2261
# Epoch 43/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5338 - loss: 0.2279 - val_accuracy: 0.5314 - val_loss: 0.2242
# Epoch 44/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5456 - loss: 0.2223 - val_accuracy: 0.5410 - val_loss: 0.2223
# Epoch 45/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5518 - loss: 0.2212 - val_accuracy: 0.5410 - val_loss: 0.2206
# Epoch 46/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5526 - loss: 0.2214 - val_accuracy: 0.5410 - val_loss: 0.2193
# Epoch 47/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5541 - loss: 0.2167 - val_accuracy: 0.5429 - val_loss: 0.2177
# Epoch 48/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5558 - loss: 0.2166 - val_accuracy: 0.5467 - val_loss: 0.2158
# Epoch 49/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5670 - loss: 0.2146 - val_accuracy: 0.5505 - val_loss: 0.2144
# Epoch 50/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5721 - loss: 0.2150 - val_accuracy: 0.5848 - val_loss: 0.2126
# Epoch 51/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5833 - loss: 0.2135 - val_accuracy: 0.6076 - val_loss: 0.2111
# Epoch 52/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5970 - loss: 0.2119 - val_accuracy: 0.6133 - val_loss: 0.2096
# Epoch 53/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5961 - loss: 0.2113 - val_accuracy: 0.6076 - val_loss: 0.2076
# Epoch 54/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6178 - loss: 0.2062 - val_accuracy: 0.6114 - val_loss: 0.2059
# Epoch 55/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6234 - loss: 0.2034 - val_accuracy: 0.6190 - val_loss: 0.2041
# Epoch 56/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6197 - loss: 0.2039 - val_accuracy: 0.6171 - val_loss: 0.2022
# Epoch 57/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6288 - loss: 0.1986 - val_accuracy: 0.6248 - val_loss: 0.2004
# Epoch 58/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6410 - loss: 0.1981 - val_accuracy: 0.6267 - val_loss: 0.1987
# Epoch 59/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6370 - loss: 0.1972 - val_accuracy: 0.6324 - val_loss: 0.1967
# Epoch 60/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6336 - loss: 0.1963 - val_accuracy: 0.6343 - val_loss: 0.1948
# Epoch 61/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6463 - loss: 0.1940 - val_accuracy: 0.6533 - val_loss: 0.1933
# Epoch 62/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6551 - loss: 0.1895 - val_accuracy: 0.6571 - val_loss: 0.1914
# Epoch 63/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6394 - loss: 0.1906 - val_accuracy: 0.6610 - val_loss: 0.1899
# Epoch 64/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6660 - loss: 0.1858 - val_accuracy: 0.6648 - val_loss: 0.1882
# Epoch 65/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6600 - loss: 0.1878 - val_accuracy: 0.6667 - val_loss: 0.1863
# Epoch 66/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6694 - loss: 0.1832 - val_accuracy: 0.6705 - val_loss: 0.1855
# Epoch 67/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6715 - loss: 0.1806 - val_accuracy: 0.6667 - val_loss: 0.1841
# Epoch 68/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6701 - loss: 0.1785 - val_accuracy: 0.6705 - val_loss: 0.1827
# Epoch 69/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6750 - loss: 0.1786 - val_accuracy: 0.6743 - val_loss: 0.1815
# Epoch 70/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6803 - loss: 0.1760 - val_accuracy: 0.6743 - val_loss: 0.1814
# Epoch 71/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6806 - loss: 0.1739 - val_accuracy: 0.6743 - val_loss: 0.1802
# Epoch 72/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6876 - loss: 0.1739 - val_accuracy: 0.6705 - val_loss: 0.1788
# Epoch 73/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6812 - loss: 0.1720 - val_accuracy: 0.6743 - val_loss: 0.1779
# Epoch 74/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6768 - loss: 0.1719 - val_accuracy: 0.6705 - val_loss: 0.1775
# Epoch 75/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6870 - loss: 0.1681 - val_accuracy: 0.6667 - val_loss: 0.1768
# Epoch 76/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6902 - loss: 0.1699 - val_accuracy: 0.6686 - val_loss: 0.1753
# Epoch 77/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6914 - loss: 0.1649 - val_accuracy: 0.6705 - val_loss: 0.1740
# Epoch 78/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6924 - loss: 0.1663 - val_accuracy: 0.6724 - val_loss: 0.1744
# Epoch 79/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6996 - loss: 0.1628 - val_accuracy: 0.6629 - val_loss: 0.1736
# Epoch 80/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7034 - loss: 0.1615 - val_accuracy: 0.6667 - val_loss: 0.1731
# Epoch 81/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7044 - loss: 0.1585 - val_accuracy: 0.6705 - val_loss: 0.1714
# Epoch 82/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7023 - loss: 0.1611 - val_accuracy: 0.6743 - val_loss: 0.1715
# Epoch 83/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7060 - loss: 0.1576 - val_accuracy: 0.6705 - val_loss: 0.1708
# Epoch 84/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7100 - loss: 0.1564 - val_accuracy: 0.6781 - val_loss: 0.1700
# Epoch 85/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7169 - loss: 0.1531 - val_accuracy: 0.6743 - val_loss: 0.1691
# Epoch 86/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7133 - loss: 0.1541 - val_accuracy: 0.6705 - val_loss: 0.1685
# Epoch 87/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7162 - loss: 0.1520 - val_accuracy: 0.6762 - val_loss: 0.1685
# Epoch 88/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7181 - loss: 0.1502 - val_accuracy: 0.6743 - val_loss: 0.1683
# Epoch 89/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7264 - loss: 0.1462 - val_accuracy: 0.6838 - val_loss: 0.1677
# Epoch 90/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7306 - loss: 0.1468 - val_accuracy: 0.6781 - val_loss: 0.1673
# Epoch 91/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7307 - loss: 0.1450 - val_accuracy: 0.6762 - val_loss: 0.1678
# Epoch 92/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7233 - loss: 0.1479 - val_accuracy: 0.6686 - val_loss: 0.1677
# Epoch 93/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7299 - loss: 0.1439 - val_accuracy: 0.6743 - val_loss: 0.1675
# Epoch 94/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7330 - loss: 0.1426 - val_accuracy: 0.6781 - val_loss: 0.1679
# Epoch 95/500
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7340 - loss: 0.1428 - val_accuracy: 0.6781 - val_loss: 0.1670
# Epoch 96/500
#  1/10 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7120 - loss: 0.1516
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 3
#       1 # run cross-validation
#       2 keras_cv = KerasCrossValidation(X=X, y=y_true, keras_model=model, save_filepath='./logs/fit-01')
# ----> 3 y_pred, y_test, history = keras_cv(n_splits=7, batch_size=500, min_epochs=5, patience=30, max_epochs=500, training_repeat=2)
#
# File c:\Users\huang\Documents\GitHub\DeepTCR-2\utils.py:61, in KerasCrossValidation.__call__(self, n_splits, batch_size, min_epochs, patience, max_epochs, training_repeat)
#      56 callbacks = [
#      57     keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=patience, mode='min', restore_best_weights=True, start_from_epoch=min_epochs),
#      58 ]
#      60 # running training
# ---> 61 self.keras_model.fit(
#      62     train_tfds, # training data - used to update calculate model parameter updates
#      63     validation_data=valid_tfds, # used to assess stopping criteria for training
#      64     class_weight=dict(zip(np.arange(self.keras_model.output_shape[-1]), np.ones(self.keras_model.output_shape[-1]))), # balanced training
#      65     callbacks=callbacks, # callback such are early stopping based on validation data performance
#      66     epochs=max_epochs
#      67 )
#      69 # save model
#      70 history.append(self.keras_model.history.history)
#
# File c:\Users\huang\miniconda3\envs\gpu-ml-base\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\huang\miniconda3\envs\gpu-ml-base\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:320, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     318 for step, iterator in epoch_iterator.enumerate_epoch():
#     319     callbacks.on_train_batch_begin(step)
# --> 320     logs = self.train_function(iterator)
#     321     callbacks.on_train_batch_end(step, logs)
#     322     if self.stop_training:
#
# File c:\Users\huang\miniconda3\envs\gpu-ml-base\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\huang\miniconda3\envs\gpu-ml-base\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\huang\miniconda3\envs\gpu-ml-base\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\huang\miniconda3\envs\gpu-ml-base\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\huang\miniconda3\envs\gpu-ml-base\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\huang\miniconda3\envs\gpu-ml-base\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\huang\miniconda3\envs\gpu-ml-base\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\huang\miniconda3\envs\gpu-ml-base\Lib\site-packages\tensorflow\python\eager\context.py:1683, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1681 cancellation_context = cancellation.context()
#    1682 if cancellation_context is None:
# -> 1683   outputs = execute.execute(
#    1684       name.decode("utf-8"),
#    1685       num_outputs=num_outputs,
#    1686       inputs=tensor_inputs,
#    1687       attrs=attrs,
#    1688       ctx=self,
#    1689   )
#    1690 else:
#    1691   outputs = execute.execute_with_cancellation(
#    1692       name.decode("utf-8"),
#    1693       num_outputs=num_outputs,
#    (...)   1697       cancellation_manager=cancellation_context,
#    1698   )
#
# File c:\Users\huang\miniconda3\envs\gpu-ml-base\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
from utils import plot_classification_performance

# %%
f, axs = plt.subplots(8, 3, figsize=(12, 3 * 8))
for i in range(7):
    plot_classification_performance(
        axs[i, :],
        y_true[y_test[:, i]],
        y_pred[y_test[:, i], :],
        history[i]
    )
plot_classification_performance(
    axs[-1, :],
    y_true,
    y_pred
)
